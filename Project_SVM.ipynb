# %%
import pandas as pd
#read the data
Data = pd.read_csv('Output100.csv')
labelled = pd.read_csv('Labels100.csv')

#remove the first column from dataset1
Data.drop(['Unnamed: 0'], axis=1)

print(Data)


#classify data into dependent and indepedent variables
x = Data.iloc[:, :]
y = labelled.iloc[:, :]

#classify the data into training and testing
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

#now predict using svm classifier
from sklearn.svm import SVC
SVC_classifier = SVC()

#fit the model
SVC_classifier.fit(x_train, y_train)
pred = SVC_classifier.predict(x_test)

#lets now find the accuracy
from sklearn.metrics import accuracy_score
print("The accuracy is ", accuracy_score(y_test, pred))

#confusion matrix
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, pred))


#classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, pred))
# Out:
#      Unnamed: 0    Mean_R     RMS_R  Median_R  Variance_R     Std_R  \
# 0             0  0.499272  0.530498  0.521569    0.032156  0.179320
# 1             1  0.450862  0.493341  0.482412    0.040108  0.200270
# 2             2  0.490711  0.529387  0.552941    0.039453  0.198628
# 3             3  0.456121  0.516174  0.470588    0.058389  0.241638
# 4             4  0.666764  0.680847  0.701961    0.018978  0.137762
# ..          ...       ...       ...       ...         ...       ...
# 995         995  0.418237  0.430380  0.419608    0.010305  0.101515
# 996         996  0.590572  0.599581  0.580311    0.010722  0.103548
# 997         997  0.483599  0.522445  0.541176    0.039081  0.197689
# 998         998  0.557272  0.568569  0.527273    0.012719  0.112779
# 999         999  0.487018  0.521116  0.521569    0.034375  0.185405
#
#      Skewness_R  Kurtosis_R  Contrast_R    Entropy_R  ...     Std_B  \
# 0     -0.484763   -0.322512    7.417660   956.450061  ...  0.203257
# 1     -0.025098   -1.355651    7.058108   360.687224  ...  0.185545
# 2     -0.561403   -0.793254    7.469795   604.175751  ...  0.210727
# 3     -0.111255   -1.422784    7.603757   787.841958  ...  0.227122
# 4     -0.641985   -0.495426    6.970347   147.902145  ...  0.215415
# ..          ...         ...         ...          ...  ...       ...
# 995   -0.085111   -0.159028    6.728981   449.245864  ...  0.103370
# 996    0.225162    0.363138    6.343208   290.771124  ...  0.157947
# 997   -0.557668   -0.767418    7.444655   919.157966  ...  0.192531
# 998    1.226141    0.888180    6.124820   151.262377  ...  0.113174
# 999   -0.577153   -0.400621    7.435183  1080.239277  ...  0.213786
#
#      Skewness_B  Kurtosis_B  Contrast_B    Entropy_B  Energy_B  Homogeneity_B  \
# 0     -0.407196   -0.696663    7.517717   946.369715  0.011527       0.075315
# 1      0.163490   -1.162955    7.040838   359.933441  0.015140       0.094008
# 2     -0.467573   -1.005314    7.497503   601.133165  0.010352       0.060593
# 3     -0.061711   -1.496490    7.352011   770.710692  0.018813       0.113546
# 4     -0.336407   -1.415606    7.252476   151.646691  0.017100       0.140658
# ..          ...         ...         ...          ...       ...            ...
# 995    0.101753   -0.313152    6.736928   448.325015  0.013697       0.067834
# 996    0.026264   -1.087109    6.773158   288.201287  0.020749       0.133481
# 997   -0.477387   -0.855702    7.341992   909.278309  0.012369       0.075149
# 998   -1.349279    0.963541    6.077422   140.346615  0.041242       0.235752
# 999   -0.528862   -0.846365    7.469885  1065.680668  0.012757       0.069051
#
#      Correlation_B     IDM_B  Smoothness_B
# 0         0.824158  0.001056      0.014440
# 1         0.919477  0.002771      0.005492
# 2         0.896033  0.001661      0.009172
# 3         0.885132  0.001296      0.011759
# 4         0.974893  0.006552      0.002314
# ..             ...       ...           ...
# 995       0.677463  0.002226      0.006841
# 996       0.911138  0.003458      0.004397
# 997       0.811647  0.001099      0.013874
# 998       0.916007  0.007077      0.002142
# 999       0.820889  0.000937      0.016260
#
# [1000 rows x 43 columns]
# The accuracy is  0.905
# [[  0  19]
#  [  0 181]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        19
#            1       0.91      1.00      0.95       181
#
#     accuracy                           0.91       200
#    macro avg       0.45      0.50      0.48       200
# weighted avg       0.82      0.91      0.86       200
# /home/uca/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/uca/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/uca/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/uca/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
