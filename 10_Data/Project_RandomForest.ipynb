# %%
#import required libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

#read the datasets using pandas\
dataset = pd.read_csv('10_Output30.csv')

#remove column 1 as it is not necessary
dataset1 = dataset.drop(['Unnamed: 0'], axis=1)

#read second dataset
dataset2 = pd.read_csv('10_diseases.csv')
dataset1.head()
# Out:
#      Mean_R    RMS_R  Median_R  Variance_R      Std_R  Skewness_R  Kurtosis_R  \
# 0  3.033508  2.15963         0   236.07511  15.364736    5.146547   25.765351
# 1  3.033508  2.15963         0   236.07511  15.364736    5.146547   25.765351
# 2  3.033508  2.15963         0   236.07511  15.364736    5.146547   25.765351
# 3  3.033508  2.15963         0   236.07511  15.364736    5.146547   25.765351
# 4  3.033508  2.15963         0   236.07511  15.364736    5.146547   25.765351
#
#    Contrast_R  Entropy_R  Energy_R  ...      Std_B  Skewness_B  Kurtosis_B  \
# 0    0.493839  16.810754  0.958043  ...  30.230334    4.994391   23.834725
# 1    0.493839  16.810754  0.958043  ...  30.230334    4.994391   23.834725
# 2    0.493839  16.810754  0.958043  ...  30.230334    4.994391   23.834725
# 3    0.493839  16.810754  0.958043  ...  30.230334    4.994391   23.834725
# 4    0.493839  16.810754  0.958043  ...  30.230334    4.994391   23.834725
#
# ...

# %%
#classifyy daata into de[pedent and independent
x = dataset1.iloc[:, :]
y = dataset2.iloc[:, :]


#now split data into training and testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

#now import random classifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

#fit data
rf.fit(x_train, y_train)

#predict data
pred = rf.predict(x_test)

#accuracy
print("The accuracy is ", accuracy_score(pred, y_test)*100)
# Out:
# The accuracy is  1.6666666666666667
# /tmp/ipykernel_11120/3576905011.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train, y_train)
