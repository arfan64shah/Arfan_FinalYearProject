# %%
#import the required libraries
import skimage.feature as skf
import openpyxl
import numpy as np
import math
import cv2
from PIL import Image
from numpy import asarray
from scipy.stats import skew, kurtosis
import skimage.feature
import xlsxwriter
import os


#creates general file for features of all the three channels
outWorkbook = xlsxwriter.Workbook("Output30.xlsx")
outSheet = outWorkbook.add_worksheet()

#Writes headers for general file 
outSheet.write("A1", "Mean_R")
outSheet.write("B1", "RMS_R")
outSheet.write("C1", "Median_R")
outSheet.write("D1", "Variance_R")
outSheet.write("E1", "Std_R")
outSheet.write("F1", "Skewness_R")
outSheet.write("G1", "Kurtosis_R")
outSheet.write("H1", "Contrast_R")
outSheet.write("I1", "Entropy_R")
outSheet.write("J1", "Energy_R")
outSheet.write("K1", "Homogeneity_R")
outSheet.write("L1", "Correlation_R")
outSheet.write("M1", "IDM_R")
outSheet.write("N1", "Smoothness_R")
outSheet.write("O1", "Mean_G")
outSheet.write("P1", "RMS_G")
outSheet.write("Q1", "Median_G")
outSheet.write("R1", "Variance_G")
outSheet.write("S1", "Std_G")
outSheet.write("T1", "Skewness_G")
outSheet.write("U1", "Kurtosis_G")
outSheet.write("V1", "Contrast_G")
outSheet.write("W1", "Entropy_G")
outSheet.write("X1", "Energy_G")
outSheet.write("Y1", "Homogeneity_G")
outSheet.write("Z1", "Correlation_G")
outSheet.write("AA1", "IDM_G")
outSheet.write("AB1", "Smoothness_G")
outSheet.write("AC1", "Mean_B")
outSheet.write("AD1", "RMS_B")
outSheet.write("AE1", "Median_B")
outSheet.write("AF1", "Variance_B")
outSheet.write("AG1", "Std_B")
outSheet.write("AH1", "Skewness_B")
outSheet.write("AI1", "Kurtosis_B")
outSheet.write("AJ1", "Contrast_B")
outSheet.write("AK1", "Entropy_B")
outSheet.write("AL1", "Energy_B")
outSheet.write("AM1", "Homogeneity_B")
outSheet.write("AN1", "Correlation_B")
outSheet.write("AO1", "IDM_B")
outSheet.write("AP1", "Smoothness_B")
outWorkbook.close()

# %%
#creates a file for red channel
outWorkbookR = xlsxwriter.Workbook("RedChannel30.xlsx")
outSheetR = outWorkbookR.add_worksheet()

#writes headers for red file
outSheetR.write("A1", "Mean_R")
outSheetR.write("B1", "RMS_R")
outSheetR.write("C1", "Median_R")
outSheetR.write("D1", "Variance_R")
outSheetR.write("E1", "Std_R")
outSheetR.write("F1", "Skewness_R")
outSheetR.write("G1", "Kurtosis_R")
outSheetR.write("H1", "Contrast_R")
outSheetR.write("I1", "Entropy_R")
outSheetR.write("J1", "Energy_R")
outSheetR.write("K1", "Homogeneity_R")
outSheetR.write("L1", "Correlation_R")
outSheetR.write("M1", "IDM_R")
outSheetR.write("N1", "Smoothness_R")
outWorkbookR.close()

# %%
#creates file for green channel
outWorkbookG = xlsxwriter.Workbook("GreenChannel30.xlsx")
outSheetG = outWorkbookG.add_worksheet()

#writes headers for green file
outSheetG.write("A1", "Mean_G")
outSheetG.write("B1", "RMS_G")
outSheetG.write("C1", "Median_G")
outSheetG.write("D1", "Variance_G")
outSheetG.write("E1", "Std_G")
outSheetG.write("F1", "Skewness_G")
outSheetG.write("G1", "Kurtosis_G")
outSheetG.write("H1", "Contrast_G")
outSheetG.write("I1", "Entropy_G")
outSheetG.write("J1", "Energy_G")
outSheetG.write("K1", "Homogeneity_G")
outSheetG.write("L1", "Correlation_G")
outSheetG.write("M1", "IDM_G")
outSheetG.write("N1", "Smoothness_G")
outWorkbookG.close()

# %%
#creates a file for blue channel
outWorkbookB = xlsxwriter.Workbook("BlueChannel30.xlsx")
outSheetB = outWorkbookB.add_worksheet()

#writes headers for blue file
outSheetB.write("A1", "Mean_B")
outSheetB.write("B1", "RMS_B")
outSheetB.write("C1", "Median_B")
outSheetB.write("D1", "Variance_B")
outSheetB.write("E1", "Std_B")
outSheetB.write("F1", "Skewness_B")
outSheetB.write("G1", "Kurtosis_B")
outSheetB.write("H1", "Contrast_B")
outSheetB.write("I1", "Entropy_B")
outSheetB.write("J1", "Energy_B")
outSheetB.write("K1", "Homogeneity_B")
outSheetB.write("L1", "Correlation_B")
outSheetB.write("M1", "IDM_B")
outSheetB.write("N1", "Smoothness_B")
outWorkbookB.close()

# %%
#import required libaray to read and make a list of all the needy images
import glob

#declare an empty list
Image_list = []

#using for loop to append to the list declared above
for filename in glob.glob('/home/uca/Desktop/Undergrad/Arfan_FinalYearProject/10_Data/data30/*.*'):
    im = Image.open(filename)
    
    #append each image to the list declared above
    Image_list.append(im)
    
#prints number of images used
print(len(Image_list))
# Out:
# 300

# %%
#uses for loop to read each image and array of each image
for i in range(0, len(Image_list)):
    Image = Image_list[i]
    im = asarray(Image)
    
    #Apply image enhancement 
#     #apply image inverse
#     # Invert the colors
#     image = 255 - image

#     # Apply contrast stretching for image enhancement
#     min_val = np.min(image)
#     max_val = np.max(image)
#     image = (image - min_val) / (max_val - min_val)

    #apply mean filter
    #convert to HSV
    image = cv2.cvtColor(im, cv2.COLOR_BGR2HSV)
    image = cv2.blur(image, (5, 5))

    
    
    
    #Here i am extracting the single channel like red, green, and blue from the whole image array
    R = image[:, :, 0]
    G = image[:, :, 1]
    B = image[:, :, 2]


    #selecting features from Red Channel
    print("Calculating Statistical features for Red Channel: ")
    
    #calculates mean
    Mean_R = np.mean(R);
    print(Mean_R)
    
    #calculating root mean square
    RMS_R = np.sqrt(np.mean(R**2))
    print(RMS_R)
    
    #calculating median
    Median_R = np.median(R)
    print(Median_R)
    
    #calculating variance of the pixels
    Variance_R = np.var(R)
    print(Variance_R)
    
    #calculating standard deviation
    Std_R = math.sqrt(Variance_R)
    print(Std_R)
    
    #calculates skewness
    Skewness_R = skew(R.reshape(-1))
    print(Skewness_R)
    
    #calculates kurtosis
    Kurtosis_R = kurtosis(R.reshape(-1))
    print(Kurtosis_R)
    
    #calculates entropy
    Entropy_R = skimage.measure.shannon_entropy(R)
    print(Entropy_R)
    
    #returns an image array where lowest pixel value is 0 and highest 8 instead of 0 and 255
    R = skimage.img_as_ubyte(R)
    
    #calculates contrast
    g1 = skf.graycomatrix(R, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_R = skf.graycoprops(g1, 'contrast')[0][0]
    print(Contrast_R)
    
    #calculates energy
    Energy_R = skf.graycoprops(g1, 'energy')[0][0]
    print(Energy_R)
    
    #calculating homogeniety
    Homogeneity_R = skf.graycoprops(g1, 'homogeneity')[0][0]
    print(Homogeneity_R)
    
    #finding correlation
    Correlation_R = skf.graycoprops(g1, 'correlation')[0][0]
    print(Correlation_R)
    
    #glcm_R = skf.graycomatrix(R, distances=[1], angles=[0], levels=256, symmetric= False, normed=True)
    
    #calculate inverse difference moment (IDM)
    IDM_R = 1 / (1 + Contrast_R - Energy_R)
    print(IDM_R)
    
    #calculates smoothness
    diff_R = np.diff(R.astype(float))
    variance_R = np.var(diff_R)
    Smoothness_R = variance_R / (R.shape[0] * R.shape[1])
    print(Smoothness_R)
    

    #selecting features from Green Channel
    print("Calculating Statistical Features for Green Channel: ")
    
    #calculates mean
    Mean_G = np.mean(G);
    print(Mean_G)
    
    #calculates root mean square
    RMS_G = np.sqrt(np.mean(G**2))
    print(RMS_G)
    
    #calculates median
    Median_G = np.median(G)
    print(Median_G)
    
    #claculates variance
    Variance_G = np.var(G)
    print(Variance_G)
    
    #calculates standard deviation
    Std_G = math.sqrt(Variance_G)
    print(Std_G)
    
    #calculates skewness
    Skewness_G = skew(G.reshape(-1))
    print(Skewness_G)
    
    #calculates kurtosis
    Kurtosis_G = kurtosis(G.reshape(-1))
    print(Kurtosis_G)
    
    #calculates entropy
    Entropy_G = skimage.measure.shannon_entropy(G)
    print(Entropy_G)
    
    #converts images pixels to range of 0 to 8 instead of 0 to 255
    G = skimage.img_as_ubyte(G)
    
    #calculates contrast
    g2 = skf.graycomatrix(G, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_G = skf.graycoprops(g2, 'contrast')[0][0]
    print(Contrast_G)
    
    #calculates energy
    Energy_G = skf.graycoprops(g2, 'energy')[0][0]
    print(Energy_G)
    
    #calculates homogeniety
    Homogeneity_G = skf.graycoprops(g2, 'homogeneity')[0][0]
    print(Homogeneity_G)
    
    #calculates correlation
    Correlation_G = skf.graycoprops(g2, 'correlation')[0][0]
    print(Correlation_G)
    #glcm_G = skf.graycomatrix(G, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
    
    #calculates inverse difference moment (IDM)
    IDM_G = 1 / (1 + Contrast_G - Energy_G)
    print(IDM_G)
    
    #calculates smoothness
    diff_G = np.diff(G.astype(float))
    variance_G = np.var(diff_G)
    Smoothness_G = variance_G / (G.shape[0] * G.shape[1])
    print(Smoothness_G)

    #selecting features from Blue Channel
    print("Calculating Statistical Features for Blue Channel: ")
    
    #calculates mean
    Mean_B = np.mean(B);
    print(Mean_B)
    
    #calculates root mean square
    RMS_B = np.sqrt(np.mean(B**2))
    print(RMS_B)
    
    #calculates median
    Median_B = np.median(B)
    print(Median_B)
    
    #calculates variance
    Variance_B = np.var(B)
    print(Variance_B)
    
    #calculates standard deviation
    Std_B = math.sqrt(Variance_B)
    print(Std_B)
    
    #calculates skewness
    Skewness_B = skew(B.reshape(-1))
    print(Skewness_B)
    
    #calculates kurtosis
    Kurtosis_B = kurtosis(B.reshape(-1))
    print(Kurtosis_B)
    
    #calculates entropy
    Entropy_B = skimage.measure.shannon_entropy(B)
    print(Entropy_B)
    
    #converts range of pixels values from 0-255 to 0-8
    B = skimage.img_as_ubyte(B)
    
    #calculates contrast
    g3 = skf.graycomatrix(B, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_B = skf.graycoprops(g3, 'contrast')[0][0]
    print(Contrast_B)
    
    #calculates energy
    Energy_B = skf.graycoprops(g3, 'energy')[0][0]
    print(Energy_B)
    
    #calculates homogeniety
    Homogeneity_B = skf.graycoprops(g3, 'homogeneity')[0][0]
    print(Homogeneity_B)
    
    #calculates correlation
    Correlation_B = skf.graycoprops(g3, 'correlation')[0][0]
    print(Correlation_B)
    
    #glcm_B = skf.graycomatrix(B, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
    
    #calculates inverse difference moment (IDM)
    IDM_B = 1 / (1 + Contrast_B - Energy_B)
    print(IDM_B)
    
    #calculates smoothness
    diff_B = np.diff(B.astype(float))
    variance_B = np.var(diff_B)
    Smoothness_B = variance_B / (B.shape[0] * B.shape[1])
    print(Smoothness_B)
    
    #count the number of images
    print("Image number: ", i)


    #Declares data for all the three channels
    values_R = [Mean_R, RMS_R, Median_R, Variance_R, Std_R, Skewness_R, Kurtosis_R, Entropy_R, Contrast_R, Energy_R, Homogeneity_R, Correlation_R, IDM_R, Smoothness_R]
    values_G = [Mean_G, RMS_G, Median_G, Variance_G, Std_G, Skewness_G, Kurtosis_G, Entropy_G, Contrast_G, Energy_G, Homogeneity_G, Correlation_G, IDM_G, Smoothness_G]
    values_B = [Mean_B, RMS_B, Median_B, Variance_B, Std_B, Skewness_B, Kurtosis_B, Entropy_B, Contrast_B, Energy_B, Homogeneity_B, Correlation_B, IDM_B, Smoothness_B]

    #Writes red channels into a file
    outWorkbookR = openpyxl.load_workbook("RedChannel30.xlsx")
    outSheetR = outWorkbookR.active
    outSheetR.append(values_R)
    outWorkbookR.save(filename="RedChannel30.xlsx")

    #Writes green channels into a file
    outWorkbookG = openpyxl.load_workbook("GreenChannel30.xlsx")
    outSheetG = outWorkbookG.active
    outSheetG.append(values_G)
    outWorkbookG.save(filename="GreenChannel30.xlsx")

    #writes blue chanels into a file
    outWorkbookB = openpyxl.load_workbook("BlueChannel30.xlsx")
    outSheetB = outWorkbookB.active
    outSheetB.append(values_B)
    outWorkbookB.save(filename="BlueChannel30.xlsx")
    
    #creates a general fle where all the three channels data will be merged
    outWorkbook = xlsxwriter.Workbook("Output30.xlsx")
    outSheet = outWorkbook.add_worksheet()
        
    #declares data for general file
    values = [Mean_R, RMS_R, Median_R, Variance_R, Std_R, Skewness_R, Kurtosis_R, Entropy_R, Contrast_R, Energy_R, Homogeneity_R, Correlation_R, IDM_R, Smoothness_R, Mean_G, RMS_G, Median_R, Variance_G, Std_G, Skewness_G, Kurtosis_G, Entropy_G, Contrast_G, Energy_G, Homogeneity_G, Correlation_G, IDM_G, Smoothness_G, Mean_B, RMS_B, Median_R, Variance_B, Std_B, Skewness_B, Kurtosis_B, Entropy_B, Contrast_B, Energy_B, Homogeneity_B, Correlation_B, IDM_B, Smoothness_B]
    
     
    #writes into the general file
    outWorkbook = openpyxl.load_workbook("Output30.xlsx") 
    outSheet = outWorkbook.active
    outSheet.append(values)
    
    #here the general file is being saved
    outWorkbook.save(filename="Output30.xlsx")
# Out:
# Calculating Statistical features for Red Channel:
# 114.01951599121094
# 9.188085420602546
# 126.0
# 677.5490118262824
# 26.029771643759812
# -0.19548711989414586
# -1.4680188425584704
# 5.460045798671923
# 2.6222886029411767
# 0.1579084999485046
# 0.7793454733174453
# 0.9980678697815063
# 0.2886519291391148
# 4.000325937157799e-05
# Calculating Statistical Features for Green Channel:
# 63.370086669921875
# 10.366338216437766
# 28.0
# 2928.560270964168
# 54.116173838919615
# 0.8753326647608866
# -0.6155990517864485
# 6.509691397552168
# 35.30007659313725
# 0.09420394929896113
# 0.5112287798514208
# 0.9939828076963529
# 0.027619828690144423
# 0.000538609403137924
# Calculating Statistical Features for Blue Channel:
# 133.8418426513672
# 9.80864197519009
# 138.0
# 1489.8713943341281
# 38.59885224114997
# -0.9914124860573088
# 0.8921123062420615
# 7.037569321114265
# 33.227144607843144
# 0.028964425785101455
# 0.28409832835610027
# 0.9888763243900255
# 0.02924132204334798
# 0.0005065597189316058
# Image number:  0
# Calculating Statistical features for Red Channel:
# 120.1531982421875
# 10.919626858662427
# 135.0
# 616.8495466560125
# 24.836456000323647
# -0.21435650867633987
# -1.6788318712162609
# 5.121581881811357
# 2.446829044117647
# 0.19990395861935495
# 0.8060698168046683
# 0.9980198758620378
# 0.307983699552013
# 3.731392681676006e-05
# Calculating Statistical Features for Green Channel:
# 76.7540283203125
# 10.608989545648893
# 30.5
# 3570.842452034354
# 59.75652643882804
# 0.6268965442627308
# -1.2083676069473854
# 6.117183362765723
# 25.192110906862744
# 0.11683487933536646
# 0.5017435177893242
# 0.9964771683067148
# 0.03835050485925101
# 0.0003844010780047323
# Calculating Statistical Features for Blue Channel:
# 144.63282775878906
# 10.535314120989923
# 151.0
# 774.5762593743857
# 27.8312101672634
# -2.403568978711127
# 6.844916697695588
# 6.196998740139114
# 21.56747855392157
# 0.0441136629719993
# 0.3153091895316173
# 0.9861255258579734
# 0.04439833945068412
# 0.00032903250179016117
# Image number:  1
# Calculating Statistical features for Red Channel:
# 132.56350708007812
# 10.459305149434373
# 148.0
# 1238.5988110890612
# 35.19373255409351
# -0.9617129127483806
# -0.7756352872696657
# 5.379376125350111
# 6.3478860294117645
# 0.19354221023323212
# 0.7941302091796086
# 0.9974433972713431
# 0.13977522261640773
# 9.685242923119124e-05
# Calculating Statistical Features for Green Channel:
# 55.410430908203125
# 10.499068445934709
# 30.0
# 2330.8091160496697
# 48.27845395256221
# 1.553772856069469
# 1.0652878459989505
# 5.660483460698498
# 27.6765318627451
# 0.1285298917854449
# 0.5586891770601692
# 0.9940790369061987
# 0.03502872113492377
# 0.00042231024822642006
# Calculating Statistical Features for Blue Channel:
# 139.29945373535156
# 10.009846988998586
# 144.0
# 850.1600070258137
# 29.157503442952958
# -1.5723093766036285
# 3.4075440497414835
# 6.624268001563868
# 24.160646446078434
# 0.0328814400680194
# 0.295776284118542
# 0.9858245365964659
# 0.03979661540772949
# 0.00036862113154273067
# Image number:  2
# Calculating Statistical features for Red Channel:
# 116.88246154785156
# 10.735463094188331
# 101.0
# 817.9044128616806
# 28.599028180371455
# 0.3051078239349674
# -1.7104636752978495
# 5.380760837518638
# 2.8145373774509808
# 0.1581463611744137
# 0.7823303150991147
# 0.998284129946735
# 0.2734937252466875
# 4.285551443973878e-05
# Calculating Statistical Features for Green Channel:
# 107.64463806152344
# 10.577444846348246
# 128.0
# 5006.404861081159
# 70.75595283141313
# -0.003280139202942
# -1.7016675641983692
# 6.6900292451562775
# 29.795756740196076
# 0.07463083426869317
# 0.4352520840505535
# 0.9970248174755116
# 0.03255089032420711
# 0.00045453209425324497
# Calculating Statistical Features for Blue Channel:
# 140.37107849121094
# 10.124390383605743
# 146.0
# 1410.4948538539466
# 37.55655540453552
# -1.640030195384926
# 2.8702122247433444
# 6.632062042442579
# 20.671675857843145
# 0.036916811573966875
# 0.34519615851430235
# 0.9926875407452265
# 0.046221915292023824
# 0.00031474076887117884
# Image number:  3
# Calculating Statistical features for Red Channel:
# 128.67401123046875
# 11.304950703138454
# 133.0
# 1755.7265255115926
# 41.90139049615887
# -0.1234240791114585
# -1.651825817849696
# 5.926659315140013
# 15.319056372549019
# 0.1277491588658045
# 0.7648653510797334
# 0.9956363230065896
# 0.061761535792175165
# 0.00023373880274293058
# Calculating Statistical Features for Green Channel:
# 66.05252075195312
# 10.278693997438038
# 33.0
# 2639.4426151057705
# 51.37550598393918
# 0.7361551769671749
# -0.5967656138444255
# 6.677434035565907
# 36.27132352941177
# 0.09665520789498762
# 0.512087449147988
# 0.99313651396491
# 0.02690003825592165
# 0.0005534564695825534
# Calculating Statistical Features for Blue Channel:
# 161.982177734375
# 10.615681230532559
# 167.0
# 1613.0995969176292
# 40.163411171333905
# -1.1788580424311725
# 1.7121635250245744
# 7.019549916948405
# 37.58515625
# 0.037420625829704984
# 0.37157610143146835
# 0.9883784192306874
# 0.025941861014865363
# 0.000573235005108079
# Image number:  4
# Calculating Statistical features for Red Channel:
# 116.89802551269531
# 7.5510783050724575
# 127.0
# 563.4172898025718
# 23.736412740820207
# -0.9864974535500868
# -0.5152667523349104
# 4.880041765088737
# 3.6962162990196075
# 0.2501059004348993
# 0.8237183219279396
# 0.9967281179080195
# 0.22491569267338066
# 5.6381834690952845e-05
# Calculating Statistical Features for Green Channel:
# 38.56620788574219
# 9.91259023618094
# 21.0
# 1863.6297107541468
# 43.16977774733322
# 1.7002699016569292
# 1.9548391840439905
# 5.86844321479672
# 25.385922181372553
# 0.15623834989968668
# 0.6755448917017273
# 0.993207649623524
# 0.03812474471385374
# 0.00038735421651223096
# Calculating Statistical Features for Blue Channel:
# 144.375732421875
# 9.831127199447618
# 146.0
# 1444.9473871588707
# 38.012463576554346
# -1.0067302530061757
# 1.256547248451163
# 7.029348817436878
# 21.892218137254904
# 0.03387353468467785
# 0.3907066638573028
# 0.9924438524499207
# 0.04374769990507355
# 0.00033389596372373006
# Image number:  5
# Calculating Statistical features for Red Channel:
# 127.16368103027344
# 10.590816305396315
# 148.0
# 1278.594866845524
# 35.75744491494777
# -0.7701334931344291
# -1.2245139488299863
# 5.418447119191687
# 5.3099724264705905
# 0.1887731808058829
# 0.7817065588631065
# 0.9979271257255063
# 0.16336668026420514
# 8.101570349786774e-05
# Calculating Statistical Features for Green Channel:
# 63.0087890625
# 10.342960753971907
# 33.0
# 3144.1037130355835
# 56.07230789824496
# 1.4346085908640125
# 0.8339758718347143
# 6.194918524641406
# 37.71119791666666
# 0.11096560597298644
# 0.5771529699293441
# 0.9940180023153563
# 0.02590657983483077
# 0.0005754060536209079
# Calculating Statistical Features for Blue Channel:
# 137.35760498046875
# 10.271573321836309
# 143.0
# 1048.9091975353658
# 32.38686767094598
# -1.8759873609176876
# 3.775010737353968
# 6.492061044132466
# 22.86204044117647
# 0.044499819122382295
# 0.40241626821047327
# 0.9891330481990194
# 0.04198586310267652
# 0.00034860617342601596
# Image number:  6
# Calculating Statistical features for Red Channel:
# 133.7740020751953
# 11.530439477569727
# 141.0
# 403.60802833153866
# 20.08999821631497
# -1.523792261844077
# 0.8577404354381368
# 4.399003806501722
# 2.2116268382352944
# 0.2774708502544961
# 0.8742263922007784
# 0.9972676705153057
# 0.34081350960763723
# 3.374608226767851e-05
# Calculating Statistical Features for Green Channel:
# 39.378997802734375
# 10.328492866463051
# 24.0
# 1499.7418281948194
# 38.72650033497501
# 2.1299347811485947
# 3.136347827781198
# 5.199807295518915
# 8.390272671568628
# 0.18146040542786587
# 0.7730111496799269
# 0.997211249021274
# 0.10859163712966872
# 0.0001280217843437449
# Calculating Statistical Features for Blue Channel:
# 124.71842956542969
# 9.643681615066594
# 126.0
# 472.24751557572745
# 21.731256649713735
# 0.31053096530231034
# 0.0017712968424419273
# 6.351870921339585
# 5.185768995098041
# 0.05723209784585034
# 0.5809212582494807
# 0.9945244469102801
# 0.1631710825545267
# 7.903893195344756e-05
# Image number:  7
# Calculating Statistical features for Red Channel:
# 127.20062255859375
# 10.11704421954527
# 155.0
# 2162.418704446405
# 46.50181399092303
# -0.7243250566516083
# -1.3566040871419767
# 5.3018007168235535
# 10.701654411764707
# 0.2021599595524134
# 0.7753331357132148
# 0.9975300165471426
# 0.08696034457476677
# 0.00016329152703640416
# Calculating Statistical Features for Green Channel:
# 56.007965087890625
# 10.860067704974984
# 43.0
# 1068.9278235202655
# 32.6944616643288
# 1.2374892946719274
# 0.6858971677783261
# 6.224938548704897
# 16.01852022058824
# 0.07926815865609406
# 0.524951794345793
# 0.9925253202295559
# 0.05903448371532981
# 0.000244409675516191
# Calculating Statistical Features for Blue Channel:
# 117.75828552246094
# 10.24491570143416
# 115.0
# 970.889801040059
# 31.15910462513419
# -0.28700356187074133
# 0.11494578180309745
# 6.902479478872786
# 13.994102328431374
# 0.030993002007984573
# 0.3422280367969483
# 0.9928093880903517
# 0.0668310294461391
# 0.0002132912944882008
# Image number:  8
# Calculating Statistical features for Red Channel:
# 132.54159545898438
# 11.428703552572275
# 168.0
# 2403.0946443295106
# 49.02136926208315
# -0.560704408166901
# -1.5033981852542766
# 5.20243516857369
# 19.39324448529412
# 0.2068312399143425
# 0.7696474732906637
# 0.9959705240405584
# 0.04953827051117553
# 0.0002959163710926128
# Calculating Statistical Features for Green Channel:
# 44.57560729980469
# 10.84723002853688
# 38.0
# 540.7635706455912
# 23.25432369787587
# 3.110549160748737
# 15.346629601451124
# 5.917907447758379
# 14.21436887254902
# 0.07922736657776563
# 0.5437540742617797
# 0.9868922251124609
# 0.06607140075997775
# 0.00021689404733120962
# Calculating Statistical Features for Blue Channel:
# 137.3401336669922
# 9.770574526961763
# 138.0
# 874.9916546696331
# 29.5802578533324
# -0.9991372019308552
# 2.0408176698377867
# 6.740342745000976
# 28.052420343137253
# 0.030319592434850856
# 0.2965041690273976
# 0.9839908904310634
# 0.034456499499809556
# 0.00042804355709106346
# Image number:  9
# Calculating Statistical features for Red Channel:
# 92.65077209472656
# 10.263150594814242
# 100.0
# 664.3659091328736
# 25.775296489718087
# -0.09301296453494308
# -1.5957140547648283
# 5.577363591555034
# 4.69312193627451
# 0.16779447918731064
# 0.7023115185059537
# 0.9964701316114553
# 0.18098474846360918
# 7.160677746445319e-05
# Calculating Statistical Features for Green Channel:
# 67.58381652832031
# 10.687009565912911
# 45.0
# 2301.366479428252
# 47.97255965057787
# 0.7739623349888679
# -0.47874715113581523
# 6.657178381715392
# 30.556464460784316
# 0.08931994667931543
# 0.4556592010720959
# 0.9933681686484389
# 0.031779178423760525
# 0.0004662490509642358
# Calculating Statistical Features for Blue Channel:
# 113.29524230957031
# 10.402346683720953
# 113.0
# 1493.9359490440693
# 38.65146761824277
# -0.19591615956085354
# -0.955626705067929
# 7.157121768477459
# 17.370894607843134
# 0.028190453521190328
# 0.34605099659230587
# 0.9942029789928769
# 0.05451758866014192
# 0.0002644317090849334
# Image number:  10
# Calculating Statistical features for Red Channel:
# 123.73951721191406
# 10.36473292461667
# 142.0
# 1192.3384750110563
# 34.53025448807258
# -0.29465987064036947
# -1.6419099047286538
# 5.509183875642825
# 4.112377450980394
# 0.16080029999679274
# 0.7637817601710029
# 0.9982775684529329
# 0.20195585558055093
# 6.27398181395868e-05
# Calculating Statistical Features for Green Channel:
# 44.478179931640625
# 10.749276070282884
# 31.0
# 671.5040710037574
# 25.913395589998572
# 1.329936261034351
# 1.7717975936021926
# 6.073745674393276
# 18.876899509803923
# 0.07442152149203352
# 0.4746936134049336
# 0.9859647358083407
# 0.050498730542219754
# 0.0002880234919525668
# Calculating Statistical Features for Blue Channel:
# 128.4452362060547
# 9.254057947785748
# 135.0
# 869.4510719717946
# 29.486455737707686
# -1.9654876895091202
# 4.153833773893844
# 6.328995834958778
# 36.96306678921569
# 0.033569631792548515
# 0.24030935806994042
# 0.9787868332827464
# 0.02636470491157806
# 0.0005638996311432981
# Image number:  11
# Calculating Statistical features for Red Channel:
# 105.95663452148438
# 9.891612312491073
# 101.0
# 721.9652825212106
# 26.869411651936307
# 0.003824543538390171
# -1.6631063504707417
# 5.727007969736538
# 2.8617034313725496
# 0.1359276013964449
# 0.7286654488625515
# 0.9980190007305674
# 0.26840047432655484
# 4.364988404608652e-05
# Calculating Statistical Features for Green Channel:
# 83.50686645507812
# 10.174790768733281
# 87.0
# 3760.321028291248
# 61.321456508234114
# 0.3534577274904033
# -1.1941638146168982
# 6.82936873997676
# 36.30468750000001
# 0.08938293758677031
# 0.4399805224597691
# 0.995173047701958
# 0.02687066548986358
# 0.000553941512190347
# Calculating Statistical Features for Blue Channel:
# 145.33401489257812
# 10.287701006162042
# 158.0
# 1675.5523134460673
# 40.93351088589968
# -1.1700707546971498
# 1.1703778158458986
# 6.925586118683417
# 32.87637867647058
# 0.028347764747889758
# 0.28454025713712777
# 0.9902056025907302
# 0.02954381608218359
# 0.0005015056864607338
# Image number:  12
# Calculating Statistical features for Red Channel:
# 121.51089477539062
# 10.718883813851317
# 136.0
# 743.3953585987911
# 27.265277526531637
# -0.7500538085509502
# -1.241806281061069
# 4.76942300824985
# 3.5226868872549026
# 0.23867353056717283
# 0.8057830593481852
# 0.9976361508843167
# 0.23342597623765812
# 5.3731705108997636e-05
# Calculating Statistical Features for Green Channel:
# 58.686431884765625
# 10.494634801608898
# 26.0
# 3153.4267910039052
# 56.15538078407006
# 1.161525062833119
# -0.20156231782003875
# 6.150456139725746
# 26.218321078431373
# 0.10406296200221181
# 0.5468070708703954
# 0.9958524402098031
# 0.0368809648306061
# 0.00040005950434065374
# Calculating Statistical Features for Blue Channel:
# 137.5186004638672
# 9.618002193102445
# 138.0
# 744.0154926457908
# 27.276647386469453
# -0.8806391401178463
# 2.0086260477425197
# 6.680113957574745
# 24.369178921568626
# 0.030756523363263025
# 0.27347207326421463
# 0.9836659520318937
# 0.039465756166051864
# 0.0003718145440308601
# Image number:  13
# Calculating Statistical features for Red Channel:
# 99.137451171875
# 10.74886724137275
# 104.0
# 131.65157836675644
# 11.473952168575414
# -0.28830349873664385
# -1.3461240338952152
# 4.967414383390488
# 0.782751225490196
# 0.15247975859393775
# 0.8118149075494895
# 0.9970336324241463
# 0.6133947752295628
# 1.1900423086752847e-05
# Calculating Statistical Features for Green Channel:
# 113.350830078125
# 10.510366499560238
# 125.0
# 3933.447749555111
# 62.71720457382576
# 0.01916832023837133
# -1.0317298696490673
# 7.3750858108761985
# 51.90814950980392
# 0.05563296957021701
# 0.3538352343724484
# 0.9934039968255772
# 0.018920574940622843
# 0.0007909311910447409
# Calculating Statistical Features for Blue Channel:
# 149.1177520751953
# 10.294357709890388
# 150.0
# 2305.4401291997638
# 48.014999002392614
# -0.22729107205169707
# -0.6794258635790844
# 7.469888290030585
# 44.97748161764706
# 0.02503807046672725
# 0.2995751755636152
# 0.9902605786243669
# 0.021761628388124326
# 0.0006847661565051131
# Image number:  14
# Calculating Statistical features for Red Channel:
# 66.87855529785156
# 10.559908757827069
# 77.0
# 1299.1572329958435
# 36.043823784330144
# -0.31377614058998793
# 0.0038393720704523737
# 5.392156721220405
# 17.985891544117646
# 0.1719270508764134
# 0.7667842922866495
# 0.9930599412844522
# 0.05315200846473597
# 0.00027412808683558706
# Calculating Statistical Features for Green Channel:
# 66.22836303710938
# 8.597540002337697
# 10.0
# 6137.127873516642
# 78.33982303730741
# 0.764870883543823
# -1.0335827003550626
# 6.059916626638941
# 26.393489583333338
# 0.19201530258285143
# 0.6242648398307601
# 0.9978531742498318
# 0.03676271328821557
# 0.00040272820664670705
# Calculating Statistical Features for Blue Channel:
# 123.89260864257812
# 9.392217263095414
# 128.0
# 765.5227688541636
# 27.66808213183855
# -0.1538671252691409
# 0.31787001786468094
# 6.591173898874234
# 6.174188112745098
# 0.05755057673047703
# 0.5604335695221563
# 0.9959754860623768
# 0.1405157976557576
# 9.418629845679495e-05
# Image number:  15
# Calculating Statistical features for Red Channel:
# 119.73870849609375
# 11.219227390173616
# 111.0
# 2249.7744696699083
# 47.43178754453503
# -0.1311232950268989
# -1.358966657261126
# 5.569234328251437
# 16.49229473039216
# 0.14322452512925915
# 0.7492055610680273
# 0.9963320098188903
# 0.05763997656177831
# 0.00025162950905397254
# Calculating Statistical Features for Green Channel:
# 65.92581176757812
# 10.608878796846152
# 44.0
# 1804.0504958620295
# 42.47411559835036
# 0.9014471102004822
# 0.003949277602091517
# 6.765689660325165
# 38.44338235294117
# 0.05719950054818102
# 0.4117998831212293
# 0.9893566303527214
# 0.02538961451907348
# 0.0005865606579103181
# Calculating Statistical Features for Blue Channel:
# 132.84059143066406
# 10.260411626875877
# 142.0
# 1384.7861276043113
# 37.212714596012894
# -1.3210047520853283
# 1.555219347489194
# 6.89744261620696
# 42.32833946078431
# 0.0265450112186197
# 0.24452784615758735
# 0.9847337368164374
# 0.02309373116545358
# 0.0006453792829322889
# Image number:  16
# Calculating Statistical features for Red Channel:
# 80.53207397460938
# 11.28656168234485
# 80.0
# 378.7488797074184
# 19.461471673730596
# -1.8470622268905417
# 4.926052075205544
# 5.002582302357727
# 2.731204044117646
# 0.1852299205146671
# 0.8374076608110699
# 0.9964442306731218
# 0.28200995414594965
# 4.146679536565159e-05
# Calculating Statistical Features for Green Channel:
# 94.91241455078125
# 9.850422465757815
# 62.0
# 7189.984699394554
# 84.79377748039389
# 0.23313549782540788
# -1.66633192945771
# 7.087461516350534
# 25.39044117647059
# 0.08777321690771792
# 0.5252579321472592
# 0.9982343244295322
# 0.038018956918643286
# 0.0003874145143997299
# Calculating Statistical Features for Blue Channel:
# 144.20681762695312
# 10.227662099496852
# 144.0
# 901.0496031781659
# 30.01748828896525
# -0.1538502575504103
# -0.5270716745558901
# 6.827764462009101
# 10.544822303921567
# 0.04236260552494126
# 0.50379553365597
# 0.9941663540261384
# 0.08693792686266869
# 0.0001605588775049352
# Image number:  17
# Calculating Statistical features for Red Channel:
# 105.79815673828125
# 10.669235238123033
# 88.0
# 1589.62558009848
# 39.87010885486118
# -0.45975260849626104
# 0.07489752753429091
# 5.821152227763959
# 20.840410539215686
# 0.0978820618308194
# 0.61155540983216
# 0.9934271251351755
# 0.04599281086558694
# 0.00031754205554082094
# Calculating Statistical Features for Green Channel:
# 45.70481872558594
# 8.358182048347613
# 20.0
# 2783.2100024146494
# 52.75613710664049
# 1.1285281459450058
# 0.34610199564856714
# 6.392871876653471
# 56.509420955882334
# 0.16811235191426366
# 0.47295498978718137
# 0.9898617858367994
# 0.01743943457772429
# 0.0008622645333184446
# Calculating Statistical Features for Blue Channel:
# 228.14935302734375
# 9.062944493409688
# 245.0
# 1532.8534260950983
# 39.15167207278762
# -2.330930468510602
# 4.984332675166806
# 5.93425262635846
# 52.63673406862745
# 0.07679895141855657
# 0.3853165502524031
# 0.9828798302346138
# 0.018670672356335596
# 0.0008031681850151529
# Image number:  18
# Calculating Statistical features for Red Channel:
# 75.82919311523438
# 10.459067350569553
# 87.0
# 2063.9818113362417
# 45.43106658814254
# 0.12530884970713593
# -0.16067410449829422
# 5.882251013163677
# 29.553140318627456
# 0.1317026975103255
# 0.7137839588853286
# 0.992828823130507
# 0.032871556316781264
# 0.00045042305786244247
# Calculating Statistical Features for Green Channel:
# 67.63676452636719
# 9.660506905786974
# 17.0
# 5176.292696831515
# 71.9464571527432
# 0.6777526555900483
# -1.1303865405828188
# 6.628328995957033
# 40.97582720588235
# 0.13105399405061124
# 0.525373358478968
# 0.996047442018797
# 0.023897847287585417
# 0.0006252295913168303
# Calculating Statistical Features for Blue Channel:
# 103.98211669921875
# 9.619655958594297
# 111.0
# 696.4525000117719
# 26.39038650743433
# -0.8281234226606022
# 0.013085177250572677
# 6.567464421676641
# 13.53541666666667
# 0.0471722152989638
# 0.46982276743559526
# 0.9903084700154513
# 0.06902147484856931
# 0.00020651529059358305
# Image number:  19
# Calculating Statistical features for Red Channel:
# 127.23762512207031
# 11.04446648182537
# 160.0
# 2298.5162119136658
# 47.942843177200764
# -0.26838585360054323
# -1.7697740237193467
# 5.667232172069333
# 13.316528799019611
# 0.17964179165562796
# 0.6928186255721297
# 0.997104925493252
# 0.07073693094378518
# 0.0002031907280215973
# Calculating Statistical Features for Green Channel:
# 45.56388854980469
# 10.766867246225875
# 29.0
# 1163.0059280188289
# 34.10287272384584
# 1.7578531737610859
# 3.227869429410365
# 6.352712089480799
# 35.69482230392157
# 0.09288694525077887
# 0.5359820254982185
# 0.9846882403678233
# 0.027320959676060016
# 0.0005446465370008599
# Calculating Statistical Features for Blue Channel:
# 138.60060119628906
# 10.140115639894335
# 147.0
# 2044.5741994676646
# 45.21696804815273
# -1.0065336917160224
# 0.6490786474751888
# 7.226657518588396
# 39.370618872549024
# 0.030566446974413925
# 0.3471132342546298
# 0.9903949462092074
# 0.02478925881033373
# 0.000600294794805666
# Image number:  20
# Calculating Statistical features for Red Channel:
# 113.60580444335938
# 10.521105671495807
# 94.0
# 1279.0867363279685
# 35.76432211475521
# 0.1840274203270075
# -1.8003214404785013
# 5.213612987966047
# 5.055208333333334
# 0.1654488270970682
# 0.7617406175339849
# 0.9980243139816164
# 0.16978621944430297
# 7.709811709789715e-05
# Calculating Statistical Features for Green Channel:
# 72.97758483886719
# 10.722159596876855
# 75.0
# 2807.4711925068405
# 52.98557532486404
# 0.5593528235059025
# -0.7484891800418136
# 6.7884395801201975
# 40.23206188725491
# 0.06403483111845605
# 0.39837473270221235
# 0.992837795271395
# 0.024290695267869082
# 0.0006138865781145194
# Calculating Statistical Features for Blue Channel:
# 127.00556945800781
# 9.908899765143659
# 135.0
# 1070.8458399528172
# 32.723780954419325
# -1.0391685541112037
# 0.876117768015138
# 6.83938761743103
# 40.96007965686274
# 0.02605784532044307
# 0.22626938840229635
# 0.9809304283872542
# 0.02384698525922813
# 0.0006249933299973397
# Image number:  21
# Calculating Statistical features for Red Channel:
# 133.21192932128906
# 11.636937728721781
# 162.0
# 1723.9064562020358
# 41.51995250722279
# -0.30108789442191153
# -1.7462134258736297
# 5.603483879362696
# 12.70453431372549
# 0.15024285832923437
# 0.7486331809859816
# 0.9963189814454027
# 0.07377737178595775
# 0.00019385371922942506
# Calculating Statistical Features for Green Channel:
# 75.95574951171875
# 10.426320559065438
# 35.0
# 3532.3385265134275
# 59.433479845230565
# 0.6014522268131205
# -1.189641294149069
# 6.530059083305349
# 25.123376225490198
# 0.08302367654129503
# 0.49964826879777674
# 0.9964493878128757
# 0.03840193784320958
# 0.0003833091346083673
# Calculating Statistical Features for Blue Channel:
# 138.69017028808594
# 10.225323257373013
# 147.0
# 1794.105619929498
# 42.356883973322425
# -1.6318721813041264
# 2.5844430345201994
# 6.795125432422824
# 19.487469362745102
# 0.03803356997802669
# 0.3618353952276087
# 0.9945807374371534
# 0.04890110466293148
# 0.0002966042242654925
# Image number:  22
# Calculating Statistical features for Red Channel:
# 88.84242248535156
# 8.451183385204203
# 87.0
# 2137.7628737946507
# 46.23594785223561
# -0.43270519721758727
# -1.0813318669216658
# 5.604004747967794
# 13.993964460784314
# 0.18002501164729703
# 0.7085613149846148
# 0.9967118807551428
# 0.06750398862054582
# 0.00021353095115342536
# Calculating Statistical Features for Green Channel:
# 47.98341369628906
# 10.310143403795891
# 43.0
# 1154.1371608076151
# 33.97259426078048
# 1.590604866601545
# 4.87380033478857
# 6.267470699289486
# 53.09067095588235
# 0.10963659921466476
# 0.5143002486857589
# 0.9768558765716759
# 0.018525024796537285
# 0.0008100957183653587
# Calculating Statistical Features for Blue Channel:
# 94.69166564941406
# 9.642759114730937
# 101.0
# 2313.0181348843034
# 48.09384716244172
# -0.721466102192375
# -0.3740282288258854
# 6.657958224261318
# 22.422564338235293
# 0.10440301501170807
# 0.39918654451575225
# 0.9951260934353544
# 0.04288502794618099
# 0.00034207665638605003
# Image number:  23
# Calculating Statistical features for Red Channel:
# 111.9593505859375
# 9.01063925995525
# 119.0
# 462.74074874818325
# 21.51140973409654
# -1.9274153659828421
# 8.384061906303812
# 5.126882651517519
# 20.756755514705883
# 0.24722417859625065
# 0.773674272455588
# 0.9776426111471215
# 0.0464910176039599
# 0.000316722944707555
# Calculating Statistical Features for Green Channel:
# 56.93370056152344
# 10.42743348185711
# 35.0
# 1601.3437031393405
# 40.016792764280105
# 1.3865696193714745
# 0.7711082357493821
# 5.946609077706163
# 18.65127144607843
# 0.13291164536415032
# 0.5761292633003775
# 0.9941890773767778
# 0.05123381319999054
# 0.0002845892620046281
# Calculating Statistical Features for Blue Channel:
# 133.73487854003906
# 10.466397969224909
# 150.0
# 1442.5511858311947
# 37.980931871548314
# -1.243974482430429
# 0.42201457954397226
# 6.581328572867291
# 18.066421568627455
# 0.057073193132496085
# 0.44169980979217704
# 0.9937524027456881
# 0.052605695905342274
# 0.0002756475107525918
# Image number:  24
# Calculating Statistical features for Red Channel:
# 129.1859588623047
# 11.376111322129217
# 156.0
# 1867.4312853903975
# 43.21378582571073
# -0.5700037399432967
# -1.558521861860814
# 5.115330349146721
# 8.07668504901961
# 0.21237574608014473
# 0.8324089513311177
# 0.9978408226522336
# 0.11281194798430526
# 0.0001232401155127282
# Calculating Statistical Features for Green Channel:
# 71.39419555664062
# 10.409862361001705
# 40.0
# 2700.027043945156
# 51.961784456898286
# 0.9437382792729598
# -0.7859084438221862
# 6.0855127202734165
# 19.298391544117646
# 0.10145614736625622
# 0.5277333210676465
# 0.9964342663752542
# 0.04951246218081416
# 0.00029446426505113347
# Calculating Statistical Features for Blue Channel:
# 135.03115844726562
# 9.990247930403804
# 137.0
# 659.7663021003827
# 25.68591641542857
# -0.7861723280288331
# 0.9011143511993458
# 6.539703685443672
# 11.104901960784312
# 0.03696766638920623
# 0.35503649841870477
# 0.9915986194262154
# 0.08286422312263045
# 0.00016941330098088365
# Image number:  25
# Calculating Statistical features for Red Channel:
# 108.9918212890625
# 9.747381396651969
# 120.0
# 1796.2669924348593
# 42.38239012178123
# -0.14877778249284823
# -1.5405481788488393
# 6.024254110390183
# 8.00330882352941
# 0.16590249487597278
# 0.7287093840452794
# 0.9977762848538971
# 0.11315537192826695
# 0.00012206084536433633
# Calculating Statistical Features for Green Channel:
# 56.55198669433594
# 9.766096082387767
# 21.0
# 3058.2884961140808
# 55.30179469161992
# 0.7035121048122006
# -1.0258433290615319
# 6.329734086729099
# 19.755392156862744
# 0.14650839724371745
# 0.577346022584585
# 0.9967767523785453
# 0.04852276385581816
# 0.0003013906731302122
# Calculating Statistical Features for Blue Channel:
# 105.4779052734375
# 10.446429972479683
# 107.0
# 1537.0823670476675
# 39.205642030805556
# -0.08405439904858364
# -1.4879186563114892
# 6.791981567961046
# 6.550183823529413
# 0.04668302894374676
# 0.4900532994455194
# 0.9978912149175857
# 0.13327112602181296
# 9.900515328309298e-05
# Image number:  26
# Calculating Statistical features for Red Channel:
# 120.22665405273438
# 10.739884696355713
# 139.0
# 1103.0256848251447
# 33.211830494947804
# -0.7993527459783751
# -1.1933270933044606
# 5.224365610354483
# 5.19829963235294
# 0.18627245765083147
# 0.7863446647936114
# 0.9976492108310493
# 0.16633324683026723
# 7.930013470019413e-05
# Calculating Statistical Features for Green Channel:
# 54.49836730957031
# 10.592637265261112
# 32.0
# 1614.5498935745563
# 40.18146206367504
# 1.3699404975365554
# 0.8397775497949143
# 6.011907178210444
# 24.61724877450981
# 0.10720963997371882
# 0.5529696319560892
# 0.9923944148181236
# 0.03920025346594535
# 0.00037562922346493405
# Calculating Statistical Features for Blue Channel:
# 138.0026397705078
# 10.018294575240292
# 145.0
# 754.0009238177445
# 27.45907725721577
# -1.8004838193339752
# 4.026328790247153
# 6.423596458620092
# 23.157935049019606
# 0.03893985456090252
# 0.32065327692204704
# 0.984678692600724
# 0.04146109702902334
# 0.0003533576819035971
# Image number:  27
# Calculating Statistical features for Red Channel:
# 105.55928039550781
# 9.746384953064409
# 114.0
# 902.9959670358803
# 30.04989129823734
# 0.07144231016591984
# -1.6113976413283055
# 5.627713108538003
# 4.954457720588235
# 0.14305640762068572
# 0.7534291743860357
# 0.9972593922643043
# 0.17207553671583514
# 7.557157127373566e-05
# Calculating Statistical Features for Green Channel:
# 57.03961181640625
# 10.445335873197484
# 47.0
# 2173.7400690875947
# 46.62338543142909
# 0.9415597547382536
# 0.3098552050621306
# 6.650850919098528
# 43.18797487745099
# 0.09708259157014994
# 0.4794014957107872
# 0.9900759022014277
# 0.022680421015662422
# 0.0006589387078769147
# Calculating Statistical Features for Blue Channel:
# 130.06698608398438
# 9.767382654325345
# 135.0
# 1623.5551136946306
# 40.293363146982784
# -0.8854797427032487
# 0.4068407930517117
# 7.108579906113328
# 40.968290441176464
# 0.027614612300265826
# 0.28667813946129916
# 0.987406040697818
# 0.02384320186160422
# 0.0006244718031481522
# Image number:  28
# Calculating Statistical features for Red Channel:
# 116.37049865722656
# 9.568808076907766
# 130.0
# 957.6605365311261
# 30.946090811783094
# -0.2767701441933461
# -1.4467166175007633
# 5.735820669220936
# 3.4816176470588234
# 0.15343773325698684
# 0.7789150015017007
# 0.9981859506169687
# 0.23104399999897612
# 5.310172984940141e-05
# Calculating Statistical Features for Green Channel:
# 57.97355651855469
# 10.739413704381967
# 32.0
# 2331.6165950538125
# 48.28681595481123
# 1.3311768286852026
# 0.8602418584408467
# 6.697277409518563
# 36.770389093137254
# 0.061283340356341226
# 0.4336927017086237
# 0.9921308458078424
# 0.02651879380423264
# 0.0005610281233280117
# Calculating Statistical Features for Blue Channel:
# 115.06303405761719
# 9.475965916660472
# 123.0
# 1200.4054047593381
# 34.646867170919485
# -0.8963979874004578
# 0.16066918604567482
# 6.871576889079017
# 35.814169730392166
# 0.026244050306013764
# 0.2365430128375775
# 0.9851073126880893
# 0.027182831907842923
# 0.0005462566580084861
# Image number:  29
# Calculating Statistical features for Red Channel:
# 107.84056091308594
# 10.603885989168738
# 132.0
# 1953.6331637722906
# 44.19992266703971
# -0.13713907427248387
# -1.8641039514451663
# 5.589402048559771
# 8.49105392156863
# 0.15549553981880224
# 0.7850778915729383
# 0.9978278606587463
# 0.10711732058308472
# 0.00012955144425851937
# Calculating Statistical Features for Green Channel:
# 53.61747741699219
# 10.518572412670169
# 39.0
# 1325.9627310389187
# 36.413771172990565
# 0.9231396438689451
# 0.2230794298625729
# 6.473198134645553
# 12.12049632352941
# 0.09057651688450871
# 0.5604185245883173
# 0.9954376114357056
# 0.07674644317381198
# 0.00018491849422122553
# Calculating Statistical Features for Blue Channel:
# 138.5989227294922
# 10.167902720204353
# 140.0
# 1572.990488951793
# 39.660944125824756
# -0.4820373706726739
# -0.3784889924951935
# 7.198518055189521
# 14.937990196078431
# 0.03331029815419182
# 0.41967170881642313
# 0.995262482546789
# 0.06287457568577111
# 0.0002277711425542327
# Image number:  30
# Calculating Statistical features for Red Channel:
# 76.14381408691406
# 11.05386135936888
# 84.0
# 552.405083499616
# 23.50329941730769
# -1.9537594938637972
# 3.323471258440846
# 4.997418494999297
# 3.8824601715686287
# 0.18239991919835563
# 0.8449588679943874
# 0.9964866402667903
# 0.21276322989597699
# 5.924132068937601e-05
# Calculating Statistical Features for Green Channel:
# 76.02635192871094
# 9.381565897360815
# 17.0
# 6256.855247348314
# 79.10028601306264
# 0.4267687439279118
# -1.6349695877994084
# 6.255319331738792
# 17.288955269607843
# 0.1721074483909126
# 0.6432348347165626
# 0.998619806408233
# 0.055197240152830784
# 0.00026380614322416484
# Calculating Statistical Features for Blue Channel:
# 147.4545440673828
# 10.079868278248279
# 141.0
# 614.0150846370962
# 24.779327768062963
# 0.31599295977260355
# -0.17973040695429887
# 6.348233810283061
# 4.653002450980393
# 0.07393917939587699
# 0.613213201728981
# 0.99621899208673
# 0.17924155925838584
# 7.099912606067999e-05
# Image number:  31
# Calculating Statistical features for Red Channel:
# 108.63665771484375
# 10.996724421301412
# 114.0
# 943.6725172959268
# 30.71925320211946
# 0.03562227654017625
# -1.7637020724665675
# 5.3484153563897
# 3.449954044117647
# 0.1691119857321811
# 0.7628304225427804
# 0.998172670329197
# 0.23359890095481672
# 5.2625088820356396e-05
# Calculating Statistical Features for Green Channel:
# 69.31895446777344
# 10.53589054726858
# 66.0
# 2531.5164473687764
# 50.31417739930542
# 0.39754554200485803
# -1.218199233249352
# 6.755780925046334
# 33.662591911764714
# 0.0648328038389796
# 0.42354732104083154
# 0.9933545971067786
# 0.028903606065368487
# 0.0005136503490466469
# Calculating Statistical Features for Blue Channel:
# 127.52981567382812
# 10.002453312344176
# 136.0
# 1216.6170614650473
# 34.88003815171433
# -1.0448346883030162
# 0.7061582650180593
# 6.83521122296692
# 37.92121629901961
# 0.028148193651634446
# 0.23914054605965837
# 0.984455271468442
# 0.025711522610940046
# 0.0005786119484776249
# Image number:  32
# Calculating Statistical features for Red Channel:
# 127.52593994140625
# 11.066835749916278
# 167.0
# 3312.875120576471
# 57.557580913173126
# -0.7931285270350217
# -0.6852734111124938
# 5.5414499490549725
# 29.15603553921569
# 0.17747028895821101
# 0.7725807168020948
# 0.9955896534151343
# 0.03335716675071404
# 0.0004444941832343462
# Calculating Statistical Features for Green Channel:
# 57.975830078125
# 10.5199120045742
# 35.0
# 1895.803706586361
# 43.54082804203844
# 1.2053322553541326
# 0.08711680260195953
# 6.26448107952908
# 22.088465073529417
# 0.09192452678963656
# 0.5807487561878242
# 0.9941923998330695
# 0.04348480146252998
# 0.00033698105556200734
# Calculating Statistical Features for Blue Channel:
# 146.3756866455078
# 10.174400098207188
# 150.0
# 1020.7939639145043
# 31.949866414658203
# -1.5266940232626816
# 3.809050749652643
# 6.757460048367066
# 19.85119485294118
# 0.03642110550920496
# 0.3845652574685922
# 0.9903012214930504
# 0.048042799414208144
# 0.0003022427262680341
# Image number:  33
# Calculating Statistical features for Red Channel:
# 69.52560424804688
# 8.489180916139857
# 65.0
# 2682.2174840709195
# 51.79012921465749
# 0.5854608927063506
# -0.8564447982010561
# 5.332756335464216
# 15.808517156862745
# 0.18193997086758354
# 0.8195919789374813
# 0.9970440475396047
# 0.06014467011540514
# 0.00024121859402713385
# Calculating Statistical Features for Green Channel:
# 40.452484130859375
# 9.96197145369031
# 20.0
# 1403.224121636711
# 37.459633228806595
# 0.5866481020287628
# -1.372813836724454
# 5.930581690351753
# 5.08607536764706
# 0.13775174015314257
# 0.7059341196180886
# 0.9981903068724443
# 0.1681145920470553
# 7.759911112017539e-05
# Calculating Statistical Features for Blue Channel:
# 124.98701477050781
# 9.23427998708523
# 131.0
# 339.0610343867447
# 18.413610031353024
# -0.6978121649714012
# -0.3712880916143435
# 5.922286185472951
# 5.342922794117647
# 0.059939947272176115
# 0.49608855927551954
# 0.9921266576726108
# 0.1591600716373235
# 8.15232731015212e-05
# Image number:  34
# Calculating Statistical features for Red Channel:
# 132.64442443847656
# 10.864506010156493
# 148.0
# 907.3339999800082
# 30.121985326004133
# -1.375297738375368
# 0.09708143596343399
# 4.493076588344686
# 4.41544117647059
# 0.29856720050867114
# 0.8313715736793337
# 0.9975735510425198
# 0.19543182120525268
# 6.73647487864775e-05
# Calculating Statistical Features for Green Channel:
# 48.68994140625
# 10.673266117695212
# 30.0
# 1621.4660279750824
# 40.26743135556429
# 1.8274353313029095
# 1.9493999734389114
# 5.115794903237265
# 19.07052696078432
# 0.15635527859443546
# 0.6284228207200013
# 0.994137291455859
# 0.05021549557566302
# 0.0002909903500983917
# Calculating Statistical Features for Blue Channel:
# 139.7423553466797
# 10.222381599768669
# 143.0
# 226.78995773359202
# 15.059547062697206
# -2.274096224678219
# 7.933379680048281
# 5.531673409738379
# 13.345496323529414
# 0.05791523105427011
# 0.3467522171847589
# 0.970652744157376
# 0.06999085384205946
# 0.00020363327711591444
# Image number:  35
# Calculating Statistical features for Red Channel:
# 119.51187133789062
# 11.04272072037517
# 107.0
# 2435.6433527236804
# 49.35223756552159
# -0.2699540517827046
# -0.9671491650086086
# 5.9921977419412356
# 28.983746936274514
# 0.12712317287719876
# 0.7313996357336077
# 0.9940387455360367
# 0.03349340528000184
# 0.00044225122316631963
# Calculating Statistical Features for Green Channel:
# 76.46133422851562
# 10.355252879917092
# 73.0
# 2978.176880202256
# 54.57267521573646
# 0.7495399401852545
# -0.2490831436752461
# 7.148751886264022
# 46.803814338235306
# 0.06657602732986305
# 0.44049054125874293
# 0.9921485044370144
# 0.020948006951871632
# 0.0007141187740328712
# Calculating Statistical Features for Blue Channel:
# 123.66847229003906
# 10.213527639879668
# 136.0
# 4201.3938582984265
# 64.81815994224479
# -0.3240135753490531
# -1.0885207792045934
# 7.44481065912444
# 36.726562500000014
# 0.05031997275619644
# 0.39967799586438507
# 0.9956392716208067
# 0.026541924908698014
# 0.0005594951436725639
# Image number:  36
# Calculating Statistical features for Red Channel:
# 88.54855346679688
# 9.471638959550672
# 69.0
# 2288.2992172678933
# 47.836170595772955
# -0.08564920885522603
# -1.0734466462934493
# 5.933733355955066
# 25.521262254901963
# 0.1155790248297779
# 0.5946900085274978
# 0.9944271449902199
# 0.03787063532070048
# 0.0003877162726532263
# Calculating Statistical Features for Green Channel:
# 32.393707275390625
# 8.465881086935074
# 14.0
# 1189.5532465344295
# 34.48990064547054
# 0.9371684378411743
# -0.06353717564276495
# 6.124430832432669
# 21.766237745098035
# 0.1312776682318073
# 0.5225389310672383
# 0.9908615151153939
# 0.044179446157806
# 0.00033212024813051737
# Calculating Statistical Features for Blue Channel:
# 224.83560180664062
# 8.26590190344307
# 247.0
# 1954.0429195230827
# 44.2045576781748
# -1.9995772931030122
# 3.4476842860428514
# 5.99698401954395
# 54.94638480392157
# 0.13051056511255665
# 0.45419047213292163
# 0.9859734000103857
# 0.017916050113655584
# 0.0008384135107537362
# Image number:  37
# Calculating Statistical features for Red Channel:
# 119.48336791992188
# 11.198506827956184
# 140.0
# 1139.6430644383654
# 33.758599858974684
# -0.5408702995675579
# -1.5722489619450026
# 5.0923890470003625
# 4.24312193627451
# 0.1999036451970386
# 0.8008743688633739
# 0.9981414375641686
# 0.19828608287077584
# 6.472888561620913e-05
# Calculating Statistical Features for Green Channel:
# 69.03363037109375
# 9.927554353878842
# 33.0
# 2919.7032757364213
# 54.03427871024486
# 0.9395558136746441
# -0.576204285801603
# 5.944379163734369
# 29.942493872549015
# 0.13944192584865647
# 0.5540917895231012
# 0.9948822080344484
# 0.03246431560516589
# 0.00045687621197978707
# Calculating Statistical Features for Blue Channel:
# 137.79762268066406
# 10.172300268327879
# 145.0
# 648.7205638063606
# 25.469993400202533
# -2.3197255023823407
# 6.746878671574491
# 6.155448881515562
# 19.11254595588235
# 0.0527612936487982
# 0.3910897446763412
# 0.9853121157255896
# 0.04985098378860939
# 0.0002915762410374191
# Image number:  38
# Calculating Statistical features for Red Channel:
# 112.34806823730469
# 10.771205834170578
# 127.0
# 728.6296572179999
# 26.9931409290953
# -0.11388413304273864
# -1.8316156375483954
# 5.103254789680975
# 3.0210937500000004
# 0.19495578849257486
# 0.8140761537675135
# 0.9979294438221522
# 0.26136015221103504
# 4.60793401026201e-05
# Calculating Statistical Features for Green Channel:
# 75.86134338378906
# 10.120935448395368
# 27.0
# 3896.4860081074294
# 62.42183919196413
# 0.37394375461999396
# -1.5698885964994114
# 6.243329867263385
# 26.00018382352941
# 0.12203322058776972
# 0.5227495077787631
# 0.9966662916325078
# 0.03720494072574161
# 0.0003967174808453569
# Calculating Statistical Features for Blue Channel:
# 165.5556182861328
# 10.624479393265803
# 173.0
# 826.9316600242164
# 28.756419457648345
# -2.4807307689038565
# 7.837583367886008
# 6.292579132750638
# 23.778707107843136
# 0.04128291372616907
# 0.3219945518048347
# 0.9856582758496302
# 0.0404245806739175
# 0.0003627496332027553
# Image number:  39
# Calculating Statistical features for Red Channel:
# 104.35433959960938
# 8.64587000337354
# 120.0
# 674.176781094633
# 25.964914424943384
# -0.13128539607349843
# -1.760196219762236
# 5.284804955669036
# 3.8072303921568635
# 0.17128627249686235
# 0.744187579452404
# 0.9971784242115908
# 0.21570579243162658
# 5.808758074242261e-05
# Calculating Statistical Features for Green Channel:
# 60.592559814453125
# 10.550831144596945
# 48.0
# 1491.4750142237172
# 38.61961955047871
# 0.8245157712887257
# 0.05029101594881924
# 6.838933524745047
# 18.25001531862745
# 0.06235283926295585
# 0.4754667919008117
# 0.9938874551629371
# 0.05211682251944222
# 0.0002784729363938871
# Calculating Statistical Features for Blue Channel:
# 126.70657348632812
# 9.932671291469129
# 129.0
# 1884.5709443381056
# 43.41164526182008
# -0.3158861623981828
# -0.42318383207847265
# 7.349640969224993
# 27.273973651960784
# 0.024646990837124672
# 0.3100500631372718
# 0.9927704552694784
# 0.03539907382557852
# 0.0004161588834711093
# Image number:  40
# Calculating Statistical features for Red Channel:
# 92.096435546875
# 8.580613183649632
# 70.0
# 3324.088325917721
# 57.65490721454437
# -0.04135730695299297
# -1.1756400775926996
# 5.224907731588651
# 42.64502144607843
# 0.20835037010429017
# 0.7809659064934131
# 0.9935604860930758
# 0.023022022066353145
# 0.0006506742383161848
# Calculating Statistical Features for Green Channel:
# 34.26451110839844
# 9.919720946047875
# 15.0
# 1093.223048399901
# 33.063923669157916
# 0.8607643500225856
# -0.005593973216789561
# 5.809281857141635
# 20.56083026960784
# 0.1581679047379222
# 0.6477310698772799
# 0.9905686014224551
# 0.04672315915432037
# 0.00031373334367161917
# Calculating Statistical Features for Blue Channel:
# 103.16346740722656
# 8.560656272472905
# 122.0
# 2185.8299220835324
# 46.752860041750736
# -1.3531531972906679
# 0.5404746510289593
# 6.179515766999008
# 16.844316789215686
# 0.11663035973204598
# 0.42548231520226926
# 0.9961209150612372
# 0.056408939992127746
# 0.00025698714232897936
# Image number:  41
# Calculating Statistical features for Red Channel:
# 110.82412719726562
# 10.154346275906471
# 139.0
# 2654.3032667553052
# 51.51993077203525
# -0.901499668523272
# -0.37066704327924027
# 5.908681683179874
# 19.548529411764708
# 0.15253131429328695
# 0.7396079714958363
# 0.9962971859697555
# 0.049029225989385354
# 0.00029826020067847726
# Calculating Statistical Features for Green Channel:
# 62.6414794921875
# 10.005183593041597
# 32.0
# 3575.3714020103216
# 59.794409454482626
# 1.1896453103121305
# 0.2158160423994797
# 6.267671830253751
# 84.57670036764702
# 0.12895173274735125
# 0.540223187063838
# 0.9881625701853397
# 0.011703058488676987
# 0.0012905369669747543
# Calculating Statistical Features for Blue Channel:
# 110.01481628417969
# 9.364166103371055
# 133.0
# 3530.9434297697153
# 59.421742062730836
# -0.8429155159519268
# -0.7417896835543076
# 6.769796721889382
# 36.99687500000001
# 0.10384963379410653
# 0.44582170727619097
# 0.9947384767177955
# 0.026390080769107153
# 0.000564434817093054
# Image number:  42
# Calculating Statistical features for Red Channel:
# 86.54299926757812
# 10.826752370611016
# 89.0
# 877.5122196665034
# 29.62283274210121
# 0.0038096341045702206
# -1.5916900269791507
# 5.780959492977651
# 5.659160539215686
# 0.15900147183719532
# 0.7105217581550961
# 0.9967719969369407
# 0.15384238902991942
# 8.631743820114164e-05
# Calculating Statistical Features for Green Channel:
# 59.64585876464844
# 10.21817285616928
# 67.0
# 2224.716182496166
# 47.16689710481458
# 0.1969767052961316
# -1.5307992981320173
# 6.410810274114745
# 18.81041666666667
# 0.10075284052450575
# 0.5225173769802999
# 0.9957712239258728
# 0.05073653253657413
# 0.0002870139776399987
# Calculating Statistical Features for Blue Channel:
# 105.97012329101562
# 10.2239450670656
# 107.0
# 887.6198349213228
# 29.7929494162851
# -0.007405037056792764
# -0.6235196433901704
# 6.87262722054816
# 11.842003676470588
# 0.035508062960443315
# 0.4266064594310823
# 0.9933467452671215
# 0.07808537403042995
# 0.0001801752369823661
# Image number:  43
# Calculating Statistical features for Red Channel:
# 114.93434143066406
# 9.785188996951193
# 132.0
# 723.4213023555931
# 26.896492380152342
# -0.5525705549586019
# -1.517906761006403
# 4.917517714597249
# 4.641988357843137
# 0.259390243088233
# 0.7776094363210441
# 0.9967961916894124
# 0.1857838870152272
# 7.082940158761839e-05
# Calculating Statistical Features for Green Channel:
# 55.261627197265625
# 10.274180106240534
# 21.0
# 2614.031648865901
# 51.1276016342044
# 0.8464053678069137
# -0.9433918971805331
# 5.6357689437534075
# 24.339093137254903
# 0.17147898732761227
# 0.5973048871558457
# 0.9953529894093377
# 0.03973360343347798
# 0.00037138225193472375
# Calculating Statistical Features for Blue Channel:
# 174.54742431640625
# 10.181596976515399
# 183.0
# 582.9983002506196
# 24.14535773706034
# -1.7575440383634626
# 4.857776175115008
# 6.186712862349139
# 17.458716299019606
# 0.04206005275095949
# 0.31068189354182874
# 0.9850601304880857
# 0.05429867325685723
# 0.0002663861734986661
# Image number:  44
# Calculating Statistical features for Red Channel:
# 82.60905456542969
# 11.356244061079556
# 83.0
# 361.8490079806652
# 19.02232919441426
# -0.6756888008044278
# 1.121234547619463
# 5.2921269485838
# 6.896400122549021
# 0.16325841705210134
# 0.7331303295653094
# 0.9904631836496728
# 0.12931354914771234
# 0.00010493647904048995
# Calculating Statistical Features for Green Channel:
# 66.92718505859375
# 8.415172280572676
# 21.0
# 4847.055305894464
# 69.62079650430942
# 0.557070923305894
# -1.3273366178541286
# 6.386483041674415
# 25.334696691176468
# 0.1557141396429182
# 0.5741061715249429
# 0.9973894502170306
# 0.038198581554171995
# 0.0003865625703244004
# Calculating Statistical Features for Blue Channel:
# 123.4398193359375
# 10.200787263295693
# 134.0
# 881.1514381021261
# 29.684195089342175
# -0.6502947058825658
# -0.7984606368295366
# 6.497914246864689
# 10.021109068627451
# 0.050594145126245625
# 0.4859000637320472
# 0.9943314957254694
# 0.09115342415311652
# 0.00015228326091888732
# Image number:  45
# Calculating Statistical features for Red Channel:
# 120.36686706542969
# 10.94223321134069
# 126.0
# 1297.9755617545452
# 36.02742790922695
# 0.020935691144328594
# -1.7717572571981988
# 5.659425416984044
# 5.877221200980392
# 0.13308562750498662
# 0.7311755774289884
# 0.9977372812941505
# 0.1482769717638813
# 8.96614245097885e-05
# Calculating Statistical Features for Green Channel:
# 42.04383850097656
# 10.719535064863399
# 31.0
# 834.8764198606368
# 28.894228140939095
# 1.0457894393087652
# 0.845721439978643
# 6.236455121499131
# 19.61982230392157
# 0.07889955395007023
# 0.5063362975885269
# 0.9882661390203406
# 0.04868330464858924
# 0.0002993744452330343
# Calculating Statistical Features for Blue Channel:
# 130.84671020507812
# 9.708767293200287
# 136.0
# 1070.5196846118197
# 32.71879711437784
# -1.2696537459147796
# 1.7248500616049744
# 6.776427674438452
# 29.452879901960785
# 0.029501990259879443
# 0.27635901974807014
# 0.9862777189713748
# 0.03286945989042846
# 0.0004494149464310384
# Image number:  46
# Calculating Statistical features for Red Channel:
# 55.93592834472656
# 8.696366211143612
# 68.0
# 2378.826049241936
# 48.77321036431717
# 0.7780761564268242
# 0.12305278767419692
# 4.889442883615044
# 37.41056985294118
# 0.23643960806075634
# 0.8125873391741405
# 0.9920940343143294
# 0.026195750723989608
# 0.0005701090188633245
# Calculating Statistical Features for Green Channel:
# 36.65119934082031
# 9.304183216026155
# 17.0
# 1057.1558496968355
# 32.513933162520274
# 0.41375184142386773
# -1.5189713642371179
# 5.657056121164766
# 4.30998774509804
# 0.14532580266465717
# 0.6706512338268373
# 0.9979635640894162
# 0.19362351517800214
# 6.57622935518949e-05
# Calculating Statistical Features for Blue Channel:
# 114.44473266601562
# 9.706789955501993
# 118.0
# 552.6405612444505
# 23.50830834501816
# -0.5025327275658227
# -0.5052669173033806
# 6.420640776783782
# 8.363679534313725
# 0.0422325529793533
# 0.4110987657427645
# 0.9924442377867982
# 0.10727948160864283
# 0.00012761758075026605
# Image number:  47
# Calculating Statistical features for Red Channel:
# 110.42045593261719
# 8.960374703065488
# 125.0
# 680.4901327022817
# 26.086205793527768
# -0.35855504591508797
# -1.5479657879935664
# 5.331039936867836
# 2.598345588235294
# 0.17866919067724538
# 0.7604635473725532
# 0.9980952608723274
# 0.29242533027806034
# 3.9621038317267876e-05
# Calculating Statistical Features for Green Channel:
# 49.3880615234375
# 10.674498385005469
# 20.0
# 2031.4635134786367
# 45.07175960042648
# 1.1879164782794194
# 0.3440651049391197
# 6.096821578407067
# 21.98823529411765
# 0.14298619063712728
# 0.5738588300005755
# 0.9945978788042138
# 0.043772777240045406
# 0.0003354992337957432
# Calculating Statistical Features for Blue Channel:
# 153.32130432128906
# 10.46899705282183
# 160.0
# 1648.22441551066
# 40.59833020594147
# -1.168827183559653
# 1.1219460254512494
# 7.0530690071262345
# 28.4585631127451
# 0.03192490901672115
# 0.29529865976575903
# 0.9913922237831775
# 0.033982814926962986
# 0.00043382811493260703
# Image number:  48
# Calculating Statistical features for Red Channel:
# 81.54762268066406
# 10.239668686990607
# 71.0
# 2832.68370620138
# 53.222962208067486
# 0.35091730422648815
# -0.7675096633512979
# 6.5393412234157955
# 32.4069699754902
# 0.12112411699425778
# 0.6477957460100061
# 0.9942527458177298
# 0.03004279970084516
# 0.0004944085868548849
# Calculating Statistical Features for Green Channel:
# 64.36979675292969
# 10.521553080398007
# 52.0
# 3299.9432827101555
# 57.44513280261571
# 0.8548553332210891
# 0.051406463868857166
# 6.821006065755692
# 24.0280943627451
# 0.09944603054696413
# 0.4824009695751797
# 0.9963610032447783
# 0.04011448942895104
# 0.00036663862523185617
# Calculating Statistical Features for Blue Channel:
# 114.13859558105469
# 10.077442897217512
# 116.0
# 1874.338197881123
# 43.29362768215575
# -0.001948755689073602
# -0.8491489703271764
# 7.2533351894636215
# 15.587224264705883
# 0.033125907600657686
# 0.42339508298603284
# 0.9958410617283487
# 0.06040800159742844
# 0.0002378383831696435
# Image number:  49
# Calculating Statistical features for Red Channel:
# 115.55807495117188
# 11.012373467366862
# 119.0
# 1482.1739954641089
# 38.499012915451594
# 0.07392012561317267
# -1.7534473361900431
# 5.736908434675703
# 5.833746936274509
# 0.1349752264244664
# 0.7586206938052021
# 0.9980325438414241
# 0.1492810985825319
# 8.900169149594024e-05
# Calculating Statistical Features for Green Channel:
# 62.24085998535156
# 10.75140868427431
# 57.0
# 2095.5040744801518
# 45.77667609689624
# 0.7529475472901924
# -0.34422494457788666
# 6.7633539109174565
# 31.942999387254904
# 0.06328264241862128
# 0.43631238324419785
# 0.9923844684610396
# 0.030413887314191927
# 0.00048739841348580766
# Calculating Statistical Features for Blue Channel:
# 123.36619567871094
# 10.18779730801795
# 136.0
# 1750.6628215012606
# 41.840922808911145
# -0.8850791695968392
# -0.17612937881822832
# 7.020377395360671
# 33.95562193627451
# 0.03012101836440341
# 0.27503170510297953
# 0.9903242743689771
# 0.0286323738734751
# 0.0005181131697510847
# Image number:  50
# Calculating Statistical features for Red Channel:
# 111.55258178710938
# ...
# 0.0001318436402967862
# Image number:  282
# Calculating Statistical features for Red Channel:
# 111.17477416992188
# 10.758467776883936
# 136.0
# 1279.8985921731219
# 35.77567039446112
# -0.3394919071695738
# -1.742049946123463
# 5.403265478327625
# 6.28501838235294
# 0.1719049451715165
# 0.7282200875634669
# 0.9975484252969687
# 0.14058541436620905
# 9.589965780713565e-05
# Calculating Statistical Features for Green Channel:
# 44.053253173828125
# 10.614800078799913
# 33.0
# 755.4926780154929
# 27.486227060393226
# 1.7795068460083816
# 4.557628930877303
# 6.215952080561748
# 23.33489583333334
# 0.07910235151106274
# 0.49044519144413534
# 0.9845858677666813
# 0.04122726394209358
# 0.0003560383452309502
# Calculating Statistical Features for Blue Channel:
# 121.13703918457031
# 10.029183338269233
# 133.0
# 1371.4335060284939
# 37.032870615555765
# -0.8686964053339941
# -0.19607567111652235
# 6.954215225155465
# 38.04068627450981
# 0.027143501283159503
# 0.2592018840360801
# 0.9861534325258069
# 0.02563212487039905
# 0.00058023640302306
# Image number:  283
# Calculating Statistical features for Red Channel:
# 116.28587341308594
# 9.51723402729351
# 127.0
# 959.5288568360265
# 30.97626279647089
# -0.28864681754640703
# -1.3762101829928974
# 5.7448626959079006
# 3.298927696078432
# 0.14741618936786252
# 0.7759526191809152
# 0.9982840989086005
# 0.24087612388489926
# 5.033132710029693e-05
# Calculating Statistical Features for Green Channel:
# 59.73284912109375
# 10.422901291765678
# 29.0
# 2430.7212634645402
# 49.302345415451995
# 1.295741898241666
# 1.060346393346622
# 6.475928093141456
# 42.49578737745099
# 0.08670716892883013
# 0.5010676669608503
# 0.9912737858028013
# 0.023036654893316032
# 0.0006483991092600154
# Calculating Statistical Features for Blue Channel:
# 129.3392333984375
# 10.092741641293046
# 139.0
# 1652.2144189924002
# 40.64744049743354
# -0.9621959039941744
# 0.13141352373961457
# 7.00306112580175
# 37.0016237745098
# 0.02866134436406427
# 0.2964946837930367
# 0.988825079704988
# 0.026334526884479424
# 0.000564269293192738
# Image number:  284
# Calculating Statistical features for Red Channel:
# 70.851806640625
# 9.831048042565675
# 88.0
# 3227.6749076247215
# 56.812629824931726
# 0.3516711695535165
# -0.9743192858410081
# 5.5260032644251
# 23.094117647058823
# 0.18259739408443082
# 0.7858067995692724
# 0.9964241639383017
# 0.04182084574382545
# 0.0003509611681372969
# Calculating Statistical Features for Green Channel:
# 40.92243957519531
# 10.159256616264656
# 23.0
# 1244.5683404596057
# 35.27844016477494
# 0.8133879898399667
# -0.6762798672458836
# 6.106438804920239
# 8.726807598039215
# 0.13017958520588288
# 0.6551278249153702
# 0.9964989852892564
# 0.1042032679252259
# 0.00013315502849222378
# Calculating Statistical Features for Blue Channel:
# 162.4952850341797
# 10.617173846799536
# 159.0
# 539.9950034038629
# 23.237792567364547
# 0.5732311971327465
# 0.47157005012872233
# 6.443691636043458
# 10.338924632352942
# 0.05170625193456563
# 0.4901251348829256
# 0.9904567758880609
# 0.08859578740275366
# 0.000157720642257446
# Image number:  285
# Calculating Statistical features for Red Channel:
# 76.52066040039062
# 9.757382458998514
# 74.0
# 2887.357544339262
# 53.73413760673248
# 0.31281094193666376
# -0.6896508122910938
# 6.215835518038828
# 38.98733149509804
# 0.14016245610504013
# 0.680275274673965
# 0.9932458639063407
# 0.02509588570825285
# 0.0005926402164633882
# Calculating Statistical Features for Green Channel:
# 61.623260498046875
# 10.029649648433015
# 22.0
# 3649.573887660168
# 60.411703234225804
# 0.6624806201005188
# -0.9344335045652064
# 6.535646670455823
# 26.562117034313733
# 0.14645273130757605
# 0.5408231693288661
# 0.9963643279352489
# 0.036475497691673624
# 0.0004053043953892486
# Calculating Statistical Features for Blue Channel:
# 95.72610473632812
# 10.077934227845569
# 97.0
# 1062.7963803103194
# 32.600557975444524
# -0.16786479729341625
# -1.0007455262857967
# 6.9120910657982035
# 7.703952205882354
# 0.042092895683003895
# 0.5262081148525166
# 0.9963789391023702
# 0.11544865417318644
# 0.00011753507958197307
# Image number:  286
# Calculating Statistical features for Red Channel:
# 95.63395690917969
# 10.356005090316636
# 115.0
# 748.0689085738268
# 27.35084840683789
# -0.6129653977496721
# -1.3372592615138315
# 5.206886131494382
# 2.896767769607843
# 0.22683347041438368
# 0.7459092948234265
# 0.9980660672853103
# 0.2724844420838187
# 4.42009014985175e-05
# Calculating Statistical Features for Green Channel:
# 48.36796569824219
# 10.76379715637715
# 31.0
# 1467.8406296873
# 38.312408299235116
# 1.435459357700054
# 1.7923337493585274
# 6.510925862099567
# 16.72541360294118
# 0.09802192086653866
# 0.5890842513776519
# 0.9943139946307847
# 0.05672989050427146
# 0.0002552071446570776
# Calculating Statistical Features for Blue Channel:
# 138.4476776123047
# 10.26378095951784
# 147.0
# 2235.7693570943084
# 47.283922818377796
# -0.7031878956539828
# -0.3377788260059189
# 7.284143675572886
# 21.011596200980396
# 0.0311674858579328
# 0.38579870877670486
# 0.9953099871423393
# 0.0454950179980795
# 0.00032058958068378315
# Image number:  287
# Calculating Statistical features for Red Channel:
# 89.6820068359375
# 10.712685340159377
# 79.0
# 402.98912082612514
# 20.074588932930236
# 0.6220366548363943
# -1.350775007834113
# 5.074939468271114
# 1.5953125
# 0.16770177367586528
# 0.782649828315518
# 0.9980136650123815
# 0.4119276575755581
# 2.4339013354496886e-05
# Calculating Statistical Features for Green Channel:
# 100.37142944335938
# 10.23377413551035
# 111.0
# 2216.6930033033714
# 47.08176933063764
# -0.2207594974570857
# -0.781639416593551
# 7.039458009813905
# 19.678232230392155
# 0.05742834321577703
# 0.4179041337835672
# 0.9955630614203548
# 0.048494714632433794
# 0.00029985474441551405
# Calculating Statistical Features for Blue Channel:
# 114.05891418457031
# 10.205652832202619
# 119.0
# 1347.3756947682705
# 36.70661649850433
# -0.4450223992157056
# -0.6281107918113493
# 7.094113418622004
# 10.89532781862745
# 0.030977681283515184
# 0.4015007817448263
# 0.9959950510211544
# 0.08428611667927978
# 0.00016399852510059007
# Image number:  288
# Calculating Statistical features for Red Channel:
# 109.96815490722656
# 9.14563914956749
# 119.0
# 288.19059050432406
# 16.976177146352004
# -0.9651745527539338
# -0.1858294114638337
# 4.647171980697537
# 4.582138480392157
# 0.28014529392579823
# 0.8070509918684892
# 0.9920683992261307
# 0.18860831480367748
# 6.991726487748948e-05
# Calculating Statistical Features for Green Channel:
# 57.623016357421875
# 10.366607580803617
# 25.0
# 3345.960788606666
# 57.844280517668004
# 1.275772638869302
# 0.2493037147540993
# 5.957184822418428
# 29.01896446078432
# 0.14169420538477567
# 0.6090406717559969
# 0.9956737122318808
# 0.03347025988156585
# 0.00044278755663725467
# Calculating Statistical Features for Blue Channel:
# 135.41575622558594
# 10.659890009042439
# 152.0
# 1896.0030958575662
# 43.543117663501846
# -1.6087306391504166
# 1.3080311115768044
# 6.450219606850617
# 23.443137254901963
# 0.04983194010382785
# 0.41759263408140823
# 0.9938355128407127
# 0.04099485441168781
# 0.0003576578496626275
# Image number:  289
# Calculating Statistical features for Red Channel:
# 85.74772644042969
# 10.581664987662991
# 86.0
# 102.58420045836829
# 10.128385876257296
# -0.9929926506611136
# 2.5785030393382575
# 4.843184802525233
# 2.0585171568627456
# 0.17457050982923458
# 0.8203105517391653
# 0.9899805019084293
# 0.3467470526989885
# 3.1392448673061297e-05
# Calculating Statistical Features for Green Channel:
# 78.30712890625
# 9.927388354989507
# 30.0
# 6208.570039510727
# 78.79447975277664
# 0.7543266079629062
# -1.0011651632944494
# 7.037945193031425
# 25.825229779411764
# 0.10112012443104974
# 0.5302876484849964
# 0.9979230708680835
# 0.03741939443111156
# 0.00039405618362438105
# Calculating Statistical Features for Blue Channel:
# 109.51905822753906
# 9.857910047415206
# 110.0
# 959.2503692058381
# 30.9717672922589
# -0.639559415218262
# 0.5058498230557724
# 6.723104090742161
# 9.760738357843136
# 0.05154872231694372
# 0.5107578993296424
# 0.9949277824424495
# 0.09337774696627317
# 0.00014892186767212913
# Image number:  290
# Calculating Statistical features for Red Channel:
# 126.36698913574219
# 10.392232165414839
# 148.0
# 1573.0505148970988
# 39.661700857339675
# -0.9218718067186462
# -0.994778815812063
# 5.304957445185767
# 7.457643995098039
# 0.19892284775515498
# 0.7790490334220027
# 0.9976347437457461
# 0.1210841221248564
# 0.00011377961302490498
# Calculating Statistical Features for Green Channel:
# 45.962860107421875
# 10.285912103113109
# 31.0
# 1256.7896972885355
# 35.45122984169288
# 2.4209177705903473
# 6.393036768143519
# 5.620335065808395
# 32.2303768382353
# 0.14456974114549953
# 0.6164872282774834
# 0.9872152393245645
# 0.03022444025819032
# 0.0004917864276290294
# Calculating Statistical Features for Blue Channel:
# 143.03778076171875
# 10.657230813091909
# 152.0
# 1058.148749615997
# 32.52919841643807
# -1.6320290461494669
# 2.5106276694793888
# 6.571621161463144
# 28.39810049019608
# 0.046144913514933085
# 0.3938494133492821
# 0.986612710737433
# 0.03406928023543537
# 0.0004331218910871539
# Image number:  291
# Calculating Statistical features for Red Channel:
# 87.1212158203125
# 10.79163336042962
# 79.0
# 542.9468545764685
# 23.301220023347888
# -0.28850602623472493
# 0.6337566901799998
# 5.70860252889026
# 9.48359375
# 0.12203292638037117
# 0.6861076919690083
# 0.9912343779368659
# 0.09651055637490988
# 0.0001446305677654227
# Calculating Statistical Features for Green Channel:
# 95.08419799804688
# 10.260184833728173
# 92.0
# 5144.708090140484
# 71.7266205124742
# 0.3845929757626382
# -1.1777161155898994
# 7.3184016867522965
# 47.848728553921575
# 0.069234780121776
# 0.3708087990883102
# 0.9953477621610118
# 0.020500417750073392
# 0.0007300895438427501
# Calculating Statistical Features for Blue Channel:
# 119.08822631835938
# 10.453990586826311
# 132.0
# 1930.9599590366706
# 43.94268948342455
# -0.524856790647544
# -0.9608092551727205
# 7.150519976702185
# 31.5547181372549
# 0.029912474796922897
# 0.32765029596169604
# 0.9918339017506566
# 0.030745764029399207
# 0.0004807702700153813
# Image number:  292
# Calculating Statistical features for Red Channel:
# 100.60397338867188
# 11.127301267427505
# 109.0
# 331.41518440749496
# 18.20481212227951
# -0.5136863379864086
# -0.8699802488136328
# 5.31886030966262
# 3.828523284313725
# 0.19329203883302562
# 0.7239848364250455
# 0.9942129692367984
# 0.21573896684766034
# 5.8418443080600715e-05
# Calculating Statistical Features for Green Channel:
# 84.88772583007812
# 10.64120145740279
# 61.0
# 5350.652921854518
# 73.14815733738287
# 0.5181754883678464
# -1.2476568087648665
# 6.9001180297005105
# 61.97564338235294
# 0.10687735564555355
# 0.4769852058201479
# 0.9942131632554833
# 0.015906149638362368
# 0.0009456732160899098
# Calculating Statistical Features for Blue Channel:
# 127.22761535644531
# 10.543806700675566
# 141.0
# 2419.200281703612
# 49.18536654029948
# -0.5924819745914434
# -0.7806589298850941
# 7.338157932698489
# 34.06205575980392
# 0.03318768528693921
# 0.3857584404335998
# 0.9929765206554569
# 0.02854788221739561
# 0.0005197200638817473
# Image number:  293
# Calculating Statistical features for Red Channel:
# 65.21784973144531
# 8.813229794415875
# 76.0
# 3141.4222833157983
# 56.048392334801164
# 0.13247015310378724
# -1.3340864682140907
# 5.170336268126616
# 38.773360906862735
# 0.34546042130527643
# 0.6507481347039659
# 0.9938287135418236
# 0.02536275043015041
# 0.0005902992646642795
# Calculating Statistical Features for Green Channel:
# 33.45524597167969
# 6.425379926677366
# 2.0
# 3388.1453054265585
# 58.20777701842391
# 1.814241379491037
# 2.160944402320361
# 4.952042089634329
# 52.72571997549021
# 0.3739049508960967
# 0.6531898120124161
# 0.9922400089260824
# 0.018743504781215413
# 0.0008045296523625497
# Calculating Statistical Features for Blue Channel:
# 239.24169921875
# 5.858020676815677
# 254.0
# 1686.7882611751556
# 41.070527890144724
# -3.5063103442788726
# 11.907838949439935
# 4.018492149949158
# 38.134957107843135
# 0.42140103663167217
# 0.698078002672015
# 0.9887343091658809
# 0.025830745131254666
# 0.0005818928177054916
# Image number:  294
# Calculating Statistical features for Red Channel:
# 128.3656005859375
# 11.140797574925628
# 167.0
# 2628.561831817031
# 51.26950196575963
# -0.5058969682778969
# -1.0653650414570468
# 5.337070687526813
# 28.058226102941184
# 0.17946501362353534
# 0.7573461839164541
# 0.9946628099367124
# 0.03462752425241342
# 0.0004276907567424655
# Calculating Statistical Features for Green Channel:
# 64.88583374023438
# 10.775114309319704
# 41.0
# 2214.7324494635686
# 47.060943992482436
# 1.0039102884028266
# -0.13788275195276833
# 6.7306918132452305
# 40.28759191176471
# 0.07313842060223148
# 0.517806622945265
# 0.9909237849440208
# 0.024263332770248374
# 0.0006147312643475507
# Calculating Statistical Features for Blue Channel:
# 141.96481323242188
# 10.13188784813509
# 145.0
# 1296.6430490007624
# 36.00893012852176
# -1.0996125075146685
# 1.5578897794951212
# 6.90481882988928
# 39.07257965686276
# 0.03304214802781883
# 0.3515339989039548
# 0.984964442816268
# 0.024975313458087386
# 0.0005961141397017141
# Image number:  295
# Calculating Statistical features for Red Channel:
# 73.20353698730469
# 11.04616292900397
# 78.0
# 331.6895755024161
# 18.212346787342266
# -1.8884253776891478
# 6.840517433112186
# 4.984183605744416
# 6.9177236519607845
# 0.17967801473761263
# 0.7819323577396495
# 0.989542223326347
# 0.12923159759999217
# 0.0001054948042957875
# Calculating Statistical Features for Green Channel:
# 101.90243530273438
# 9.546545744117672
# 95.0
# 8486.088808766566
# 92.11996965244055
# 0.1983431675258022
# -1.6675092043230906
# 7.012404207918176
# 30.073636642156863
# 0.1110527613396633
# 0.49450945010164515
# 0.9982279665197527
# 0.032297046133140966
# 0.00045887265298178966
# Calculating Statistical Features for Blue Channel:
# 145.72824096679688
# 10.31721749342528
# 146.0
# 1203.2247615298256
# 34.68753034636259
# -0.2749464650456308
# -0.07424366442859043
# 7.062411074993737
# 13.20200674019608
# 0.03940114169233499
# 0.4567468448268515
# 0.9945347071750701
# 0.07060847617656234
# 0.00020094646189987704
# Image number:  296
# Calculating Statistical features for Red Channel:
# 112.4659423828125
# 8.44977225273243
# 128.0
# 713.8143613189459
# 26.71730452944207
# -0.5826342807060044
# -1.4131678358588702
# 5.132631041206812
# 3.831541053921568
# 0.18798029962510787
# 0.7990024861387901
# 0.9973215500435396
# 0.21535197942112605
# 5.844260109047829e-05
# Calculating Statistical Features for Green Channel:
# 43.589141845703125
# 9.66385250125516
# 20.0
# 1952.3689458211884
# 44.18561921961928
# 1.1284253155785793
# 0.21850798133702476
# 6.125808014145314
# 18.284083946078432
# 0.1466261202658973
# 0.6347116880123271
# 0.9953274156388919
# 0.05225354428482155
# 0.0002789910352455509
# Calculating Statistical Features for Blue Channel:
# 144.6519317626953
# 10.14234399552849
# 147.0
# 1682.6545290441718
# 41.02017222104475
# -0.6495874340289033
# 0.1586911077111406
# 7.240470225113081
# 19.903002450980388
# 0.02949862550425824
# 0.3799149145220608
# 0.9940971903681365
# 0.04790762530148384
# 0.00030354739879700186
# Image number:  297
# Calculating Statistical features for Red Channel:
# 103.26414489746094
# 9.32618557754229
# 107.0
# 1002.12302227295
# 31.656326733734442
# -0.13114176183986836
# -1.7256001446878104
# 5.754809655389783
# 2.828569240196078
# 0.1597921487580304
# 0.7340999785087106
# 0.9985887908215947
# 0.2725703892814133
# 4.315819792873421e-05
# Calculating Statistical Features for Green Channel:
# 62.48187255859375
# 10.779436838022749
# 59.0
# 1220.1063913665712
# 34.93002134792607
# 0.753106014376444
# -0.28585606650449114
# 6.62803759859703
# 11.651072303921568
# 0.0726023758299341
# 0.5456517094556143
# 0.9952301461603607
# 0.07950092544775172
# 0.00017773318501538104
# Calculating Statistical Features for Blue Channel:
# 122.87142944335938
# 9.834050901276964
# 120.0
# 525.7735086744651
# 22.92975160516278
# 0.20687531187725874
# 0.35739098604492714
# 6.493384421465881
# 7.631173406862747
# 0.04317606168086154
# 0.43194791868999866
# 0.992756932702603
# 0.11644158233945298
# 0.00011634620277856303
# Image number:  298
# Calculating Statistical features for Red Channel:
# 88.1917724609375
# 9.897894864763227
# 68.0
# 2516.113186702132
# 50.160873065589
# -0.05325066981923073
# -1.226921706427301
# 6.061567695547389
# 21.47781862745098
# 0.12669751261982268
# 0.6889367502039849
# 0.9957137133351466
# 0.04474048504602514
# 0.0003277242063232817
# Calculating Statistical Features for Green Channel:
# 50.43267822265625
# 10.20455758989427
# 41.0
# 1628.3967128954828
# 40.35339778625194
# 1.6813940880964344
# 3.645929870239959
# 6.578923489014599
# 66.66130514705885
# 0.10199364180212003
# 0.4838716104671921
# 0.9794467347379519
# 0.014801808628884427
# 0.0010171691479103375
# Calculating Statistical Features for Blue Channel:
# 101.97250366210938
# 9.652592728729351
# 112.0
# 3124.757605767809
# 55.89953135552935
# -0.5754199820413388
# -0.7952534423272319
# 7.0400334693545155
# 35.45955882352942
# 0.10179938290363665
# 0.40096636000776287
# 0.9942990701613209
# 0.027504445141429985
# 0.0005410697550349216
# Image number:  299

# %%
#change the specific channels to csv data
import pandas as pd
#Convert red channel
red_file = pd.read_excel('RedChannel30.xlsx')
red_file.to_csv('RedData30.csv')

#Convert green channel
green_file = pd.read_excel('GreenChannel30.xlsx')
green_file.to_csv('GreenData30.csv')

#Convert blue channel
blue_file = pd.read_excel('BlueChannel30.xlsx')
blue_file.to_csv('BlueData30.csv')

# %%
#change the main file which contains features of all the three channels into csv
file = pd.read_excel('Output30.xlsx')
file.to_csv('Output30.csv')

# %% [markdown]
# # SVM

# %% [markdown]
# ## Apply SVM on Red Channel

# %%
# #read the data
# redData = pd.read_csv('RedData.csv')
# labelled = pd.read_csv('Labels1.csv')

# #classify data into dependent and indepedent variables
# redX = redData.iloc[:, :]
# redY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# redx_train, redx_test, redy_train, redy_test = train_test_split(redX, redY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# redSVC = SVC()

# #fit the model
# redSVC.fit(redx_train, redy_train)
# pred_r = redSVC.predict(redx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(redy_test, pred_r))

# %% [markdown]
# ## Apply SVM on Green Channel

# %%
# #read the data
# greenData = pd.read_csv('GreenData.csv')

# #classify data into dependent and indepedent variables
# greenX = greenData.iloc[:, :]
# greenY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# greenx_train, greenx_test, greeny_train, greeny_test = train_test_split(greenX, greenY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# greenSVC = SVC()

# #fit the model
# greenSVC.fit(greenx_train, greeny_train)
# pred_g = greenSVC.predict(greenx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for green Channel is ", accuracy_score(greeny_test, pred_g))

# %% [markdown]
# ## Apply SVM on Blue Channel

# %%
# #read the data
# blueData = pd.read_csv('BlueData.csv')

# #classify data into dependent and indepedent variables
# blueX = blueData.iloc[:, :]
# blueY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# bluex_train, bluex_test, bluey_train, bluey_test = train_test_split(blueX, blueY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# blueSVC = SVC()

# #fit the model
# blueSVC.fit(bluex_train, bluey_train)
# pred_b = blueSVC.predict(bluex_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(bluey_test, pred_b))

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Apply Random Forest on red channel

# %%
# #read the data
# RedData = pd.read_csv('RedData.csv')
# labelled = pd.read_csv('Labels1.csv')

# #classify data into dependent and indepedent variables
# RedX = RedData.iloc[:, :]
# RedY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Redx_train, Redx_test, Redy_train, Redy_test = train_test_split(RedX, RedY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# RedRF = RandomForestClassifier()

# #fit the model
# RedRF.fit(Redx_train, Redy_train)
# pred_R = RedRF.predict(Redx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(Redy_test, pred_R))

# %% [markdown]
# ## Apply Random Forest on green channel

# %%
# #read the data
# GreenData = pd.read_csv('GreenData.csv')

# #classify data into dependent and indepedent variables
# GreenX = GreenData.iloc[:, :]
# GreenY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Greenx_train, Greenx_test, Greeny_train, Greeny_test = train_test_split(GreenX, GreenY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# GreenRF = RandomForestClassifier()

# #fit the model
# GreenRF.fit(Greenx_train, Greeny_train)
# pred_G = GreenRF.predict(Greenx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for green Channel is ", accuracy_score(Greeny_test, pred_G))

# %% [markdown]
# ## Apply Random Forest on blue channel

# %%
# #read the data
# BlueData = pd.read_csv('BlueData.csv')

# #classify data into dependent and indepedent variables
# BlueX = BlueData.iloc[:, :]
# BlueY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Bluex_train, Bluex_test, Bluey_train, Bluey_test = train_test_split(BlueX, BlueY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# BlueRF = RandomForestClassifier()

# #fit the model
# BlueRF.fit(Bluex_train, Bluey_train)
# pred_B = BlueRF.predict(Bluex_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(Bluey_test, pred_B))
