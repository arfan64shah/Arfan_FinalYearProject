# %%
#import the required libraries
import skimage.feature as skf
import openpyxl
import numpy as np
import math
from PIL import Image
from numpy import asarray
from scipy.stats import skew, kurtosis
import skimage.feature
import xlsxwriter
import os


#creates general file for features of all the three channels
outWorkbook = xlsxwriter.Workbook("Output50.xlsx")
outSheet = outWorkbook.add_worksheet()

#Writes headers for general file 
outSheet.write("A1", "Mean_R")
outSheet.write("B1", "RMS_R")
outSheet.write("C1", "Median_R")
outSheet.write("D1", "Variance_R")
outSheet.write("E1", "Std_R")
outSheet.write("F1", "Skewness_R")
outSheet.write("G1", "Kurtosis_R")
outSheet.write("H1", "Contrast_R")
outSheet.write("I1", "Entropy_R")
outSheet.write("J1", "Energy_R")
outSheet.write("K1", "Homogeneity_R")
outSheet.write("L1", "Correlation_R")
outSheet.write("M1", "IDM_R")
outSheet.write("N1", "Smoothness_R")
outSheet.write("O1", "Mean_G")
outSheet.write("P1", "RMS_G")
outSheet.write("Q1", "Median_G")
outSheet.write("R1", "Variance_G")
outSheet.write("S1", "Std_G")
outSheet.write("T1", "Skewness_G")
outSheet.write("U1", "Kurtosis_G")
outSheet.write("V1", "Contrast_G")
outSheet.write("W1", "Entropy_G")
outSheet.write("X1", "Energy_G")
outSheet.write("Y1", "Homogeneity_G")
outSheet.write("Z1", "Correlation_G")
outSheet.write("AA1", "IDM_G")
outSheet.write("AB1", "Smoothness_G")
outSheet.write("AC1", "Mean_B")
outSheet.write("AD1", "RMS_B")
outSheet.write("AE1", "Median_B")
outSheet.write("AF1", "Variance_B")
outSheet.write("AG1", "Std_B")
outSheet.write("AH1", "Skewness_B")
outSheet.write("AI1", "Kurtosis_B")
outSheet.write("AJ1", "Contrast_B")
outSheet.write("AK1", "Entropy_B")
outSheet.write("AL1", "Energy_B")
outSheet.write("AM1", "Homogeneity_B")
outSheet.write("AN1", "Correlation_B")
outSheet.write("AO1", "IDM_B")
outSheet.write("AP1", "Smoothness_B")
outWorkbook.close()

# %%
#creates a file for red channel
outWorkbookR = xlsxwriter.Workbook("RedChannel50.xlsx")
outSheetR = outWorkbookR.add_worksheet()

#writes headers for red file
outSheetR.write("A1", "Mean_R")
outSheetR.write("B1", "RMS_R")
outSheetR.write("C1", "Median_R")
outSheetR.write("D1", "Variance_R")
outSheetR.write("E1", "Std_R")
outSheetR.write("F1", "Skewness_R")
outSheetR.write("G1", "Kurtosis_R")
outSheetR.write("H1", "Contrast_R")
outSheetR.write("I1", "Entropy_R")
outSheetR.write("J1", "Energy_R")
outSheetR.write("K1", "Homogeneity_R")
outSheetR.write("L1", "Correlation_R")
outSheetR.write("M1", "IDM_R")
outSheetR.write("N1", "Smoothness_R")
outWorkbookR.close()

# %%
#creates file for green channel
outWorkbookG = xlsxwriter.Workbook("GreenChannel50.xlsx")
outSheetG = outWorkbookG.add_worksheet()

#writes headers for green file
outSheetG.write("A1", "Mean_G")
outSheetG.write("B1", "RMS_G")
outSheetG.write("C1", "Median_G")
outSheetG.write("D1", "Variance_G")
outSheetG.write("E1", "Std_G")
outSheetG.write("F1", "Skewness_G")
outSheetG.write("G1", "Kurtosis_G")
outSheetG.write("H1", "Contrast_G")
outSheetG.write("I1", "Entropy_G")
outSheetG.write("J1", "Energy_G")
outSheetG.write("K1", "Homogeneity_G")
outSheetG.write("L1", "Correlation_G")
outSheetG.write("M1", "IDM_G")
outSheetG.write("N1", "Smoothness_G")
outWorkbookG.close()

# %%
#creates a file for blue channel
outWorkbookB = xlsxwriter.Workbook("BlueChannel50.xlsx")
outSheetB = outWorkbookB.add_worksheet()

#writes headers for blue file
outSheetB.write("A1", "Mean_B")
outSheetB.write("B1", "RMS_B")
outSheetB.write("C1", "Median_B")
outSheetB.write("D1", "Variance_B")
outSheetB.write("E1", "Std_B")
outSheetB.write("F1", "Skewness_B")
outSheetB.write("G1", "Kurtosis_B")
outSheetB.write("H1", "Contrast_B")
outSheetB.write("I1", "Entropy_B")
outSheetB.write("J1", "Energy_B")
outSheetB.write("K1", "Homogeneity_B")
outSheetB.write("L1", "Correlation_B")
outSheetB.write("M1", "IDM_B")
outSheetB.write("N1", "Smoothness_B")
outWorkbookB.close()

# %%
#import required libaray to read and make a list of all the needy images
import glob

#declare an empty list
Image_list = []

#using for loop to append to the list declared above
for filename in glob.glob('/home/uca/Desktop/Undergrad/Arfan_FinalYearProject/data100/*.*'):
    im = Image.open(filename)
    
    #append each image to the list declared above
    Image_list.append(im)
    
#prints number of images used
print(len(Image_list))
# Out:
# 1000

# %%
#uses for loop to read each image and array of each image
for i in range(0, len(Image_list)):
    Image = Image_list[i]
    image = asarray(Image)
    
    #Apply image enhancement 
#     #apply image inverse
#     # Invert the colors
#     image = 255 - image

    # Apply contrast stretching for image enhancement
    min_val = np.min(image)
    max_val = np.max(image)
    image = (image - min_val) / (max_val - min_val)
    
    
    
    #Here i am extracting the single channel like red, green, and blue from the whole image array
    R = image[:, :, 0]
    G = image[:, :, 1]
    B = image[:, :, 2]


    #selecting features from Red Channel
    print("Calculating Statistical features for Red Channel: ")
    
    #calculates mean
    Mean_R = np.mean(R);
    print(Mean_R)
    
    #calculating root mean square
    RMS_R = np.sqrt(np.mean(R**2))
    print(RMS_R)
    
    #calculating median
    Median_R = np.median(R)
    print(Median_R)
    
    #calculating variance of the pixels
    Variance_R = np.var(R)
    print(Variance_R)
    
    #calculating standard deviation
    Std_R = math.sqrt(Variance_R)
    print(Std_R)
    
    #calculates skewness
    Skewness_R = skew(R.reshape(-1))
    print(Skewness_R)
    
    #calculates kurtosis
    Kurtosis_R = kurtosis(R.reshape(-1))
    print(Kurtosis_R)
    
    #calculates entropy
    Entropy_R = skimage.measure.shannon_entropy(R)
    print(Entropy_R)
    
    #returns an image array where lowest pixel value is 0 and highest 8 instead of 0 and 255
    R = skimage.img_as_ubyte(R)
    
    #calculates contrast
    g1 = skf.graycomatrix(R, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_R = skf.graycoprops(g1, 'contrast')[0][0]
    print(Contrast_R)
    
    #calculates energy
    Energy_R = skf.graycoprops(g1, 'energy')[0][0]
    print(Energy_R)
    
    #calculating homogeniety
    Homogeneity_R = skf.graycoprops(g1, 'homogeneity')[0][0]
    print(Homogeneity_R)
    
    #finding correlation
    Correlation_R = skf.graycoprops(g1, 'correlation')[0][0]
    print(Correlation_R)
    
    #glcm_R = skf.graycomatrix(R, distances=[1], angles=[0], levels=256, symmetric= False, normed=True)
    
    #calculate inverse difference moment (IDM)
    IDM_R = 1 / (1 + Contrast_R - Energy_R)
    print(IDM_R)
    
    #calculates smoothness
    diff_R = np.diff(R.astype(float))
    variance_R = np.var(diff_R)
    Smoothness_R = variance_R / (R.shape[0] * R.shape[1])
    print(Smoothness_R)
    

    #selecting features from Green Channel
    print("Calculating Statistical Features for Green Channel: ")
    
    #calculates mean
    Mean_G = np.mean(G);
    print(Mean_G)
    
    #calculates root mean square
    RMS_G = np.sqrt(np.mean(G**2))
    print(RMS_G)
    
    #calculates median
    Median_G = np.median(G)
    print(Median_G)
    
    #claculates variance
    Variance_G = np.var(G)
    print(Variance_G)
    
    #calculates standard deviation
    Std_G = math.sqrt(Variance_G)
    print(Std_G)
    
    #calculates skewness
    Skewness_G = skew(G.reshape(-1))
    print(Skewness_G)
    
    #calculates kurtosis
    Kurtosis_G = kurtosis(G.reshape(-1))
    print(Kurtosis_G)
    
    #calculates entropy
    Entropy_G = skimage.measure.shannon_entropy(G)
    print(Entropy_G)
    
    #converts images pixels to range of 0 to 8 instead of 0 to 255
    G = skimage.img_as_ubyte(G)
    
    #calculates contrast
    g2 = skf.graycomatrix(G, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_G = skf.graycoprops(g2, 'contrast')[0][0]
    print(Contrast_G)
    
    #calculates energy
    Energy_G = skf.graycoprops(g2, 'energy')[0][0]
    print(Energy_G)
    
    #calculates homogeniety
    Homogeneity_G = skf.graycoprops(g2, 'homogeneity')[0][0]
    print(Homogeneity_G)
    
    #calculates correlation
    Correlation_G = skf.graycoprops(g2, 'correlation')[0][0]
    print(Correlation_G)
    #glcm_G = skf.graycomatrix(G, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
    
    #calculates inverse difference moment (IDM)
    IDM_G = 1 / (1 + Contrast_G - Energy_G)
    print(IDM_G)
    
    #calculates smoothness
    diff_G = np.diff(G.astype(float))
    variance_G = np.var(diff_G)
    Smoothness_G = variance_G / (G.shape[0] * G.shape[1])
    print(Smoothness_G)

    #selecting features from Blue Channel
    print("Calculating Statistical Features for Blue Channel: ")
    
    #calculates mean
    Mean_B = np.mean(B);
    print(Mean_B)
    
    #calculates root mean square
    RMS_B = np.sqrt(np.mean(B**2))
    print(RMS_B)
    
    #calculates median
    Median_B = np.median(B)
    print(Median_B)
    
    #calculates variance
    Variance_B = np.var(B)
    print(Variance_B)
    
    #calculates standard deviation
    Std_B = math.sqrt(Variance_B)
    print(Std_B)
    
    #calculates skewness
    Skewness_B = skew(B.reshape(-1))
    print(Skewness_B)
    
    #calculates kurtosis
    Kurtosis_B = kurtosis(B.reshape(-1))
    print(Kurtosis_B)
    
    #calculates entropy
    Entropy_B = skimage.measure.shannon_entropy(B)
    print(Entropy_B)
    
    #converts range of pixels values from 0-255 to 0-8
    B = skimage.img_as_ubyte(B)
    
    #calculates contrast
    g3 = skf.graycomatrix(B, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_B = skf.graycoprops(g3, 'contrast')[0][0]
    print(Contrast_B)
    
    #calculates energy
    Energy_B = skf.graycoprops(g3, 'energy')[0][0]
    print(Energy_B)
    
    #calculates homogeniety
    Homogeneity_B = skf.graycoprops(g3, 'homogeneity')[0][0]
    print(Homogeneity_B)
    
    #calculates correlation
    Correlation_B = skf.graycoprops(g3, 'correlation')[0][0]
    print(Correlation_B)
    
    #glcm_B = skf.graycomatrix(B, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
    
    #calculates inverse difference moment (IDM)
    IDM_B = 1 / (1 + Contrast_B - Energy_B)
    print(IDM_B)
    
    #calculates smoothness
    diff_B = np.diff(B.astype(float))
    variance_B = np.var(diff_B)
    Smoothness_B = variance_B / (B.shape[0] * B.shape[1])
    print(Smoothness_B)
    
    #count the number of images
    print("Image number: ", i)


    #Declares data for all the three channels
    values_R = [Mean_R, RMS_R, Median_R, Variance_R, Std_R, Skewness_R, Kurtosis_R, Entropy_R, Contrast_R, Energy_R, Homogeneity_R, Correlation_R, IDM_R, Smoothness_R]
    values_G = [Mean_G, RMS_G, Median_G, Variance_G, Std_G, Skewness_G, Kurtosis_G, Entropy_G, Contrast_G, Energy_G, Homogeneity_G, Correlation_G, IDM_G, Smoothness_G]
    values_B = [Mean_B, RMS_B, Median_B, Variance_B, Std_B, Skewness_B, Kurtosis_B, Entropy_B, Contrast_B, Energy_B, Homogeneity_B, Correlation_B, IDM_B, Smoothness_B]

    #Writes red channels into a file
    outWorkbookR = openpyxl.load_workbook("RedChannel50.xlsx")
    outSheetR = outWorkbookR.active
    outSheetR.append(values_R)
    outWorkbookR.save(filename="RedChannel50.xlsx")

    #Writes green channels into a file
    outWorkbookG = openpyxl.load_workbook("GreenChannel50.xlsx")
    outSheetG = outWorkbookG.active
    outSheetG.append(values_G)
    outWorkbookG.save(filename="GreenChannel50.xlsx")

    #writes blue chanels into a file
    outWorkbookB = openpyxl.load_workbook("BlueChannel50.xlsx")
    outSheetB = outWorkbookB.active
    outSheetB.append(values_B)
    outWorkbookB.save(filename="BlueChannel50.xlsx")
    
    #creates a general fle where all the three channels data will be merged
    outWorkbook = xlsxwriter.Workbook("Output50.xlsx")
    outSheet = outWorkbook.add_worksheet()
        
    #declares data for general file
    values = [Mean_R, RMS_R, Median_R, Variance_R, Std_R, Skewness_R, Kurtosis_R, Entropy_R, Contrast_R, Energy_R, Homogeneity_R, Correlation_R, IDM_R, Smoothness_R, Mean_G, RMS_G, Median_R, Variance_G, Std_G, Skewness_G, Kurtosis_G, Entropy_G, Contrast_G, Energy_G, Homogeneity_G, Correlation_G, IDM_G, Smoothness_G, Mean_B, RMS_B, Median_R, Variance_B, Std_B, Skewness_B, Kurtosis_B, Entropy_B, Contrast_B, Energy_B, Homogeneity_B, Correlation_B, IDM_B, Smoothness_B]
    
     
    #writes into the general file
    outWorkbook = openpyxl.load_workbook("Output50.xlsx") 
    outSheet = outWorkbook.active
    outSheet.append(values)
    
    #here the general file is being saved
    outWorkbook.save(filename="Output50.xlsx")
# Out:
# Calculating Statistical features for Red Channel:
# 0.4992721258425245
# 0.5304981197321795
# 0.5215686274509804
# 0.03215559939606426
# 0.17931982432532176
# -0.48476316667423575
# -0.3225124933960033
# 7.417659776493037
# 956.4500612745098
# 0.010660267953311918
# 0.0711359202318431
# 0.7716908822398524
# 0.001044452525087958
# 0.01459419043554922
# Calculating Statistical Features for Green Channel:
# 0.4872301887063418
# 0.5126856632901552
# 0.49411764705882355
# 0.02545333255644886
# 0.15954100587763906
# -0.4382639617819483
# 0.11094074881015104
# 7.275191922647461
# 956.2337316176473
# 0.011504238221473886
# 0.07112833553528213
# 0.711631439318335
# 0.0010446894894382951
# 0.014590891316355492
# Calculating Statistical Features for Blue Channel:
# 0.42636192172181375
# 0.4723326053641115
# 0.4588235294117647
# 0.04131360179573148
# 0.20325747660475244
# -0.40719645953774497
# -0.6966632360023031
# 7.517716835038574
# 946.3697150735296
# 0.011526511379204168
# 0.07531527594593222
# 0.824158409264919
# 0.0010555669566943275
# 0.014440407656539218
# Image number:  0
# Calculating Statistical features for Red Channel:
# 0.4508624052881596
# 0.4933405370632094
# 0.4824120603015075
# 0.04010797700759124
# 0.20026976059203558
# -0.025097688595199983
# -1.3556514662739156
# 7.058108129129907
# 360.687224264706
# 0.015127452916317084
# 0.09371470521972974
# 0.930788702288254
# 0.0027649354451592914
# 0.005503650256036933
# Calculating Statistical Features for Green Channel:
# 0.4765053753876806
# 0.49745256520435177
# 0.4723618090452261
# 0.02040168185503547
# 0.1428344561197874
# 0.13765461801260923
# -0.7293918775733568
# 6.8207370433311425
# 359.7607077205883
# 0.015967771625763006
# 0.09380142501667026
# 0.8642586484555048
# 0.002772043190820961
# 0.005489512355031388
# Calculating Statistical Features for Blue Channel:
# 0.4227778755839745
# 0.4617011478824393
# 0.4120603015075377
# 0.03442681787266342
# 0.18554465196459696
# 0.16349030962503988
# -1.1629549313848129
# 7.040837608382264
# 359.9334405637255
# 0.015140493071198635
# 0.09400789983477724
# 0.9194774814990772
# 0.0027707101574074725
# 0.005492148205909344
# Image number:  1
# Calculating Statistical features for Red Channel:
# 0.49071104760263473
# 0.5293869090288147
# 0.5529411764705883
# 0.039453167211807194
# 0.19862821353424895
# -0.5614032665882043
# -0.7932538260157216
# 7.469794651927234
# 604.1757506127451
# 0.010409275059139531
# 0.05857716222051744
# 0.8824085370672154
# 0.0016524409639678851
# 0.009218816135256984
# Calculating Statistical Features for Green Channel:
# 0.4911390715954351
# 0.5160929335296878
# 0.5254901960784314
# 0.025134328391652888
# 0.15853809760323506
# -0.860166976638511
# 0.29838334603943606
# 7.208611606191483
# 603.4486979166666
# 0.011382410237448891
# 0.059158114618648505
# 0.8156917343951885
# 0.0016544312773974716
# 0.009207675462840743
# Calculating Statistical Features for Blue Channel:
# 0.43775485169653794
# 0.4858344495489334
# 0.5058823529411764
# 0.04440580218465714
# 0.21072684258218538
# -0.4675732178289011
# -1.0053136756368968
# 7.497502752341811
# 601.1331648284314
# 0.010352037831253701
# 0.060593269972382215
# 0.8960326265115697
# 0.0016607907535763295
# 0.009172328596774264
# Image number:  2
# Calculating Statistical features for Red Channel:
# 0.4561212876263787
# 0.516173919523113
# 0.47058823529411764
# 0.05838888616990749
# 0.2416379236997113
# -0.11125537124160517
# -1.4227842955033578
# 7.603757318671866
# 787.8419577205883
# 0.011805087329860318
# 0.10143454545362665
# 0.8962647337014669
# 0.0012677000196579938
# 0.012020762146105765
# Calculating Statistical Features for Green Channel:
# 0.4316807765586703
# 0.4805014847892947
# 0.4627450980392157
# 0.04453338403442015
# 0.2110293440126755
# -0.2126525512710738
# -1.3102898227634245
# 7.457242727040662
# 788.9705575980392
# 0.012744398371160913
# 0.1028998892705197
# 0.8638274612211922
# 0.0012658903846391124
# 0.012037706104583783
# Calculating Statistical Features for Blue Channel:
# 0.3407049440870098
# 0.4094684327359646
# 0.36470588235294116
# 0.05158453848191474
# 0.22712229851319035
# -0.06171110214656092
# -1.496490067211876
# 7.352011294602223
# 770.7106924019611
# 0.018812634175969112
# 0.11354577142657386
# 0.8851321684393416
# 0.0012958539881240123
# 0.011759225917233154
# Image number:  3
# Calculating Statistical features for Red Channel:
# 0.6667636646943934
# 0.680846645934454
# 0.7019607843137254
# 0.01897837072349827
# 0.1377620075474304
# -0.6419850674756359
# -0.4954256958560128
# 6.970347196401367
# 147.90214460784316
# 0.01823620672674856
# 0.14135477735657836
# 0.9401713445812443
# 0.006716642589109392
# 0.0022566013530137354
# Calculating Statistical Features for Green Channel:
# 0.6716646680644914
# 0.6789377392301049
# 0.6862745098039216
# 0.009823027424702634
# 0.09911118718238943
# -1.0055045887800607
# 1.5002615577328555
# 6.571435733079529
# 147.26420036764705
# 0.021358484896183662
# 0.14390499241711496
# 0.8849261271913297
# 0.006745688272698698
# 0.0022468518782822397
# Calculating Statistical Features for Blue Channel:
# 0.5630426743451287
# 0.6028437997761444
# 0.6470588235294118
# 0.04640359379482548
# 0.21541493401067968
# -0.33640746253251463
# -1.4156063431436205
# 7.252475762042471
# 151.6466911764706
# 0.017100460401903918
# 0.14065810639936563
# 0.9748933650447666
# 0.006551809484048632
# 0.0023137054011019456
# Image number:  4
# Calculating Statistical features for Red Channel:
# 0.6159060609106924
# 0.6473904214805313
# 0.6666666666666666
# 0.039774081958214344
# 0.19943440515170482
# -1.2037199456685241
# 1.0431600353160642
# 7.345088636981555
# 1067.719056372549
# 0.010839376786992072
# 0.05767878726506852
# 0.7940422794780245
# 0.0009357090963622353
# 0.016292092639212427
# Calculating Statistical Features for Green Channel:
# 0.562211519129136
# 0.5968740837673577
# 0.615686274509804
# 0.04017687963163183
# 0.200441711306883
# -1.1385767931315474
# 0.7398514174432598
# 7.3507718953443115
# 1074.5556832107845
# 0.010843078113204313
# 0.05851874868251846
# 0.7948042291400701
# 0.0009297613290364047
# 0.016396405890992904
# Calculating Statistical Features for Blue Channel:
# 0.5057438869102329
# 0.562805656233867
# 0.592156862745098
# 0.06097332754176323
# 0.24692777798733628
# -0.5364571671489076
# -0.8861651439849467
# 7.644661662212232
# 1066.7500612745098
# 0.010549297111949227
# 0.06156920809359892
# 0.86566166571678
# 0.0009365580169905413
# 0.016277299031575154
# Image number:  5
# Calculating Statistical features for Red Channel:
# 0.6185434977213542
# 0.6403072448400169
# 0.6588235294117647
# 0.02739730922124638
# 0.1655213255784474
# -1.3942088298059139
# 2.1227429967330496
# 7.15076877814121
# 714.3518535539215
# 0.01221721764170534
# 0.060753676698240444
# 0.7999527814838981
# 0.0013979373561929986
# 0.010900115471434239
# Calculating Statistical Features for Green Channel:
# 0.5921608719171262
# 0.6122384162388541
# 0.6274509803921569
# 0.024181380089009323
# 0.15550363368426257
# -1.6482720963382385
# 3.110604460524602
# 6.975579839388735
# 712.7889705882353
# 0.013316408038402209
# 0.06191342335374171
# 0.7739230493174183
# 0.0014010004321995885
# 0.010876261782286397
# Calculating Statistical Features for Blue Channel:
# 0.48618487189797793
# 0.5446329727416868
# 0.596078431372549
# 0.06024934533499367
# 0.2454574206150502
# -0.46790090211547314
# -1.2083293990467274
# 7.464481702081175
# 694.2475030637256
# 0.012677309590010977
# 0.06654762007685146
# 0.9115044516641776
# 0.0014383629285476015
# 0.010593327584199145
# Image number:  6
# Calculating Statistical features for Red Channel:
# 0.4411215222316232
# 0.4537757048029077
# 0.4331983805668016
# 0.011324192893431135
# 0.10641519108393846
# 0.255592805849859
# 0.6827896707363328
# 6.7353129320009835
# 738.2789675245099
# 0.013743498285883515
# 0.05686164472265155
# 0.4988140247115118
# 0.0013526944965079636
# 0.011265236595752966
# Calculating Statistical Features for Green Channel:
# 0.489756904632939
# 0.5027012293326468
# 0.5060728744939271
# 0.012846700336916659
# 0.11334328536316855
# -0.4563806344909565
# 0.37016392646693896
# 6.786366316402962
# 740.243443627451
# 0.013772493975813588
# 0.05748274981819982
# 0.5569578284988413
# 0.001349109512131129
# 0.011295212131825744
# Calculating Statistical Features for Blue Channel:
# 0.4154894747714765
# 0.4298782963680964
# 0.4008097165991903
# 0.012163846042459459
# 0.11028982746590665
# 0.5371301450570792
# 0.5642034157578855
# 6.759234468612
# 736.6860906862747
# 0.013573911763525128
# 0.05675134813111692
# 0.5342158717668792
# 0.001355615096482815
# 0.01124093194229701
# Image number:  7
# Calculating Statistical features for Red Channel:
# 0.4875112496170343
# 0.5225728381116326
# 0.5137254901960784
# 0.03541515262888423
# 0.18818914057108668
# -0.6196893198868245
# 0.009840469642348193
# 7.4241112564630845
# 609.1996783088235
# 0.01563268745914501
# 0.11962752406161159
# 0.8678692546850226
# 0.0016388497981484867
# 0.009294926473972563
# Calculating Statistical Features for Green Channel:
# 0.489027255189185
# 0.5219765403283438
# 0.5137254901960784
# 0.03331185233527892
# 0.1825153482183866
# -0.81741256441824
# 0.43017644607382755
# 7.3288142988021265
# 607.8077665441176
# 0.016516293777950126
# 0.1210138136049452
# 0.8598143851111889
# 0.0016425991661161233
# 0.00927361118313611
# Calculating Statistical Features for Blue Channel:
# 0.44130805520450367
# 0.4977764673960098
# 0.48627450980392156
# 0.05302861190486952
# 0.2302794213664554
# -0.31864032339141246
# -0.8609716998302832
# 7.679119878321088
# 598.9716911764707
# 0.015633272872382614
# 0.12489223326114758
# 0.9131534512719507
# 0.0016667887369856032
# 0.009138760637292857
# Image number:  8
# Calculating Statistical features for Red Channel:
# 0.5178623573452819
# 0.548470630312641
# 0.5529411764705883
# 0.03263861116033329
# 0.18066159293090853
# -0.8222052096036362
# 0.25771859455339463
# 7.3388203422754295
# 718.3319852941177
# 0.013826535772898385
# 0.1087976045689592
# 0.8310421058659546
# 0.0013902054158151044
# 0.01095995225066728
# Calculating Statistical Features for Green Channel:
# 0.5131141213809742
# 0.5447815260147932
# 0.5490196078431373
# 0.03350080952643761
# 0.18303226362157468
# -0.8387251914477304
# 0.3068053048129671
# 7.323963704326262
# 717.7804993872551
# 0.014076626757777854
# 0.11014136693714184
# 0.8354745259935995
# 0.0013912725585585868
# 0.010951370296796431
# Calculating Statistical Features for Blue Channel:
# 0.4732584635416667
# 0.5241110915779775
# 0.49019607843137253
# 0.050718863001240067
# 0.22520848785345562
# -0.4705186887633617
# -0.6783631286202856
# 7.582207829333987
# 714.5564644607842
# 0.013437326764975088
# 0.10924759201560069
# 0.8918039126724089
# 0.0013975399970080386
# 0.010902120887829287
# Image number:  9
# Calculating Statistical features for Red Channel:
# 0.48513578527113965
# 0.5257490021465775
# 0.5176470588235295
# 0.041055283107476505
# 0.2026210332307002
# -0.42947061259594266
# -0.5637380874867213
# 7.573019127401879
# 1177.598023897059
# 0.009606990219182222
# 0.06136241656808847
# 0.7798356255751926
# 0.0008484726183076377
# 0.017968204321879688
# Calculating Statistical Features for Green Channel:
# 0.47062090705422793
# 0.5112698461748638
# 0.49411764705882355
# 0.03991281745112467
# 0.19978192473575948
# -0.28341685630731617
# -0.32617596274865157
# 7.590285955825233
# 1177.4079810049022
# 0.009718289860458954
# 0.06211756780072534
# 0.7736284539452902
# 0.000848609533500151
# 0.017965264212922324
# Calculating Statistical Features for Blue Channel:
# 0.41295997769224874
# 0.4671600707749479
# 0.4666666666666667
# 0.047702588550871755
# 0.21840922267814553
# -0.49170136795017594
# -0.89787365075783
# 7.442126560070987
# 1153.1516084558825
# 0.018304022755799846
# 0.0729887433317664
# 0.8143499454200469
# 0.0008664510383323249
# 0.017595188305929866
# Image number:  10
# Calculating Statistical features for Red Channel:
# 0.8846544452742036
# 0.9148049206197093
# 1.0
# 0.054254555246624085
# 0.23292607249216238
# -2.199103174001611
# 3.6312980000480524
# 4.341056849904079
# 732.7565104166667
# 0.3791597326220915
# 0.4576209254126949
# 0.8964654718123252
# 0.0013635545181034945
# 0.011180975462167864
# Calculating Statistical Features for Green Channel:
# 0.9096174053117342
# 0.9319518394124515
# 0.9921568627450981
# 0.04113040693820036
# 0.20280632864435064
# -2.845811234959191
# 7.179461519431188
# 4.769044385846813
# 671.75859375
# 0.2540084963850475
# 0.4186445108326943
# 0.874829922055504
# 0.001486978709034199
# 0.010250216415667566
# Calculating Statistical Features for Blue Channel:
# 0.8401362998812806
# 0.8890093423407147
# 0.996078431372549
# 0.08450860839086108
# 0.29070364358029827
# -1.7397366827766882
# 1.59555269564241
# 4.493139362486465
# 727.6813419117645
# 0.37933299622202626
# 0.45582056236542784
# 0.9339768032226102
# 0.0013730567645817999
# 0.01110353439620931
# Image number:  11
# Calculating Statistical features for Red Channel:
# 0.5771201937806373
# 0.6110844223937405
# 0.6392156862745098
# 0.04035645322289112
# 0.20088915655876283
# -0.7629390682734948
# -0.3548785483173966
# 7.433579796193717
# 637.5305147058825
# 0.01288288371951729
# 0.09971266691273158
# 0.8788046574173664
# 0.0015661274648693106
# 0.009727907617967069
# Calculating Statistical Features for Green Channel:
# 0.5859045888863358
# 0.615003577922676
# 0.6392156862745098
# 0.0349452135796268
# 0.18693638912642666
# -1.1883683250165793
# 0.7386046469567331
# 7.229886859328233
# 634.0699754901963
# 0.013597385314355944
# 0.10060522216816344
# 0.8608487778197516
# 0.0015746633440391119
# 0.00967510025388275
# Calculating Statistical Features for Blue Channel:
# 0.4815500895182292
# 0.5463079633701475
# 0.5019607843137255
# 0.0665619021266239
# 0.2579959343218879
# -0.25240932890379997
# -1.3447672235585335
# 7.630326786084751
# 639.8594056372549
# 0.01304886328439938
# 0.10235154805015294
# 0.9261423923650202
# 0.0015604364282166073
# 0.009763440090327917
# Image number:  12
# Calculating Statistical features for Red Channel:
# 0.5054762896369485
# 0.5340538253320876
# 0.5568627450980392
# 0.029707208966699553
# 0.17235779346086894
# -0.9202229350331499
# 0.3156842184226387
# 7.234533214561203
# 437.4857689950981
# 0.018947154469988674
# 0.1628654597426146
# 0.8869634977711757
# 0.0022806742726898394
# 0.006675060863206675
# Calculating Statistical Features for Green Channel:
# 0.4815938313802083
# 0.5087919808051751
# 0.5254901960784314
# 0.026936661308185155
# 0.16412392058498101
# -0.9580370963480969
# 0.5484842401851342
# 7.189496237615124
# 435.0838388480392
# 0.0188430450599714
# 0.16299893263093018
# 0.876001743991404
# 0.002293236122194534
# 0.006638441884923141
# Calculating Statistical Features for Blue Channel:
# 0.43839931114047176
# 0.4942710980123304
# 0.5176470588235295
# 0.05210996232187445
# 0.22827606602943387
# -0.4766809310674944
# -1.123599886560277
# 7.455278339762592
# 439.3516850490196
# 0.01917832202830996
# 0.16808772991376508
# 0.935255815718323
# 0.002271011076227461
# 0.006703664331135842
# Image number:  13
# Calculating Statistical features for Red Channel:
# 0.4572182153995801
# 0.48774760003685014
# 0.5138339920948617
# 0.028849224848530308
# 0.1698505956672814
# -0.9225019048881612
# -0.15251317171723544
# 7.0659452852052
# 440.6983609068627
# 0.017610333027131
# 0.09973430111307974
# 0.882584902151549
# 0.002264078746245543
# 0.006724499881561875
# Calculating Statistical Features for Green Channel:
# 0.4576458233618454
# 0.48013798896024396
# 0.4901185770750988
# 0.021092788802245986
# 0.1452335663758416
# -1.174434115941161
# 1.1515266328748552
# 6.8228582635195805
# 437.9878216911766
# 0.01879532539852165
# 0.09933998258198727
# 0.8404505179358951
# 0.002278065056842379
# 0.006683128546949897
# Calculating Statistical Features for Blue Channel:
# 0.37427457424962945
# 0.41355193915874433
# 0.43478260869565216
# 0.03094374945221637
# 0.17590835526550855
# -0.4537664547807027
# -1.0726065545177785
# 7.19377134110195
# 433.4932904411766
# 0.01428581720066719
# 0.09708506900391332
# 0.8925640039099637
# 0.0023016071878213303
# 0.00661454509080075
# Image number:  14
# Calculating Statistical features for Red Channel:
# 0.44226995729932594
# 0.4872567257640284
# 0.4549019607843137
# 0.04181640167273395
# 0.2044905906704119
# -0.1327478695236526
# -0.9337600140969133
# 7.570700911704883
# 621.9140625000002
# 0.01380997841427075
# 0.11055274557445433
# 0.8856449264990858
# 0.0016053934734363367
# 0.009489638881570946
# Calculating Statistical Features for Green Channel:
# 0.45386777391620703
# 0.4872220509024791
# 0.47843137254901963
# 0.03138937068596462
# 0.17717045658338362
# -0.5438380066693074
# -0.07272640818320752
# 7.352605287232596
# 619.0428615196079
# 0.015850775342171775
# 0.11118341605294924
# 0.8484949886751537
# 0.0016128329615827926
# 0.009445819715349456
# Calculating Statistical Features for Blue Channel:
# 0.3454180549172794
# 0.40947882607938707
# 0.2901960784313726
# 0.04835927634451628
# 0.2199074267607083
# 0.21468780880401353
# -1.2005762498582333
# 7.530244856136853
# 612.4659466911764
# 0.013286240426040196
# 0.1108070359751047
# 0.9025299084073917
# 0.001630117634937346
# 0.009345465714866722
# Image number:  15
# Calculating Statistical features for Red Channel:
# 0.5022585499043367
# 0.5166176680041267
# 0.49795918367346936
# 0.014630163942014905
# 0.12095521461274378
# 0.5231089420929104
# 0.72151529907272
# 6.825205207497136
# 31.635539215686272
# 0.03303477548602317
# 0.3140575419533988
# 0.9834410702673648
# 0.030672490263262055
# 0.00048256024334440776
# Calculating Statistical Features for Green Channel:
# 0.6122988953882333
# 0.6292544375046417
# 0.5836734693877551
# 0.021051209825632168
# 0.1450903505600292
# 0.20857867471663885
# -0.6754740882809118
# 7.094302545391914
# 31.797763480392156
# 0.02917463866532305
# 0.3229669931338779
# 0.98841511444887
# 0.03051702973326154
# 0.00048502211334016954
# Calculating Statistical Features for Blue Channel:
# 0.303095665756537
# 0.3528855119086033
# 0.2816326530612245
# 0.03266120191459861
# 0.1807241044094523
# 0.0226175738623416
# -1.4514384370898425
# 7.081666487675027
# 23.416268382352946
# 0.02875677276499411
# 0.3209969799736127
# 0.9944903548768832
# 0.041004593498864796
# 0.00035711183124255874
# Image number:  16
# Calculating Statistical features for Red Channel:
# 0.45365960015190976
# 0.49044891131380114
# 0.4444444444444444
# 0.034733101798902134
# 0.18636818880619657
# -0.03505543572186797
# -0.5383777168971666
# 7.331763496886642
# 526.6666207107844
# 0.012128735503732538
# 0.08456384213094341
# 0.8834712441589669
# 0.0018951795449641462
# 0.008036280677767356
# Calculating Statistical Features for Green Channel:
# 0.4665121799045139
# 0.49412519563392265
# 0.47555555555555556
# 0.026526094961000814
# 0.162868336275044
# -0.531252648899936
# 0.14676833673028744
# 7.133453439022367
# 527.1497242647059
# 0.012954668977366763
# 0.08538369800464632
# 0.847381822745133
# 0.0018934489275675074
# 0.008043658195972237
# Calculating Statistical Features for Blue Channel:
# 0.43939615885416666
# 0.48280571781963855
# 0.4311111111111111
# 0.040032376743540356
# 0.20008092548651496
# 0.02682810833280179
# -0.6164315079802454
# 7.419494370408239
# 528.232843137255
# 0.011744323227403647
# 0.08514921960875292
# 0.8985610368816425
# 0.0018895694110476265
# 0.008060178511053818
# Image number:  17
# Calculating Statistical features for Red Channel:
# 0.5976150421325319
# 0.6284597861419337
# 0.6646706586826348
# 0.037817964214497186
# 0.1944684144392019
# -0.7519154308459268
# -0.5247198239263309
# 6.775253818843054
# 211.9162990196078
# 0.02565170833162271
# 0.16509911723354667
# 0.9569881947071932
# 0.004697247214143037
# 0.0032329978036627276
# Calculating Statistical Features for Green Channel:
# 0.604485334750421
# 0.6349655994433906
# 0.6646706586826348
# 0.03777879254817566
# 0.1943676736192921
# -0.8549248182835228
# -0.1450070215161019
# 6.814266361592174
# 216.14231004901967
# 0.02534256613329432
# 0.16683207561672936
# 0.9560839792016177
# 0.004605812302895315
# 0.0032974319583931504
# Calculating Statistical Features for Blue Channel:
# 0.5418871120064559
# 0.6093135455366079
# 0.6646706586826348
# 0.0776213546156947
# 0.27860609220850624
# -0.5176322839273227
# -1.2436255324770353
# 7.025819513860396
# 203.8261335784314
# 0.023827887414831456
# 0.16795653531618668
# 0.9798461407914864
# 0.004882757528661279
# 0.0031093085667935534
# Image number:  18
# Calculating Statistical features for Red Channel:
# 0.39943689013284345
# 0.4092607171859107
# 0.3888888888888889
# 0.00794450543252875
# 0.0891319551705714
# 0.22087070784316423
# -0.2761479832295426
# 6.4963161055995
# 200.20916053921565
# 0.019700934138919154
# 0.1206778587932944
# 0.8062713228849514
# 0.0049704393160702465
# 0.003054947181748386
# Calculating Statistical Features for Green Channel:
# 0.4520029340471541
# 0.46008357504252695
# 0.46825396825396826
# 0.007370243636676631
# 0.08585012310228
# -0.540530222366933
# 0.19278426252387115
# 6.394804899053172
# 202.46928615196083
# 0.020739758401329352
# 0.12046092839932233
# 0.7902640592349008
# 0.004915247701330623
# 0.003089432890699895
# Calculating Statistical Features for Blue Channel:
# 0.3939339168488033
# 0.4062271752007902
# 0.373015873015873
# 0.009836587027773633
# 0.0991795696087336
# 0.33322169248051636
# -0.6021115129521712
# 6.587135944981774
# 199.07428002450985
# 0.019161906918961732
# 0.1203702445980603
# 0.8444770038162555
# 0.004998622426706461
# 0.00303762861099975
# Image number:  19
# Calculating Statistical features for Red Channel:
# 0.5773635798202448
# 0.5912070113947285
# 0.5714285714285714
# 0.016177027019438413
# 0.12718894220583177
# -0.25993003768405226
# 0.07071045407207333
# 6.872626273086676
# 28.588495710784315
# 0.02961648935412606
# 0.3116778782041015
# 0.9864428807167198
# 0.0338307820302943
# 0.00043602199089576966
# Calculating Statistical Features for Green Channel:
# 0.6589351505428165
# 0.6730576338323357
# 0.6666666666666666
# 0.018811045839098154
# 0.1371533661238329
# -0.04699273135910264
# -0.8479701294719453
# 6.940522343410857
# 26.757904411764706
# 0.02829747320149523
# 0.3223832180171517
# 0.9890862505711063
# 0.036062537857661184
# 0.00040806037744436295
# Calculating Statistical Features for Blue Channel:
# 0.36557178579883653
# 0.4230331953617321
# 0.4025974025974026
# 0.045314353805807
# 0.2128716838985566
# -0.023758686359450734
# -1.395518748060952
# 7.269995739999839
# 27.64620098039216
# 0.025964129089481133
# 0.3114927073419462
# 0.9953125244031088
# 0.03494031182185985
# 0.00042160254082098596
# Image number:  20
# Calculating Statistical features for Red Channel:
# 0.3769990808823529
# 0.411141290685346
# 0.4
# 0.0269088539202733
# 0.16403918410024265
# -0.5026775734899366
# -0.3744218947920812
# 7.215746656501332
# 574.4767156862746
# 0.019253912093836808
# 0.15991811732450412
# 0.8359008524779046
# 0.0017377479074073018
# 0.00876546282220957
# Calculating Statistical Features for Green Channel:
# 0.386503511316636
# 0.41847838985880026
# 0.4196078431372549
# 0.025739198518725043
# 0.16043440565765513
# -0.7092742129327204
# -0.02186711773504557
# 7.1396842066289
# 574.4000765931374
# 0.01952802381082558
# 0.1594255909710452
# 0.8285503597315836
# 0.0017379801984729619
# 0.008764243253067376
# Calculating Statistical Features for Blue Channel:
# 0.3635538138595281
# 0.41131541212270006
# 0.3607843137254902
# 0.03700899267785813
# 0.19237721454958778
# -0.15539562574270446
# -0.9888463732895829
# 7.4216320669083595
# 567.5654871323528
# 0.016418138725797476
# 0.15941937003577697
# 0.8820391222457724
# 0.0017588631387086297
# 0.008659969909927281
# Image number:  21
# Calculating Statistical features for Red Channel:
# 0.4985739315257353
# 0.5043457960413106
# 0.4980392156862745
# 0.005788716787514617
# 0.07608361707696748
# 0.04519245753755048
# 2.2342241591728804
# 6.267534523155474
# 73.82657781862747
# 0.030841080565644184
# 0.23782031900868106
# 0.9020675413040696
# 0.013369745972314532
# 0.0011263408905137955
# Calculating Statistical Features for Green Channel:
# 0.53546417834712
# 0.5416199658003497
# 0.5372549019607843
# 0.006630301060615503
# 0.08142666062547023
# -0.3239245264784413
# 1.867698039808321
# 6.3663686173707035
# 73.01527267156864
# 0.029795947194015057
# 0.239995980727504
# 0.9154610740332779
# 0.013516166202799482
# 0.0011139720093934398
# Calculating Statistical Features for Blue Channel:
# 0.42285192153033085
# 0.4415957676944011
# 0.4549019607843137
# 0.016203074503714353
# 0.12729129783184062
# -0.45430697727007163
# -0.7883541446710285
# 6.8660861349942905
# 69.77951899509804
# 0.025006607162279145
# 0.23594944751287344
# 0.9669251663108902
# 0.014133374201169795
# 0.001064568575366369
# Image number:  22
# Calculating Statistical features for Red Channel:
# 0.5008137422449448
# 0.5323416466985819
# 0.5725490196078431
# 0.032573224388371604
# 0.1804805374226584
# -1.0427909111515479
# -0.10146701919919732
# 7.045798420517663
# 331.43400735294114
# 0.015659144258210973
# 0.09195582746846945
# 0.9219404234911899
# 0.003008257532680561
# 0.005057144499097774
# Calculating Statistical Features for Green Channel:
# 0.4873682957069546
# 0.5058756999355156
# 0.5254901960784314
# 0.018382368124946265
# 0.1355815921316248
# -1.2887356771745808
# 1.382530772929603
# 6.858546159398597
# 328.3707720588235
# 0.016073817608670955
# 0.09198444571777369
# 0.8629421733889148
# 0.0030362402763345854
# 0.005010360455063847
# Calculating Statistical Features for Blue Channel:
# 0.4345261517693014
# 0.4749841994385129
# 0.5176470588235295
# 0.036797013144806934
# 0.1918254757450296
# -0.7930499805181584
# -0.7701819818468052
# 7.076168476044197
# 327.9971200980392
# 0.015074946006884611
# 0.09261852954297896
# 0.9316016287995482
# 0.0030396795653023266
# 0.005004649100877469
# Image number:  23
# Calculating Statistical features for Red Channel:
# 0.4878818885952818
# 0.5586722555472194
# 0.5490196078431373
# 0.07408595189891874
# 0.2721873470588204
# -0.35438417204571104
# -1.1286789500201473
# 7.680266675652927
# 697.4894148284314
# 0.019461434476347385
# 0.17364116970207016
# 0.9276406550048573
# 0.001431700812813596
# 0.010641640407509128
# Calculating Statistical Features for Green Channel:
# 0.4807879878025429
# 0.5453475402667732
# 0.5333333333333333
# 0.06624685045980168
# 0.2573846352442229
# -0.40737101378512375
# -0.9937694099643544
# 7.660751299174573
# 695.8876225490196
# 0.018247295422031896
# 0.17353089469677002
# 0.9192796216466758
# 0.001434989160825284
# 0.01061715193869104
# Calculating Statistical Features for Blue Channel:
# 0.4422740861481311
# 0.525257469445435
# 0.49019607843137253
# 0.08028904193005768
# 0.28335321055187934
# -0.1580167657821312
# -1.2246032455869278
# 7.689992779865223
# 690.2752757352943
# 0.0216539839312408
# 0.17699871818050855
# 0.9339103334459762
# 0.0014466470316153947
# 0.010531608051549167
# Image number:  24
# Calculating Statistical features for Red Channel:
# 0.5123016485110486
# 0.5212874417161627
# 0.5230125523012552
# 0.009287617823843675
# 0.0963722876341725
# -0.2263989769642739
# -0.6656293459245601
# 6.43446586631004
# 302.97449448529414
# 0.020914409353903474
# 0.11723573273843048
# 0.7499538728280787
# 0.0032899760540743045
# 0.004622997664332659
# Calculating Statistical Features for Green Channel:
# 0.5706278270258563
# 0.5755703605587572
# 0.5774058577405857
# 0.0056651229774871414
# 0.07526701121664883
# -0.27303608519984013
# 1.404268960507645
# 6.1208700222042784
# 301.7188725490196
# 0.02494272419705374
# 0.11756618012490093
# 0.5913246265338422
# 0.00330366717488761
# 0.00460384271650796
# Calculating Statistical Features for Blue Channel:
# 0.5040045063864736
# 0.5164698398088688
# 0.5146443514644351
# 0.01272055297432572
# 0.11278542890961456
# -0.24493811360774914
# -0.9519123464814303
# 6.595804456693075
# 302.73449754901964
# 0.020078133823957567
# 0.11854358488631192
# 0.8175252711481121
# 0.00329256675374685
# 0.0046193268057567625
# Image number:  25
# Calculating Statistical features for Red Channel:
# 0.4935260249119179
# 0.5199586059910818
# 0.5137254901960784
# 0.026789014678830134
# 0.16367350023394175
# -0.45357215659974986
# -0.08586860441613409
# 7.356238195043841
# 1163.5762101715686
# 0.009443557994088173
# 0.04837150747213335
# 0.6664648979260025
# 0.0008586884227410029
# 0.017754444257366612
# Calculating Statistical Features for Green Channel:
# 0.48442017798330267
# 0.5093272703254013
# 0.49411764705882355
# 0.024751359459749645
# 0.15732564781290317
# -0.3633022925417071
# 0.4676957090765481
# 7.294911035356519
# 1161.8569393382354
# 0.009783819196078946
# 0.0482720653082054
# 0.6396109140512165
# 0.0008599582458054412
# 0.01772817038944559
# Calculating Statistical Features for Blue Channel:
# 0.4095056272020527
# 0.45630230864320936
# 0.4549019607843137
# 0.040516938162976156
# 0.20128819678007986
# -0.48603898708100146
# -0.7985893793243561
# 7.45442205770548
# 1151.805912990196
# 0.010888732107830092
# 0.052913452302758596
# 0.7816468269856242
# 0.000867456901666952
# 0.017574795453248113
# Image number:  26
# Calculating Statistical features for Red Channel:
# 0.46038531135110294
# 0.49575811547681026
# 0.4745098039215686
# 0.03382147415326633
# 0.18390615583298545
# -0.3929094904017618
# -0.41051868895486887
# 7.42350907230462
# 406.6549785539217
# 0.014961618031388402
# 0.13945699195309563
# 0.9075435540297646
# 0.002453144829883741
# 0.006205062436703299
# Calculating Statistical Features for Green Channel:
# 0.4561024385340074
# 0.4864511959081369
# 0.4745098039215686
# 0.0286053315637886
# 0.16913110761710454
# -0.6798860424104693
# 0.22432948369134476
# 7.246043888830802
# 404.4947610294118
# 0.015837460643806735
# 0.14153112853138058
# 0.891338502179306
# 0.0024662194305899677
# 0.006172095887099422
# Calculating Statistical Features for Blue Channel:
# 0.27558982699525125
# 0.3407924975218608
# 0.2196078431372549
# 0.040189773623915
# 0.20047387267151548
# 0.7775773861370022
# -0.492669293746145
# 7.34073345498591
# 404.74595588235286
# 0.015429880930202687
# 0.14207450795281823
# 0.9221403481448082
# 0.002464690073619192
# 0.006175925065260216
# Image number:  27
# Calculating Statistical features for Red Channel:
# 0.4552529129327513
# 0.5013603651578658
# 0.49019607843137253
# 0.04410700101747332
# 0.21001666842770675
# -0.3836820008941217
# -0.860243001169593
# 7.5674265439096535
# 528.4091605392156
# 0.01364813196563838
# 0.11079484310292391
# 0.9079717365798008
# 0.0018889468772654168
# 0.008062863976668505
# Calculating Statistical Features for Green Channel:
# 0.42231367522594976
# 0.46811264695542715
# 0.4470588235294118
# 0.040780609956767404
# 0.2019420955540657
# -0.3461070914321022
# -0.8487949033951572
# 7.52447455830825
# 526.875168504902
# 0.013740509961884218
# 0.11150294816699391
# 0.9007573520979926
# 0.0018944365830980655
# 0.008039438747716742
# Calculating Statistical Features for Blue Channel:
# 0.35581096574371934
# 0.4231040899472919
# 0.3215686274509804
# 0.052415627586647806
# 0.22894459501514292
# 0.0970859540062576
# -1.3608519534908068
# 7.545475127641666
# 511.8996323529411
# 0.013721061440825506
# 0.11464711886099709
# 0.9249173806792083
# 0.0019497513540231502
# 0.007810919333273677
# Image number:  28
# Calculating Statistical features for Red Channel:
# 0.5629207237094056
# 0.5745258732654269
# 0.5725490196078431
# 0.013200237869880506
# 0.11489228812187746
# -0.7323864266191679
# 2.154361915214012
# 6.827978779553275
# 611.3585784313727
# 0.01385981125417983
# 0.07013980681911848
# 0.6441615926686066
# 0.001633067077402805
# 0.00932853389797773
# Calculating Statistical Features for Green Channel:
# 0.5630220899394914
# 0.5750403844437487
# 0.5725490196078431
# 0.013677569981381551
# 0.11695114356594188
# -1.0928120125575866
# 3.106749443159571
# 6.798287675040396
# 610.6136642156863
# 0.014212995355735902
# 0.06992723304868281
# 0.6570289481810252
# 0.0016350570590027342
# 0.009317153620690119
# Calculating Statistical Features for Blue Channel:
# 0.3587735045189951
# 0.4094143963943348
# 0.29411764705882354
# 0.038901720430096126
# 0.19723519064836306
# 0.3008188563757171
# -1.2221596227195235
# 7.355410090115525
# 614.2094209558824
# 0.011688102706674692
# 0.0701417641622519
# 0.8783704460530622
# 0.0016254936365941745
# 0.00937202003355518
# Image number:  29
# Calculating Statistical features for Red Channel:
# 0.42488576851639087
# 0.46452994867813335
# 0.4588235294117647
# 0.03526015693114505
# 0.18777688071523888
# -0.3229689563293081
# -0.897283649580233
# 7.46023460074836
# 544.1216452205882
# 0.01266458665429832
# 0.10165113285475655
# 0.8814511662322637
# 0.0018344955513979076
# 0.00830248101073024
# Calculating Statistical Features for Green Channel:
# 0.420301669251685
# 0.4493579772293263
# 0.44313725490196076
# 0.0252690985238789
# 0.15896256956868463
# -0.6846689167698894
# 0.03182377562592453
# 7.142216330747215
# 542.6331801470586
# 0.015427188848179726
# 0.10350866839937194
# 0.8351375660840625
# 0.0018395278567675348
# 0.008279716015171428
# Calculating Statistical Features for Blue Channel:
# 0.4032036276424632
# 0.44443416890105547
# 0.4235294117647059
# 0.03494856514272977
# 0.1869453533595574
# -0.2573067226043118
# -0.9038506493251255
# 7.476891215346567
# 541.7936274509804
# 0.01226682554130345
# 0.10070095180999969
# 0.8808631166803882
# 0.0018423624548339586
# 0.008266911435827917
# Image number:  30
# Calculating Statistical features for Red Channel:
# 0.6528460838106781
# 0.6672177080492852
# 0.6640316205533597
# 0.018971460787602114
# 0.13773692601333207
# -0.38846426865654377
# -0.6680527441038477
# 6.966329530141421
# 123.74859068627451
# 0.025351722158203104
# 0.2202237813093779
# 0.9501539040569913
# 0.008017752010815775
# 0.001887859779108217
# Calculating Statistical Features for Green Channel:
# 0.6694547630581459
# 0.6802990837713014
# 0.6837944664031621
# 0.014637163598833762
# 0.1209841460639937
# -1.1168881501515944
# 1.9855749218503647
# 6.761536279152999
# 123.31015624999999
# 0.029040489749737417
# 0.22354770701643167
# 0.9357506737433697
# 0.008046274720683167
# 0.001881135668700811
# Calculating Statistical Features for Blue Channel:
# 0.5464861119688735
# 0.5795713624769322
# 0.5454545454545454
# 0.03725589362851148
# 0.19301785831500534
# -0.08858351712283263
# -1.2018546397171779
# 7.2516972781168585
# 125.06055453431377
# 0.02328213676613801
# 0.21587860024083871
# 0.9741900534924801
# 0.007934160911113604
# 0.001907819367279913
# Image number:  31
# Calculating Statistical features for Red Channel:
# 0.45242895986519605
# 0.5067216429730668
# 0.4980392156862745
# 0.0520748597326209
# 0.22819916680965535
# -0.43233272741781786
# -0.8253604300670232
# 7.4524509690378435
# 637.4023897058823
# 0.031296574469859055
# 0.1914129547518325
# 0.9057436476034163
# 0.0015664869709163727
# 0.00972385509924298
# Calculating Statistical Features for Green Channel:
# 0.46872241450291047
# 0.5210378831227286
# 0.5176470588235295
# 0.051779773791575924
# 0.22755169476753173
# -0.5838310752927813
# -0.5940935600336714
# 7.453493480883919
# 638.8368719362745
# 0.027367695788642864
# 0.18976263972664917
# 0.9049768839638714
# 0.0015629652160092464
# 0.009745643652316007
# Calculating Statistical Features for Blue Channel:
# 0.4479881137025122
# 0.5188972901477042
# 0.5058823529411764
# 0.06856104770389566
# 0.2618416462366055
# -0.27178904948771543
# -1.0810699687642848
# 7.725490557353345
# 631.0588848039217
# 0.019287922221313432
# 0.18603181134121194
# 0.92913764302645
# 0.0015821793522648095
# 0.009626490492996737
# Image number:  32
# Calculating Statistical features for Red Channel:
# 0.4753809311810661
# 0.5111190146655549
# 0.5372549019607843
# 0.03525561742211009
# 0.18776479281832922
# -0.9156872614699731
# 0.21847906769191638
# 7.154184225526884
# 463.85200674019615
# 0.026604517901162354
# 0.17461655551949334
# 0.8988857444596835
# 0.0021513454196329974
# 0.007077666637138598
# Calculating Statistical Features for Green Channel:
# 0.5025034586588542
# 0.5340029350852348
# 0.5568627450980392
# 0.03264940871553469
# 0.18069147383187367
# -1.4080470379490364
# 1.4592826120652163
# 6.870461741727699
# 462.8142616421569
# 0.026070827819323898
# 0.1746176413591433
# 0.8911423864798508
# 0.002156156667646411
# 0.007061825273544175
# Calculating Statistical Features for Blue Channel:
# 0.41119486490885415
# 0.4754743385176818
# 0.37254901960784315
# 0.056994629661416184
# 0.2387354805248189
# -0.06928883580811579
# -1.341564822301181
# 7.4504031020095125
# 457.7267463235293
# 0.019630508786331942
# 0.17268863522223274
# 0.9381960946364684
# 0.0021800403035471282
# 0.00698417353565901
# Image number:  33
# Calculating Statistical features for Red Channel:
# 0.46210347573588206
# 0.511218106589648
# 0.5078740157480315
# 0.04780433021792171
# 0.21864201384437007
# -0.3374403195833273
# -1.2047965067361632
# 7.426389976642226
# 449.7505514705882
# 0.020308086461922153
# 0.15708526268132053
# 0.9283311906802579
# 0.002218621924483929
# 0.0068626380791570385
# Calculating Statistical Features for Green Channel:
# 0.40134267731914364
# 0.455115900340134
# 0.44881889763779526
# 0.046054538104712495
# 0.21460321084436854
# -0.277970030237858
# -1.332226434082189
# 7.36022768808226
# 447.2225337009805
# 0.02121450163158785
# 0.15687725874905525
# 0.9260113364239836
# 0.0022311402424838125
# 0.006824060254044593
# Calculating Statistical Features for Blue Channel:
# 0.30142692505843993
# 0.37009696704666256
# 0.25984251968503935
# 0.04611357386695205
# 0.21474071310990855
# 0.28629042861153015
# -1.3043541734607569
# 7.36083769140595
# 436.51112132352955
# 0.020461810386476053
# 0.15761955678718856
# 0.9275686894810771
# 0.00228576308603443
# 0.006660609455154016
# Image number:  34
# Calculating Statistical features for Red Channel:
# 0.7106171879902422
# 0.7191110136897595
# 0.7269076305220884
# 0.012143862142754274
# 0.11019919302224619
# -1.9610283727353388
# 6.584465585370596
# 6.334944529669254
# 24.529534313725485
# 0.04416032708821417
# 0.3671753639283945
# 0.9845527099721365
# 0.03923819209105306
# 0.0003741950612487999
# Calculating Statistical Features for Green Channel:
# 0.7512425801840174
# 0.7595570830794355
# 0.7670682730923695
# 0.012561548174600758
# 0.11207831268626753
# -2.4916692653215833
# 8.447431841465688
# 6.151668901987532
# 26.041314338235292
# 0.04896726199442473
# 0.3680953147156545
# 0.9841662616002861
# 0.037047537851208845
# 0.00039726139326257245
# Calculating Statistical Features for Blue Channel:
# 0.6023387985535893
# 0.6220086271027472
# 0.6706827309236948
# 0.02408270394726291
# 0.15518603012920626
# -0.5688681017388121
# -0.5293694597306482
# 6.658497746576118
# 26.859007352941173
# 0.037753160595241225
# 0.35293753007032
# 0.9914247979293836
# 0.03594374261801309
# 0.00040974396042116145
# Image number:  35
# Calculating Statistical features for Red Channel:
# 0.9368055755016851
# 0.9508769745709117
# 1.0
# 0.026562334478086935
# 0.1629795523312263
# -3.4360980510310677
# 12.064360384421892
# 3.4915555802807363
# 592.6351102941177
# 0.5006661174509164
# 0.5854622594040837
# 0.8290176801150616
# 0.0016859584025475129
# 0.009042892251743782
# Calculating Statistical Features for Green Channel:
# 0.9589096966911765
# 0.9682765694916521
# 0.996078431372549
# 0.018051708618158194
# 0.13435664709331724
# -4.874283938442628
# 24.799953429070733
# 3.46281722737295
# 519.9170189950981
# 0.41511907348461796
# 0.5818572041844662
# 0.779314338131728
# 0.001921222574116632
# 0.007933298338549078
# Calculating Statistical Features for Blue Channel:
# 0.8962391572840073
# 0.922934492883588
# 1.0
# 0.04856345110513794
# 0.2203711666827989
# -2.3648522521528634
# 4.862890453043743
# 3.8476060946837745
# 606.1716911764706
# 0.4835687178637635
# 0.5692596432631447
# 0.9043203902297159
# 0.0016482933536715615
# 0.009249443633654446
# Image number:  36
# Calculating Statistical features for Red Channel:
# 0.5295317406747855
# 0.5702938435157832
# 0.5764705882352941
# 0.04483120356993631
# 0.2117338035598858
# -0.8624406938169522
# 0.18394250103589949
# 7.4743340067553765
# 686.6936580882353
# 0.017048221549455744
# 0.14152553812006016
# 0.8820331737073571
# 0.0014541718965748473
# 0.010475514986420173
# Calculating Statistical Features for Green Channel:
# 0.4885614133348652
# 0.5331371817842426
# 0.5411764705882353
# 0.045543000001083626
# 0.2134080598315903
# -0.8298776903404355
# -0.14676468462311965
# 7.445272590404332
# 682.8738051470589
# 0.01790370768116087
# 0.14276838106524362
# 0.8845389154758457
# 0.0014622963666690646
# 0.01041708036207353
# Calculating Statistical Features for Blue Channel:
# 0.42266666187959556
# 0.4826268298300003
# 0.44313725490196076
# 0.05428154980731568
# 0.23298401191351237
# -0.28619605887574273
# -1.0544872594625385
# 7.587605532363996
# 653.5326439950982
# 0.01738930752870438
# 0.14402883130946692
# 0.90725977747013
# 0.0015278482706676507
# 0.009969187331357623
# Image number:  37
# Calculating Statistical features for Red Channel:
# 0.6038045201982771
# 0.6107183420931718
# 0.5982142857142857
# 0.008396994757160837
# 0.09163511748866172
# 0.6847863563740523
# 2.7296298604397125
# 6.126149068477151
# 15.89295343137255
# 0.05219788081343801
# 0.40313374731328994
# 0.9854925378192293
# 0.05937975864549617
# 0.00024250658027761854
# Calculating Statistical Features for Green Channel:
# 0.6566147123064314
# 0.6669504416629003
# 0.6294642857142857
# 0.01368001121708013
# 0.11696158008970352
# 0.1821360049624734
# 0.24138438425841002
# 6.5326607985775915
# 17.176363357843137
# 0.045245536393806775
# 0.4061767957234113
# 0.990364826279928
# 0.055153797457373976
# 0.0002620904851971235
# Calculating Statistical Features for Blue Channel:
# 0.4360695566449846
# 0.46677101115068226
# 0.4955357142857143
# 0.027718518618076837
# 0.16648879427179727
# -0.3382199852096072
# -1.360069708266732
# 6.548996590133405
# 17.297012867647062
# 0.04509385033395282
# 0.3924139862654896
# 0.9952083395481863
# 0.05478875942038951
# 0.0002639308421393109
# Image number:  38
# Calculating Statistical features for Red Channel:
# 0.5066000545726103
# 0.5682683278793077
# 0.592156862745098
# 0.0662852771777727
# 0.2574592728525673
# -0.5625664329010356
# -1.0449069243854314
# 7.551195557585495
# 603.4104166666667
# 0.019019838805576648
# 0.19328714365609365
# 0.9300831353561652
# 0.0016545569729292714
# 0.009206818083200213
# Calculating Statistical Features for Green Channel:
# 0.4882865756165747
# 0.5496720110868099
# 0.5686274509803921
# 0.06371553984485703
# 0.2524193729586876
# -0.5964754061285306
# -0.9526140913786003
# 7.556401196525275
# 601.3872855392156
# 0.017762277160142927
# 0.19534079461872794
# 0.9275151395204533
# 0.0016601105490606951
# 0.009175934340577088
# Calculating Statistical Features for Blue Channel:
# 0.43799905215992646
# 0.518717690731091
# 0.5215686274509804
# 0.07722487298440173
# 0.27789363609914086
# -0.24369533867592175
# -1.4294580939108104
# 7.586863544301847
# 580.9392003676471
# 0.020662790010874538
# 0.20249047003707793
# 0.9422108166906012
# 0.0017184535900208982
# 0.008863867719878644
# Image number:  39
# Calculating Statistical features for Red Channel:
# 0.8895246917126225
# 0.9127392126480002
# 0.9882352941176471
# 0.04183869313885505
# 0.20454508827848947
# -2.3654692708464102
# 5.012400060219626
# 4.907661797115483
# 1179.065793504902
# 0.28116404986740823
# 0.3562467012973439
# 0.7839196630337512
# 0.0008476123311268424
# 0.017991103992429702
# Calculating Statistical Features for Green Channel:
# 0.9206492106119792
# 0.9357752677724673
# 0.984313725490196
# 0.028080382774172578
# 0.167572022647495
# -3.186394859172643
# 10.389855137554022
# 5.029403454017977
# 1068.631050857843
# 0.17161621527968113
# 0.33288045238270286
# 0.7082490452064945
# 0.0009350518286223936
# 0.01630597983195487
# Calculating Statistical Features for Blue Channel:
# 0.8659021115770529
# 0.8971925469327146
# 0.9882352941176471
# 0.05516799943801266
# 0.2348786908981159
# -2.089142621780427
# 3.576347411256447
# 5.040187438980283
# 1179.1775735294118
# 0.28318253359247914
# 0.35798068767636704
# 0.8360964636080014
# 0.0008475334806499163
# 0.01799280979177531
# Image number:  40
# Calculating Statistical features for Red Channel:
# 0.9179131002987132
# 0.9381815060556399
# 1.0
# 0.03762007860483308
# 0.1939589611356822
# -2.8165671240909553
# 7.30325495799862
# 3.5533946337372253
# 461.63425245098045
# 0.5433507176208516
# 0.6173054793941322
# 0.9059482002512833
# 0.002164076367331357
# 0.007043977805292638
# Calculating Statistical Features for Green Channel:
# 0.9479139141007967
# 0.9613657981614572
# 1.0
# 0.025683409328723195
# 0.16026044218310143
# -3.81052130621935
# 13.986845703579881
# 3.2446407944134807
# 409.42054227941185
# 0.5006775099217887
# 0.6420871900475497
# 0.8778504840701251
# 0.002439501195099021
# 0.006247258119020857
# Calculating Statistical Features for Blue Channel:
# 0.8687599331724878
# 0.9053014996600462
# 1.0
# 0.0648269838008633
# 0.2546114369011402
# -1.941466115421725
# 2.628149251095987
# 3.9159947303917346
# 450.64813112745105
# 0.513396583010941
# 0.5932533260115881
# 0.9467029614803091
# 0.0022166326895884194
# 0.006876342436617403
# Image number:  41
# Calculating Statistical features for Red Channel:
# 0.463545197131587
# 0.5053560252566869
# 0.48627450980392156
# 0.04051056247947523
# 0.20127235895540954
# -0.23955741270740388
# -0.6711669043745228
# 7.616202953308349
# 935.7374846813727
# 0.009146131449532005
# 0.05950119235707109
# 0.8224826697060894
# 0.0010675453691814457
# 0.014278054987117993
# Calculating Statistical Features for Green Channel:
# 0.46011370490579034
# 0.4931631365266135
# 0.4627450980392157
# 0.03150525778663437
# 0.17749720501076735
# -0.1440104472485239
# -0.39977844815498953
# 7.477028775719238
# 935.1021599264706
# 0.009624438963786256
# 0.060034517905367846
# 0.7719490793561965
# 0.0010682704562740807
# 0.014268325897233015
# Calculating Statistical Features for Blue Channel:
# 0.4336579565908395
# 0.4798444354699685
# 0.45098039215686275
# 0.042191458936950414
# 0.2054055961675592
# -0.17599525976001654
# -0.6381159534059297
# 7.637934896880958
# 933.8859375
# 0.009158233446449667
# 0.060233588454891074
# 0.8298693898166268
# 0.001069659683690655
# 0.014249746191506202
# Image number:  42
# Calculating Statistical features for Red Channel:
# 0.5979273625923883
# 0.6089013737345697
# 0.5643153526970954
# 0.013243751999156447
# 0.1150815015506682
# 1.2127667387582102
# 1.4608143147776174
# 6.184953025922612
# 21.55330882352941
# 0.05986690509230958
# 0.4029751617967851
# 0.9875263664525018
# 0.04445740245650598
# 0.0003288670449085485
# Calculating Statistical Features for Green Channel:
# 0.6337872896946317
# 0.6485297108739414
# 0.5726141078838174
# 0.018904457307771017
# 0.1374934809646298
# 0.8503745303600923
# -0.2762022610489794
# 6.339753818446185
# 20.357735906862747
# 0.05805801839053167
# 0.40854732329886134
# 0.9917422142914407
# 0.04694906679979507
# 0.0003106236939025941
# Calculating Statistical Features for Blue Channel:
# 0.4396721930919346
# 0.46504018668533703
# 0.5145228215767634
# 0.022950737854061667
# 0.15149500933714505
# -0.9368468798341931
# -0.6234413477981189
# 6.400499513252209
# 16.56369485294118
# 0.05340361789549152
# 0.3996360270491569
# 0.9944647470012405
# 0.057109272859983407
# 0.0002527358186005492
# Image number:  43
# Calculating Statistical features for Red Channel:
# 0.5229436774002878
# 0.5594166560127932
# 0.5842105263157895
# 0.03947690529159949
# 0.19868795960399685
# -0.5892922478108622
# -0.8508549177000004
# 6.981121361044815
# 255.4651501225491
# 0.018031748911741214
# 0.1261136385623775
# 0.9503363299917477
# 0.0038994394101283057
# 0.003898039793177454
# Calculating Statistical Features for Green Channel:
# 0.5641441746761925
# 0.58399551906422
# 0.5894736842105263
# 0.022792116466005412
# 0.1509705814587909
# -0.5595067087881984
# -0.21891259669949514
# 6.802019109224577
# 253.9148131127451
# 0.01882348303695651
# 0.12573730366101174
# 0.9144979019150768
# 0.003923168824479025
# 0.0038743700408145803
# Calculating Statistical Features for Blue Channel:
# 0.476797806589227
# 0.5351550913217636
# 0.5578947368421052
# 0.05905482339930729
# 0.24301198200769297
# -0.3978172151522948
# -1.2629552338250238
# 7.1641213926481955
# 248.0654258578432
# 0.016974297287380556
# 0.1292162800790853
# 0.9677485261679474
# 0.004015282944880512
# 0.0037851325508424785
# Image number:  44
# Calculating Statistical features for Red Channel:
# 0.9322895124846814
# 0.9451631818572132
# 0.996078431372549
# 0.02416970524952669
# 0.15546609035261255
# -3.329161298109245
# 11.805280251592425
# 4.1363862906032205
# 495.76092218137256
# 0.3493223032035928
# 0.44153898131280084
# 0.8427793585100054
# 0.0020144573580581585
# 0.007564709800815082
# Calculating Statistical Features for Green Channel:
# 0.9477518119064032
# 0.9567273434390022
# 0.9882352941176471
# 0.01709371271198032
# 0.130742926049482
# -4.809216568699165
# 25.459405021815204
# 4.533678269392876
# 444.1264093137255
# 0.2247194236750848
# 0.4051185507855819
# 0.800855262993269
# 0.002247687573960738
# 0.006776828995946277
# Calculating Statistical Features for Blue Channel:
# 0.8722179936427698
# 0.9034539161776857
# 0.9921568627450981
# 0.05546475022257818
# 0.23550955441887741
# -2.094696086324272
# 3.402211815122244
# 4.7967739065973936
# 548.2570772058823
# 0.3295632599032545
# 0.41428794446781303
# 0.9242115312020981
# 0.0018217341535888322
# 0.008365737734414761
# Image number:  45
# Calculating Statistical features for Red Channel:
# 0.4919140984030331
# 0.5328331523527908
# 0.5294117647058824
# 0.041931688038543476
# 0.20477228337483439
# -0.4656702678811026
# -0.7976104643351198
# 7.5382113379564375
# 818.4115655637256
# 0.0114088299691045
# 0.08776008690621016
# 0.8501994396581948
# 0.0012204049410804846
# 0.01248783291348316
# Calculating Statistical Features for Green Channel:
# 0.5131090351179535
# 0.5476103626803706
# 0.5490196078431373
# 0.03659622739524978
# 0.19130140458253247
# -0.5786061172106279
# -0.27637234926200804
# 7.475595436812278
# 813.0245251225491
# 0.01126863890995828
# 0.08842726409329715
# 0.8295570029149354
# 0.0012284812219395336
# 0.012405655954125516
# Calculating Statistical Features for Blue Channel:
# 0.42819309608609074
# 0.4840696546705098
# 0.4549019607843137
# 0.050974103037034466
# 0.22577445169246776
# -0.265957805663161
# -1.1437403561157446
# 7.619641212031553
# 802.7118412990197
# 0.011388737606364817
# 0.09012311434695174
# 0.8790787104443337
# 0.001244244664555028
# 0.012248335128581322
# Image number:  46
# Calculating Statistical features for Red Channel:
# 0.45923455930223644
# 0.49294807482214753
# 0.49019607843137253
# 0.03210142401334218
# 0.1791687026613247
# -0.756054176172178
# 0.04029585854580153
# 7.324263002746855
# 612.4690104166666
# 0.011573200228530225
# 0.08457592539291268
# 0.8536356289277736
# 0.0016301049418155204
# 0.0093453300868006
# Calculating Statistical Features for Green Channel:
# 0.44872328814338236
# 0.47860905662499276
# 0.47843137254901963
# 0.02771403976125655
# 0.16647534280264015
# -0.7890163702945057
# 0.12326871088249547
# 7.233502939770613
# 611.5367493872548
# 0.011845806554626933
# 0.084746402699091
# 0.8307071189828473
# 0.0016325866820339821
# 0.009331127979210086
# Calculating Statistical Features for Blue Channel:
# 0.38309840782015936
# 0.43261798714544564
# 0.40784313725490196
# 0.04039393272743586
# 0.20098241895110094
# -0.2245181749430579
# -0.9879322907407246
# 7.525227187092376
# 597.3515165441178
# 0.013900757631232562
# 0.08943437985883163
# 0.886306806728286
# 0.0016712972302193423
# 0.00911475251235429
# Image number:  47
# Calculating Statistical features for Red Channel:
# 0.4526108685661764
# 0.49729513913849943
# 0.49411764705882355
# 0.04244585706655084
# 0.20602392352964943
# -0.3396210003068149
# -0.823093207735357
# ...
# Calculating Statistical features for Red Channel:
# 0.8785132913028493
# 0.9011954660245703
# 0.9882352941176471
# 0.040367664987477736
# 0.2009170599712173
# -1.8496527656157944
# 2.681075725410511
# 4.966264641803519
# 644.826700367647
# 0.3056186112443339
# 0.38337845548890115
# 0.8774960013512879
# 0.0015491360828667178
# 0.009839274335916842
# Calculating Statistical Features for Green Channel:
# 0.9193927241306679
# 0.9307410841739235
# 0.9803921568627451
# 0.020995984584840012
# 0.1448999123010087
# -2.9363954743608733
# 9.579373292990734
# 5.205967045055221
# 594.6069699754902
# 0.20650499354453472
# 0.34779815253402874
# 0.7828909666365
# 0.0016795418526089378
# 0.009072973937084788
# Calculating Statistical Features for Blue Channel:
# 0.854265459846048
# 0.8853741542021524
# 0.9882352941176471
# 0.05411791704319739
# 0.2326325794965043
# -1.6843538396079425
# 1.9303488342381145
# 5.036701065409112
# 653.4199908088235
# 0.3252757244728209
# 0.3956250572639173
# 0.9073932545697283
# 0.0015288305759679499
# 0.009970397601005798
# Image number:  984
# Calculating Statistical features for Red Channel:
# 0.46279105392156866
# 0.499716333912185
# 0.47058823529411764
# 0.035540854788798176
# 0.18852282299180165
# -0.08796520492587016
# -0.6762830497337187
# 7.580306783681629
# 997.0033854166668
# 0.008739622663549627
# 0.054635917137803455
# 0.7844830141697919
# 0.0010020093837321154
# 0.01521299989036471
# Calculating Statistical Features for Green Channel:
# 0.44979930204503676
# 0.48013281518198786
# 0.4549019607843137
# 0.028208108094378716
# 0.16795269600211457
# -0.15315974282833095
# -0.4532935161178169
# 7.425257194944572
# 996.0527726715687
# 0.009266440210114553
# 0.05470626997541587
# 0.7287794149365224
# 0.0010029652605429591
# 0.015198511004942778
# Calculating Statistical Features for Blue Channel:
# 0.40923144770603553
# 0.4515293305079712
# 0.4117647058823529
# 0.03640835851739902
# 0.1908097442936262
# -0.008796816848189896
# -0.742380415038161
# 7.58684516927857
# 993.6899356617647
# 0.008674023157227692
# 0.05474199025586648
# 0.7902836054890805
# 0.0010053471786053661
# 0.015162470199419088
# Image number:  985
# Calculating Statistical features for Red Channel:
# 0.8710236194087011
# 0.905427210140667
# 0.996078431372549
# 0.06111628729527797
# 0.24721708536280004
# -1.993850873577372
# 2.616055992697553
# 4.467200752430371
# 710.0105545343138
# 0.3883238696099481
# 0.48294547847628366
# 0.9109278175509289
# 0.0014072174452868119
# 0.01083389960366535
# Calculating Statistical Features for Green Channel:
# 0.9004070207184437
# 0.927839432608869
# 0.996078431372549
# 0.05015320974488422
# 0.22394912311702456
# -2.544041334033708
# 5.190740337797015
# 4.45270808967038
# 624.7290747549021
# 0.3091637096437301
# 0.48165837878365964
# 0.9045250740026669
# 0.001598925749467601
# 0.00953260510402235
# Calculating Statistical Features for Blue Channel:
# 0.8265694412530639
# 0.8780678549890581
# 0.996078431372549
# 0.08778611675168357
# 0.2962872200276002
# -1.588020372811268
# 1.0681678924912754
# 4.646816866474292
# 716.117493872549
# 0.3924668144075369
# 0.4803077181081162
# 0.9374384499967895
# 0.0013952352188740843
# 0.010927084107746851
# Image number:  986
# Calculating Statistical features for Red Channel:
# 0.7018388336780024
# 0.7251096823069061
# 0.7607843137254902
# 0.03320630291672348
# 0.1822259666368201
# -1.1094143086948085
# 0.6594867670551832
# 7.2834120051325515
# 701.2660386029414
# 0.012009647608026369
# 0.05932797924023734
# 0.8378170110181433
# 0.0014239861343160831
# 0.010700437664603962
# Calculating Statistical Features for Green Channel:
# 0.7111569872089462
# 0.7238031755731009
# 0.7333333333333333
# 0.018146776513600065
# 0.1347099718417314
# -1.6703785696564613
# 4.391696950210277
# 6.871900041215576
# 700.6084865196078
# 0.013491667521566605
# 0.059721407212147797
# 0.7034426272216537
# 0.001425323737109648
# 0.010690392947160295
# Calculating Statistical Features for Blue Channel:
# 0.5889035094018076
# 0.636134701088627
# 0.7019607843137254
# 0.05786001454335191
# 0.24054108701706642
# -0.569426647585562
# -0.993572925392205
# 7.5182658529157775
# 704.9902113970589
# 0.011311247955272297
# 0.059501682674948514
# 0.9064089426558859
# 0.001416472928282699
# 0.010757239263720297
# Image number:  987
# Calculating Statistical features for Red Channel:
# 0.4141856602260045
# 0.4233983232950113
# 0.40625
# 0.007716379032175685
# 0.08784292249336702
# 0.31007340351639345
# -0.19194128355930795
# 6.311898322951134
# 324.70494791666675
# 0.018211934720742538
# 0.08240176598736854
# 0.6766756415045448
# 0.003070435143712557
# 0.00495459926280994
# Calculating Statistical Features for Green Channel:
# 0.4747691835675921
# 0.484651858104327
# 0.48660714285714285
# 0.009481645898538737
# 0.09737374337334853
# -0.06590442850050002
# -0.22020145012012415
# 6.453588494492989
# 327.0703890931372
# 0.017522447559655374
# 0.08188603244533942
# 0.7349962107400055
# 0.0030482891682223345
# 0.004990692807329974
# Calculating Statistical Features for Blue Channel:
# 0.38879142488752094
# 0.40364612159107627
# 0.3794642857142857
# 0.011771419409449068
# 0.10849617232625798
# 0.07778670665217811
# -0.5380809846745294
# 6.620408897046822
# 323.78965992647056
# 0.015820560484793463
# 0.08146544321386698
# 0.7887270042365693
# 0.00307906573371849
# 0.0049406363518557
# Image number:  988
# Calculating Statistical features for Red Channel:
# 0.4575663704184158
# 0.47199274745309705
# 0.4427860696517413
# 0.013410170310440185
# 0.1158022897461021
# 0.06598006222426678
# -0.7980185960960746
# 6.4814320511177455
# 230.65049019607832
# 0.020387188290316147
# 0.11822296885510213
# 0.8678709560260912
# 0.004317228145282901
# 0.003519414216781272
# Calculating Statistical Features for Green Channel:
# 0.5377976906240283
# 0.5492951200468555
# 0.5671641791044776
# 0.012498772866751332
# 0.11179791083357207
# -0.8650142581972738
# 0.33563942475890274
# 6.31831362945683
# 231.51974571078438
# 0.02457400063915142
# 0.11884266980832073
# 0.8576981130364748
# 0.004301164590405831
# 0.0035326791448093966
# Calculating Statistical Features for Blue Channel:
# 0.44399523379197764
# 0.4639190680190661
# 0.4228855721393035
# 0.018089134041686064
# 0.1344958513921008
# 0.11266164047798352
# -0.9082279300304523
# 6.641946380131
# 230.0060355392157
# 0.019342434840765324
# 0.11813791635107034
# 0.9023150077407095
# 0.004329253718300276
# 0.003509578230801178
# Image number:  989
# Calculating Statistical features for Red Channel:
# 0.6184832049954323
# 0.6347236792268021
# 0.5967741935483871
# 0.020352674109786483
# 0.14266279861893388
# -0.013715192207104912
# -0.5632023673808773
# 6.9605518454826925
# 138.52967218137255
# 0.02142120406204789
# 0.18551353958387234
# 0.9477670732046758
# 0.007168034815106665
# 0.0021137933763870536
# Calculating Statistical Features for Green Channel:
# 0.6522253713300151
# 0.6641337541710602
# 0.6733870967741935
# 0.015675708422770204
# 0.12520266939155172
# -1.1484484726491504
# 1.614752280697524
# 6.759422853623638
# 138.8685508578431
# 0.02519129537671917
# 0.18605191082777883
# 0.9319459887716516
# 0.00715085795370435
# 0.0021189657338887384
# Calculating Statistical Features for Blue Channel:
# 0.5013268993746849
# 0.5359898557495887
# 0.42338709677419356
# 0.03595646542982932
# 0.18962190123988662
# 0.5118732162231729
# -1.0402886742777997
# 7.062327467589788
# 142.29546568627455
# 0.022353557188444895
# 0.18110975659660755
# 0.9695646327295036
# 0.006979676682802986
# 0.002171256495227909
# Image number:  990
# Calculating Statistical features for Red Channel:
# 0.4133316339231005
# 0.4414919587426882
# 0.45098039215686275
# 0.02407211003291554
# 0.15515189342355942
# -0.22932005329402505
# -1.1818852567312002
# 7.121629198920898
# 200.53403799019608
# 0.014718658283091287
# 0.11322596608791091
# 0.9360367188701898
# 0.004962303382699239
# 0.003059771772945262
# Calculating Statistical Features for Green Channel:
# 0.4276130825865502
# 0.44477102249586437
# 0.44313725490196076
# 0.014968314052844812
# 0.12234506141583652
# -0.4737470251624798
# -0.30800219127484096
# 6.9292434329450145
# 200.01190257352945
# 0.015583780573976429
# 0.11483114252602905
# 0.8974047906693654
# 0.004975215496509123
# 0.0030517807532952626
# Calculating Statistical Features for Blue Channel:
# 0.34998767329197306
# 0.3866835950495695
# 0.3333333333333333
# 0.027032831224130582
# 0.16441663913403223
# -0.01967401014227097
# -1.3125002832054882
# 7.170634924625247
# 198.35379901960786
# 0.014524773263312387
# 0.11352339349066519
# 0.943586546021726
# 0.005016572894532537
# 0.003026447967067218
# Image number:  991
# Calculating Statistical features for Red Channel:
# 0.5162533030790442
# 0.5346677307036334
# 0.5333333333333333
# 0.019352109315749634
# 0.13911185900472192
# -0.6635814901818735
# 1.5773362008940977
# 7.072872825440459
# 532.0672640931374
# 0.015331152967392653
# 0.11410909240380007
# 0.7889703086982173
# 0.0018759898205119921
# 0.008118474076583304
# Calculating Statistical Features for Green Channel:
# 0.5352558210784313
# 0.5504865309516147
# 0.5411764705882353
# 0.01653662676079738
# 0.12859481622832772
# -1.046664485958288
# 3.6179090695799268
# 6.865005137254253
# 528.5988051470589
# 0.0167861404976717
# 0.1171982909326065
# 0.7545486833095114
# 0.001888281633647404
# 0.00806549493610137
# Calculating Statistical Features for Blue Channel:
# 0.4850007898667279
# 0.5255905060092778
# 0.5450980392156862
# 0.04101961383573862
# 0.20253299443729808
# -0.33201288548846236
# -0.7309668101599041
# 7.468353337201347
# 529.7546721813726
# 0.013998962709202109
# 0.11811969109253784
# 0.9008341834021136
# 0.0018841593464761714
# 0.008083144215543233
# Image number:  992
# Calculating Statistical features for Red Channel:
# 0.4687781560988653
# 0.4880365581833781
# 0.4642857142857143
# 0.018426722488025675
# 0.1357450643228905
# 0.3238383433565057
# -0.2526259083047777
# 7.07357943151713
# 65.2306832107843
# 0.02398375621026313
# 0.2611087587207419
# 0.9728372359120127
# 0.015104211631726532
# 0.000995291924757202
# Calculating Statistical Features for Green Channel:
# 0.49164974878704737
# 0.5127588445875985
# 0.4880952380952381
# 0.021202157220442164
# 0.14560960552258276
# 0.2001219189839352
# -0.5576772254128906
# 7.148337692396522
# 65.92222732843138
# 0.023054488510474987
# 0.2627002298200733
# 0.9761097102263011
# 0.014947867926451667
# 0.0010058350064417563
# Calculating Statistical Features for Blue Channel:
# 0.30268090868753106
# 0.33099555678891335
# 0.2896825396825397
# 0.017942326130093306
# 0.13394896838010104
# 0.012070728358314393
# -0.998292800844057
# 6.9686784940000015
# 59.61167279411766
# 0.02383779258387846
# 0.2595508364178292
# 0.9744030492533735
# 0.0165049634134424
# 0.00090957170297198
# Image number:  993
# Calculating Statistical features for Red Channel:
# 0.5049689797794118
# 0.5381909290453489
# 0.5294117647058824
# 0.03465580556723578
# 0.18616069823471273
# -0.4528165499160466
# -0.22414168975015025
# 7.532557444292254
# 1775.3806066176476
# 0.008227258175536838
# 0.03811133692231291
# 0.6067154205934692
# 0.0005629450286547363
# 0.027090156858400948
# Calculating Statistical Features for Green Channel:
# 0.5108177035462621
# 0.5397650327010639
# 0.5254901960784314
# 0.030411564270503493
# 0.1743891174084653
# -0.46345666070723435
# 0.14421784700411955
# 7.459946324964963
# 1774.9652420343136
# 0.008476808567540305
# 0.03735302211063659
# 0.5519693348669586
# 0.0005630767705501477
# 0.027083816098984546
# Calculating Statistical Features for Blue Channel:
# 0.49735083486519605
# 0.5420235922253542
# 0.5333333333333333
# 0.04643172158776958
# 0.21548021159208466
# -0.4438991282465276
# -0.5198116223314888
# 7.697389199426582
# 1772.5788296568626
# 0.007775829450595738
# 0.0379087381522829
# 0.7069029639525316
# 0.0005638341908219432
# 0.02704739983564888
# Image number:  994
# Calculating Statistical features for Red Channel:
# 0.41823682598039214
# 0.4303804354669098
# 0.4196078431372549
# 0.010305276626534115
# 0.10151490839543774
# -0.08511074245887972
# -0.1590277414803336
# 6.728981224091422
# 449.2458639705882
# 0.013731165121468793
# 0.06772475716528499
# 0.6648268314428506
# 0.0022210764784131327
# 0.006854931231543727
# Calculating Statistical Features for Green Channel:
# 0.44913719027650123
# 0.4614766688942144
# 0.4666666666666667
# 0.011236500244230311
# 0.10600235961633266
# -0.45928690938827726
# -0.08911001643613137
# 6.717030602489514
# 450.21994485294124
# 0.014649189895613713
# 0.06774620235486045
# 0.6921456958922689
# 0.0022162860445387755
# 0.006869800204553658
# Calculating Statistical Features for Blue Channel:
# 0.40397428624770215
# 0.41698998306299934
# 0.396078431372549
# 0.010685422025540015
# 0.10337031501132235
# 0.1017533759295021
# -0.31315219994923105
# 6.736927563865591
# 448.32501531862744
# 0.013697457202923917
# 0.06783425437006602
# 0.6774630688205753
# 0.002225628334402245
# 0.00684088724492041
# Image number:  995
# Calculating Statistical features for Red Channel:
# 0.590571586332173
# 0.5995806497982427
# 0.5803108808290155
# 0.010722157029583701
# 0.1035478489857887
# 0.225162348699089
# 0.3631378423735878
# 6.34320764237526
# 290.77112438725493
# 0.022216974597268437
# 0.13431578068617944
# 0.7916984077746058
# 0.0034276049527259154
# 0.004436588434872003
# Calculating Statistical Features for Green Channel:
# 0.5699964928503481
# 0.5819577029133796
# 0.5699481865284974
# 0.013778766118520424
# 0.11738298905088601
# -0.13229837542607373
# -0.26673281621869505
# 6.516135704241857
# 291.8090533088235
# 0.02134320784924084
# 0.13876747054858835
# 0.8373955373174106
# 0.0034154439052620344
# 0.0044524330980624605
# Calculating Statistical Features for Blue Channel:
# 0.4205927873522506
# 0.44927208710050276
# 0.44041450777202074
# 0.024947115474906183
# 0.15794655892075074
# 0.0262636812581916
# -1.0871085709666006
# 6.773157979505094
# 288.2012867647059
# 0.02074932827473229
# 0.13348089274041286
# 0.9111379719149706
# 0.0034580473805911785
# 0.004397346128275284
# Image number:  996
# Calculating Statistical features for Red Channel:
# 0.4835986567478553
# 0.5224449097506921
# 0.5411764705882353
# 0.03908102291607882
# 0.1976892078897551
# -0.5576678833005629
# -0.7674175084479264
# 7.4446549464353255
# 919.1579656862746
# 0.010563834781462302
# 0.06877212964711092
# 0.8194279747670316
# 0.001086782398111248
# 0.014025112618060238
# Calculating Statistical Features for Green Channel:
# 0.44145687327665445
# 0.4746310254633742
# 0.47843137254901963
# 0.030390439369214102
# 0.17432853859656514
# -0.6040624688044811
# -0.4198518879508195
# 7.27646909390745
# 919.5346047794118
# 0.011654948951300894
# 0.07269738131044856
# 0.767764410536798
# 0.001086339020862193
# 0.014030823018691893
# Calculating Statistical Features for Blue Channel:
# 0.37493693033854164
# 0.4214804671020053
# 0.4235294117647059
# 0.037068082416836165
# 0.19253073109723592
# -0.47738668429938586
# -0.855701789445142
# 7.341991632369723
# 909.2783088235295
# 0.012369220169066053
# 0.07514925813464288
# 0.8116471929496153
# 0.0010985800484150162
# 0.013874306124876735
# Image number:  997
# Calculating Statistical features for Red Channel:
# 0.5572716452858665
# 0.5685690197882272
# 0.5272727272727272
# 0.012719043623328917
# 0.11277873746114077
# 1.2261414878402637
# 0.8881795931312895
# 6.12482033925226
# 151.26237745098038
# 0.03982125453815586
# 0.2415961571456322
# 0.9087514756495418
# 0.006569328652644005
# 0.0023080647390468995
# Calculating Statistical Features for Green Channel:
# 0.49116987748579544
# 0.5049525731169435
# 0.45454545454545453
# 0.013729252548010882
# 0.11717189316560044
# 1.2673354548827391
# 0.8113644754660334
# 6.055689733761847
# 153.88066789215688
# 0.04211301597707599
# 0.23986760282650005
# 0.9140498262098957
# 0.00645833979011024
# 0.002348023301498196
# Calculating Statistical Features for Blue Channel:
# 0.45717357288707394
# 0.47097337650190346
# 0.5
# 0.012808245627271118
# 0.11317351999152063
# -1.3492786457139123
# 0.9635411811622951
# 6.077421991102395
# 140.34661458333335
# 0.04124209804437379
# 0.23575162786833712
# 0.9160065250867225
# 0.00707687175945209
# 0.002141515669573681
# Image number:  998
# Calculating Statistical features for Red Channel:
# 0.48701800178079047
# 0.5211157279864542
# 0.5215686274509804
# 0.034375067896298094
# 0.18540514528000052
# -0.5771529035865206
# -0.4006209093245241
# 7.435182994371605
# 1080.2392769607843
# 0.010185009686177327
# 0.06441767668838458
# 0.7586773761202238
# 0.000924873375535504
# 0.016482608749021684
# Calculating Statistical Features for Green Channel:
# 0.47869807224647665
# 0.5116685902144267
# 0.5058823529411764
# 0.032652901839525766
# 0.18070113956343986
# -0.48636507737529494
# -0.06937497344418242
# 7.431422286136736
# 1079.4846507352945
# 0.010414165825807389
# 0.06379404981269153
# 0.7462004814028037
# 0.0009255195229596807
# 0.01647104559174779
# Calculating Statistical Features for Blue Channel:
# 0.42400913612515323
# 0.47485611535918176
# 0.4745098039215686
# 0.04570458277641384
# 0.21378630165755202
# -0.5288624122708718
# -0.846365028662476
# 7.469884711545059
# 1065.6806678921569
# 0.012757483170918047
# 0.06905137365322116
# 0.8208890484798621
# 0.0009374989068683768
# 0.01626042715541987
# Image number:  999

# %%
#change the specific channels to csv data
import pandas as pd
#Convert red channel
red_file = pd.read_excel('RedChannel50.xlsx')
red_file.to_csv('RedData50.csv')

#Convert green channel
green_file = pd.read_excel('GreenChannel50.xlsx')
green_file.to_csv('GreenData100.csv')

#Convert blue channel
blue_file = pd.read_excel('BlueChannel100.xlsx')
blue_file.to_csv('BlueData100.csv')

# %%
#change the main file which contains features of all the three channels into csv
file = pd.read_excel('Output100.xlsx')
file.to_csv('Output100.csv')

# %% [markdown]
# # SVM

# %% [markdown]
# ## Apply SVM on Red Channel

# %%
# #read the data
# redData = pd.read_csv('RedData.csv')
# labelled = pd.read_csv('Labels1.csv')

# #classify data into dependent and indepedent variables
# redX = redData.iloc[:, :]
# redY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# redx_train, redx_test, redy_train, redy_test = train_test_split(redX, redY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# redSVC = SVC()

# #fit the model
# redSVC.fit(redx_train, redy_train)
# pred_r = redSVC.predict(redx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(redy_test, pred_r))

# %% [markdown]
# ## Apply SVM on Green Channel

# %%
# #read the data
# greenData = pd.read_csv('GreenData.csv')

# #classify data into dependent and indepedent variables
# greenX = greenData.iloc[:, :]
# greenY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# greenx_train, greenx_test, greeny_train, greeny_test = train_test_split(greenX, greenY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# greenSVC = SVC()

# #fit the model
# greenSVC.fit(greenx_train, greeny_train)
# pred_g = greenSVC.predict(greenx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for green Channel is ", accuracy_score(greeny_test, pred_g))

# %% [markdown]
# ## Apply SVM on Blue Channel

# %%
# #read the data
# blueData = pd.read_csv('BlueData.csv')

# #classify data into dependent and indepedent variables
# blueX = blueData.iloc[:, :]
# blueY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# bluex_train, bluex_test, bluey_train, bluey_test = train_test_split(blueX, blueY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# blueSVC = SVC()

# #fit the model
# blueSVC.fit(bluex_train, bluey_train)
# pred_b = blueSVC.predict(bluex_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(bluey_test, pred_b))

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Apply Random Forest on red channel

# %%
# #read the data
# RedData = pd.read_csv('RedData.csv')
# labelled = pd.read_csv('Labels1.csv')

# #classify data into dependent and indepedent variables
# RedX = RedData.iloc[:, :]
# RedY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Redx_train, Redx_test, Redy_train, Redy_test = train_test_split(RedX, RedY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# RedRF = RandomForestClassifier()

# #fit the model
# RedRF.fit(Redx_train, Redy_train)
# pred_R = RedRF.predict(Redx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(Redy_test, pred_R))

# %% [markdown]
# ## Apply Random Forest on green channel

# %%
# #read the data
# GreenData = pd.read_csv('GreenData.csv')

# #classify data into dependent and indepedent variables
# GreenX = GreenData.iloc[:, :]
# GreenY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Greenx_train, Greenx_test, Greeny_train, Greeny_test = train_test_split(GreenX, GreenY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# GreenRF = RandomForestClassifier()

# #fit the model
# GreenRF.fit(Greenx_train, Greeny_train)
# pred_G = GreenRF.predict(Greenx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for green Channel is ", accuracy_score(Greeny_test, pred_G))

# %% [markdown]
# ## Apply Random Forest on blue channel

# %%
# #read the data
# BlueData = pd.read_csv('BlueData.csv')

# #classify data into dependent and indepedent variables
# BlueX = BlueData.iloc[:, :]
# BlueY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Bluex_train, Bluex_test, Bluey_train, Bluey_test = train_test_split(BlueX, BlueY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# BlueRF = RandomForestClassifier()

# #fit the model
# BlueRF.fit(Bluex_train, Bluey_train)
# pred_B = BlueRF.predict(Bluex_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(Bluey_test, pred_B))
