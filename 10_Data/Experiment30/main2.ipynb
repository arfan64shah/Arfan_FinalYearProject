# %%
#import the required libraries
import skimage.feature as skf
import openpyxl
import numpy as np
import math
import cv2
from PIL import Image
from numpy import asarray
from scipy.stats import skew, kurtosis
import skimage.feature
import xlsxwriter
import os


#creates general file for features of all the three channels
outWorkbook = xlsxwriter.Workbook("Output30.xlsx")
outSheet = outWorkbook.add_worksheet()

#Writes headers for general file 
outSheet.write("A1", "Mean_R")
outSheet.write("B1", "RMS_R")
outSheet.write("C1", "Median_R")
outSheet.write("D1", "Variance_R")
outSheet.write("E1", "Std_R")
outSheet.write("F1", "Skewness_R")
outSheet.write("G1", "Kurtosis_R")
outSheet.write("H1", "Contrast_R")
outSheet.write("I1", "Entropy_R")
outSheet.write("J1", "Energy_R")
outSheet.write("K1", "Homogeneity_R")
outSheet.write("L1", "Correlation_R")
outSheet.write("M1", "IDM_R")
outSheet.write("N1", "Smoothness_R")
outSheet.write("O1", "Mean_G")
outSheet.write("P1", "RMS_G")
outSheet.write("Q1", "Median_G")
outSheet.write("R1", "Variance_G")
outSheet.write("S1", "Std_G")
outSheet.write("T1", "Skewness_G")
outSheet.write("U1", "Kurtosis_G")
outSheet.write("V1", "Contrast_G")
outSheet.write("W1", "Entropy_G")
outSheet.write("X1", "Energy_G")
outSheet.write("Y1", "Homogeneity_G")
outSheet.write("Z1", "Correlation_G")
outSheet.write("AA1", "IDM_G")
outSheet.write("AB1", "Smoothness_G")
outSheet.write("AC1", "Mean_B")
outSheet.write("AD1", "RMS_B")
outSheet.write("AE1", "Median_B")
outSheet.write("AF1", "Variance_B")
outSheet.write("AG1", "Std_B")
outSheet.write("AH1", "Skewness_B")
outSheet.write("AI1", "Kurtosis_B")
outSheet.write("AJ1", "Contrast_B")
outSheet.write("AK1", "Entropy_B")
outSheet.write("AL1", "Energy_B")
outSheet.write("AM1", "Homogeneity_B")
outSheet.write("AN1", "Correlation_B")
outSheet.write("AO1", "IDM_B")
outSheet.write("AP1", "Smoothness_B")
outWorkbook.close()

# %%
#creates a file for red channel
outWorkbookR = xlsxwriter.Workbook("RedChannel30.xlsx")
outSheetR = outWorkbookR.add_worksheet()

#writes headers for red file
outSheetR.write("A1", "Mean_R")
outSheetR.write("B1", "RMS_R")
outSheetR.write("C1", "Median_R")
outSheetR.write("D1", "Variance_R")
outSheetR.write("E1", "Std_R")
outSheetR.write("F1", "Skewness_R")
outSheetR.write("G1", "Kurtosis_R")
outSheetR.write("H1", "Contrast_R")
outSheetR.write("I1", "Entropy_R")
outSheetR.write("J1", "Energy_R")
outSheetR.write("K1", "Homogeneity_R")
outSheetR.write("L1", "Correlation_R")
outSheetR.write("M1", "IDM_R")
outSheetR.write("N1", "Smoothness_R")
outWorkbookR.close()

# %%
#creates file for green channel
outWorkbookG = xlsxwriter.Workbook("GreenChannel30.xlsx")
outSheetG = outWorkbookG.add_worksheet()

#writes headers for green file
outSheetG.write("A1", "Mean_G")
outSheetG.write("B1", "RMS_G")
outSheetG.write("C1", "Median_G")
outSheetG.write("D1", "Variance_G")
outSheetG.write("E1", "Std_G")
outSheetG.write("F1", "Skewness_G")
outSheetG.write("G1", "Kurtosis_G")
outSheetG.write("H1", "Contrast_G")
outSheetG.write("I1", "Entropy_G")
outSheetG.write("J1", "Energy_G")
outSheetG.write("K1", "Homogeneity_G")
outSheetG.write("L1", "Correlation_G")
outSheetG.write("M1", "IDM_G")
outSheetG.write("N1", "Smoothness_G")
outWorkbookG.close()

# %%
#creates a file for blue channel
outWorkbookB = xlsxwriter.Workbook("BlueChannel30.xlsx")
outSheetB = outWorkbookB.add_worksheet()

#writes headers for blue file
outSheetB.write("A1", "Mean_B")
outSheetB.write("B1", "RMS_B")
outSheetB.write("C1", "Median_B")
outSheetB.write("D1", "Variance_B")
outSheetB.write("E1", "Std_B")
outSheetB.write("F1", "Skewness_B")
outSheetB.write("G1", "Kurtosis_B")
outSheetB.write("H1", "Contrast_B")
outSheetB.write("I1", "Entropy_B")
outSheetB.write("J1", "Energy_B")
outSheetB.write("K1", "Homogeneity_B")
outSheetB.write("L1", "Correlation_B")
outSheetB.write("M1", "IDM_B")
outSheetB.write("N1", "Smoothness_B")
outWorkbookB.close()

# %%
# import glob
# import os
# import cv2
# from PIL import Image
# import numpy as np

# directory = r'/home/uca/Desktop/Undergrad/Arfan_FinalYearProject/10_Data/processed_30'
# os.makedirs(directory, exist_ok=True)  # create the directory if it does not exist

# for filename in glob.glob('/home/uca/Desktop/Undergrad/Arfan_FinalYearProject/10_Data/data30/*.*'):
#     im = cv2.imread(filename)
    
#     # Convert the image to grayscale
#     image = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

    
#     # apply mean filter
#     # convert to HSV
#     image = cv2.cvtColor(im, cv2.COLOR_BGR2HSV)
#     image = cv2.blur(image, (5, 5))
#     image = cv2.cvtColor(image, cv2.COLOR_HSV2RGB)
    
    
    
#     # Apply laplacian filter to reduce the affects of mean filter which has blurred edges
#     # Apply the Laplacian filter to enhance the edges
#     laplacian = cv2.Laplacian(image, cv2.CV_64F)
#     # Adjust the contrast of the Laplacian image
#     laplacian = cv2.convertScaleAbs(laplacian)
#     # Add the Laplacian image back to the original to create the final enhanced image
#     image = cv2.addWeighted(im, 1.5, laplacian, -0.5, 0)
    
    
#     # Convert the image to a NumPy array
#     image_array = np.array(image)
#     # Invert the colors
#     inverted_array = 255 - image_array   
#     # Convert the NumPy array back to an image
#     image = Image.fromarray(inverted_array.astype(np.uint8))
    
    
#     file = os.path.basename(filename)
#     image_array = np.array(image, dtype=np.uint8) # convert the Image object to a NumPy array of type uint8
#     cv2.imwrite(os.path.join(directory, file), image_array) # save the image in the created directory

# %%
# import glob
# import os
# import cv2
# from PIL import Image
# import numpy as np

# directory = r'/home/uca/Desktop/Undergrad/Arfan_FinalYearProject/10_Data/Experiment30/experimental_processed_30/'
# os.makedirs(directory, exist_ok=True)  # create the directory if it does not exist

# for filename in glob.glob('/home/uca/Desktop/Undergrad/Arfan_FinalYearProject/10_Data/Experiment30/experimental_30/*.*'):
#     im = cv2.imread(filename)
    
#     # Convert the image to grayscale
#     image = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    
#     # apply mean filter
#     # convert to HSV
#     image = cv2.cvtColor(im, cv2.COLOR_BGR2HSV)
#     image = cv2.blur(image, (5, 5))
#     image = cv2.cvtColor(image, cv2.COLOR_HSV2RGB)
    
#     # Apply laplacian filter to reduce the affects of mean filter which has blurred edges
#     # Apply the Laplacian filter to enhance the edges
#     laplacian = cv2.Laplacian(image, cv2.CV_64F)
#     # Adjust the contrast of the Laplacian image
#     laplacian = cv2.convertScaleAbs(laplacian)
#     # Add the Laplacian image back to the original to create the final enhanced image
#     image = cv2.addWeighted(im, 1.5, laplacian, -0.5, 0)
    
#     # Convert the image to a NumPy array
#     image_array = np.array(image)
#     # Invert the colors
#     inverted_array = 255 - image_array   
#     # Convert the NumPy array back to an image
#     image = Image.fromarray(inverted_array.astype(np.uint8))
    
#     # Convert the image to grayscale
#     image = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)
    
#     # apply otsu segmentation
#     # apply adaptive thresholding to obtain a binary image
#     thresh = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 25, 2)

#     # perform morphological opening to remove small objects and smooth edges
#     kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5,5))
#     opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel)

#     # find contours in the image
#     contours, hierarchy = cv2.findContours(opening, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

#     # create a mask for the infected parts of the leaf
#     mask = np.zeros_like(opening)
#     for cnt in contours:
#         area = cv2.contourArea(cnt)
#         if area > 1000:
#             cv2.drawContours(mask, [cnt], 0, 255, -1)

#     # apply the mask to the original image
#     image = cv2.bitwise_and(im, im, mask=mask)
    
#     file = os.path.basename(filename)
#     image_array = np.array(image, dtype=np.uint8) # convert the Image object to a NumPy array of type uint8
#     cv2.imwrite(os.path.join(directory, file), image_array) # save the image in the created directory

# %%
#import required libaray to read and make a list of all the needy images
import glob

#declare an empty list
Image_list = []

#using for loop to append to the list declared above
for filename in glob.glob('/home/uca/Desktop/Undergrad/Arfan_FinalYearProject/10_Data/Experiment30/experimental_30/*.*'):
    im = Image.open(filename)
    
    #append each image to the list declared above
    Image_list.append(im)
    
#prints number of images used
print(len(Image_list))
# Out:
# 360

# %%
#uses for loop to read each image and array of each image
for i in range(0, len(Image_list)):
    Image = Image_list[i]
    image = asarray(Image)
  
    
    #Here i am extracting the single channel like red, green, and blue from the whole image array
    R = image[:, :, 0]
    G = image[:, :, 1]
    B = image[:, :, 2]


    #selecting features from Red Channel
    print("Calculating Statistical features for Red Channel: ")
    
    #calculates mean
    Mean_R = np.mean(R);
    print(Mean_R)
    
    #calculating root mean square
    RMS_R = np.sqrt(np.mean(R**2))
    print(RMS_R)
    
    #calculating median
    Median_R = np.median(R)
    print(Median_R)
    
    #calculating variance of the pixels
    Variance_R = np.var(R)
    print(Variance_R)
    
    #calculating standard deviation
    Std_R = math.sqrt(Variance_R)
    print(Std_R)
    
    #calculates skewness
    Skewness_R = skew(R.reshape(-1))
    print(Skewness_R)
    
    #calculates kurtosis
    Kurtosis_R = kurtosis(R.reshape(-1))
    print(Kurtosis_R)
    
    #calculates entropy
    Entropy_R = skimage.measure.shannon_entropy(R)
    print(Entropy_R)
    
    #returns an image array where lowest pixel value is 0 and highest 8 instead of 0 and 255
    R = skimage.img_as_ubyte(R)
    
    #calculates contrast
    g1 = skf.graycomatrix(R, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_R = skf.graycoprops(g1, 'contrast')[0][0]
    print(Contrast_R)
    
    #calculates energy
    Energy_R = skf.graycoprops(g1, 'energy')[0][0]
    print(Energy_R)
    
    #calculating homogeniety
    Homogeneity_R = skf.graycoprops(g1, 'homogeneity')[0][0]
    print(Homogeneity_R)
    
    #finding correlation
    Correlation_R = skf.graycoprops(g1, 'correlation')[0][0]
    print(Correlation_R)
    
    #glcm_R = skf.graycomatrix(R, distances=[1], angles=[0], levels=256, symmetric= False, normed=True)
    
    #calculate inverse difference moment (IDM)
    IDM_R = 1 / (1 + Contrast_R - Energy_R)
    print(IDM_R)
    
    #calculates smoothness
    diff_R = np.diff(R.astype(float))
    variance_R = np.var(diff_R)
    Smoothness_R = variance_R / (R.shape[0] * R.shape[1])
    print(Smoothness_R)
    

    #selecting features from Green Channel
    print("Calculating Statistical Features for Green Channel: ")
    
    #calculates mean
    Mean_G = np.mean(G);
    print(Mean_G)
    
    #calculates root mean square
    RMS_G = np.sqrt(np.mean(G**2))
    print(RMS_G)
    
    #calculates median
    Median_G = np.median(G)
    print(Median_G)
    
    #claculates variance
    Variance_G = np.var(G)
    print(Variance_G)
    
    #calculates standard deviation
    Std_G = math.sqrt(Variance_G)
    print(Std_G)
    
    #calculates skewness
    Skewness_G = skew(G.reshape(-1))
    print(Skewness_G)
    
    #calculates kurtosis
    Kurtosis_G = kurtosis(G.reshape(-1))
    print(Kurtosis_G)
    
    #calculates entropy
    Entropy_G = skimage.measure.shannon_entropy(G)
    print(Entropy_G)
    
    #converts images pixels to range of 0 to 8 instead of 0 to 255
    G = skimage.img_as_ubyte(G)
    
    #calculates contrast
    g2 = skf.graycomatrix(G, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_G = skf.graycoprops(g2, 'contrast')[0][0]
    print(Contrast_G)
    
    #calculates energy
    Energy_G = skf.graycoprops(g2, 'energy')[0][0]
    print(Energy_G)
    
    #calculates homogeniety
    Homogeneity_G = skf.graycoprops(g2, 'homogeneity')[0][0]
    print(Homogeneity_G)
    
    #calculates correlation
    Correlation_G = skf.graycoprops(g2, 'correlation')[0][0]
    print(Correlation_G)
    #glcm_G = skf.graycomatrix(G, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
    
    #calculates inverse difference moment (IDM)
    IDM_G = 1 / (1 + Contrast_G - Energy_G)
    print(IDM_G)
    
    #calculates smoothness
    diff_G = np.diff(G.astype(float))
    variance_G = np.var(diff_G)
    Smoothness_G = variance_G / (G.shape[0] * G.shape[1])
    print(Smoothness_G)

    #selecting features from Blue Channel
    print("Calculating Statistical Features for Blue Channel: ")
    
    #calculates mean
    Mean_B = np.mean(B);
    print(Mean_B)
    
    #calculates root mean square
    RMS_B = np.sqrt(np.mean(B**2))
    print(RMS_B)
    
    #calculates median
    Median_B = np.median(B)
    print(Median_B)
    
    #calculates variance
    Variance_B = np.var(B)
    print(Variance_B)
    
    #calculates standard deviation
    Std_B = math.sqrt(Variance_B)
    print(Std_B)
    
    #calculates skewness
    Skewness_B = skew(B.reshape(-1))
    print(Skewness_B)
    
    #calculates kurtosis
    Kurtosis_B = kurtosis(B.reshape(-1))
    print(Kurtosis_B)
    
    #calculates entropy
    Entropy_B = skimage.measure.shannon_entropy(B)
    print(Entropy_B)
    
    #converts range of pixels values from 0-255 to 0-8
    B = skimage.img_as_ubyte(B)
    
    #calculates contrast
    g3 = skf.graycomatrix(B, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_B = skf.graycoprops(g3, 'contrast')[0][0]
    print(Contrast_B)
    
    #calculates energy
    Energy_B = skf.graycoprops(g3, 'energy')[0][0]
    print(Energy_B)
    
    #calculates homogeniety
    Homogeneity_B = skf.graycoprops(g3, 'homogeneity')[0][0]
    print(Homogeneity_B)
    
    #calculates correlation
    Correlation_B = skf.graycoprops(g3, 'correlation')[0][0]
    print(Correlation_B)
    
    #glcm_B = skf.graycomatrix(B, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
    
    #calculates inverse difference moment (IDM)
    IDM_B = 1 / (1 + Contrast_B - Energy_B)
    print(IDM_B)
    
    #calculates smoothness
    diff_B = np.diff(B.astype(float))
    variance_B = np.var(diff_B)
    Smoothness_B = variance_B / (B.shape[0] * B.shape[1])
    print(Smoothness_B)
    
    #count the number of images
    print("Image number: ", i)


    #Declares data for all the three channels
    values_R = [Mean_R, RMS_R, Median_R, Variance_R, Std_R, Skewness_R, Kurtosis_R, Entropy_R, Contrast_R, Energy_R, Homogeneity_R, Correlation_R, IDM_R, Smoothness_R]
    values_G = [Mean_G, RMS_G, Median_G, Variance_G, Std_G, Skewness_G, Kurtosis_G, Entropy_G, Contrast_G, Energy_G, Homogeneity_G, Correlation_G, IDM_G, Smoothness_G]
    values_B = [Mean_B, RMS_B, Median_B, Variance_B, Std_B, Skewness_B, Kurtosis_B, Entropy_B, Contrast_B, Energy_B, Homogeneity_B, Correlation_B, IDM_B, Smoothness_B]

    #Writes red channels into a file
    outWorkbookR = openpyxl.load_workbook("RedChannel30.xlsx")
    outSheetR = outWorkbookR.active
    outSheetR.append(values_R)
    outWorkbookR.save(filename="RedChannel30.xlsx")

    #Writes green channels into a file
    outWorkbookG = openpyxl.load_workbook("GreenChannel30.xlsx")
    outSheetG = outWorkbookG.active
    outSheetG.append(values_G)
    outWorkbookG.save(filename="GreenChannel30.xlsx")

    #writes blue chanels into a file
    outWorkbookB = openpyxl.load_workbook("BlueChannel30.xlsx")
    outSheetB = outWorkbookB.active
    outSheetB.append(values_B)
    outWorkbookB.save(filename="BlueChannel30.xlsx")
    
    #creates a general fle where all the three channels data will be merged
    outWorkbook = xlsxwriter.Workbook("Output30.xlsx")
    outSheet = outWorkbook.add_worksheet()
        
    #declares data for general file
    values = [Mean_R, RMS_R, Median_R, Variance_R, Std_R, Skewness_R, Kurtosis_R, Entropy_R, Contrast_R, Energy_R, Homogeneity_R, Correlation_R, IDM_R, Smoothness_R, Mean_G, RMS_G, Median_R, Variance_G, Std_G, Skewness_G, Kurtosis_G, Entropy_G, Contrast_G, Energy_G, Homogeneity_G, Correlation_G, IDM_G, Smoothness_G, Mean_B, RMS_B, Median_R, Variance_B, Std_B, Skewness_B, Kurtosis_B, Entropy_B, Contrast_B, Energy_B, Homogeneity_B, Correlation_B, IDM_B, Smoothness_B]
    
     
    #writes into the general file
    outWorkbook = openpyxl.load_workbook("Output30.xlsx") 
    outSheet = outWorkbook.active
    outSheet.append(values)
    
    #here the general file is being saved
    outWorkbook.save(filename="Output30.xlsx")
# Out:
# Calculating Statistical features for Red Channel:
# 134.04002380371094
# 10.049618264914733
# 139.0
# 1630.528564721113
# 40.37980392128116
# -0.9593746646410427
# 1.144474172397171
# 7.19700559854357
# 467.68367034313724
# 0.014352221449755436
# 0.11126699570462711
# 0.8569309589427707
# 0.0021337005887386794
# 0.007136135192008625
# Calculating Statistical Features for Green Channel:
# 138.9476776123047
# 10.075819594600217
# 144.0
# 1506.7915891499724
# 38.8174134783601
# -1.2637467665612292
# 2.3279101999708276
# 7.06855801776787
# 467.33098958333335
# 0.01511629551697208
# 0.11103316248605911
# 0.8452623217313826
# 0.0021353109237564165
# 0.007130720864681356
# Calculating Statistical Features for Blue Channel:
# 130.74371337890625
# 10.50372539008482
# 149.0
# 3409.4409089647233
# 58.390417955043986
# -0.5505932431951983
# -0.7912137480085533
# 7.6160131324708455
# 469.8005208333334
# 0.012395051096978311
# 0.1112774994140921
# 0.9312471365493515
# 0.0021240977527597015
# 0.0071684030751364355
# Image number:  0
# Calculating Statistical features for Red Channel:
# 131.64303588867188
# 10.157357211281788
# 136.0
# 1611.7166012814268
# 40.14619037071173
# -0.4692888332913973
# 0.06458847996136496
# 7.326355878074393
# 1262.1557138480393
# 0.009142513126830584
# 0.03893376619234407
# 0.609191723718261
# 0.0007916737635151752
# 0.019258953693137716
# Calculating Statistical Features for Green Channel:
# 129.14744567871094
# 10.066774585810663
# 131.0
# 1444.503787725931
# 38.0066282077999
# -0.2591252832192681
# 0.4043745044607103
# 7.266498155384717
# 1261.3345894607846
# 0.009434682829855044
# 0.03844369678981365
# 0.5642351658900258
# 0.0007921889191663155
# 0.019246427143871304
# Calculating Statistical Features for Blue Channel:
# 114.98284912109375
# 10.077131733999263
# 124.0
# 2427.0828357301652
# 49.265432462632106
# -0.522744774210292
# -0.4867537167640483
# 7.511660157468277
# 1254.5425091911766
# 0.008786778593051077
# 0.041004005385289456
# 0.7420464201604895
# 0.0007964740270603324
# 0.019142795872313476
# Image number:  1
# Calculating Statistical features for Red Channel:
# 113.55374145507812
# 9.45039184403797
# 116.0
# 502.4905200591311
# 22.416300320506306
# -0.32447234568042244
# -0.01231480342516944
# 6.494225868483826
# 352.2446078431372
# 0.016544926110420653
# 0.0827873274381126
# 0.649498023802379
# 0.002831032143204601
# 0.005374825673979185
# Calculating Statistical Features for Green Channel:
# 123.71385192871094
# 9.71700945904389
# 127.0
# 666.9437387881335
# 25.82525389590843
# -0.3931244253996126
# -0.3142060895899186
# 6.6691783637849795
# 353.0527879901962
# 0.015388276101770576
# 0.0824949391594912
# 0.7355459883946599
# 0.002824560345340796
# 0.005387157288332345
# Calculating Statistical Features for Blue Channel:
# 112.58551025390625
# 9.72537643370907
# 114.0
# 485.2108276449144
# 22.027501620585898
# -0.07509278616580528
# -0.05593368441734903
# 6.494612938916568
# 350.8708946078431
# 0.016060702429646124
# 0.08210115919559269
# 0.6382382463096113
# 0.0028420811756385378
# 0.005353864755815196
# Image number:  2
# Calculating Statistical features for Red Channel:
# 126.21005249023438
# 10.523886984647117
# 131.0
# 3905.028753927909
# 62.49022926768559
# -0.3521394054105363
# -1.1374083677050637
# 7.570329922240151
# 497.3059129901961
# 0.02137186256894222
# 0.2063271951973802
# 0.9363700852964696
# 0.0020068854589327246
# 0.007588195288478642
# Calculating Statistical Features for Green Channel:
# 127.10195922851562
# 10.372418553567467
# 137.0
# 3387.2415269231424
# 58.20001311789493
# -0.6071011216020523
# -0.7088444188308056
# 7.527051662008643
# 496.1462775735295
# 0.020942922459566027
# 0.20823372185256428
# 0.9268512085887055
# 0.0020115651532865357
# 0.007570477454750865
# Calculating Statistical Features for Blue Channel:
# 108.17298889160156
# 10.442116453119445
# 103.0
# 4340.579770277953
# 65.8830765089029
# -0.07188181328071364
# -1.372704754524482
# 7.609212399987323
# 489.6608915441177
# 0.020988766964971317
# 0.21087993954150777
# 0.9436005151641614
# 0.002038154651384311
# 0.007471476708954541
# Image number:  3
# Calculating Statistical features for Red Channel:
# 100.70556640625
# 9.531696646809364
# 107.0
# 4839.898385763168
# 69.56937821889146
# -0.01031932649854917
# -1.2237202159379021
# 7.34390407046774
# 1260.9795955882355
# 0.12064888935512501
# 0.17682341204726537
# 0.8693866499523969
# 0.0007924816023344579
# 0.01924085648208341
# Calculating Statistical Features for Green Channel:
# 97.73162841796875
# 9.51859751909223
# 105.0
# 4208.823911752552
# 64.87544922197111
# -0.09746461221065421
# -1.1618172217281664
# 7.247285964946136
# 1258.3727022058822
# 0.12038449590189727
# 0.1811447155788262
# 0.8500872562751727
# 0.0007941220245824562
# 0.019201044036359777
# Calculating Statistical Features for Blue Channel:
# 91.536865234375
# 9.487079065205114
# 96.0
# 4452.061659753323
# 66.72377132441872
# 0.0747687267036161
# -1.2335868672841024
# 7.1825853569252835
# 1250.8288296568626
# 0.13192515622660456
# 0.18303321253366192
# 0.8592059819349742
# 0.000798915453417175
# 0.01908595891512561
# Image number:  4
# Calculating Statistical features for Red Channel:
# 108.68304443359375
# 10.632572841255751
# 105.0
# 4881.098239120096
# 69.86485696772087
# -0.00631974014183343
# -1.5005361351333601
# 7.604065785934091
# 565.8936427696079
# 0.022028527159270297
# 0.2017069890070708
# 0.9419639671044608
# 0.0017640678680592816
# 0.00863103165156618
# Calculating Statistical Features for Green Channel:
# 111.47657775878906
# 10.47150951853073
# 116.0
# 4283.511841535335
# 65.44854346381847
# -0.14109495015401938
# -1.3785595361406804
# 7.633514460438255
# 564.6350796568628
# 0.020785023645039154
# 0.20220397680585966
# 0.934000604299844
# 0.0017679892631576209
# 0.008611793510504109
# Calculating Statistical Features for Blue Channel:
# 94.43370056152344
# 9.849656431141314
# 83.0
# 5367.436461318051
# 73.26279042814335
# 0.15189689296240236
# -1.5424598753807182
# 7.390851370128645
# 554.7193933823529
# 0.031048654814861597
# 0.21554634107029028
# 0.9482781039814792
# 0.00179956986589365
# 0.008460365662602613
# Image number:  5
# Calculating Statistical features for Red Channel:
# 110.60934448242188
# 10.22691462342596
# 119.0
# 2587.1861333837733
# 50.86438963935155
# -0.22232143764852821
# -0.8402940635979212
# 7.501170049424475
# 1865.3077052696078
# 0.011019407567980664
# 0.0631839874581822
# 0.6398457910338243
# 0.0005358204874795142
# 0.028462225762476968
# Calculating Statistical Features for Green Channel:
# 111.98805236816406
# 10.158803014456154
# 119.0
# 2429.951624221867
# 49.29453949700582
# -0.19509335659597937
# -0.5729034680817837
# 7.530434963863669
# 1865.8793658088234
# 0.010139751167921074
# 0.0625734768299901
# 0.6166467743856087
# 0.0005356561595435055
# 0.028470896854563426
# Calculating Statistical Features for Blue Channel:
# 103.55209350585938
# 10.042294895469766
# 115.0
# 3125.788179821335
# 55.90874868767262
# -0.28968354488868997
# -0.9038788214434379
# 7.584715134872027
# 1862.1247242647057
# 0.010050840864969707
# 0.0626333723802949
# 0.7023425336627549
# 0.0005367356149701203
# 0.02841361041184012
# Image number:  6
# Calculating Statistical features for Red Channel:
# 133.05418395996094
# 10.110540921223086
# 138.0
# 809.0923247186001
# 28.444548242476976
# -0.8393665705055122
# 0.9783006896280666
# 6.676380185546733
# 14.691344975490193
# 0.04646057126988639
# 0.43521979960642004
# 0.9909438690927013
# 0.06391865699757064
# 0.00022414824444126025
# Calculating Statistical Features for Green Channel:
# 145.98060607910156
# 10.320322110375919
# 153.0
# 992.38654099009
# 31.502167242748396
# -0.4629248504302732
# 0.2390966623038131
# 6.852443273829775
# 14.709604779411762
# 0.043664661312890596
# 0.44138332294492616
# 0.992607264344062
# 0.0638327475058263
# 0.00022442424608632973
# Calculating Statistical Features for Blue Channel:
# 98.68653869628906
# 10.369431069639637
# 106.0
# 2165.7968683538493
# 46.538122742047186
# -0.31983265408900297
# -1.1478923727822552
# 7.171845835030791
# 14.43717830882353
# 0.038296721813419116
# 0.41937603121715666
# 0.9966711722688671
# 0.06493978113602487
# 0.0002202477366246372
# Image number:  7
# Calculating Statistical features for Red Channel:
# 179.302001953125
# 10.498367909335508
# 188.0
# 1614.2578243613243
# 40.17782752167325
# -0.6799055579233458
# -0.3654365122222858
# 7.090231613666241
# 198.66279105392155
# 0.02503917635503786
# 0.21653982796754498
# 0.9385410174542521
# 0.005009072635787234
# 0.003031128852874161
# Calculating Statistical Features for Green Channel:
# 173.33154296875
# 10.67266851689325
# 181.0
# 1340.5508153438568
# 36.61353322671628
# -1.0250882939286763
# 0.7410305954838909
# 6.9579701512534005
# 201.48460477941174
# 0.02586537430401637
# 0.21646983094053232
# 0.9249588424659468
# 0.004939278012588334
# 0.0030741674359314936
# Calculating Statistical Features for Blue Channel:
# 152.09918212890625
# 10.645361922863403
# 166.0
# 3409.7719011865556
# 58.39325218881507
# -0.3527298683398834
# -1.2445700605434433
# 7.4135668807102455
# 200.1451133578432
# 0.023586836409187673
# 0.2123530407559959
# 0.9706818830050117
# 0.004972118187922701
# 0.003053744678675229
# Image number:  8
# Calculating Statistical features for Red Channel:
# 133.06008911132812
# 10.218018298536109
# 140.0
# 2465.6471461346373
# 49.655283164378766
# -0.6291412727850862
# -0.31387243071171067
# 7.463476485258319
# 941.4939185049019
# 0.011546282704379622
# 0.08079144332029554
# 0.809437864158589
# 0.0010610278021881583
# 0.01436593123596349
# Calculating Statistical Features for Green Channel:
# 129.66445922851562
# 10.299167221624494
# 136.0
# 2362.0641396855935
# 48.60107138413302
# -0.6155950042705185
# -0.21702602128074933
# 7.430513630461698
# 940.5804074754902
# 0.012007146314597239
# 0.08086543003273634
# 0.8012817631459018
# 0.0010620577322373993
# 0.014352007940184555
# Calculating Statistical Features for Blue Channel:
# 119.90116882324219
# 10.221989016245429
# 126.0
# 2876.940961768618
# 53.63712298183617
# -0.4574584226524833
# -0.673558847358041
# 7.5795170484815335
# 940.575919117647
# 0.010958783769155505
# 0.07986121119011234
# 0.836822060426757
# 0.0010620616124514671
# 0.014351980980200657
# Image number:  9
# Calculating Statistical features for Red Channel:
# 112.92124938964844
# 10.524147241981103
# 102.0
# 4027.818642701721
# 63.465097831026156
# 0.0986343850389773
# -1.3136810082642163
# 7.656082705071759
# 660.7844975490196
# 0.014410570819521164
# 0.11953682430035183
# 0.9179580573513101
# 0.0015110988237111748
# 0.010082771220544882
# Calculating Statistical Features for Green Channel:
# 115.48384094238281
# 10.369732726137325
# 113.0
# 3186.8888380059507
# 56.45253615211588
# -0.085392182200013
# -1.0377612360491302
# 7.6099728925720465
# 659.7588848039215
# 0.014186206967940897
# 0.1207753200828197
# 0.8965367013467231
# 0.0015134438492256266
# 0.010067121589105893
# Calculating Statistical Features for Blue Channel:
# 97.75686645507812
# 10.332455833667401
# 84.0
# 4055.5890794387087
# 63.68350712263505
# 0.25464422685961724
# -1.2951995590006413
# 7.5961674417188565
# 648.7529564950983
# 0.013822444978801455
# 0.12223528219221172
# 0.9199719540461021
# 0.001539079220558173
# 0.00989918243229856
# Image number:  10
# Calculating Statistical features for Red Channel:
# 120.37959289550781
# 9.291239593224951
# 128.0
# 1033.483091240516
# 32.14783182798672
# -1.0599550558148625
# 1.7185235985480292
# 6.838017238852364
# 902.6470435049018
# 0.015141531459053585
# 0.06125157416324855
# 0.5545602469263644
# 0.0011066453030444132
# 0.013769928542109367
# Calculating Statistical Features for Green Channel:
# 116.17884826660156
# 9.842552475521705
# 115.0
# 777.2104296793696
# 27.87849403535581
# -0.3981693536571382
# 3.1715993620523486
# 6.6721308685645075
# 900.3856464460787
# 0.015672535582982913
# 0.06135138834852934
# 0.4027372642252278
# 0.001109422355907429
# 0.013735980817049841
# Calculating Statistical Features for Blue Channel:
# 110.84518432617188
# 9.355609830616835
# 123.0
# 1551.4311407497153
# 39.38821068225511
# -0.9531202171681251
# 0.4364170907842029
# 7.04078100516854
# 890.3770833333335
# 0.014112189407745853
# 0.06345869713593322
# 0.7105925103878363
# 0.0011218774308255767
# 0.013583220150171335
# Image number:  11
# Calculating Statistical features for Red Channel:
# 116.39372253417969
# 9.030182983301836
# 120.0
# 888.9713405983057
# 29.815622425136553
# 0.14269307502583053
# 0.7718858816163627
# 6.734509225827954
# 36.25507046568627
# 0.03852336033419708
# 0.32146619862208303
# 0.9796778327503478
# 0.026869768363228703
# 0.0005531306169470233
# Calculating Statistical Features for Green Channel:
# 128.75830078125
# 8.897226788794923
# 127.0
# 892.8317182064056
# 29.880289794551953
# 0.46960030290906707
# 0.9891397140606593
# 6.697156939124836
# 36.29238664215687
# 0.03913338196023585
# 0.3232568290312499
# 0.9797332511741452
# 0.026843293202219558
# 0.0005536928461805152
# Calculating Statistical Features for Blue Channel:
# 86.66848754882812
# 9.55056157083757
# 99.0
# 1406.9896173169836
# 37.50986026789467
# -0.4559865031361488
# -1.1923518723667383
# 6.82750123593837
# 34.68137254901961
# 0.03516274730105817
# 0.3160885777186689
# 0.9876990088364794
# 0.02805347344254784
# 0.0005290898622107799
# Image number:  12
# Calculating Statistical features for Red Channel:
# 127.41361999511719
# 9.923376639564985
# 124.0
# 593.0006561705377
# 24.35160479661531
# 0.12969607140228792
# -0.5171056344820184
# 6.589943687266917
# 253.15436580882357
# 0.01690964161065963
# 0.09742181808126019
# 0.7864912288864255
# 0.003934878451533872
# 0.003862811468999227
# Calculating Statistical Features for Green Channel:
# 140.3199920654297
# 10.112683752627888
# 144.0
# 456.4958869384136
# 21.36576436588248
# -0.665393086320106
# 0.7856935304348602
# 6.348779155604104
# 253.54744178921567
# 0.02000871948572015
# 0.09786260571771702
# 0.7223073092606003
# 0.0039288495858363585
# 0.003868809364208295
# Calculating Statistical Features for Blue Channel:
# 123.96832275390625
# 10.085111434994161
# 121.0
# 660.6113012395799
# 25.702359837952233
# 0.11993392562669904
# -0.5952368204235436
# 6.6554580500478515
# 252.60470281862746
# 0.01648220247588661
# 0.09798840286510728
# 0.8087476582665492
# 0.003943400831356706
# 0.0038544195869766383
# Image number:  13
# Calculating Statistical features for Red Channel:
# 125.6591796875
# 10.11540917044619
# 119.0
# 1426.8342504501343
# 37.77345960393533
# 0.9461508765891371
# 0.6441592877117555
# 7.058943561874045
# 141.9897212009804
# 0.020073855795007554
# 0.1766578230135
# 0.9503610532034816
# 0.006994491618109707
# 0.002166117748520589
# Calculating Statistical Features for Green Channel:
# 127.33174133300781
# 10.095708226021637
# 121.0
# 1507.8908174389508
# 38.83156985545332
# 0.9844243340273809
# 0.7235740237856065
# 7.0841289771998
# 142.16017156862748
# 0.019510940757688958
# 0.17645731239328277
# 0.9529743437224958
# 0.0069861351457623354
# 0.0021687319422171512
# Calculating Statistical Features for Blue Channel:
# 115.40660095214844
# 10.31379386414477
# 110.0
# 1273.0228317936417
# 35.67944550849469
# 0.28044411953370496
# 0.17440828033797384
# 7.125012887158491
# 136.9162224264706
# 0.01910217487594932
# 0.17344079059792852
# 0.9463253351647261
# 0.007251783055189914
# 0.002088690201867542
# Image number:  14
# Calculating Statistical features for Red Channel:
# 120.39041137695312
# 10.180588325932318
# 133.0
# 2761.457289650105
# 52.54956983315948
# -0.8087780515247995
# -0.09610296338787006
# 7.273048618777363
# 841.2892156862747
# 0.0281962048923241
# 0.11388199396436392
# 0.8479579943114204
# 0.0011872803998643371
# 0.012837050552539002
# Calculating Statistical Features for Green Channel:
# 110.86436462402344
# 9.688250506462794
# 122.0
# 2431.177510637557
# 49.3069722314964
# -0.8616305145853738
# 0.07240424438695481
# 7.122506619375858
# 837.5796262254902
# 0.03109763624189912
# 0.1172573392835288
# 0.8281191007724495
# 0.0011925368251285032
# 0.012780443941375834
# Calculating Statistical Features for Blue Channel:
# 99.75825500488281
# 9.91804105920864
# 108.0
# 2882.2127843329217
# 53.68624390225975
# -0.2679669653778582
# -0.8039812173014704
# 7.4970135808096074
# 834.7441942401961
# 0.022864805219383524
# 0.11486403511323552
# 0.8553279337450801
# 0.001196571111420706
# 0.012737176241961861
# Image number:  15
# Calculating Statistical features for Red Channel:
# 130.10247802734375
# 10.445191250698661
# 144.0
# 2535.9706689082086
# 50.35842202559775
# -0.7763991290312867
# -0.4093308574806036
# 7.361600527186337
# 819.6583792892159
# 0.014295521733081702
# 0.1157465890220697
# 0.8385733650173499
# 0.0012185550591056657
# 0.012506291405600379
# Calculating Statistical Features for Green Channel:
# 129.57891845703125
# 10.414144551439703
# 143.0
# 2510.9379857443273
# 50.10926047892073
# -0.80828766011313
# -0.02331021584001869
# 7.350153109098397
# 817.0043658088236
# 0.01513776502647852
# 0.117981372801523
# 0.8375724730093167
# 0.0012225099863374454
# 0.012465763130421819
# Calculating Statistical Features for Blue Channel:
# 115.59812927246094
# 10.361185827545498
# 130.0
# 3026.0087117103394
# 55.00916934212277
# -0.6253031669807505
# -0.8766764220927832
# 7.408396253279031
# 812.1130667892154
# 0.014245088102662755
# 0.1153764323484319
# 0.8659120401284558
# 0.0012298628079522545
# 0.012391203111581869
# Image number:  16
# Calculating Statistical features for Red Channel:
# 127.19218444824219
# 10.1495102336713
# 139.0
# 1487.2779607677367
# 38.565242910783496
# -1.0927597716424093
# 1.082423273798808
# 7.049117785473542
# 786.0666513480393
# 0.014401432652174613
# 0.07284542191517221
# 0.7363834508935895
# 0.0012705636761822434
# 0.011994412200481001
# Calculating Statistical Features for Green Channel:
# 125.27127075195312
# 9.247408117130206
# 129.0
# 986.1076560756192
# 31.40235112337322
# -1.2165501365264622
# 3.53651182639367
# 6.768042305411241
# 785.6053002450981
# 0.015674197465800135
# 0.07446365848170426
# 0.6028823928524999
# 0.0012713109439603067
# 0.011987374796732968
# Calculating Statistical Features for Blue Channel:
# 116.433837890625
# 10.106290886300256
# 133.0
# 2100.2360095381737
# 45.82833195238698
# -0.827155889730584
# -0.19119279946166712
# 7.230236941978046
# 778.6423253676471
# 0.013524934071611441
# 0.07355249898459534
# 0.8150295723331669
# 0.0012826616967509016
# 0.011881110178949779
# Image number:  17
# Calculating Statistical features for Red Channel:
# 93.33807373046875
# 9.282014449263054
# 102.0
# 2287.5894720219076
# 47.82875152062729
# -0.682237899235106
# -0.11487884189617992
# 6.549952697404321
# 589.3257352941177
# 0.13092557467000424
# 0.20276714457630268
# 0.8704948488218208
# 0.0016943558017315592
# 0.00899233893125745
# Calculating Statistical Features for Green Channel:
# 100.082763671875
# 9.347722360558112
# 109.0
# 2665.875016629696
# 51.632112261941174
# -0.6982917486006344
# -0.286149646325109
# 6.643875415773092
# 589.8809589460784
# 0.1288624065121069
# 0.20180350267499286
# 0.8888140008936676
# 0.0016927574288058812
# 0.009000824177401378
# Calculating Statistical Features for Blue Channel:
# 100.65090942382812
# 9.249183412541246
# 109.0
# 2443.348075955175
# 49.43023443152151
# -0.8515516515172583
# 0.17277359180796736
# 6.533090129442318
# 590.2110447303921
# 0.12130079691466117
# 0.19740645992616943
# 0.8784847761506815
# 0.0016917904772723346
# 0.009005872152716364
# Image number:  18
# Calculating Statistical features for Red Channel:
# 108.98565673828125
# 10.07618682913457
# 108.0
# 631.8124163411558
# 25.135879064420163
# 0.35388552079742186
# 0.2990288774073
# 6.680658410592264
# 644.4126838235296
# 0.013466005859555851
# 0.059365165345217054
# 0.49001418870232943
# 0.0015494285899220089
# 0.009832956655819639
# Calculating Statistical Features for Green Channel:
# 117.44169616699219
# 9.828041937496772
# 120.0
# 795.0696597450878
# 28.19697962096451
# -0.07193958082433397
# -0.36603214468725875
# 6.826975484713009
# 646.052175245098
# 0.012564001676693956
# 0.059181251418149075
# 0.5940264072109825
# 0.00154550043401252
# 0.009857973005724314
# Calculating Statistical Features for Blue Channel:
# 106.07313537597656
# 10.204096282014257
# 104.0
# 641.2775949423667
# 25.323459379444323
# 0.4668822013513043
# 0.39594136194238816
# 6.678384720350881
# 643.3876531862744
# 0.013590117857285266
# 0.05921067752892586
# 0.49831429238755287
# 0.0015518936240824825
# 0.009817313441547671
# Image number:  19
# Calculating Statistical features for Red Channel:
# 164.1425018310547
# 10.560856617949266
# 174.0
# 1557.8098476470914
# 39.469099909259285
# -1.6314234648128392
# 3.191794515143912
# 6.99719741547687
# 721.7046109068627
# 0.015322073754491326
# 0.08776457534353237
# 0.7689897942859699
# 0.0013837205220166638
# 0.0110123162408084
# Calculating Statistical Features for Green Channel:
# 160.4118194580078
# 10.525468003113701
# 164.0
# 1197.6930298560765
# 34.607701886373164
# -1.4460053165954483
# 4.520508094837297
# 6.909111703433264
# 721.2918351715688
# 0.015168071419760771
# 0.08756336441267004
# 0.6997342828369388
# 0.0013845110129541852
# 0.011006004908696812
# Calculating Statistical Features for Blue Channel:
# 157.88052368164062
# 10.438062823990768
# 175.0
# 2606.138710028492
# 51.05035465134882
# -1.3889787021248725
# 1.3377247180933587
# 7.26355701748272
# 728.5556832107844
# 0.01427577732198379
# 0.08849673395763491
# 0.8605878959438569
# 0.0013707241149176369
# 0.01111685113562074
# Image number:  20
# Calculating Statistical features for Red Channel:
# 98.44174194335938
# 9.942871177675961
# 103.0
# 811.588036662899
# 28.488384241000734
# -0.5569925906721944
# -0.2638086965171209
# 6.761144696018676
# 97.21980698529411
# 0.024235782471437466
# 0.2291293184130044
# 0.9402278444166022
# 0.010183758674151432
# 0.0014834319673491495
# Calculating Statistical Features for Green Channel:
# 98.80038452148438
# 9.97689132925197
# 103.0
# 884.3348790025339
# 29.73776856125109
# -0.6541009866104763
# -0.14636786756533393
# 6.803585529918258
# 97.15287990196077
# 0.023903911944692477
# 0.2302446625943616
# 0.9451831005804604
# 0.010190669880237441
# 0.0014823972477059511
# Calculating Statistical Features for Blue Channel:
# 80.73013305664062
# 9.959217069562841
# 88.0
# 1632.6753712957725
# 40.40637785419243
# -0.2366807471516906
# -1.1456100584455748
# 7.144879909294441
# 93.08002450980393
# 0.021368140067645102
# 0.23000372757869345
# 0.9714983059999561
# 0.010631663672390643
# 0.0014202334384925547
# Image number:  21
# Calculating Statistical features for Red Channel:
# 138.77163696289062
# 10.376192690763764
# 146.0
# 2318.512211895548
# 48.150931578688564
# -0.5580954964723224
# -0.10242037621456035
# 7.537881934149031
# 951.1088694852938
# 0.009355104722502717
# 0.05386272033652142
# 0.7951126838997117
# 0.0010503103771149305
# 0.01451231764877621
# Calculating Statistical Features for Green Channel:
# 146.27268981933594
# 10.294701585636403
# 152.0
# 1792.1834375036415
# 42.33418757344519
# -0.9657330298354454
# 1.257189472837859
# 7.293167007772311
# 950.1371783088238
# 0.010400479420977594
# 0.054292326023978474
# 0.7353010403747872
# 0.001051384550734795
# 0.014497518071508043
# Calculating Statistical Features for Blue Channel:
# 132.78744506835938
# 10.513233383306726
# 139.0
# 3354.0459458893165
# 57.914125616202796
# -0.2963108038048241
# -0.9168048522436751
# 7.7033106500205415
# 946.8434129901964
# 0.009234451839310194
# 0.05429465583220682
# 0.8589470689067772
# 0.001055036864720459
# 0.014447357898269397
# Image number:  22
# Calculating Statistical features for Red Channel:
# 117.39671325683594
# 10.270046820454906
# 118.0
# 2086.458234436577
# 45.6777652084313
# -0.5177763121788771
# 0.18868431180400824
# 7.312490937324809
# 692.0566482843136
# 0.01628546620161164
# 0.10517209693443047
# 0.8344299076491248
# 0.0014429174022905348
# 0.010559228275734639
# Calculating Statistical Features for Green Channel:
# 114.83868408203125
# 10.228008217615459
# 116.0
# 2120.579415407032
# 46.049749352271526
# -0.5660415336461474
# 0.24594422399062665
# 7.311046734372632
# 691.2061274509804
# 0.015258060411584055
# 0.10483583639329346
# 0.8372676794343041
# 0.0014446882272232775
# 0.010546091519960735
# Calculating Statistical Features for Blue Channel:
# 106.71630859375
# 10.067449833129446
# 112.0
# 2931.123651266098
# 54.139852708204685
# -0.15373941697829027
# -0.5721492539796968
# 7.6297799480390065
# 681.9627297794118
# 0.013947591366640902
# 0.10837063042726389
# 0.8837555983703098
# 0.001464238645826675
# 0.010405054394523112
# Image number:  23
# Calculating Statistical features for Red Channel:
# 131.97682189941406
# 10.458569122533937
# 150.0
# 1833.000149421161
# 42.81355100223714
# -1.1206601280624102
# 0.08637590311958165
# 6.852223358554015
# 332.202037377451
# 0.029507446234638482
# 0.20445520036562795
# 0.9095744871163066
# 0.0030014479291148354
# 0.005068962784284947
# Calculating Statistical Features for Green Channel:
# 118.375244140625
# 10.057230641861295
# 133.0
# 1446.3830565810204
# 38.031343081477154
# -1.0606867039772763
# 0.16011296248716844
# 6.8220451637894355
# 328.17886029411767
# 0.02871519925413259
# 0.20608156261133764
# 0.8868034396591928
# 0.0030381271735784665
# 0.005007561865960553
# Calculating Statistical Features for Blue Channel:
# 108.13706970214844
# 10.150813599097996
# 126.0
# 1838.5811417063233
# 42.87867933724549
# -0.696754582545926
# -0.8348065644241855
# 6.950587522449546
# 325.53884803921557
# 0.027462706211928544
# 0.2027395534884434
# 0.9115896112787313
# 0.0030626803380228726
# 0.004967278261231784
# Image number:  24
# Calculating Statistical features for Red Channel:
# 102.3310546875
# 10.578236070779505
# 93.0
# 4833.445731163025
# 69.52298707019877
# 0.1643502701633783
# -1.4252495033552026
# 7.65611147980778
# 588.2014246323529
# 0.018277581325070857
# 0.17818107473180855
# 0.9390886236530308
# 0.0016972651118844582
# 0.008972575005050068
# Calculating Statistical Features for Green Channel:
# 104.93130493164062
# 10.278060093573561
# 108.0
# 4225.571483380161
# 65.0043958773571
# 0.010300141395005357
# -1.3185288021355799
# 7.695072360532218
# 584.4162071078433
# 0.016869474599841637
# 0.1802203810352064
# 0.9307685067341129
# 0.0017082356191979611
# 0.008914660750911563
# Calculating Statistical Features for Blue Channel:
# 85.01620483398438
# 9.760952006952563
# 70.0
# 4985.786724708043
# 70.61010355967511
# 0.37964892429765046
# -1.3287756995230433
# 7.413306056444401
# 557.1869791666668
# 0.028029178782898803
# 0.19362327512648275
# 0.9440386228493813
# 0.001791604345001916
# 0.00849916523989177
# Image number:  25
# Calculating Statistical features for Red Channel:
# 125.51809692382812
# 10.206997614037576
# 133.0
# 2411.9487386634573
# 49.111594747711635
# -0.42646635609181
# -0.40138780595300405
# 7.5367117898574385
# 1951.6633578431374
# 0.008768117939382083
# 0.04336768083836053
# 0.5960904835978302
# 0.0005121233449387136
# 0.029780010216980773
# Calculating Statistical Features for Green Channel:
# 123.06916809082031
# 10.168923132793564
# 128.0
# 2357.5626443640795
# 48.554738639643396
# -0.33469559204557986
# -0.2579904587533517
# 7.549529105440292
# 1952.2390165441177
# 0.008669422888182838
# 0.04340053890852353
# 0.5868208449199168
# 0.0005119723853737226
# 0.02978879636503406
# Calculating Statistical Features for Blue Channel:
# 116.64315795898438
# 10.13329286399925
# 126.0
# 2719.447950622998
# 52.148326441248315
# -0.44192184753064273
# -0.5634384041287617
# 7.586479460101065
# 1946.9078890931378
# 0.008408154457229838
# 0.04236175116444505
# 0.6425000219014436
# 0.0005133735132564983
# 0.029707454963025424
# Image number:  26
# Calculating Statistical features for Red Channel:
# 110.9566650390625
# 9.337385478715388
# 114.0
# 416.17243848741055
# 20.40030486260954
# -0.30348969765771067
# -0.1511590061495336
# 6.32117353314605
# 19.03158700980392
# 0.03601372499311425
# 0.31432943947954306
# 0.9771904881764075
# 0.05001106923799118
# 0.00029035287555801277
# Calculating Statistical Features for Green Channel:
# 130.72984313964844
# 9.031135954351289
# 129.0
# 516.7539043088909
# 22.732221719596414
# 0.036156881237953055
# 0.44802672684828604
# 6.483137473379691
# 19.066344975490196
# 0.03559849950983186
# 0.3215998016073965
# 0.9816000068268653
# 0.049923251796888266
# 0.00029088124030931026
# Calculating Statistical Features for Blue Channel:
# 77.92117309570312
# 9.82740613676636
# 94.0
# 1824.0913510164246
# 42.709382470558204
# -0.24991438291425327
# -1.5672699907013503
# 6.8162735685800175
# 18.887867647058822
# 0.03062790911376557
# 0.30968771475443907
# 0.9948268731888263
# 0.05035946653195243
# 0.0002881506857523456
# Image number:  27
# Calculating Statistical features for Red Channel:
# 118.7208251953125
# 10.193800773938541
# 125.0
# 2397.7167391628027
# 48.96648587720792
# -0.24101334230552066
# -0.5666030429773974
# 7.515144692100382
# 2304.2782322303924
# 0.011871985689334227
# 0.05645048534278267
# 0.5201663772870521
# 0.00043378935174061636
# 0.03516040202566436
# Calculating Statistical Features for Green Channel:
# 117.33087158203125
# 10.180604812852168
# 122.0
# 2401.2362881563604
# 49.00241104431863
# -0.21621202270790946
# -0.31933057864889847
# 7.51978949730567
# 2303.338740808824
# 0.011936130601912625
# 0.05620166920087086
# 0.5212666336546443
# 0.0004339662230070013
# 0.03514601827592663
# Calculating Statistical Features for Blue Channel:
# 112.76358032226562
# 10.166155025761338
# 121.0
# 2704.741285911761
# 52.00712726071073
# -0.3164009394312514
# -0.6317311798992713
# 7.574421343785602
# 2303.8537530637254
# 0.010289648744027706
# 0.053949754363195435
# 0.5745940803917606
# 0.00043386894419213427
# 0.035153881208634566
# Image number:  28
# Calculating Statistical features for Red Channel:
# 93.49409484863281
# 10.521276080695294
# 91.0
# 448.55147880106233
# 21.179033943999013
# 0.43960971106193514
# 0.11007883744597002
# 6.416243013664173
# 322.59589460784315
# 0.017603615869948516
# 0.09181330634680797
# 0.6402375122514729
# 0.0030904421830474605
# 0.004922398947972785
# Calculating Statistical Features for Green Channel:
# 106.58621215820312
# 10.00302383481334
# 108.0
# 437.0648636063561
# 20.90609632634357
# 0.035440805451957526
# 0.13402069768761438
# 6.418031796366517
# 323.31314338235296
# 0.01738805249311481
# 0.0923561091136286
# 0.6305444123787969
# 0.0030836049611036153
# 0.004933347516864688
# Calculating Statistical Features for Blue Channel:
# 97.34466552734375
# 10.27129255174799
# 95.0
# 572.0038253031671
# 23.916601458049325
# 0.31506989209522157
# -0.24947227100969682
# 6.597083360302526
# 322.2488664215687
# 0.016026066614435824
# 0.09156934058094433
# 0.7182123117974288
# 0.003093745050477736
# 0.004917083565462259
# Image number:  29
# Calculating Statistical features for Red Channel:
# 125.10646057128906
# 9.959732617079183
# 130.0
# 1803.3822971282061
# 42.46624891756047
# -0.864066405277628
# 0.93181314138107
# 7.219723187454867
# 533.6629442401961
# 0.01520044793579511
# 0.11651216899757305
# 0.8522045294566414
# 0.0018703903862139072
# 0.008142715960176019
# Calculating Statistical Features for Green Channel:
# 127.03254699707031
# 9.97252160357595
# 132.0
# 1697.5660030709114
# 41.20152913510506
# -1.031997875403686
# 1.4958632545510309
# 7.122652253932247
# 533.3483762254901
# 0.015946551380506453
# 0.11759574996294551
# 0.8431230940690468
# 0.0018714941195126446
# 0.008137874913096473
# Calculating Statistical Features for Blue Channel:
# 117.93746948242188
# 10.004395091287535
# 126.0
# 2655.384181975387
# 51.53041996699995
# -0.4260324570184119
# -0.4151387239569826
# 7.594826778464081
# 529.2111825980393
# 0.012715881830580481
# 0.11723416173442593
# 0.9004034329637328
# 0.0018860861786219665
# 0.00807479126345236
# Image number:  30
# Calculating Statistical features for Red Channel:
# 119.52503967285156
# 10.124076895371669
# 122.0
# 2015.0665116866585
# 44.88949221907794
# -0.17220206600719
# -0.18584114076287506
# 7.471958117513521
# 2220.1718443627456
# 0.008969497867811378
# 0.041202715432969966
# 0.44965776283443754
# 0.0004502146201506425
# 0.0338770144806458
# Calculating Statistical Features for Green Channel:
# 118.23965454101562
# 10.134529056607354
# 120.0
# 1980.5732419705018
# 44.50363178405221
# -0.20952635382978918
# 0.015465308264818844
# 7.458231605175464
# 2220.5343443627453
# 0.008957402851276787
# 0.04096635954821668
# 0.4401178593268414
# 0.0004501411534029223
# 0.033882498134089424
# Calculating Statistical Features for Blue Channel:
# 111.82080078125
# 10.139111139889495
# 116.0
# 2428.9999310970306
# 49.28488542237905
# -0.1842212732900897
# -0.351701319757574
# 7.588297766293114
# 2219.108409926471
# 0.00830215906120898
# 0.03978647910576262
# 0.5435307797788798
# 0.00045043013893892653
# 0.03386074180882359
# Image number:  31
# Calculating Statistical features for Red Channel:
# 110.66622924804688
# 10.41637727462594
# 102.0
# 3692.209275796078
# 60.76355219863367
# 0.3984278076529921
# -0.7788614893912942
# 7.668138743339613
# 591.5044117647059
# 0.014939691198538843
# 0.15617259862304267
# 0.9197428473430539
# 0.0016877937028996436
# 0.009025490974756056
# Calculating Statistical Features for Green Channel:
# 121.81163024902344
# 10.304384679733657
# 121.0
# 3135.595360953128
# 55.99638703481795
# 0.03361021613726106
# -0.6859033850052811
# 7.658008534640938
# 585.9188878676472
# 0.014440713368471447
# 0.15646513137850476
# 0.9065316197359549
# 0.0017038548691336317
# 0.008940204755843163
# Calculating Statistical Features for Blue Channel:
# 95.93144226074219
# 10.435228660282572
# 84.0
# 3888.7906642162707
# 62.36016889181965
# 0.6122125166804162
# -0.5611231691207639
# 7.629261594928621
# 586.5400122549021
# 0.01458127354047937
# 0.15533492202903235
# 0.9243805073109801
# 0.0017020539831436225
# 0.008949651320417288
# Image number:  32
# Calculating Statistical features for Red Channel:
# 99.572021484375
# 10.416900225246202
# 94.0
# 1224.1704415678978
# 34.98814715825772
# 0.16906760422299702
# -0.83703982048416
# 7.067516111263956
# 193.3603400735294
# 0.01652304110898435
# 0.1472388450891911
# 0.9209113911750034
# 0.005145520013292629
# 0.0029496735328345095
# Calculating Statistical Features for Green Channel:
# 110.98231506347656
# 9.61668532274399
# 118.0
# 975.273567247903
# 31.22937026659204
# -0.8267978118749577
# 0.12222547541337736
# 6.840214350368909
# 194.09413296568627
# 0.017812962134915806
# 0.14680113795553065
# 0.9003445643393085
# 0.005126198812761051
# 0.0029609109694728976
# Calculating Statistical Features for Blue Channel:
# 83.40878295898438
# 10.422286407265831
# 74.0
# 1831.7278855061159
# 42.79869023119885
# 0.3948350976714897
# -0.9581736907424072
# 7.213884806162902
# 194.0918964460785
# 0.01642168294516838
# 0.1452776438632188
# 0.946938838191663
# 0.005126221024012532
# 0.002960636610593483
# Image number:  33
# Calculating Statistical features for Red Channel:
# 120.23880004882812
# 10.168715307062822
# 127.0
# 2128.1509213140234
# 46.131886166880534
# -0.7502532814419587
# 0.34610788484557586
# 7.235547019482428
# 531.7435202205884
# 0.022622620384715263
# 0.1442963088356482
# 0.8753097199306166
# 0.0018771555696515587
# 0.008113736281313233
# Calculating Statistical Features for Green Channel:
# 124.33396911621094
# 10.082244646133725
# 133.0
# 2015.723593413597
# 44.89681050379411
# -1.1166581269270885
# 1.155195716280315
# 7.0376559823749565
# 531.3594822303921
# 0.023572923905693578
# 0.14408693443976298
# 0.8685295017813237
# 0.0018785131390117462
# 0.008107864178831
# Calculating Statistical Features for Blue Channel:
# 106.29893493652344
# 10.14123664974508
# 119.0
# 3434.67408089689
# 58.60609252370345
# -0.16368848699325583
# -1.1068743251079152
# 7.623254509351336
# 532.6261488970589
# 0.015593068583380915
# 0.14294639930892875
# 0.9225170333514346
# 0.0018740258959971574
# 0.008127170070108516
# Image number:  34
# Calculating Statistical features for Red Channel:
# 138.2886962890625
# 10.330089757331795
# 145.0
# 2826.001920565963
# 53.16015350397291
# -0.5281116578877256
# -0.35668718858301496
# 7.622870657908498
# 899.664322916667
# 0.009972979431824628
# 0.07263066041106732
# 0.8408543379404307
# 0.0011103038585997926
# 0.013727472216769572
# Calculating Statistical Features for Green Channel:
# 146.402099609375
# 10.310863388125833
# 154.0
# 2265.578977525234
# 47.59809846543488
# -0.9614941924816649
# 0.8294447856935658
# 7.389716170902576
# 899.4252144607846
# 0.010721419695627647
# 0.0717974765840976
# 0.8016067713104579
# 0.0011105996268702515
# 0.01372376387501304
# Calculating Statistical Features for Blue Channel:
# 125.60966491699219
# 10.59415545292508
# 121.0
# 3949.362271701684
# 62.84395175115648
# -0.05403340431071402
# -1.228535584130213
# 7.779730258889433
# 897.370818014706
# 0.009185225810604835
# 0.071281985024256
# 0.886330827897582
# 0.001113137475490328
# 0.013692318072387862
# Image number:  35
# Calculating Statistical features for Red Channel:
# 108.97073364257812
# 10.48436335692349
# 103.0
# 769.449521898292
# 27.738953150728165
# 0.31214350976214866
# -1.1799736232718592
# 6.5671976097668905
# 89.56879595588236
# 0.02366162224570909
# 0.19379099163930702
# 0.9418464141953301
# 0.0110442157644302
# 0.0013667112361691297
# Calculating Statistical Features for Green Channel:
# 125.2010498046875
# 9.545828054807666
# 125.0
# 401.01917980611324
# 20.02546328567989
# -0.1468344880136425
# -0.2598632048874854
# 6.337924448596684
# 88.89721200980392
# 0.025960830058415763
# 0.19572646726468432
# 0.8892257609712567
# 0.011127028798118839
# 0.0013564632448014367
# Calculating Statistical Features for Blue Channel:
# 105.38862609863281
# 10.31687362865934
# 101.0
# 1000.0269330122974
# 31.623202447132034
# 0.20699983007340392
# -1.243816332477334
# 6.7583849194085
# 89.3854473039216
# 0.022178568893742902
# 0.19293200530712784
# 0.9553453133158958
# 0.011066443412226479
# 0.0013639129280058615
# Image number:  36
# Calculating Statistical features for Red Channel:
# 128.25714111328125
# 10.092800603570721
# 136.0
# 1236.923502471298
# 35.16992326507549
# -0.7206797640707494
# 0.4459945408769217
# 7.049767366053512
# 51.067693014705895
# 0.02335625054044846
# 0.21675703453466688
# 0.979416362456788
# 0.019214386466896795
# 0.0007790185841067519
# Calculating Statistical Features for Green Channel:
# 144.7563934326172
# 10.203151171243235
# 147.0
# 1276.0267917045858
# 35.72151720888386
# -0.6809004548000244
# 1.024880467192438
# 7.066750964922958
# 50.237714460784325
# 0.0228606072875704
# 0.22161598239462946
# 0.980363726880464
# 0.0195255853479649
# 0.0007663580159821772
# Calculating Statistical Features for Blue Channel:
# 88.07485961914062
# 10.084787647468401
# 98.0
# 2588.3267324632034
# 50.87560056120422
# -0.16095396913170418
# -1.44596020642526
# 7.279111793397716
# 44.898069852941184
# 0.02190932198544885
# 0.22689671216652635
# 0.9913376787335562
# 0.021797813688554706
# 0.0006848848809626688
# Image number:  37
# Calculating Statistical features for Red Channel:
# 120.10353088378906
# 10.419266358539613
# 133.0
# 2742.972511946922
# 52.37339507752884
# -0.2845756815599946
# -1.1001212220334018
# 7.541131189208527
# 974.5110753676472
# 0.010472139095611807
# 0.07506883725881226
# 0.8224766372411323
# 0.0010251146915648893
# 0.014869571029849891
# Calculating Statistical Features for Green Channel:
# 110.8438720703125
# 10.115540406465872
# 120.0
# 2173.1203384250402
# 46.616738822284
# -0.36003419117062513
# -0.7596222165076241
# 7.379441098517286
# 975.7293658088239
# 0.011686295650004733
# 0.0773949882461019
# 0.7757069601236162
# 0.0010238373083391208
# 0.01488806907435244
# Calculating Statistical Features for Blue Channel:
# 92.33914184570312
# 9.91061276416994
# 104.0
# 2693.144534810446
# 51.89551555587868
# -0.27694911606856953
# -1.1109338555346786
# 7.420471176521224
# 967.9548100490196
# 0.014118357123176717
# 0.08395493704181457
# 0.8204072072286079
# 0.0010320549116931707
# 0.014769443251874322
# Image number:  38
# Calculating Statistical features for Red Channel:
# 163.5478057861328
# 10.53593399520741
# 174.0
# 1694.8203464427497
# 41.168195812334915
# -1.5941714027606553
# 3.020230993379225
# 7.059542062737787
# 831.9962009803924
# 0.01463285778003059
# 0.08461458068230067
# 0.7551120938776256
# 0.0012005067558143172
# 0.012695125198748672
# Calculating Statistical Features for Green Channel:
# 159.79757690429688
# 10.48019284835312
# 164.0
# 1345.1391701539978
# 36.67613897555191
# -1.488592100173528
# 4.438845055152371
# 6.969773089773329
# 832.9229013480394
# 0.014715947714518354
# 0.085620030480023
# 0.6910576816982426
# 0.0011991727836559625
# 0.012709223740100029
# Calculating Statistical Features for Blue Channel:
# 157.35629272460938
# 10.429904023969671
# 175.0
# 2713.0925379162654
# 52.08735487540393
# -1.3326244222650288
# 1.1671857651530102
# 7.310136114487276
# 826.9485294117648
# 0.013677981777937467
# 0.08568017651009117
# 0.8479645648315306
# 0.0012078245024627564
# 0.012618021431183162
# Image number:  39
# Calculating Statistical features for Red Channel:
# 120.08558654785156
# 10.3081215551194
# 137.0
# 2356.865523453569
# 48.54755939749772
# -0.739502443698631
# -0.5679506297986117
# 7.306645629638013
# 468.54670649509796
# 0.01299657125402939
# 0.08613423507241175
# 0.900798840417302
# 0.0021297725357401816
# 0.007149442229351915
# Calculating Statistical Features for Green Channel:
# 121.54573059082031
# 9.783702798741464
# 131.0
# 1633.6179343478289
# 40.418039714313565
# -1.0514589783439
# 0.542620634059463
# 7.043306294166299
# 466.8181219362745
# 0.014210270900572806
# 0.08677831349222204
# 0.8575068795882951
# 0.002137647794435957
# 0.007123070189590405
# Calculating Statistical Features for Blue Channel:
# 102.92964172363281
# 9.919050256118195
# 121.0
# 2616.7318813779857
# 51.15400161647167
# -0.4888843977593449
# -1.0272347474640338
# 7.382037899523464
# 458.01187193627436
# 0.012008826928548306
# 0.0853273144151272
# 0.9126347278401733
# 0.002178649887226162
# 0.006988691946044736
# Image number:  40
# Calculating Statistical features for Red Channel:
# 106.626220703125
# 10.129652673278093
# 106.0
# 544.9003280997276
# 23.34310022468583
# 0.11877915869102812
# 0.5269072271440245
# 6.57835713725723
# 508.06393995098045
# 0.0152342036368136
# 0.06991779390666256
# 0.5335752279857778
# 0.001964448565941999
# 0.007752362199525841
# Calculating Statistical Features for Green Channel:
# 122.60108947753906
# 10.002638659442177
# 126.0
# 881.8811078218278
# 29.696483088437052
# -0.2919374982289509
# -0.342683925564923
# 6.8788105403652615
# 509.40701593137254
# 0.01342427532607719
# 0.07021249197708453
# 0.7113552005296079
# 0.0019592722486098508
# 0.00777286775057841
# Calculating Statistical Features for Blue Channel:
# 96.26945495605469
# 10.20925695691438
# 93.0
# 752.0889388264623
# 27.42423998630522
# 0.3536794788213105
# -0.3582105584825941
# 6.75961049227872
# 508.17107843137256
# 0.013864652672171903
# 0.06966420325550073
# 0.6621012639105679
# 0.0019640299163759646
# 0.007753998070886528
# Image number:  41
# Calculating Statistical features for Red Channel:
# 117.50791931152344
# 10.159420328499694
# 126.0
# 2037.44256423763
# 45.13803899415248
# -0.5604978202385528
# -0.3963672825125166
# 7.345186109723318
# 832.5077971813726
# 0.01339748625854366
# 0.08525776503655634
# 0.7960596944699758
# 0.0011997681092587936
# 0.012703029730742865
# Calculating Statistical Features for Green Channel:
# 114.70811462402344
# 10.020878929832811
# 119.0
# 1655.3805164282676
# 40.68636769764865
# -0.6177847828814693
# 0.20625293118810584
# 7.174684543272909
# 831.7042892156865
# 0.01367207881775357
# 0.08504179404128001
# 0.74935776245837
# 0.0012009262256832069
# 0.012690760510794957
# Calculating Statistical Features for Blue Channel:
# 92.76446533203125
# 10.175641043899734
# 100.0
# 2131.793736066669
# 46.17135189775873
# -0.18372238814833214
# -0.9552032553210279
# 7.40034941880725
# 828.8008118872549
# 0.011919112859002396
# 0.08077561220328115
# 0.805773390450323
# 0.001205125796100384
# 0.012646460212227881
# Image number:  42
# Calculating Statistical features for Red Channel:
# 129.1439666748047
# 10.006148164935038
# 135.0
# 2192.630747595569
# 46.825535208853395
# -0.47131629637956096
# 0.04504233634307875
# 7.462802773240141
# 840.6794424019608
# 0.010674544578893828
# 0.06640493393896678
# 0.8085263267147845
# 0.0011881158457924944
# 0.012827307679051277
# Calculating Statistical Features for Green Channel:
# 126.41291809082031
# 9.958399646064732
# 128.0
# 1999.6587070242967
# 44.717543615725326
# -0.45860232268620943
# 0.32065394979722806
# 7.39672433040854
# 841.5121476715686
# 0.010913293812039641
# 0.0675521518684684
# 0.7898941145433732
# 0.0011869418811458084
# 0.01283994408976394
# Calculating Statistical Features for Blue Channel:
# 109.61000061035156
# 9.852484808878403
# 119.0
# 2777.75437935791
# 52.70440569210424
# -0.2986993549305267
# -0.5286577230480631
# 7.575893392077435
# 828.4843903186273
# 0.011287905644787977
# 0.07084914432101044
# 0.8509681817418654
# 0.001205584601949051
# 0.0126411209218469
# Image number:  43
# Calculating Statistical features for Red Channel:
# 107.25535583496094
# 10.600092156927296
# 120.0
# 3413.9826297012623
# 58.42929598841032
# -0.3981069229652301
# -1.059541507130995
# 7.23910071753086
# 450.8149356617647
# 0.051713272263842806
# 0.2547568972810292
# 0.9340090295551111
# 0.002213548935459427
# 0.006878257488276164
# Calculating Statistical Features for Green Channel:
# 111.69195556640625
# 10.347659936531997
# 130.0
# 3492.7311279140413
# 59.09933271970202
# -0.60611059853824
# -0.9131427215475103
# 7.1358544348382225
# 449.7750459558824
# 0.05490545267065278
# 0.25405443585105636
# 0.9356922656976885
# 0.0022186716548400487
# 0.006862320045821343
# Calculating Statistical Features for Blue Channel:
# 102.33821105957031
# 10.267181882274754
# 102.0
# 4121.5555809305515
# 64.19934252724518
# -0.010412838946203207
# -1.268857964672144
# 7.614246243580982
# 449.5250919117648
# 0.029352129147514304
# 0.24702449515481617
# 0.945441546187052
# 0.002219776818494535
# 0.006858582016723701
# Image number:  44
# Calculating Statistical features for Red Channel:
# 125.86274719238281
# 9.24965605225194
# 124.0
# 939.1406312712934
# 30.645401470225405
# 0.4779106700941636
# 0.9511631891367598
# 6.776404841590745
# 38.10029105392157
# 0.03449189590126299
# 0.3055127854473281
# 0.9797860419311327
# 0.02559783804639505
# 0.0005812525365040457
# Calculating Statistical Features for Green Channel:
# 139.28350830078125
# 9.49654606723051
# 132.0
# 1216.4137026332319
# 34.87712291220753
# 0.5870243155431808
# -0.1736884255503779
# 6.909178179878108
# 34.12666973039215
# 0.033129010199993404
# 0.3140640345974135
# 0.9860139901222993
# 0.028495272334393404
# 0.0005206060393182408
# Calculating Statistical Features for Blue Channel:
# 87.43771362304688
# 9.471758172634022
# 104.0
# 1697.6104392549023
# 41.20206838563936
# -0.5947840865668594
# -0.9838680526057981
# 6.90270085993118
# 28.127435661764707
# 0.03387718530279328
# 0.31974343598932164
# 0.9917274763482643
# 0.034371869663487466
# 0.00042904011618384645
# Image number:  45
# Calculating Statistical features for Red Channel:
# 116.12820434570312
# 10.180054734837965
# 132.0
# 2078.7799198469147
# 45.593639028343794
# -0.7130439786569378
# -0.5758940234959748
# 7.257319459969206
# 482.7724264705883
# 0.012771785636948387
# 0.08039345890912594
# 0.8840750443290762
# 0.0020671422064976676
# 0.007366520935674555
# Calculating Statistical Features for Green Channel:
# 117.96214294433594
# 9.676080876971591
# 125.0
# 1334.6726543677505
# 36.53317197243829
# -1.0702114058940846
# 0.9648569837026826
# 6.975234158969062
# 481.0948069852941
# 0.013997906619559639
# 0.08064641582421057
# 0.8202171258607055
# 0.002074341025752805
# 0.0073409226613770215
# Calculating Statistical Features for Blue Channel:
# 95.77555847167969
# 9.809965741858903
# 111.0
# 2259.1489210443106
# 47.53050516294047
# -0.3505676619198885
# -1.1512515943716009
# 7.314183078401641
# 471.8131587009804
# 0.01234449480729323
# 0.08253082799997312
# 0.8956783948345615
# 0.0021150555793331026
# 0.007199291717579753
# Image number:  46
# Calculating Statistical features for Red Channel:
# 93.78572082519531
# 10.381026023180238
# 88.0
# 524.3284893424716
# 22.898220222158567
# 0.5858282763956809
# -0.23385060919004808
# 6.425457882974296
# 204.98394607843142
# 0.022252245505002374
# 0.13605300854124935
# 0.8044455470076696
# 0.00485527178083507
# 0.0031278066211070338
# Calculating Statistical Features for Green Channel:
# 109.87620544433594
# 9.646424859669109
# 114.0
# 552.6050209773239
# 23.507552424217284
# -0.21594054869642326
# -0.13065228218220515
# 6.50924174075166
# 205.13949142156858
# 0.020320250255241683
# 0.13591919045187298
# 0.8145067591230346
# 0.004851562299214093
# 0.003130180226557991
# Calculating Statistical Features for Blue Channel:
# 91.16903686523438
# 10.226817641488756
# 84.0
# 637.1929536378011
# 25.24268118956069
# 0.6477150550902391
# -0.3949641586052577
# 6.512600078048618
# 204.11844362745097
# 0.021281692286533975
# 0.13588385243472303
# 0.8397182799435164
# 0.004875737872550968
# 0.003114599779574792
# Image number:  47
# Calculating Statistical features for Red Channel:
# 99.17828369140625
# 10.170097230879696
# 111.0
# 2309.485640462488
# 48.05710811589153
# -0.34792983311860437
# -1.1196391384342579
# 7.33640752030177
# 320.023268995098
# 0.015369828647884175
# 0.14147226480218278
# 0.9305926206628214
# 0.003115188138973105
# 0.004882996934492919
# Calculating Statistical Features for Green Channel:
# 83.35704040527344
# 10.256038468787166
# 90.0
# 1808.3721711968537
# 42.52495939089012
# -0.18801000846940116
# -1.1320656237910152
# 7.246856498444824
# 313.1494332107843
# 0.015301246266725303
# 0.1442660765987647
# 0.9132360974206983
# 0.00318335353674001
# 0.004778201949221583
# Calculating Statistical Features for Blue Channel:
# 67.04914855957031
# 10.066853404892013
# 65.0
# 1888.7219649122562
# 43.45942895290108
# 0.1406973147691187
# -1.1741597884275186
# 7.22028579172329
# 304.2431832107844
# 0.017342567170042438
# 0.14683696509535224
# 0.9191564531520685
# 0.003276262579509488
# 0.004642250584789346
# Image number:  48
# Calculating Statistical features for Red Channel:
# 122.04310607910156
# 10.06029870259087
# 127.0
# 2067.139087300515
# 45.46580129394526
# -0.5716801937433439
# 0.06547082649663372
# 7.416195182410942
# 1310.0348192401962
# 0.009224815891362122
# 0.04364979065101352
# 0.6836574591483511
# 0.000762761615221645
# 0.01998954404364256
# Calculating Statistical Features for Green Channel:
# 123.46253967285156
# 10.118729521723024
# 127.0
# 1936.862640913343
# 44.009801645921364
# -0.48463500306835566
# 0.102312182923463
# 7.418883312008934
# 1310.6787530637257
# 0.009059074152947556
# 0.043668604316649734
# 0.6622234598409924
# 0.0007623870587101859
# 0.01999936768907219
# Calculating Statistical Features for Blue Channel:
# 123.97138977050781
# 10.01286327831722
# 131.0
# 2766.4144493991043
# 52.59671519590462
# -0.5889743199432257
# -0.11891034577716164
# 7.577136079610097
# 1306.1902879901963
# 0.009250827672167833
# 0.045917579828594915
# 0.7642874083755792
# 0.0007650049775589486
# 0.019930873807234656
# Image number:  49
# Calculating Statistical features for Red Channel:
# 130.7986297607422
# 10.461016995823783
# 135.0
# 2830.323204299202
# 53.200781989546
# -0.2747725018464074
# -1.0427436005853137
# 7.567153247153546
# 773.6365655637255
# 0.013046219485848517
# 0.11274438350948983
# 0.8635249280210275
# 0.0012909497001156816
# 0.011804003817659846
# Calculating Statistical Features for Green Channel:
# 137.95645141601562
# 10.258449142467576
# 146.0
# 2089.100947759114
# 45.70668384119673
# -0.7447831673851675
# 0.04865760974063482
# 7.394109596738799
# 767.2331495098041
# 0.013595141621066235
# 0.11373177157045175
# 0.8167178169858361
# 0.001301711202629362
# 0.011706572282043892
# Calculating Statistical Features for Blue Channel:
# 112.93914794921875
# 10.458253249714135
# 99.0
# ...
# 24.191259155140187
# 0.17401612739711875
# 0.4884204927734057
# 6.629673225667613
# 578.2699754901961
# 0.014687568380864484
# 0.06982075522686282
# 0.5057804375404512
# 0.001726354546693365
# 0.008823693224337412
# Calculating Statistical Features for Green Channel:
# 129.64035034179688
# 9.973518403048018
# 134.0
# 765.7061013421044
# 27.671395001736077
# -0.3839208291802058
# -0.22279320552263782
# 6.776460623650998
# 579.7085171568627
# 0.013894493324508444
# 0.07052344888421487
# 0.6214650194191118
# 0.0017220755298424945
# 0.008845646844053215
# Calculating Statistical Features for Blue Channel:
# 112.76235961914062
# 10.135658211621607
# 110.0
# 679.9872892564163
# 26.076565902288902
# 0.46938182834156605
# 0.2506764586679098
# 6.715395466789789
# 577.6130974264706
# 0.014043213337711271
# 0.0699234524913805
# 0.5752921121053469
# 0.0017283125382220892
# 0.008813674372317601
# Image number:  343
# Calculating Statistical features for Red Channel:
# 104.13603210449219
# 10.463788032321352
# 94.0
# 3756.263615017524
# 61.28836443418542
# 0.22364342935360648
# -1.2144740614644283
# 7.590054976158677
# 445.2629136029412
# 0.0175366774612113
# 0.1552070242235914
# 0.9406876953556732
# 0.0022409195740911696
# 0.0067941018749065685
# Calculating Statistical Features for Green Channel:
# 111.259033203125
# 10.234618019538363
# 112.0
# 3058.182749211788
# 55.30083859410984
# -0.13524968917649036
# -0.9285858612150455
# 7.56929736362605
# 441.5338082107844
# 0.0174964612323543
# 0.15617019560504974
# 0.9278401992505804
# 0.002259803703159225
# 0.006737170777309031
# Calculating Statistical Features for Blue Channel:
# 89.70831298828125
# 10.29537670481953
# 75.0
# 3871.94851854071
# 62.22498307384832
# 0.41107705534490524
# -1.142353563512067
# 7.543539032488221
# 438.61049325980406
# 0.017340347962299475
# 0.1575819154407558
# 0.9432874837847772
# 0.0022748307005604
# 0.006692536566682197
# Image number:  344
# Calculating Statistical features for Red Channel:
# 137.77938842773438
# 10.071429158899663
# 140.0
# 1722.5472472822294
# 41.50358113804433
# -0.543864774015005
# 0.1335145380667102
# 7.347895605424588
# 811.8657322303923
# 0.01053467255591013
# 0.06286042942185048
# 0.7647186348404231
# 0.001230231415145559
# 0.012388019294247763
# Calculating Statistical Features for Green Channel:
# 134.07923889160156
# 10.170531575311788
# 134.0
# 1443.138817023253
# 37.988666955070336
# -0.37529330217710327
# 0.25974800850671187
# 7.232884556721855
# 810.1808210784313
# 0.010944813593965028
# 0.06298821007910063
# 0.7196741642563318
# 0.0012327873966482353
# 0.012362311737127072
# Calculating Statistical Features for Blue Channel:
# 122.77897644042969
# 10.191488596830983
# 126.0
# 2321.9042278097477
# 48.18614144969223
# -0.5334873091094082
# -0.31071403734490755
# 7.4951714270622425
# 807.5328737745099
# 0.01012724644573323
# 0.0637166489954893
# 0.8263924217819224
# 0.001236823582631623
# 0.012321923106539276
# Image number:  345
# Calculating Statistical features for Red Channel:
# 133.2021026611328
# 10.205977270496856
# 128.0
# 1502.1079124489333
# 38.75703694103734
# -0.05159750158230975
# -1.053138336383141
# 7.028660045308209
# 219.27409620098044
# 0.018370681548045418
# 0.13946157555320707
# 0.927018917602912
# 0.004540177094791452
# 0.0033448181126011774
# Calculating Statistical Features for Green Channel:
# 136.51287841796875
# 10.206194802839873
# 140.0
# 1030.3691883943975
# 32.09936429891405
# -0.7205311032903282
# 0.17759415000034862
# 6.862461265289816
# 220.06253063725492
# 0.019140856402437262
# 0.14092834805956964
# 0.8931589819009859
# 0.004523998663752954
# 0.003356837291114378
# Calculating Statistical Features for Blue Channel:
# 119.71121215820312
# 10.378912865776966
# 113.0
# 2542.920172139071
# 50.42737522555652
# 0.025727504541853165
# -1.261169141962258
# 7.293325573457797
# 218.07428002450987
# 0.017675067556984985
# 0.13927590890888714
# 0.9571445051057302
# 0.004565030121764698
# 0.0033264845943916984
# Image number:  346
# Calculating Statistical features for Red Channel:
# 94.29873657226562
# 9.562699459214727
# 106.0
# 3844.478658071719
# 62.00386002558001
# -0.20162784879265575
# -1.308846549730781
# 7.144963453109363
# 744.4934589460785
# 0.1201981605940257
# 0.19548742489433457
# 0.9029114438089881
# 0.0013416097043059828
# 0.011360067406272524
# Calculating Statistical Features for Green Channel:
# 96.28794860839844
# 9.266801576066864
# 114.0
# 3350.6412829866167
# 57.88472409009666
# -0.44414116514616864
# -1.0888207627536686
# 6.954415689879088
# 740.3822610294118
# 0.12173646058291522
# 0.1983498367528469
# 0.8891601127744901
# 0.0013490533582395648
# 0.011297336021586479
# Calculating Statistical Features for Blue Channel:
# 85.3165283203125
# 9.367384602284107
# 93.0
# 3757.4316396564245
# 61.29789262002752
# -0.06516334722426678
# -1.3981633779023923
# 7.028328504974296
# 735.3655637254901
# 0.13012642139501415
# 0.20104279132957692
# 0.9019451457156002
# 0.0013582611612146013
# 0.011220787654056865
# Image number:  347
# Calculating Statistical features for Red Channel:
# 150.33631896972656
# 10.317920716648246
# 154.0
# 1090.8999052976724
# 33.02877389939978
# -1.4558644566674708
# 3.882922224799808
# 6.846726958950286
# 556.6923406862745
# 0.01406086458301877
# 0.07241195132530949
# 0.7454485151275945
# 0.0017931485521002067
# 0.008494450809825778
# Calculating Statistical Features for Green Channel:
# 140.58241271972656
# 10.02003075021986
# 145.0
# 1071.9550001358148
# 32.74072387922745
# -1.4456356781691544
# 3.6429028878812186
# 6.836898331072875
# 556.4772365196079
# 0.013902108055175928
# 0.07278235562418309
# 0.7409732690291229
# 0.0017938399501297789
# 0.008491168120336711
# Calculating Statistical Features for Blue Channel:
# 105.45411682128906
# 10.347958541262122
# 117.0
# 2785.025116413599
# 52.77333717336435
# -0.17272699586741683
# -1.3043310737361014
# 7.424342167978275
# 558.9618259803922
# 0.011582503258284948
# 0.0739578183535619
# 0.8997694292211146
# 0.0017858729621944274
# 0.008529079027433823
# Image number:  348
# Calculating Statistical features for Red Channel:
# 148.99331665039062
# 10.297442546479532
# 154.0
# 1389.4468852644786
# 37.27528518018982
# -1.139538231159339
# 1.7384591028599257
# 7.0378715036850155
# 430.3610906862746
# 0.014726547979683627
# 0.10572918140152125
# 0.8454990278072753
# 0.0023183225434105846
# 0.0065667147798086295
# Calculating Statistical Features for Green Channel:
# 143.57806396484375
# 10.113517372436661
# 148.0
# 1295.2985629998147
# 35.990256500889444
# -1.0179383355755982
# 1.482213992990415
# 7.04471165565884
# 430.88691789215693
# 0.01462697118736196
# 0.10622079450981434
# 0.8340788580055802
# 0.0023154993293677062
# 0.0065747340313405634
# Calculating Statistical Features for Blue Channel:
# 126.19868469238281
# 10.35986032399169
# 144.0
# 2813.906187845161
# 53.04626459841599
# -0.716457093574258
# -0.6071625532269063
# 7.374028859449031
# 424.0426164215687
# 0.014252976519486473
# 0.11033461638663374
# 0.9247994878728589
# 0.002352784157496085
# 0.0064703478353790546
# Image number:  349
# Calculating Statistical features for Red Channel:
# 112.85845947265625
# 10.191299198124993
# 120.0
# 2508.54945480451
# 50.085421579582516
# -0.4462533585122367
# -0.5287527104441718
# 7.520791151785734
# 1595.6600337009804
# 0.009745320226130732
# 0.060111566988169725
# 0.6823397556015062
# 0.0006263112262448853
# 0.02434783807992921
# Calculating Statistical Features for Green Channel:
# 115.85879516601562
# 10.198811061604804
# 122.0
# 2361.470173499547
# 48.59496037141657
# -0.4722792727185003
# -0.2743886844364982
# 7.496946588307303
# 1595.0016084558822
# 0.010269423213628845
# 0.05976766515207583
# 0.6628225319618773
# 0.0006265698162285146
# 0.024337792656638994
# Calculating Statistical Features for Blue Channel:
# 114.6690673828125
# 10.139121674488285
# 124.0
# 3091.7130238860846
# 55.60317458460519
# -0.4148401463897174
# -0.6762352243325012
# 7.640283383495555
# 1594.3781250000002
# 0.009488031877722472
# 0.05931450183311368
# 0.7423661664978772
# 0.0006268143780865747
# 0.02432827908617345
# Image number:  350
# Calculating Statistical features for Red Channel:
# 97.65733337402344
# 10.243514079088122
# 99.0
# 2002.8537252133247
# 44.75325379470553
# -0.09969157937755718
# -0.9860742430497842
# 7.3661559535342604
# 128.69492953431376
# 0.016936847008888898
# 0.1955986459865792
# 0.9678353744044589
# 0.0077114086922313784
# 0.001963727615744317
# Calculating Statistical Features for Green Channel:
# 95.93043518066406
# 10.284677044476394
# 102.0
# 1765.7082192075904
# 42.0203310221087
# -0.25984549249601135
# -0.7495202352489136
# 7.27347110283648
# 128.00366115196076
# 0.01811255231861643
# 0.19613894278663593
# 0.9637295271023935
# 0.0077528065031835245
# 0.0019531808617341837
# Calculating Statistical Features for Blue Channel:
# 78.66728210449219
# 10.163356137782364
# 74.0
# 2548.0337842756417
# 50.47805250082101
# 0.13908616376727506
# -1.2690309844677283
# 7.359617314170578
# 129.25410539215684
# 0.018304586833779474
# 0.19837939780167396
# 0.9745929089534958
# 0.007678380244267884
# 0.001972261070975979
# Image number:  351
# Calculating Statistical features for Red Channel:
# 226.54360961914062
# 6.717225935427371
# 254.0
# 2868.4226587479934
# 53.55765733065621
# -2.3007725145303883
# 4.714223342247708
# 4.531366675461844
# 607.1658241421569
# 0.40644823948092657
# 0.4797761621091866
# 0.8944707347056048
# 0.0016453880263299068
# 0.009264615071029395
# Calculating Statistical Features for Green Channel:
# 238.418212890625
# 5.925481256826318
# 254.0
# 1947.011621415615
# 44.12495463358138
# -3.558166145026139
# 12.23531196305237
# 4.046395721456324
# 517.7144607843138
# 0.36006677793270264
# 0.506671052228087
# 0.8675064135804039
# 0.001929182064554255
# 0.007899695498362521
# Calculating Statistical Features for Blue Channel:
# 207.7056121826172
# 6.598229789310089
# 254.0
# 5241.009054196766
# 72.39481372444276
# -1.3408653718189159
# 0.5444929993063399
# 4.738510869109601
# 594.6628829656862
# 0.4096882367762652
# 0.48002250162271703
# 0.9434011572446298
# 0.0016799573842781637
# 0.009073835396988804
# Image number:  352
# Calculating Statistical features for Red Channel:
# 138.83494567871094
# 10.434917198916443
# 147.0
# 1232.0617615876254
# 35.10073733680854
# -0.7931948093066898
# 0.05779465075491563
# 6.914565098481537
# 13.965226715686278
# 0.04321096178526444
# 0.41435138681443173
# 0.9943453552403049
# 0.06701507467170267
# 0.0002130564218276008
# Calculating Statistical Features for Green Channel:
# 155.20169067382812
# 10.482845280076189
# 164.0
# 1038.6846321513876
# 32.228630627927515
# -1.05061288569203
# 1.6707180133852022
# 6.838970738672901
# 12.783501838235294
# 0.043954393104974655
# 0.42101459913326866
# 0.9938621261399068
# 0.07278260102769456
# 0.00019501885302187225
# Calculating Statistical Features for Blue Channel:
# 108.85618591308594
# 10.607885601686915
# 112.0
# 2380.0533378941473
# 48.78579032765737
# -0.18933815694351014
# -1.3671351419861755
# 7.185346316181799
# 13.514767156862748
# 0.03785925558634242
# 0.401536065896024
# 0.9971631114137521
# 0.06907552405661375
# 0.00020618045939614526
# Image number:  353
# Calculating Statistical features for Red Channel:
# 103.54844665527344
# 10.52973071269327
# 98.0
# 1869.6686429118272
# 43.239665157258415
# -0.022588843839588202
# -1.18020856048788
# 7.22812948456719
# 260.9872549019608
# 0.014309434844517535
# 0.11118569145390207
# 0.9301615873187888
# 0.0038171880619845278
# 0.00398190973045126
# Calculating Statistical Features for Green Channel:
# 111.93714904785156
# 9.904352915008586
# 118.0
# 1051.006807204103
# 32.419235142182224
# -0.516934211460698
# -0.6692907689962042
# 6.911257175718697
# 261.2255514705883
# 0.015714104592024485
# 0.11008485763569416
# 0.8757007000163605
# 0.0038137394464120944
# 0.003985567014007007
# Calculating Statistical Features for Blue Channel:
# 87.35502624511719
# 10.38304543215954
# 82.0
# 2434.4773346611764
# 49.34042292746563
# 0.04313271922728896
# -1.255131267487214
# 7.32428875381001
# 257.43030024509807
# 0.01508916684992148
# 0.11641324437094022
# 0.9470837956430446
# 0.00386974124250449
# 0.003927597811145537
# Image number:  354
# Calculating Statistical features for Red Channel:
# 169.67808532714844
# 10.517981980698059
# 179.0
# 1509.0963984092232
# 38.84708996062927
# -1.3575577004249597
# 2.3452474056751083
# 7.081651044851285
# 909.0398590686275
# 0.012385789998112953
# 0.05657311462621771
# 0.6994920187419198
# 0.001098867923621272
# 0.013870775015557078
# Calculating Statistical Features for Green Channel:
# 156.73387145996094
# 10.510955181761922
# 166.0
# 1679.8682472554501
# 40.986195813413204
# -1.250662472423269
# 1.7554482222655992
# 7.175544736589469
# 913.0306985294119
# 0.011882279254810998
# 0.056524639925867516
# 0.7289168644780655
# 0.0010940693804341887
# 0.013931677367528188
# Calculating Statistical Features for Blue Channel:
# 131.82174682617188
# 10.490203647145929
# 147.0
# 3352.266748755239
# 57.89876292940324
# -0.43050167746036727
# -0.9625846615016767
# 7.6149065409022105
# 901.3355392156863
# 0.010283466602630008
# 0.059272133169739595
# 0.8657005819797898
# 0.0011082478226433214
# 0.013753231175570412
# Image number:  355
# Calculating Statistical features for Red Channel:
# 110.46945190429688
# 8.994566230768857
# 119.0
# 732.195386393927
# 27.05910912047784
# -0.6602347512112897
# -0.32126177537049827
# 6.578391175525621
# 24.64171262254902
# 0.04671998549942842
# 0.3921416672900887
# 0.9831986771971549
# 0.03907014212430236
# 0.00037595754469609157
# Calculating Statistical Features for Green Channel:
# 128.46951293945312
# 8.784073236656962
# 129.0
# 460.3965314766392
# 21.456852785919914
# 0.21191231826307436
# 0.6974850902345016
# 6.352534230044707
# 24.66099877450981
# 0.051009916154018384
# 0.3918427398603208
# 0.9733019019297674
# 0.03904726415660775
# 0.0003762655638900228
# Calculating Statistical Features for Blue Channel:
# 93.70846557617188
# 9.111872178625498
# 110.0
# 1465.39031895902
# 38.28041691203245
# -0.3960635434889723
# -1.3985610963824602
# 6.635647375793269
# 19.973866421568626
# 0.048051811847443754
# 0.38956765344783917
# 0.9931858026686389
# 0.04778786482870996
# 0.0003047529209988111
# Image number:  356
# Calculating Statistical features for Red Channel:
# 138.07852172851562
# 10.076457892638135
# 144.0
# 1789.1771534299478
# 42.298666095161295
# -1.1419658827967325
# 1.258940063003962
# 7.085798648790948
# 572.447181372549
# 0.014553163692177615
# 0.10188017177948244
# 0.8399378214567922
# 0.0017438840254408716
# 0.008734349006402383
# Calculating Statistical Features for Green Channel:
# 129.60813903808594
# 10.053407340076687
# 137.0
# 1778.1880129796918
# 42.168566646018355
# -1.1727576377794269
# 1.19227653118622
# 7.062312054098127
# 572.820419730392
# 0.01454735776701356
# 0.10301365458227313
# 0.8388521968647333
# 0.0017427496791991837
# 0.00874005622138806
# Calculating Statistical Features for Blue Channel:
# 86.91175842285156
# 10.167796171220791
# 72.0
# 2691.7342330773827
# 51.88192588057408
# 0.21411141818565255
# -1.1662211009830699
# 7.435953148869403
# 565.7875765931371
# 0.013981921438363328
# 0.10404721150665455
# 0.8947472586582648
# 0.0017643729513885447
# 0.008632527163699097
# Image number:  357
# Calculating Statistical features for Red Channel:
# 116.40670776367188
# 10.51460920985357
# 118.0
# 3580.1564882090315
# 59.83440889830058
# -0.1324306235836393
# -1.2245404483157152
# 7.660221144431835
# 356.71723345588236
# 0.017225440674206494
# 0.18292164042436918
# 0.9502001439779536
# 0.0027956387408229625
# 0.005443043547497345
# Calculating Statistical Features for Green Channel:
# 113.95756530761719
# 10.197780921248183
# 121.0
# 2645.390701127937
# 51.43336175215399
# -0.3902796519535048
# -0.8565586269951293
# 7.500291214319588
# 350.4025428921569
# 0.017081348060123538
# 0.18362871896721347
# 0.9338546718331221
# 0.002845877560231689
# 0.005346669470092875
# Calculating Statistical Features for Blue Channel:
# 94.13804626464844
# 10.305092480432839
# 94.0
# 3153.746614005184
# 56.15822837309938
# 0.032258878200062
# -1.1993348502489642
# 7.571459142746885
# 348.89375
# 0.01635052342352769
# 0.18206066205536028
# 0.9447026989273324
# 0.0028581440284397327
# 0.005323644540931848
# Image number:  358
# Calculating Statistical features for Red Channel:
# 124.87236022949219
# 10.171371705338668
# 128.0
# 2034.119984334102
# 45.10121932203277
# -0.5002394788658286
# -0.04193395361006358
# 7.449414243865999
# 759.5023437500001
# 0.011126154388860759
# 0.08656006538787997
# 0.8136405108151817
# 0.0013149395770297335
# 0.01158905298674679
# Calculating Statistical Features for Green Channel:
# 124.27137756347656
# 10.197686654842439
# 126.0
# 1615.7308128362056
# 40.196154204553025
# -0.5013365319220515
# 0.38909101015067016
# 7.286426519988438
# 759.4807291666667
# 0.01152091148234735
# 0.08673698022778703
# 0.7654117815733164
# 0.0013149776337353532
# 0.011588719852185625
# Calculating Statistical Features for Blue Channel:
# 119.80406188964844
# 10.153430347776482
# 124.0
# 2727.3484338184353
# 52.22402161667019
# -0.39397519539109194
# -0.48485193160259277
# 7.623389349436094
# 754.3810968137257
# 0.01083963657041647
# 0.08908676139742847
# 0.8619243766273464
# 0.0013238540841375387
# 0.011510896802346711
# Image number:  359

# %%
#change the specific channels to csv data
import pandas as pd
#Convert red channel
red_file = pd.read_excel('RedChannel30.xlsx')
red_file.to_csv('RedData30.csv')

#Convert green channel
green_file = pd.read_excel('GreenChannel30.xlsx')
green_file.to_csv('GreenData30.csv')

#Convert blue channel
blue_file = pd.read_excel('BlueChannel30.xlsx')
blue_file.to_csv('BlueData30.csv')

# %%
#change the main file which contains features of all the three channels into csv
file = pd.read_excel('Output30.xlsx')
file.to_csv('Output30.csv')

# %% [markdown]
# # SVM

# %% [markdown]
# ## Apply SVM on Red Channel

# %%
# #read the data
# redData = pd.read_csv('RedData.csv')
# labelled = pd.read_csv('Labels1.csv')

# #classify data into dependent and indepedent variables
# redX = redData.iloc[:, :]
# redY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# redx_train, redx_test, redy_train, redy_test = train_test_split(redX, redY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# redSVC = SVC()

# #fit the model
# redSVC.fit(redx_train, redy_train)
# pred_r = redSVC.predict(redx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(redy_test, pred_r))

# %% [markdown]
# ## Apply SVM on Green Channel

# %%
# #read the data
# greenData = pd.read_csv('GreenData.csv')

# #classify data into dependent and indepedent variables
# greenX = greenData.iloc[:, :]
# greenY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# greenx_train, greenx_test, greeny_train, greeny_test = train_test_split(greenX, greenY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# greenSVC = SVC()

# #fit the model
# greenSVC.fit(greenx_train, greeny_train)
# pred_g = greenSVC.predict(greenx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for green Channel is ", accuracy_score(greeny_test, pred_g))

# %% [markdown]
# ## Apply SVM on Blue Channel

# %%
# #read the data
# blueData = pd.read_csv('BlueData.csv')

# #classify data into dependent and indepedent variables
# blueX = blueData.iloc[:, :]
# blueY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# bluex_train, bluex_test, bluey_train, bluey_test = train_test_split(blueX, blueY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# blueSVC = SVC()

# #fit the model
# blueSVC.fit(bluex_train, bluey_train)
# pred_b = blueSVC.predict(bluex_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(bluey_test, pred_b))

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Apply Random Forest on red channel

# %%
# #read the data
# RedData = pd.read_csv('RedData.csv')
# labelled = pd.read_csv('Labels1.csv')

# #classify data into dependent and indepedent variables
# RedX = RedData.iloc[:, :]
# RedY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Redx_train, Redx_test, Redy_train, Redy_test = train_test_split(RedX, RedY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# RedRF = RandomForestClassifier()

# #fit the model
# RedRF.fit(Redx_train, Redy_train)
# pred_R = RedRF.predict(Redx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(Redy_test, pred_R))

# %% [markdown]
# ## Apply Random Forest on green channel

# %%
# #read the data
# GreenData = pd.read_csv('GreenData.csv')

# #classify data into dependent and indepedent variables
# GreenX = GreenData.iloc[:, :]
# GreenY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Greenx_train, Greenx_test, Greeny_train, Greeny_test = train_test_split(GreenX, GreenY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# GreenRF = RandomForestClassifier()

# #fit the model
# GreenRF.fit(Greenx_train, Greeny_train)
# pred_G = GreenRF.predict(Greenx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for green Channel is ", accuracy_score(Greeny_test, pred_G))

# %% [markdown]
# ## Apply Random Forest on blue channel

# %%
# #read the data
# BlueData = pd.read_csv('BlueData.csv')

# #classify data into dependent and indepedent variables
# BlueX = BlueData.iloc[:, :]
# BlueY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Bluex_train, Bluex_test, Bluey_train, Bluey_test = train_test_split(BlueX, BlueY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# BlueRF = RandomForestClassifier()

# #fit the model
# BlueRF.fit(Bluex_train, Bluey_train)
# pred_B = BlueRF.predict(Bluex_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(Bluey_test, pred_B))
