# %%
#import the required libraries
import skimage.feature as skf
import openpyxl
import numpy as np
import math
from PIL import Image
from numpy import asarray
from scipy.stats import skew, kurtosis
import skimage.feature
import xlsxwriter
import os


#creates general file for features of all the three channels
outWorkbook = xlsxwriter.Workbook("Output30.xlsx")
outSheet = outWorkbook.add_worksheet()

#Writes headers for general file 
outSheet.write("A1", "Mean_R")
outSheet.write("B1", "RMS_R")
outSheet.write("C1", "Median_R")
outSheet.write("D1", "Variance_R")
outSheet.write("E1", "Std_R")
outSheet.write("F1", "Skewness_R")
outSheet.write("G1", "Kurtosis_R")
outSheet.write("H1", "Contrast_R")
outSheet.write("I1", "Entropy_R")
outSheet.write("J1", "Energy_R")
outSheet.write("K1", "Homogeneity_R")
outSheet.write("L1", "Correlation_R")
outSheet.write("M1", "IDM_R")
outSheet.write("N1", "Smoothness_R")
outSheet.write("O1", "Mean_G")
outSheet.write("P1", "RMS_G")
outSheet.write("Q1", "Median_G")
outSheet.write("R1", "Variance_G")
outSheet.write("S1", "Std_G")
outSheet.write("T1", "Skewness_G")
outSheet.write("U1", "Kurtosis_G")
outSheet.write("V1", "Contrast_G")
outSheet.write("W1", "Entropy_G")
outSheet.write("X1", "Energy_G")
outSheet.write("Y1", "Homogeneity_G")
outSheet.write("Z1", "Correlation_G")
outSheet.write("AA1", "IDM_G")
outSheet.write("AB1", "Smoothness_G")
outSheet.write("AC1", "Mean_B")
outSheet.write("AD1", "RMS_B")
outSheet.write("AE1", "Median_B")
outSheet.write("AF1", "Variance_B")
outSheet.write("AG1", "Std_B")
outSheet.write("AH1", "Skewness_B")
outSheet.write("AI1", "Kurtosis_B")
outSheet.write("AJ1", "Contrast_B")
outSheet.write("AK1", "Entropy_B")
outSheet.write("AL1", "Energy_B")
outSheet.write("AM1", "Homogeneity_B")
outSheet.write("AN1", "Correlation_B")
outSheet.write("AO1", "IDM_B")
outSheet.write("AP1", "Smoothness_B")
outWorkbook.close()

# %%
#creates a file for red channel
outWorkbookR = xlsxwriter.Workbook("RedChannel30.xlsx")
outSheetR = outWorkbookR.add_worksheet()

#writes headers for red file
outSheetR.write("A1", "Mean_R")
outSheetR.write("B1", "RMS_R")
outSheetR.write("C1", "Median_R")
outSheetR.write("D1", "Variance_R")
outSheetR.write("E1", "Std_R")
outSheetR.write("F1", "Skewness_R")
outSheetR.write("G1", "Kurtosis_R")
outSheetR.write("H1", "Contrast_R")
outSheetR.write("I1", "Entropy_R")
outSheetR.write("J1", "Energy_R")
outSheetR.write("K1", "Homogeneity_R")
outSheetR.write("L1", "Correlation_R")
outSheetR.write("M1", "IDM_R")
outSheetR.write("N1", "Smoothness_R")
outWorkbookR.close()

# %%
#creates file for green channel
outWorkbookG = xlsxwriter.Workbook("GreenChannel30.xlsx")
outSheetG = outWorkbookG.add_worksheet()

#writes headers for green file
outSheetG.write("A1", "Mean_G")
outSheetG.write("B1", "RMS_G")
outSheetG.write("C1", "Median_G")
outSheetG.write("D1", "Variance_G")
outSheetG.write("E1", "Std_G")
outSheetG.write("F1", "Skewness_G")
outSheetG.write("G1", "Kurtosis_G")
outSheetG.write("H1", "Contrast_G")
outSheetG.write("I1", "Entropy_G")
outSheetG.write("J1", "Energy_G")
outSheetG.write("K1", "Homogeneity_G")
outSheetG.write("L1", "Correlation_G")
outSheetG.write("M1", "IDM_G")
outSheetG.write("N1", "Smoothness_G")
outWorkbookG.close()

# %%
#creates a file for blue channel
outWorkbookB = xlsxwriter.Workbook("BlueChannel30.xlsx")
outSheetB = outWorkbookB.add_worksheet()

#writes headers for blue file
outSheetB.write("A1", "Mean_B")
outSheetB.write("B1", "RMS_B")
outSheetB.write("C1", "Median_B")
outSheetB.write("D1", "Variance_B")
outSheetB.write("E1", "Std_B")
outSheetB.write("F1", "Skewness_B")
outSheetB.write("G1", "Kurtosis_B")
outSheetB.write("H1", "Contrast_B")
outSheetB.write("I1", "Entropy_B")
outSheetB.write("J1", "Energy_B")
outSheetB.write("K1", "Homogeneity_B")
outSheetB.write("L1", "Correlation_B")
outSheetB.write("M1", "IDM_B")
outSheetB.write("N1", "Smoothness_B")
outWorkbookB.close()

# %%
#import required libaray to read and make a list of all the needy images
import glob

#declare an empty list
Image_list = []

#using for loop to append to the list declared above
for filename in glob.glob('/home/uca/Desktop/Undergrad/Arfan_FinalYearProject/4_Data/data30/*.*'):
    im = Image.open(filename)
    
    #append each image to the list declared above
    Image_list.append(im)
    
#prints number of images used
print(len(Image_list))
# Out:
# 120

# %%
#uses for loop to read each image and array of each image
for i in range(0, len(Image_list)):
    Image = Image_list[i]
    image = asarray(Image)
    
    #Apply image enhancement 
#     #apply image inverse
#     # Invert the colors
#     image = 255 - image

#     # Apply contrast stretching for image enhancement
#     min_val = np.min(image)
#     max_val = np.max(image)
#     image = (image - min_val) / (max_val - min_val)
    
    
    
    #Here i am extracting the single channel like red, green, and blue from the whole image array
    R = image[:, :, 0]
    G = image[:, :, 1]
    B = image[:, :, 2]


    #selecting features from Red Channel
    print("Calculating Statistical features for Red Channel: ")
    
    #calculates mean
    Mean_R = np.mean(R);
    print(Mean_R)
    
    #calculating root mean square
    RMS_R = np.sqrt(np.mean(R**2))
    print(RMS_R)
    
    #calculating median
    Median_R = np.median(R)
    print(Median_R)
    
    #calculating variance of the pixels
    Variance_R = np.var(R)
    print(Variance_R)
    
    #calculating standard deviation
    Std_R = math.sqrt(Variance_R)
    print(Std_R)
    
    #calculates skewness
    Skewness_R = skew(R.reshape(-1))
    print(Skewness_R)
    
    #calculates kurtosis
    Kurtosis_R = kurtosis(R.reshape(-1))
    print(Kurtosis_R)
    
    #calculates entropy
    Entropy_R = skimage.measure.shannon_entropy(R)
    print(Entropy_R)
    
    #returns an image array where lowest pixel value is 0 and highest 8 instead of 0 and 255
    R = skimage.img_as_ubyte(R)
    
    #calculates contrast
    g1 = skf.graycomatrix(R, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_R = skf.graycoprops(g1, 'contrast')[0][0]
    print(Contrast_R)
    
    #calculates energy
    Energy_R = skf.graycoprops(g1, 'energy')[0][0]
    print(Energy_R)
    
    #calculating homogeniety
    Homogeneity_R = skf.graycoprops(g1, 'homogeneity')[0][0]
    print(Homogeneity_R)
    
    #finding correlation
    Correlation_R = skf.graycoprops(g1, 'correlation')[0][0]
    print(Correlation_R)
    
    #glcm_R = skf.graycomatrix(R, distances=[1], angles=[0], levels=256, symmetric= False, normed=True)
    
    #calculate inverse difference moment (IDM)
    IDM_R = 1 / (1 + Contrast_R - Energy_R)
    print(IDM_R)
    
    #calculates smoothness
    diff_R = np.diff(R.astype(float))
    variance_R = np.var(diff_R)
    Smoothness_R = variance_R / (R.shape[0] * R.shape[1])
    print(Smoothness_R)
    

    #selecting features from Green Channel
    print("Calculating Statistical Features for Green Channel: ")
    
    #calculates mean
    Mean_G = np.mean(G);
    print(Mean_G)
    
    #calculates root mean square
    RMS_G = np.sqrt(np.mean(G**2))
    print(RMS_G)
    
    #calculates median
    Median_G = np.median(G)
    print(Median_G)
    
    #claculates variance
    Variance_G = np.var(G)
    print(Variance_G)
    
    #calculates standard deviation
    Std_G = math.sqrt(Variance_G)
    print(Std_G)
    
    #calculates skewness
    Skewness_G = skew(G.reshape(-1))
    print(Skewness_G)
    
    #calculates kurtosis
    Kurtosis_G = kurtosis(G.reshape(-1))
    print(Kurtosis_G)
    
    #calculates entropy
    Entropy_G = skimage.measure.shannon_entropy(G)
    print(Entropy_G)
    
    #converts images pixels to range of 0 to 8 instead of 0 to 255
    G = skimage.img_as_ubyte(G)
    
    #calculates contrast
    g2 = skf.graycomatrix(G, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_G = skf.graycoprops(g2, 'contrast')[0][0]
    print(Contrast_G)
    
    #calculates energy
    Energy_G = skf.graycoprops(g2, 'energy')[0][0]
    print(Energy_G)
    
    #calculates homogeniety
    Homogeneity_G = skf.graycoprops(g2, 'homogeneity')[0][0]
    print(Homogeneity_G)
    
    #calculates correlation
    Correlation_G = skf.graycoprops(g2, 'correlation')[0][0]
    print(Correlation_G)
    #glcm_G = skf.graycomatrix(G, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
    
    #calculates inverse difference moment (IDM)
    IDM_G = 1 / (1 + Contrast_G - Energy_G)
    print(IDM_G)
    
    #calculates smoothness
    diff_G = np.diff(G.astype(float))
    variance_G = np.var(diff_G)
    Smoothness_G = variance_G / (G.shape[0] * G.shape[1])
    print(Smoothness_G)

    #selecting features from Blue Channel
    print("Calculating Statistical Features for Blue Channel: ")
    
    #calculates mean
    Mean_B = np.mean(B);
    print(Mean_B)
    
    #calculates root mean square
    RMS_B = np.sqrt(np.mean(B**2))
    print(RMS_B)
    
    #calculates median
    Median_B = np.median(B)
    print(Median_B)
    
    #calculates variance
    Variance_B = np.var(B)
    print(Variance_B)
    
    #calculates standard deviation
    Std_B = math.sqrt(Variance_B)
    print(Std_B)
    
    #calculates skewness
    Skewness_B = skew(B.reshape(-1))
    print(Skewness_B)
    
    #calculates kurtosis
    Kurtosis_B = kurtosis(B.reshape(-1))
    print(Kurtosis_B)
    
    #calculates entropy
    Entropy_B = skimage.measure.shannon_entropy(B)
    print(Entropy_B)
    
    #converts range of pixels values from 0-255 to 0-8
    B = skimage.img_as_ubyte(B)
    
    #calculates contrast
    g3 = skf.graycomatrix(B, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_B = skf.graycoprops(g3, 'contrast')[0][0]
    print(Contrast_B)
    
    #calculates energy
    Energy_B = skf.graycoprops(g3, 'energy')[0][0]
    print(Energy_B)
    
    #calculates homogeniety
    Homogeneity_B = skf.graycoprops(g3, 'homogeneity')[0][0]
    print(Homogeneity_B)
    
    #calculates correlation
    Correlation_B = skf.graycoprops(g3, 'correlation')[0][0]
    print(Correlation_B)
    
    #glcm_B = skf.graycomatrix(B, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
    
    #calculates inverse difference moment (IDM)
    IDM_B = 1 / (1 + Contrast_B - Energy_B)
    print(IDM_B)
    
    #calculates smoothness
    diff_B = np.diff(B.astype(float))
    variance_B = np.var(diff_B)
    Smoothness_B = variance_B / (B.shape[0] * B.shape[1])
    print(Smoothness_B)
    
    #count the number of images
    print("Image number: ", i)


    #Declares data for all the three channels
    values_R = [Mean_R, RMS_R, Median_R, Variance_R, Std_R, Skewness_R, Kurtosis_R, Entropy_R, Contrast_R, Energy_R, Homogeneity_R, Correlation_R, IDM_R, Smoothness_R]
    values_G = [Mean_G, RMS_G, Median_G, Variance_G, Std_G, Skewness_G, Kurtosis_G, Entropy_G, Contrast_G, Energy_G, Homogeneity_G, Correlation_G, IDM_G, Smoothness_G]
    values_B = [Mean_B, RMS_B, Median_B, Variance_B, Std_B, Skewness_B, Kurtosis_B, Entropy_B, Contrast_B, Energy_B, Homogeneity_B, Correlation_B, IDM_B, Smoothness_B]

    #Writes red channels into a file
    outWorkbookR = openpyxl.load_workbook("RedChannel30.xlsx")
    outSheetR = outWorkbookR.active
    outSheetR.append(values_R)
    outWorkbookR.save(filename="RedChannel30.xlsx")

    #Writes green channels into a file
    outWorkbookG = openpyxl.load_workbook("GreenChannel30.xlsx")
    outSheetG = outWorkbookG.active
    outSheetG.append(values_G)
    outWorkbookG.save(filename="GreenChannel30.xlsx")

    #writes blue chanels into a file
    outWorkbookB = openpyxl.load_workbook("BlueChannel30.xlsx")
    outSheetB = outWorkbookB.active
    outSheetB.append(values_B)
    outWorkbookB.save(filename="BlueChannel30.xlsx")
    
    #creates a general fle where all the three channels data will be merged
    outWorkbook = xlsxwriter.Workbook("Output30.xlsx")
    outSheet = outWorkbook.add_worksheet()
        
    #declares data for general file
    values = [Mean_R, RMS_R, Median_R, Variance_R, Std_R, Skewness_R, Kurtosis_R, Entropy_R, Contrast_R, Energy_R, Homogeneity_R, Correlation_R, IDM_R, Smoothness_R, Mean_G, RMS_G, Median_R, Variance_G, Std_G, Skewness_G, Kurtosis_G, Entropy_G, Contrast_G, Energy_G, Homogeneity_G, Correlation_G, IDM_G, Smoothness_G, Mean_B, RMS_B, Median_R, Variance_B, Std_B, Skewness_B, Kurtosis_B, Entropy_B, Contrast_B, Energy_B, Homogeneity_B, Correlation_B, IDM_B, Smoothness_B]
    
     
    #writes into the general file
    outWorkbook = openpyxl.load_workbook("Output30.xlsx") 
    outSheet = outWorkbook.active
    outSheet.append(values)
    
    #here the general file is being saved
    outWorkbook.save(filename="Output30.xlsx")
# Out:
# Calculating Statistical features for Red Channel:
# 136.1082000732422
# 10.071902603078449
# 141.0
# 1649.2003136181738
# 40.61034737130642
# -0.8880922090526485
# 1.2362349027803257
# 7.235152940291849
# 898.8067401960784
# 0.0109732280194814
# 0.06162337443474059
# 0.7280825293078097
# 0.0011113633078866196
# 0.013714698402985202
# Calculating Statistical Features for Green Channel:
# 129.0299072265625
# 9.811770661091675
# 133.0
# 1260.1046658605337
# 35.4979529812711
# -1.0378545039394191
# 2.293167514307471
# 7.0084479295700985
# 900.1107996323532
# 0.012055302377524295
# 0.06190037470563756
# 0.6435965923070701
# 0.001109756290631127
# 0.013734592475403087
# Calculating Statistical Features for Blue Channel:
# 120.52578735351562
# 10.01757184179224
# 131.0
# 2244.632422170602
# 47.377551880300885
# -0.6924506381116184
# -0.03154220348670078
# 7.430000944841996
# 898.0696231617646
# 0.010444271201761189
# 0.06291361621075796
# 0.8003777203760872
# 0.00111227383411401
# 0.013703444969193328
# Image number:  0
# Calculating Statistical features for Red Channel:
# 105.17645263671875
# 10.35539875848659
# 100.0
# 529.1168442033231
# 23.002539951129812
# 0.6746027069281887
# 0.41588871338168065
# 6.447092891949835
# 398.73350183823516
# 0.01965245575812517
# 0.10295624727214038
# 0.6231535048091746
# 0.0025017897216844318
# 0.006084181981895983
# Calculating Statistical Features for Green Channel:
# 119.38824462890625
# 9.401273405788741
# 123.0
# 530.1942673288286
# 23.025947696649286
# -0.1929621525467792
# -0.30619044479300017
# 6.50034621141618
# 400.28965992647056
# 0.01792410335422557
# 0.10329942887875823
# 0.6226362136871882
# 0.0024920768415167115
# 0.006107925221732875
# Calculating Statistical Features for Blue Channel:
# 101.71835327148438
# 10.319882241693549
# 97.0
# 733.7554834699258
# 27.0879213574967
# 0.5160652770679471
# -0.21699029675799242
# 6.708747610590099
# 398.65378370098034
# 0.017123690467088528
# 0.10223320662964995
# 0.728405469004411
# 0.0025022729395588806
# 0.006082969654014178
# Image number:  1
# Calculating Statistical features for Red Channel:
# 121.71726989746094
# 10.390619860196097
# 128.0
# 3421.879002287751
# 58.4968289934399
# -0.33243072968346526
# -0.9922405312386577
# 7.590309574404936
# 436.8997855392157
# 0.015277318689910394
# 0.14233780197674914
# 0.9362002504871232
# 0.002283707190427444
# 0.006666541556938367
# Calculating Statistical Features for Green Channel:
# 119.28927612304688
# 9.98719425425708
# 127.0
# 2692.5782761117443
# 51.8900595115456
# -0.6254516519127873
# -0.4578728274239192
# 7.406289205616081
# 432.2750459558824
# 0.015452327079932564
# 0.14307223743265915
# 0.9198212974476145
# 0.002308085071179648
# 0.006595966684378136
# Calculating Statistical Features for Blue Channel:
# 101.19580078125
# 10.046445181805135
# 104.0
# 3574.1300275325775
# 59.78402819760958
# -0.11928456536919312
# -1.230861603306473
# 7.544737268039628
# 426.7801930147059
# 0.016805197595807696
# 0.14751285459904073
# 0.9403142133133968
# 0.0023377409766250244
# 0.006512117335588595
# Image number:  2
# Calculating Statistical features for Red Channel:
# 111.76441955566406
# 10.061445287552582
# 109.0
# 404.38079640991054
# 20.10922167588568
# 0.3650029866379923
# 0.3548014994122104
# 6.330353347392802
# 240.39215686274517
# 0.021594147026171656
# 0.11782389275373512
# 0.7023328617568123
# 0.004143007286177554
# 0.0036680887702971363
# Calculating Statistical Features for Green Channel:
# 125.43402099609375
# 9.108740128498322
# 129.0
# 408.1817734800279
# 20.203508939786374
# -0.5862595639676879
# 0.5127436305553168
# 6.27103117256572
# 240.8999080882353
# 0.02227785625461369
# 0.11904856140187135
# 0.7050790323084373
# 0.0041343219670248845
# 0.0036758379952574593
# Calculating Statistical Features for Blue Channel:
# 109.95576477050781
# 10.184587120710193
# 105.0
# 442.56107730208896
# 21.037135672474257
# 0.6120266422568468
# 0.09024439513609206
# 6.331950926102922
# 239.65127144607848
# 0.021636648915781452
# 0.11746706690893136
# 0.7287384468119603
# 0.004155764109615775
# 0.0036567852927944047
# Image number:  3
# Calculating Statistical features for Red Channel:
# 117.37419128417969
# 10.482975555120683
# 129.0
# 3084.250590624055
# 55.536029662049614
# -0.33741793993688346
# -1.2048956662750974
# 7.426021141257511
# 442.323131127451
# 0.020375340865632533
# 0.15752726716121723
# 0.9284178230573352
# 0.0022557946842122036
# 0.006749304811606633
# Calculating Statistical Features for Green Channel:
# 101.94041442871094
# 10.378998870493769
# 114.0
# 2971.246617406374
# 54.509142512117855
# -0.2779669926440606
# -1.332234156544724
# 7.360318108213527
# 439.67734375
# 0.02126279568236406
# 0.15720309478379732
# 0.9261535600097096
# 0.002269343470386987
# 0.006708930158573719
# Calculating Statistical Features for Blue Channel:
# 76.5621337890625
# 10.188558886208313
# 66.0
# 2975.1089018434286
# 54.54455886560481
# 0.28624935927593875
# -1.304379298783474
# 7.360492650278716
# 430.7965839460785
# 0.02046411536694382
# 0.15745972493276675
# 0.9275589919767505
# 0.0023160150690873654
# 0.006573412552334853
# Image number:  4
# Calculating Statistical features for Red Channel:
# 123.57257080078125
# 10.346801676442853
# 138.0
# 2465.641675617546
# 49.65522807940314
# -0.9332347081777987
# 0.11527495884726191
# 7.264542556534149
# 654.3710631127451
# 0.020439481065370656
# 0.13371520126041042
# 0.8675345535251586
# 0.0015259007376210573
# 0.00998486767349688
# Calculating Statistical Features for Green Channel:
# 112.47496032714844
# 9.781706290525266
# 125.0
# 2093.6822648604866
# 45.75677288512037
# -0.9442307213889587
# 0.25307602798822293
# 7.1220158306369346
# 653.9342677696078
# 0.024047034801976005
# 0.13473929774295093
# 0.8441370501162212
# 0.0015269268494206812
# 0.009978207441380548
# Calculating Statistical Features for Blue Channel:
# 102.39241027832031
# 9.903299078670782
# 117.0
# 2836.5844937877264
# 53.259595321291414
# -0.4074117930026064
# -0.908392169645099
# 7.45422456953849
# 648.961611519608
# 0.018349170929820104
# 0.13462825087611044
# 0.8857371178518662
# 0.0015385958404835732
# 0.009902336882919312
# Image number:  5
# Calculating Statistical features for Red Channel:
# 150.4571533203125
# 10.51632148510709
# 164.0
# 2065.5036573261023
# 45.44781245919436
# -1.2422770246526966
# 1.0359899836214739
# 7.2044901401851265
# 595.3433210784314
# 0.015643866565280867
# 0.11726100310583192
# 0.8562864522975879
# 0.0016769303827645673
# 0.00908413483128553
# Calculating Statistical Features for Green Channel:
# 146.85263061523438
# 10.45141697088097
# 159.0
# 1926.4510605847463
# 43.891355191936675
# -1.3991132585661201
# 1.5815895558201074
# 7.111334096660391
# 596.2709865196078
# 0.01596824188678043
# 0.11729442531158756
# 0.8456760423820772
# 0.0016743266601319776
# 0.009098303507711281
# Calculating Statistical Features for Blue Channel:
# 135.8088836669922
# 10.561789945854422
# 162.0
# 3544.541492735734
# 59.53605204189924
# -0.703164926494533
# -0.8389845056420802
# 7.448420272014279
# 589.5461856617649
# 0.0154636365743062
# 0.11818758336494349
# 0.9170078210995326
# 0.001693391999268994
# 0.008995732596453447
# Image number:  6
# Calculating Statistical features for Red Channel:
# 103.22879028320312
# 10.688350889008206
# 100.0
# 2279.6787951430306
# 47.745981979042284
# -0.11509853550058863
# -1.124318109396123
# 7.290384133283989
# 97.39007352941177
# 0.02498064711030802
# 0.25269670404271044
# 0.9786601479635342
# 0.010166208059159238
# 0.001486054588251048
# Calculating Statistical Features for Green Channel:
# 111.28390502929688
# 10.4970742645384
# 113.0
# 2007.655268295668
# 44.806866307471985
# -0.41862361061729547
# -0.7314094688683674
# 7.257549297169255
# 97.41660539215685
# 0.025257940854485145
# 0.2531630558566517
# 0.9757767308171938
# 0.010163495326608249
# 0.0014864594300565057
# Calculating Statistical Features for Blue Channel:
# 104.47154235839844
# 10.610123575625265
# 101.0
# 2791.0801532974
# 52.83067435966912
# -0.09021435009899875
# -1.1150599744612157
# 7.430263538351387
# 98.80726102941176
# 0.023171478650189092
# 0.24766690621097048
# 0.9823143000551913
# 0.01002163776311539
# 0.001507678148091435
# Image number:  7
# Calculating Statistical features for Red Channel:
# 154.6433563232422
# 10.524485059450727
# 160.0
# 1078.201037099352
# 32.835971694155056
# -1.0302092752717722
# 1.8022789234258108
# 6.923200527566513
# 475.0780330882354
# 0.017533077571033562
# 0.11408195818347058
# 0.7802004032673114
# 0.0021005733514492357
# 0.007249112438062484
# Calculating Statistical Features for Green Channel:
# 145.24684143066406
# 10.118910477080231
# 148.0
# 1102.9388099086937
# 33.210522578072954
# -0.979977533193824
# 1.7830262915793522
# 6.949433084881874
# 480.01302083333337
# 0.016781023253472457
# 0.1138236297969031
# 0.7829074421686905
# 0.002079018331608678
# 0.007324415220048669
# Calculating Statistical Features for Blue Channel:
# 113.67713928222656
# 10.449674347544356
# 122.0
# 2140.055261078989
# 46.260731307221995
# -0.39622680354923895
# -0.8967303218701379
# 7.32431731597917
# 458.7452512254902
# 0.014671326971937572
# 0.11116838089452802
# 0.8929167159620681
# 0.0021751870415510355
# 0.006999888639970153
# Image number:  8
# Calculating Statistical features for Red Channel:
# 121.79817199707031
# 10.387924784250327
# 124.0
# 3850.5947482453194
# 62.053160662816516
# -0.2941133465670334
# -1.1758143597534085
# 7.551919637252037
# 450.02098651960796
# 0.019859571049388635
# 0.18905153667037708
# 0.9415578539029903
# 0.0022172893597094284
# 0.006866703570542175
# Calculating Statistical Features for Green Channel:
# 119.53323364257812
# 10.297322519675625
# 126.0
# 3487.067468523048
# 59.05139683803464
# -0.3988090001021353
# -1.0005380299083806
# 7.562548869673953
# 447.77267156862746
# 0.018600939454971266
# 0.1906364438597412
# 0.9358035664592012
# 0.0022283920424341934
# 0.006832349616396845
# Calculating Statistical Features for Blue Channel:
# 104.97822570800781
# 10.354344408030727
# 98.0
# 4219.538481568685
# 64.95797473419783
# -0.023187978712103787
# -1.3678708719117878
# 7.574828734483309
# 439.6966452205884
# 0.019137729934393027
# 0.19328926738826613
# 0.94785733891079
# 0.0022692331308087205
# 0.006709088518730766
# Image number:  9
# Calculating Statistical features for Red Channel:
# 105.6595458984375
# 9.869760402874846
# 116.0
# 1738.4412809461355
# 41.69461932847133
# -0.41478995468442
# -0.9147114160187813
# 7.171412271144649
# 178.73452818627447
# 0.02057229501528184
# 0.1970100689544995
# 0.9486146728840897
# 0.005564398129464565
# 0.0027269804957639663
# Calculating Statistical Features for Green Channel:
# 103.88470458984375
# 10.06121097624902
# 112.0
# 1584.8718998394907
# 39.8104496312148
# -0.47481871494491623
# -0.6361875775455106
# 7.143642271000455
# 179.50658700980395
# 0.020496506710984238
# 0.19736573477827346
# 0.9433883733427926
# 0.005540593168219039
# 0.002738700078579037
# Calculating Statistical Features for Blue Channel:
# 83.59095764160156
# 9.935031416314901
# 78.0
# 2976.3191498031374
# 54.555651859391595
# 0.05263263117145974
# -1.4493433369466053
# 7.287256064470292
# 173.69774816176474
# 0.02128222154691634
# 0.20461534117697092
# 0.9707944388711353
# 0.0057248696589856886
# 0.002649988678467676
# Image number:  10
# Calculating Statistical features for Red Channel:
# 121.14686584472656
# 10.13999676044119
# 128.0
# 2229.7720553015824
# 47.220462252095565
# -0.5015806328020079
# -0.37114597857210585
# 7.41219946828824
# 511.128324142157
# 0.015007330249676223
# 0.12758535391058756
# 0.8854745282573347
# 0.0019526928263169676
# 0.007799195961386497
# Calculating Statistical Features for Green Channel:
# 118.74862670898438
# 9.974037035971035
# 126.0
# 1973.3856945252046
# 44.42280601813898
# -0.7643632403897923
# 0.09446111061388063
# 7.260165063386285
# 509.7783854166667
# 0.015640911256560523
# 0.12783629174842448
# 0.8710246009350705
# 0.0019578561881374804
# 0.007778591067941629
# Calculating Statistical Features for Blue Channel:
# 73.91433715820312
# 10.387302687844725
# 59.0
# 2751.316819592379
# 52.452996288032764
# 0.6234619445678051
# -0.7998370103349455
# 7.404397651354594
# 501.1041973039215
# 0.01460500788793263
# 0.1283096445381689
# 0.9085921252295469
# 0.001991676416607331
# 0.007646230508697601
# Image number:  11
# Calculating Statistical features for Red Channel:
# 122.14506530761719
# 9.956528589214795
# 120.0
# 477.71548254578374
# 21.856703377814867
# 0.005951980334269565
# 0.5403827023825816
# 6.4197526166580685
# 55.27101715686275
# 0.03214045904813924
# 0.28425443858392396
# 0.9421587043847801
# 0.01778129398588893
# 0.0008429807656999967
# Calculating Statistical Features for Green Channel:
# 118.77531433105469
# 9.684584837342264
# 122.0
# 657.8174515308347
# 25.647952189811075
# -0.09457328333778696
# -0.4688937881660533
# 6.622825624752891
# 57.674586397058825
# 0.030323810202441175
# 0.2854563699335643
# 0.9562249134718759
# 0.017051966482124793
# 0.0008796111703089444
# Calculating Statistical Features for Blue Channel:
# 108.90995788574219
# 10.016131550421628
# 116.0
# 1283.7916208112147
# 35.830037968319466
# -0.3307879157708534
# -0.9687761438128502
# 6.921699728591651
# 54.07423406862746
# 0.027012774001209813
# 0.2760581879050382
# 0.9789543906011339
# 0.018166221227548515
# 0.0008246840992050875
# Image number:  12
# Calculating Statistical features for Red Channel:
# 121.61709594726562
# 9.628160626556935
# 131.0
# 902.9209504043683
# 30.048643070933643
# -1.1672674277328168
# 0.9856240398437301
# 6.641074957987986
# 188.33002450980388
# 0.023221968099619426
# 0.1446555939602913
# 0.895909912651321
# 0.005282430354184975
# 0.002873537208554104
# Calculating Statistical Features for Green Channel:
# 122.59783935546875
# 9.515445400603957
# 133.0
# 932.6377052925527
# 30.53911762465564
# -1.4123521738130893
# 1.5005807711058132
# 6.556308019757379
# 187.21806066176472
# 0.02426208494027315
# 0.14749903175623497
# 0.8998183679605332
# 0.00531367137260785
# 0.0028565621229052623
# Calculating Statistical Features for Blue Channel:
# 95.21730041503906
# 10.015243356369563
# 116.0
# 2574.8223636595067
# 50.74270749240236
# -0.3487472675457097
# -1.4292332017317595
# 7.112607741963484
# 179.5374080882353
# 0.01939851208370402
# 0.14793515533327767
# 0.9651587265525744
# 0.005539613484260969
# 0.002739290366066002
# Image number:  13
# Calculating Statistical features for Red Channel:
# 105.7515869140625
# 10.218735067840772
# 101.0
# 501.82909904420376
# 22.401542336281306
# 0.4742981171883267
# 0.04665986960021318
# 6.45898035259971
# 256.9725643382354
# 0.019860043683070632
# 0.11048943472691788
# 0.7439946246319077
# 0.0038766796523215167
# 0.003921077323072046
# Calculating Statistical Features for Green Channel:
# 118.26399230957031
# 9.788202806673466
# 122.0
# 639.1401621864643
# 25.28122153271998
# -0.18179644175622933
# -0.7149525391857567
# 6.604021684378311
# 259.2922947303922
# 0.017611265763000643
# 0.11090976002306645
# 0.7974105192191561
# 0.003842094769604812
# 0.003956478619568483
# Calculating Statistical Features for Blue Channel:
# 99.59501647949219
# 10.270419738571803
# 94.0
# 677.5720265561249
# 26.030213724749263
# 0.5123864388013024
# -0.36172003768728045
# 6.642224794575574
# 256.32596507352946
# 0.018029744685635736
# 0.11039811299457807
# 0.8109245420211384
# 0.003886393937761707
# 0.003911214048545614
# Image number:  14
# Calculating Statistical features for Red Channel:
# 150.3372039794922
# 10.319770608171163
# 154.0
# 1090.7657337838318
# 33.02674270623477
# -1.4556297082049836
# 3.8825131534405646
# 6.846405949588148
# 556.475367647059
# 0.014068355903003782
# 0.07293098803578091
# 0.7455163732042153
# 0.0017938464988898014
# 0.008491140063988137
# Calculating Statistical Features for Green Channel:
# 140.58056640625
# 10.025000791478304
# 145.0
# 1071.9721772670746
# 32.74098619875514
# -1.4458092700388412
# 3.6432457105150684
# 6.837065188976222
# 556.4179840686274
# 0.01389776935192978
# 0.07268176476750006
# 0.7410051757297544
# 0.0017940306226300082
# 0.008490264005772841
# Calculating Statistical Features for Blue Channel:
# 105.46083068847656
# 10.34901427951557
# 117.0
# 2784.3379433040973
# 52.76682616288474
# -0.17255386470266912
# -1.3046933321407637
# 7.424470246840902
# 559.0952818627451
# 0.011575795289243821
# 0.07359552871491393
# 0.8997207204258604
# 0.001785447405748242
# 0.008531115364436574
# Image number:  15
# Calculating Statistical features for Red Channel:
# 138.07852172851562
# 10.076457892638135
# 144.0
# 1789.1771534299478
# 42.298666095161295
# -1.1419658827967325
# 1.258940063003962
# 7.085798648790948
# 572.447181372549
# 0.014553163692177615
# 0.10188017177948244
# 0.8399378214567922
# 0.0017438840254408716
# 0.008734349006402383
# Calculating Statistical Features for Green Channel:
# 129.60813903808594
# 10.053407340076687
# 137.0
# 1778.1880129796918
# 42.168566646018355
# -1.1727576377794269
# 1.19227653118622
# 7.062312054098127
# 572.820419730392
# 0.01454735776701356
# 0.10301365458227313
# 0.8388521968647333
# 0.0017427496791991837
# 0.00874005622138806
# Calculating Statistical Features for Blue Channel:
# 86.91175842285156
# 10.167796171220791
# 72.0
# 2691.7342330773827
# 51.88192588057408
# 0.21411141818565255
# -1.1662211009830699
# 7.435953148869403
# 565.7875765931371
# 0.013981921438363328
# 0.10404721150665455
# 0.8947472586582648
# 0.0017643729513885447
# 0.008632527163699097
# Image number:  16
# Calculating Statistical features for Red Channel:
# 114.457275390625
# 10.09211571280011
# 118.0
# 1998.5274409651756
# 44.70489280789269
# -0.3915695613992187
# 0.05885334459210867
# 7.442186841745804
# 1766.8234375
# 0.008745796022137835
# 0.038889089627388164
# 0.5586003679819654
# 0.0005656701489657328
# 0.026959197222026363
# Calculating Statistical Features for Green Channel:
# 119.88983154296875
# 10.121038721627711
# 122.0
# 2028.5629361532629
# 45.03957078118377
# -0.3377220059107112
# 0.16729943038861306
# 7.47054051170775
# 1768.3914522058826
# 0.00867061378015898
# 0.039279709358631926
# 0.5648420404039742
# 0.0005651688319811688
# 0.026983033159460552
# Calculating Statistical Features for Blue Channel:
# 121.85490417480469
# 10.056137442803509
# 128.0
# 2565.105885067722
# 50.64687438596504
# -0.5134117145916265
# -0.08827453594614587
# 7.566477234168458
# 1766.2966911764709
# 0.008432984413299708
# 0.03955461461865595
# 0.6561229571850551
# 0.0005658386487685963
# 0.026951087366392845
# Image number:  17
# Calculating Statistical features for Red Channel:
# 108.98597717285156
# 10.0721283334278
# 108.0
# 631.7701738437172
# 25.135038767499786
# 0.35364099885890876
# 0.2982034137863079
# 6.680682071573494
# 644.379656862745
# 0.013460811871606823
# 0.059518447229686286
# 0.49000610080980367
# 0.0015495078702900814
# 0.009832452704391655
# Calculating Statistical Features for Green Channel:
# 117.44050598144531
# 9.833002720679112
# 120.0
# 795.0873723269906
# 28.197293705726274
# -0.0718220601513238
# -0.3654796876265034
# 6.827019834970077
# 646.1369485294116
# 0.01256409506233689
# 0.05899102270745411
# 0.5939822460022024
# 0.0015452979737026892
# 0.009859266543387795
# Calculating Statistical Features for Blue Channel:
# 106.07272338867188
# 10.19981491818525
# 104.0
# 641.254202275537
# 25.32299749783854
# 0.4669197330208262
# 0.39647934563006926
# 6.678324712535263
# 643.2454963235297
# 0.01358757937356361
# 0.059400997581067386
# 0.4984067485222645
# 0.0015522360603798192
# 0.009815144299965255
# Image number:  18
# Calculating Statistical features for Red Channel:
# 113.93203735351562
# 9.834618780740817
# 119.0
# 1616.4996535396203
# 40.205716677353486
# -0.5270543427597898
# 0.4030163337279027
# 7.229859934652909
# 938.793275122549
# 0.011619317767889631
# 0.06308456873096648
# 0.7101182003983916
# 0.0010640769521550737
# 0.014324845154549513
# Calculating Statistical Features for Green Channel:
# 118.92707824707031
# 9.958653996836668
# 121.0
# 1511.9232865439262
# 38.883457749329935
# -0.5106317620489209
# 0.7919502790679873
# 7.210197672678091
# 940.9738051470589
# 0.011341123874922959
# 0.06285592866055524
# 0.6894885428326828
# 0.0010616134274915095
# 0.014358119302554938
# Calculating Statistical Features for Blue Channel:
# 113.13224792480469
# 9.800485435452053
# 122.0
# 2214.9682130010333
# 47.063448800539824
# -0.531368689417478
# -0.006382119489610982
# 7.419675869698059
# 937.7460477941178
# 0.010843294525926611
# 0.06294080606150528
# 0.7886126122076651
# 0.0010652631276708818
# 0.014308869129906867
# Image number:  19
# Calculating Statistical features for Red Channel:
# 175.81332397460938
# 9.997805545351252
# 177.0
# 1894.5843537217006
# 43.52682338192968
# -0.014469016514921895
# -0.7510562103363392
# 7.279757873013196
# 903.922993259804
# 0.013307047522148863
# 0.06530731626342473
# 0.7613842556952373
# 0.0011050826565750906
# 0.013792621550482857
# Calculating Statistical Features for Green Channel:
# 191.87298583984375
# 9.774165015888185
# 204.0
# 2392.5337941609323
# 48.91353385476184
# -0.4869680728890156
# -0.9862411499820518
# 7.183859054857119
# 890.3904718137255
# 0.024957913440250605
# 0.08127189863257012
# 0.8139503365665588
# 0.001121874230498744
# 0.013586151403937489
# Calculating Statistical Features for Blue Channel:
# 166.568603515625
# 9.944829193382201
# 161.0
# 1838.6163567900658
# 42.87908997157083
# 0.27978049163614627
# -0.4626028164310889
# 7.2693551821506075
# 909.3610753676473
# 0.012298826001824898
# 0.0631785995829577
# 0.7526399157889168
# 0.0010984800834235571
# 0.013875631144992157
# Image number:  20
# Calculating Statistical features for Red Channel:
# 116.48980712890625
# 9.936709198586101
# 116.0
# 474.22630601748824
# 21.776737726700212
# -0.07675264857259151
# -0.47156796597842066
# 6.447813950490488
# 196.0121323529412
# 0.018408006507211493
# 0.1094083529817972
# 0.7933531080936765
# 0.005076303843270641
# 0.0029909019513640754
# Calculating Statistical Features for Green Channel:
# 128.55386352539062
# 9.526692686087667
# 133.0
# 449.4472024803981
# 21.200169869140154
# -0.6864892325120582
# 0.34094298685038593
# 6.351786651916481
# 196.60333946078435
# 0.020820364782083562
# 0.1106226125170354
# 0.7812136711318264
# 0.005061176487552097
# 0.0029999242975064675
# Calculating Statistical Features for Blue Channel:
# 114.01182556152344
# 10.172222266297613
# 112.0
# 581.9535192137118
# 24.123712799105196
# 0.025167476062904644
# -0.6944097518423584
# 6.562211160380542
# 195.68988970588234
# 0.01766632956013656
# 0.10935714074587075
# 0.831958438953376
# 0.005084602100046184
# 0.0029859867859853774
# Image number:  21
# Calculating Statistical features for Red Channel:
# 124.72384643554688
# 10.498885322622499
# 142.0
# 2775.837160839699
# 52.68621414411648
# -0.9957832778935148
# 0.04066174168019243
# 7.141858311268425
# 650.4935814950982
# 0.029575410244790108
# 0.15366733015560316
# 0.8830425270712796
# 0.0015350042222743304
# 0.009925680913196525
# Calculating Statistical Features for Green Channel:
# 115.54014587402344
# 9.781721889825064
# 132.0
# 2502.5513057892676
# 50.0255065520507
# -1.064484587694694
# 0.11975473176479223
# 6.953392171203036
# 650.4975643382354
# 0.035598578612071406
# 0.1545329676786524
# 0.8703165165512895
# 0.0015350090297811497
# 0.009925731089576987
# Calculating Statistical Features for Blue Channel:
# 103.15678405761719
# 9.999976348848984
# 118.0
# 2935.9391486176755
# 54.1843072172901
# -0.47490171162453954
# -0.9061260825026718
# 7.350820750801
# 643.0776348039218
# 0.025614238437444287
# 0.15615927840686467
# 0.8905985097643638
# 0.0015526696106348517
# 0.009812499517327843
# Image number:  22
# Calculating Statistical features for Red Channel:
# 151.07627868652344
# 10.324276390304476
# 160.0
# 2123.4197949653026
# 46.08057936881114
# -1.0248128278109472
# 0.6102556432233741
# 7.303880325533995
# 604.2432444852943
# 0.017877632371006476
# 0.15149509016789517
# 0.8580817701735522
# 0.0016522770768843391
# 0.009219879040584793
# Calculating Statistical Features for Green Channel:
# 151.606689453125
# 10.210798523824698
# 159.0
# 1908.1018070578575
# 43.68182467637836
# -1.1162386983121937
# 1.1357941146459911
# 7.226986676063594
# 604.7030330882354
# 0.01822937263024196
# 0.15117349785893383
# 0.8419483543691071
# 0.0016510237566890362
# 0.009226826041269445
# Calculating Statistical Features for Blue Channel:
# 134.31703186035156
# 10.556340515218434
# 145.0
# 3835.5158085485455
# 61.93154130609496
# -0.3860867591297006
# -0.9921251398728383
# 7.675356928355379
# 604.8604166666667
# 0.016679544544523833
# 0.1485548866294219
# 0.9212388936559259
# 0.0016505906370348868
# 0.009229177224397178
# Image number:  23
# Calculating Statistical features for Red Channel:
# 120.28749084472656
# 10.468660359924058
# 130.0
# 4294.301458511269
# 65.5309198662072
# -0.2080510344066333
# -1.302734168421163
# 7.709638976830608
# 685.9695772058824
# 0.014879079914942462
# 0.15884802602672016
# 0.9201532499095724
# 0.0014557000668719922
# 0.01046480133161321
# Calculating Statistical Features for Green Channel:
# 106.46389770507812
# 10.338339136607757
# 117.0
# 4506.554116546176
# 67.13087305067748
# -0.16115185816166486
# -1.428029836902814
# 7.573377215584314
# 682.1156403186276
# 0.016889104597182736
# 0.16325789843684074
# 0.9243281466226101
# 0.0014639171836030444
# 0.010405842072596455
# Calculating Statistical Features for Blue Channel:
# 100.85740661621094
# 9.894939909642185
# 109.0
# 5481.45899146772
# 74.0368758894358
# 0.015780947335937143
# -1.5133065127153804
# 7.526425717378725
# 656.1566023284315
# 0.022693304448828906
# 0.16888206664883787
# 0.9401272660504705
# 0.0015217598517861663
# 0.01000975456081262
# Image number:  24
# Calculating Statistical features for Red Channel:
# 99.17828369140625
# 10.170097230879696
# 111.0
# 2309.485640462488
# 48.05710811589153
# -0.34792983311860437
# -1.1196391384342579
# 7.33640752030177
# 320.023268995098
# 0.015369828647884175
# 0.14147226480218278
# 0.9305926206628214
# 0.003115188138973105
# 0.004882996934492919
# Calculating Statistical Features for Green Channel:
# 83.35704040527344
# 10.256038468787166
# 90.0
# 1808.3721711968537
# 42.52495939089012
# -0.18801000846940116
# -1.1320656237910152
# 7.246856498444824
# 313.1494332107843
# 0.015301246266725303
# 0.1442660765987647
# 0.9132360974206983
# 0.00318335353674001
# 0.004778201949221583
# Calculating Statistical Features for Blue Channel:
# 67.04914855957031
# 10.066853404892013
# 65.0
# 1888.7219649122562
# 43.45942895290108
# 0.1406973147691187
# -1.1741597884275186
# 7.22028579172329
# 304.2431832107844
# 0.017342567170042438
# 0.14683696509535224
# 0.9191564531520685
# 0.003276262579509488
# 0.004642250584789346
# Image number:  25
# Calculating Statistical features for Red Channel:
# 179.81394958496094
# 10.588470493771087
# 189.0
# 1112.9068983045872
# 33.36025926614761
# -0.988075985021409
# 0.6333832586283146
# 6.8877471948947795
# 295.6232383578431
# 0.02221735483356769
# 0.14974379379991665
# 0.8674261565336333
# 0.0033715325612107493
# 0.004510471511776144
# Calculating Statistical Features for Green Channel:
# 168.2598876953125
# 10.326190900126695
# 180.0
# 1465.8380675166845
# 38.28626473706575
# -0.8794556721789797
# 0.233594861084232
# 7.096588907336343
# 298.1652113970589
# 0.020639302438771365
# 0.14984051991996009
# 0.8985346378060286
# 0.0033428652674456607
# 0.0045492303496859
# Calculating Statistical Features for Blue Channel:
# 134.77700805664062
# 10.193228953766626
# 130.0
# 2235.7397033041343
# 47.28360924574323
# -0.11460824822358075
# -1.0285247787006881
# 7.351765857877415
# 292.1238970588236
# 0.01726208814279003
# 0.1433707748174374
# 0.9346334661754314
# 0.003411727612716884
# 0.004456964759575042
# Image number:  26
# Calculating Statistical features for Red Channel:
# 77.57638549804688
# 10.566212018778597
# 78.0
# 820.3617494842038
# 28.641957850052844
# 0.024482605253792256
# -0.667808407536175
# 6.851559209762529
# 100.61064644607846
# 0.020614820567389457
# 0.19357728568065832
# 0.9385539522512257
# 0.009843485468006116
# 0.0015351938775940003
# Calculating Statistical Features for Green Channel:
# 89.41184997558594
# 10.433440189809684
# 92.0
# 607.9832268876489
# 24.657315889764824
# -0.32185895915046286
# -0.3104741206911421
# 6.636368936562321
# 100.50462622549021
# 0.022759944256655822
# 0.19579538253368142
# 0.9173238842817498
# 0.009853977234008793
# 0.0015335722881061715
# Calculating Statistical Features for Blue Channel:
# 59.12031555175781
# 10.443484115640375
# 49.0
# 1301.9601182842162
# 36.082684466156564
# 0.5706119142667109
# -0.710238090400328
# 6.975274472868301
# 96.91594669117649
# 0.021301211081244414
# 0.1987794258614518
# 0.9625737380906048
# 0.010215063296830963
# 0.0014788149253374646
# Image number:  27
# Calculating Statistical features for Red Channel:
# 100.07223510742188
# 10.364305246478777
# 97.0
# 597.1111150970683
# 24.435857159041266
# 0.4502349316174688
# 0.24166065990637264
# 6.61734116964322
# 485.0092677696079
# 0.015263949598624102
# 0.07596042713580753
# 0.5936620000343898
# 0.0020576385554961617
# 0.007400585009595784
# Calculating Statistical Features for Green Channel:
# 116.09584045410156
# 9.788441314837794
# 119.0
# 718.7608188798185
# 26.80971500929875
# -0.11597083703908283
# -0.31434636334823995
# 6.753926253640374
# 486.35942095588246
# 0.013983817802981484
# 0.07633755921073196
# 0.6618854493214779
# 0.0020519326206734755
# 0.007421192620483093
# Calculating Statistical Features for Blue Channel:
# 96.62167358398438
# 10.207739074433611
# 93.0
# 811.5477870916948
# 28.487677811497637
# 0.3831887236303194
# -0.36927285710140634
# 6.810322882768328
# 483.86438419117655
# 0.01394632947691788
# 0.07550696893048633
# 0.701881241458216
# 0.0020624916920983444
# 0.007383111904198729
# Image number:  28
# Calculating Statistical features for Red Channel:
# 162.594970703125
# 10.489332320471922
# 176.0
# 2796.87034457922
# 52.88544548908726
# -0.5476346217874442
# -0.7315163426821898
# 7.522152892230895
# 693.74303002451
# 0.0164285119850627
# 0.12320945422046267
# 0.8760554527526372
# 0.0014394151567290625
# 0.010585394745566573
# Calculating Statistical Features for Green Channel:
# 165.07176208496094
# 10.356176006119563
# 176.0
# 2348.2160873857792
# 48.458395427271206
# -0.6622828328335405
# -0.2206776595347919
# 7.478562173870252
# 691.9028952205884
# 0.015838305178385824
# 0.12466872697617329
# 0.8528309834796148
# 0.0014432366574312894
# 0.0105572086420506
# Calculating Statistical Features for Blue Channel:
# 133.16969299316406
# 10.360076834493148
# 138.0
# 3452.968747623032
# 58.761966846107455
# -0.23887936685080038
# -1.0745784935775426
# 7.716191605510069
# 697.2181219362745
# 0.014652105001127048
# 0.12232186458277287
# 0.898878084112403
# 0.0014322472505638767
# 0.010638294995875914
# Image number:  29
# Calculating Statistical features for Red Channel:
# 119.95881652832031
# 9.927147805377166
# 116.0
# 715.2548194245901
# 26.744248342860377
# 0.6233446989920806
# 0.4133321051717389
# 6.667928469682095
# 179.91609987745096
# 0.022991703395025032
# 0.19285136004667122
# 0.8744238995149581
# 0.005528126583118893
# 0.0027450606440004538
# Calculating Statistical Features for Green Channel:
# 118.45033264160156
# 10.560733805505288
# 111.0
# 941.0673268546816
# 30.676820677095623
# 0.6095612863440726
# -0.4540957303097919
# 6.722593448025968
# 182.12855392156865
# 0.0228715675032926
# 0.1942607514529266
# 0.9034073839071878
# 0.005461326962351356
# 0.0027788403140855773
# Calculating Statistical Features for Blue Channel:
# 113.43704223632812
# 9.7551928654331
# 121.0
# 959.3340490153059
# 30.973118167457823
# -0.6728013629151313
# -0.022517723841634307
# 6.806823102181888
# 175.07336090686277
# 0.02201141248925664
# 0.18723852507001568
# 0.9088439636231668
# 0.005680160946633126
# 0.0026711881280723085
# Image number:  30
# Calculating Statistical features for Red Channel:
# 120.55931091308594
# 10.368690870414207
# 111.0
# 1562.665427528089
# 39.53056320782805
# 0.8267207986352478
# 0.1623570336457636
# 7.192263826039311
# 342.5936274509804
# 0.013105423756686402
# 0.08094540784691501
# 0.8905190026689701
# 0.0029105258764370954
# 0.005227438322340397
# Calculating Statistical Features for Green Channel:
# 119.87242126464844
# 10.31758944606438
# 112.0
# 1365.1099596282002
# 36.947394490385925
# 0.8003545496529434
# 0.25073810020714804
# 7.123568476202287
# 342.81617647058835
# 0.013408953840714517
# 0.08076895466403787
# 0.8745936692848651
# 0.002908644416165984
# 0.005230853292161527
# Calculating Statistical Features for Blue Channel:
# 107.62295532226562
# 10.223073435554985
# 106.0
# 892.4200931703672
# 29.873401098140253
# 0.40550467556577346
# 1.1689833594746117
# 6.8951256949896536
# 340.41547181372545
# 0.014743715376594087
# 0.08061851130253994
# 0.8095297305485979
# 0.002929109160282533
# 0.005194248309926843
# Image number:  31
# Calculating Statistical features for Red Channel:
# 115.37164306640625
# 10.369189002347593
# 118.0
# 2864.954837974161
# 53.52527289023533
# -0.26271335175141414
# -1.0089525452913566
# 7.569173791694053
# 631.8186427696078
# 0.012537994777741167
# 0.1045945939055839
# 0.8898807955137275
# 0.0015802628837720011
# 0.0096407861535798
# Calculating Statistical Features for Green Channel:
# 107.18865966796875
# 10.426870815818408
# 109.0
# 2706.662436094135
# 52.02559404845018
# -0.22571973715675128
# -1.0071596457427487
# 7.551284507940697
# 630.8759037990197
# 0.012205284050518638
# 0.1056267846410559
# 0.8836239468621573
# 0.001582619799729339
# 0.009626402340393253
# Calculating Statistical Features for Blue Channel:
# 87.85260009765625
# 10.32282272178073
# 76.0
# 3556.6649187766016
# 59.637780967911624
# 0.21197642308850487
# -1.3449008034174679
# 7.489044842396401
# 601.5681832107844
# 0.015125529278981899
# 0.11174881252830533
# 0.9154756278083835
# 0.001659604888319354
# 0.00917920031452316
# Image number:  32
# Calculating Statistical features for Red Channel:
# 160.5634307861328
# 10.235247905283838
# 160.0
# 1358.043431369355
# 36.851640823297885
# -0.1087118298389383
# -1.0767603919515552
# 7.09653144778435
# 190.3387867647059
# 0.016072956249423336
# 0.1437682197169027
# 0.929994314553558
# 0.0052267709363622876
# 0.0029043086163015016
# Calculating Statistical Features for Green Channel:
# 165.15292358398438
# 10.334031440369575
# 167.0
# 813.5501312231645
# 28.522800199545003
# -0.5012516605543099
# 0.2367757913318238
# 6.824521768333803
# 190.5212469362745
# 0.018191023283668735
# 0.145460775553471
# 0.883062931678683
# 0.00522184878581963
# 0.002907096381277356
# Calculating Statistical Features for Blue Channel:
# 126.46658325195312
# 10.423833797368234
# 120.0
# 2331.7971316119656
# 48.28868533737449
# 0.1971697250106243
# -1.2153090884418154
# 7.347613249720449
# 192.61433823529418
# 0.015814477941698973
# 0.14012215520602325
# 0.9586686869207363
# 0.005165328642967103
# 0.0029390411730175385
# Image number:  33
# Calculating Statistical features for Red Channel:
# 91.01747131347656
# 9.5170079621569
# 97.0
# 2232.123825002229
# 47.24535770847998
# -0.5621578058152316
# -0.023426056757448244
# 6.5653606404760865
# 780.0371017156863
# 0.12906287178327275
# 0.17624127167841347
# 0.8241824118352842
# 0.0012805605145011084
# 0.0119023212436293
# Calculating Statistical Features for Green Channel:
# 106.68162536621094
# 8.8151721555416
# 121.0
# 2639.980256855255
# 51.38073818908458
# -1.0549874783840294
# 0.26071407252754764
# 6.445208658919971
# 779.990349264706
# 0.1303711046480831
# 0.1772436931466189
# 0.8512880663515473
# 0.0012806393309544462
# 0.01190162279975043
# Calculating Statistical Features for Blue Channel:
# 85.94557189941406
# 9.505914553530525
# 89.0
# 2252.4593636316713
# 47.46008179124507
# -0.30152713070715187
# -0.30833931302586093
# 6.710824972487425
# 780.435631127451
# 0.128069543138217
# 0.1760253963317932
# 0.8258033482019856
# 0.0012799056980483193
# 0.011908422088173892
# Image number:  34
# Calculating Statistical features for Red Channel:
# 117.06059265136719
# 10.502205026793407
# 106.0
# 1113.254583535483
# 33.36546992828789
# 0.8788664315085642
# 0.5015686954916312
# 6.743388300431892
# 66.26018688725492
# 0.03617654661047662
# 0.2873005918703209
# 0.9703356088895635
# 0.014875637364279472
# 0.0010110498083055718
# Calculating Statistical Features for Green Channel:
# 117.0296630859375
# 10.454532089526413
# 108.0
# 988.5387929528952
# 31.4410367665078
# 0.9636989180771918
# 0.9325118667144459
# 6.697920842166333
# 65.48282781862747
# 0.03654002268994848
# 0.2878643851242914
# 0.9669867927199755
# 0.015049749702663439
# 0.0009991885617666122
# Calculating Statistical Features for Blue Channel:
# 109.17282104492188
# 9.788641626028225
# 112.0
# 663.2688999762759
# 25.754007454690928
# 0.027782500100800838
# 1.1216218726591727
# 6.623656224919694
# 63.165257352941175
# 0.03257137908499372
# 0.28235726235392716
# 0.9525048602751837
# 0.015592672984375736
# 0.0009638135035918658
# Image number:  35
# Calculating Statistical features for Red Channel:
# 90.33949279785156
# 10.465182023741349
# 94.0
# 1835.8312320669647
# 42.84660117286977
# -0.11932089919031542
# -1.1462235085297598
# 7.233706969067991
# 107.77470894607842
# 0.019865572661724323
# 0.22764399409663796
# 0.9706325863969927
# 0.009194992783598945
# 0.001644003729417244
# Calculating Statistical Features for Green Channel:
# 87.75979614257812
# 10.408968183847223
# 91.0
# 1731.1077684154734
# 41.606583234092575
# -0.1419860023862371
# -1.0104588233054832
# 7.23484605388573
# 106.74502144607844
# 0.019942793879587487
# 0.23043135042401672
# 0.9691543276643856
# 0.0092828894860091
# 0.001628186887112954
# Calculating Statistical Features for Blue Channel:
# 63.840362548828125
# 9.765376559339794
# 47.0
# 2963.6222514798865
# 54.439161010065966
# 0.47380414372796437
# -1.260913678718764
# 7.0657270974999555
# 104.0344975490196
# 0.0343865894141648
# 0.24812274031701037
# 0.9824159314731294
# 0.009523799459456854
# 0.001586663131056062
# Image number:  36
# Calculating Statistical features for Red Channel:
# 165.94976806640625
# 10.525183132870836
# 186.0
# 3404.090677436441
# 58.344585673706185
# -0.7203482884197772
# -0.6486035840846216
# 7.492753936795674
# 542.1957261029413
# 0.017412596967894548
# 0.13063240769263068
# 0.9204557175075234
# 0.0018410160625623043
# 0.008273250000266325
# Calculating Statistical Features for Green Channel:
# 150.5030059814453
# 10.644138467523819
# 169.0
# 3413.822561764857
# 58.42792621482348
# -0.6353170750461301
# -0.7725105478932184
# 7.544459715192633
# 540.7986366421569
# 0.016505151097020783
# 0.13018579286581725
# 0.9208773389522742
# 0.001845760393108316
# 0.008251931966521972
# Calculating Statistical Features for Blue Channel:
# 132.7646484375
# 10.629067753045332
# 154.0
# 4216.490050315857
# 64.93450585255775
# -0.42834511946410775
# -1.1860479570990643
# 7.586473997621146
# 534.0963082107843
# 0.016356435319140925
# 0.13105037343253118
# 0.936709583108071
# 0.0018688795883341721
# 0.008149662889000951
# Image number:  37
# Calculating Statistical features for Red Channel:
# 122.77449035644531
# 10.441151968003593
# 126.0
# 2523.5281096340623
# 50.23473011407608
# -0.2305876022239354
# -0.7550301708551079
# 7.611857933250015
# 489.4614889705883
# 0.01143736366947614
# 0.11469225639087656
# 0.9028336617807371
# 0.002038943612552559
# 0.007466567531944194
# Calculating Statistical Features for Green Channel:
# 120.0487060546875
# 10.137100336025892
# 129.0
# 2360.080696567893
# 48.580661755145876
# -0.5288845497539006
# -0.4292326011561496
# 7.507748937264931
# 490.1231004901962
# 0.012229676857349046
# 0.11600767194136619
# 0.8960169338392455
# 0.002036200091323329
# 0.007477346551788971
# Calculating Statistical Features for Blue Channel:
# 75.696044921875
# 10.11318544156047
# 65.0
# 3168.3423342108727
# 56.28803011485544
# 0.6392830657208007
# -0.5677867615512882
# 7.416453194145431
# 455.29306066176474
# 0.03007252968928564
# 0.1412317145965034
# 0.9278138691864173
# 0.002191718429965062
# 0.0069441942826467705
# Image number:  38
# Calculating Statistical features for Red Channel:
# 105.89990234375
# 10.217252195754034
# 104.0
# 855.7513635158539
# 29.25322825802058
# 0.3415258959960867
# -0.07377337095229919
# 6.893331525156202
# 586.8868566176471
# 0.012922912511427836
# 0.06956729491223046
# 0.6569289283863274
# 0.0017010449735326712
# 0.00895518230502764
# Calculating Statistical Features for Green Channel:
# 116.35050964355469
# 9.68976079340447
# 121.0
# 857.7550574184861
# 29.287455632377593
# -0.3008721785011979
# -0.29217972792634894
# 6.853187102635323
# 587.784037990196
# 0.013304719592126884
# 0.07021950624156602
# 0.6573075871058316
# 0.0016984539880999688
# 0.008968872591331802
# Calculating Statistical Features for Blue Channel:
# 102.29801940917969
# 10.255290085192389
# 98.0
# 939.1533871905413
# 30.645609590780555
# 0.4136458267483122
# -0.20216324911972228
# 6.935518115495326
# 586.1292892156863
# 0.012904286654701419
# 0.06945030574056747
# 0.6879158826621802
# 0.0017032398101457793
# 0.008943623186578572
# Image number:  39
# Calculating Statistical features for Red Channel:
# 105.39323425292969
# 10.23092812303894
# 101.0
# 547.2154077158775
# 23.392635758201287
# 0.24377488510629974
# -0.7048083246572898
# 6.4586618946086585
# 136.03241421568626
# 0.020389386617486828
# 0.13088689735507994
# 0.8756842855808913
# 0.007298629454221728
# 0.002075642001862047
# Calculating Statistical Features for Green Channel:
# 123.3319091796875
# 9.04680922093962
# 125.0
# 392.3974351733923
# 19.809024084325614
# -0.3934999716665606
# 1.0799983914051854
# 6.281700257982054
# 136.5917585784314
# 0.02291084976505542
# 0.1306606076799985
# 0.8260815048224276
# 0.007269087562413462
# 0.002084185696811756
# Calculating Statistical Features for Blue Channel:
# 104.74871826171875
# 10.307678205127901
# 100.0
# 602.8644087575376
# 24.553297309272693
# 0.25892377590092014
# -0.7851631260371659
# 6.5117330110263225
# 135.4878676470588
# 0.019875917641864013
# 0.1310896713280578
# 0.8875923402050943
# 0.007327725625088397
# 0.0020673401280664697
# Image number:  40
# Calculating Statistical features for Red Channel:
# 117.359375
# 10.17630231991218
# 122.0
# 2171.338134765625
# 46.59761941092726
# -0.20576912145432044
# -0.5360474243850075
# 7.519874742005199
# 1777.9718596813727
# 0.008526519223021412
# 0.042032370628642735
# 0.5912201843565825
# 0.000562125132856154
# 0.0271296713276029
# Calculating Statistical Features for Green Channel:
# 121.48005676269531
# 10.176974798044803
# 124.0
# 2083.760374972364
# 45.64822422583779
# -0.169070174505892
# -0.22437701339050742
# 7.508238502329743
# 1778.3857689950983
# 0.008582506253824338
# 0.04170420737440267
# 0.5741732311411484
# 0.0005619943919665789
# 0.027135994031832696
# Calculating Statistical Features for Blue Channel:
# 101.75726318359375
# 10.113515863684597
# 109.0
# 2853.480873759836
# 53.41798268148879
# -0.15539177580103952
# -0.8364432911388824
# 7.617658999567066
# 1765.3260569852941
# 0.008636717690027154
# 0.04330195517787628
# 0.6909376858172543
# 0.0005661496560728569
# 0.02693673170062827
# Image number:  41
# Calculating Statistical features for Red Channel:
# 107.44264221191406
# 10.390035374482986
# 100.0
# 2722.4220946056303
# 52.17683484656414
# 0.18948918908086554
# -0.9809208439947814
# 7.53930470659665
# 583.5245404411764
# 0.012585723158394294
# 0.11197621031255353
# 0.8926395264688167
# 0.0017108289949046857
# 0.008903877870213727
# Calculating Statistical Features for Green Channel:
# 115.13597106933594
# 10.241055936014133
# 115.0
# 2032.4975488556083
# 45.083229130748926
# -0.299665844900106
# -0.3993520054096864
# 7.383784338270465
# 579.8972886029412
# 0.013153983281417843
# 0.1125004954572504
# 0.8573020754007045
# 0.0017215137071263978
# 0.008848530026503631
# Calculating Statistical Features for Blue Channel:
# 81.39633178710938
# 10.507225820053252
# 63.0
# 3138.1014660364017
# 56.01875994732838
# 0.6095361190081445
# -0.9255030117058594
# 7.404638575213455
# 579.6725949754903
# 0.013252179933956918
# 0.11206504680609605
# 0.907337914006754
# 0.0017221801602046879
# 0.008845101193059772
# Image number:  42
# Calculating Statistical features for Red Channel:
# 160.09664916992188
# 10.49078109756892
# 163.0
# 3028.900662600063
# 55.03544914507433
# -0.3692000897941548
# -0.842587153336344
# 7.5696561800182565
# 509.302512254902
# 0.01852594043308515
# 0.16398163105159744
# 0.915941167967346
# 0.001959693086241075
# 0.0077711110155469455
# Calculating Statistical Features for Green Channel:
# 162.89675903320312
# 10.492370740209289
# 171.0
# 2495.474021478556
# 49.95471971174051
# -0.6240865742834046
# -0.4284941638093698
# 7.471788022941437
# 508.18002450980407
# 0.018013233879269536
# 0.16393860362365054
# 0.8982460435547694
# 0.0019640114106197143
# 0.007754044571489681
# Calculating Statistical Features for Blue Channel:
# 127.36996459960938
# 10.260416831905667
# 122.0
# 4236.164365208708
# 65.08582307391302
# -0.015271820836966899
# -0.9956663908982759
# 7.726675985484678
# 518.7945465686274
# 0.017087542690043638
# 0.1618253429284425
# 0.9387301152963377
# 0.0019239002820053018
# 0.007915917730395012
# Image number:  43
# Calculating Statistical features for Red Channel:
# 134.63893127441406
# 10.044571536825174
# 141.0
# 2193.6734776420053
# 46.83666808860345
# -0.9534835070714552
# 0.8188986991679554
# 7.343173647017283
# 782.7609681372552
# 0.012910122617909853
# 0.10970244151169245
# 0.8219126982936102
# 0.0012759202268815368
# 0.011943774403390497
# Calculating Statistical Features for Green Channel:
# 121.73721313476562
# 9.786237621136314
# 130.0
# 2075.1065412079915
# 45.55333732239595
# -0.9960384562575759
# 0.6241747803387923
# 7.257687237995532
# 777.212193627451
# 0.013421163472173316
# 0.11106962741125473
# 0.8130366668091443
# 0.001285018732211233
# 0.011859060768904547
# Calculating Statistical Features for Blue Channel:
# 114.96510314941406
# 10.07689324473671
# 132.0
# 2850.740710310405
# 53.39232819713339
# -0.6713730664692041
# -0.5810725994955295
# 7.430960610651407
# 750.3624540441176
# 0.015775494130692774
# 0.11709173298739574
# 0.8685731117599471
# 0.0013309435291973149
# 0.01144929468035569
# Image number:  44
# Calculating Statistical features for Red Channel:
# 145.8988494873047
# 9.92204493579866
# 144.0
# 1505.4336314888205
# 38.79991793147017
# -0.6528407422806942
# 1.0994563568374103
# 7.173498990868816
# 483.6430912990196
# 0.014080493715732662
# 0.10562058187939354
# 0.8398543851075295
# 0.002063434044813596
# 0.00737979567019639
# Calculating Statistical Features for Green Channel:
# 135.4772491455078
# 9.831463221076648
# 134.0
# 1325.4124767833855
# 36.406214809883565
# -0.91389202056587
# 1.7393419675594872
# 6.9941593253622125
# 482.2986672794118
# 0.01480473820140789
# 0.10695749318004082
# 0.8185336112591534
# 0.0020691773044971646
# 0.007359282550373698
# Calculating Statistical Features for Blue Channel:
# 97.57662963867188
# 10.001809528663113
# 105.0
# 2227.9859797051176
# 47.20154636985019
# -0.13644195081117036
# -1.1556487019795698
# 7.269015899015165
# 476.5945465686276
# 0.014593804811730272
# 0.10571945776891771
# 0.8930679355543354
# 0.002093890235996869
# 0.0072722547947186
# Image number:  45
# Calculating Statistical features for Red Channel:
# 153.230224609375
# 10.43236447386809
# 162.0
# 3788.102025926113
# 61.547559057416024
# -0.46347603563835643
# -0.8491889658794376
# 7.7275347862058945
# 720.8218903186275
# 0.01335248405607919
# 0.1296580751802485
# 0.9048736754677843
# 0.001385408938220659
# 0.010998806643687542
# Calculating Statistical Features for Green Channel:
# 147.3229217529297
# 10.389832705930667
# 156.0
# 3770.5381623373833
# 61.40470798185904
# -0.4790953933652349
# -0.7700591794940617
# 7.749127358516341
# 720.1229319852943
# 0.01309612745822799
# 0.12930780329557945
# 0.9045449047559657
# 0.001386751296784622
# 0.010988083839275426
# Calculating Statistical Features for Blue Channel:
# 131.74844360351562
# 10.447417338880188
# 128.0
# 4719.300824603997
# 68.69716751514575
# -0.10020129569123995
# -1.2507439574700592
# 7.849267160751787
# 717.7050857843137
# 0.012634515672526417
# 0.12747673675047505
# 0.9239259234239505
# 0.0013914157554247198
# 0.010951173937077797
# Image number:  46
# Calculating Statistical features for Red Channel:
# 96.15614318847656
# 10.411448969923462
# 92.0
# 692.1131467705127
# 26.30804338544607
# 0.574902825954021
# 0.1829850586679651
# 6.707173965464116
# 538.4956035539217
# 0.014325578747577597
# 0.0718674505109195
# 0.6110231944620589
# 0.0018536324443978538
# 0.00821679068675214
# Calculating Statistical Features for Green Channel:
# 110.45301818847656
# 9.80089957331923
# 113.0
# 740.1805930023547
# 27.20626018037677
# -0.035049003637554144
# 0.008545247037592407
# 6.789212898138062
# 539.5990655637254
# 0.013819185056245263
# 0.07169590695277417
# 0.6356587666468843
# 0.0018498470069224198
# 0.008233628202453885
# Calculating Statistical Features for Blue Channel:
# 89.83251953125
# 10.40463400083858
# 85.0
# 830.8553121089935
# 28.824560917887258
# 0.5645961098989741
# -0.03652476148463224
# 6.827354398402834
# 536.7626072303922
# 0.013555626455108815
# 0.07143354765726768
# 0.6769668484808237
# 0.0018596034656264162
# 0.00819034694401803
# Image number:  47
# Calculating Statistical features for Red Channel:
# 151.0315399169922
# 10.531862144903807
# 171.0
# 4106.319851791253
# 64.08057312314905
# -0.7106170889107587
# -0.674513025512721
# 7.666862029032774
# 567.6278339460786
# 0.014667071821359182
# 0.14706241592980132
# 0.9310452808145853
# 0.001758664867887485
# 0.008661280445627773
# Calculating Statistical Features for Green Channel:
# 146.47085571289062
# 10.628664349737223
# 169.0
# 4082.8897450929508
# 63.89749404392124
# -0.8367790359911594
# -0.5750054312099282
# 7.54803375280606
# 569.941574754902
# 0.015428679437508886
# 0.14731325333626927
# 0.9303715954737733
# 0.0017515400317080956
# 0.008696588526670747
# Calculating Statistical Features for Blue Channel:
# 134.04603576660156
# 10.408769548823138
# 142.0
# 5171.9949662794825
# 71.91658338853065
# -0.32432864575994047
# -1.225933175457617
# 7.79853992443859
# 568.1953125
# 0.014410310274707185
# 0.14583942706307537
# 0.9451313379179785
# 0.001756910669618127
# 0.008669964703389288
# Image number:  48
# Calculating Statistical features for Red Channel:
# 91.07853698730469
# 9.383621523978546
# 102.0
# 1973.5376094074454
# 44.424515860135664
# -0.9465041387814508
# 0.22744594042362332
# 6.309268221371443
# 525.5344515931373
# 0.1312392364707382
# 0.19934225703579073
# 0.8660022164926983
# 0.0018996844558054216
# 0.008018976846897471
# Calculating Statistical Features for Green Channel:
# 105.56071472167969
# 8.772365215806522
# 123.0
# 2580.4797426776495
# 50.79842263966126
# -1.125396457585434
# 0.14201962181461925
# 6.400082354818963
# 526.0717984068626
# 0.12958834156140225
# 0.19954693844735552
# 0.8974371693379161
# 0.0018977413099551756
# 0.00802718372596231
# Calculating Statistical Features for Blue Channel:
# 88.71144104003906
# 9.556561389986774
# 96.0
# 2002.869812950259
# 44.75343353252641
# -0.7015640000463514
# 0.07147357953719258
# 6.471138039521971
# 526.0668504901962
# 0.12524915433708597
# 0.1972972762759494
# 0.8678819366682063
# 0.0018977435022493614
# 0.008027105283970354
# Image number:  49
# Calculating Statistical features for Red Channel:
# 111.69084167480469
# 9.540574812296345
# 119.0
# 871.9636099727359
# 29.529029953128088
# -0.4211149709255588
# -0.9354430015709458
# 6.7300988318819766
# 59.069270833333334
# 0.028808608450074935
# 0.2658857320168904
# 0.9661547299648847
# 0.01665543473423758
# 0.0009011700436449978
# Calculating Statistical Features for Green Channel:
# 111.23789978027344
# 9.776115459203604
# 112.0
# 323.6708359455224
# 17.99085423056733
# -0.5033688863398067
# 1.147199059939254
# 6.171563431527411
# 58.01438419117647
# 0.03474373447523607
# 0.2686094957016707
# 0.9104297453245493
# 0.016955003324140825
# 0.0008850944823034392
# Calculating Statistical Features for Blue Channel:
# 81.95646667480469
# 10.109090479719153
# 100.0
# ...
# 103.0
# 1442.028577366611
# 37.97405136888361
# 0.9244792002254483
# -0.06506021839792986
# 6.908077565173269
# 219.3845281862745
# 0.018102573699898733
# 0.13598420102001874
# 0.9241222201499258
# 0.004537896357034425
# 0.0033475421542521625
# Calculating Statistical Features for Green Channel:
# 101.20457458496094
# 10.628514325740024
# 95.0
# 1309.4783060995396
# 36.18671449716788
# 0.7968914789383432
# -0.2544406274446849
# 6.885762406483116
# 219.94442401960794
# 0.018064344875910885
# 0.13621155385986713
# 0.9162228591696122
# 0.004526395136697546
# 0.003356085571230191
# Calculating Statistical Features for Blue Channel:
# 95.07899475097656
# 9.983237140512637
# 98.0
# 937.3099371974822
# 30.615517914898682
# -0.5010006318545727
# -0.3061820755682052
# 6.874158001781462
# 200.52840073529416
# 0.01765886298427357
# 0.13441468086520722
# 0.8931558255541376
# 0.004962514606956606
# 0.0030598205615440873
# Image number:  103
# Calculating Statistical features for Red Channel:
# 149.41204833984375
# 10.394049012911788
# 155.0
# 3997.400284525007
# 63.22499730743377
# -0.34370973546659384
# -1.07705161057276
# 7.649632323779419
# 444.56397058823524
# 0.01661724431864184
# 0.1631960500750712
# 0.9444316235463311
# 0.002244430345045958
# 0.00678349426455197
# Calculating Statistical Features for Green Channel:
# 153.1560821533203
# 10.55159833470703
# 163.0
# 3216.6640081123915
# 56.715641653007786
# -0.6657634509475707
# -0.4209952084181636
# 7.592238535143191
# 440.1736672794117
# 0.015863516762228472
# 0.16362368611670433
# 0.9316723274554908
# 0.002266762576726439
# 0.006716500263498586
# Calculating Statistical Features for Blue Channel:
# 131.49378967285156
# 10.579350320234328
# 133.0
# 4579.180930670118
# 67.6696455633552
# -0.2404970065615165
# -1.169125696990314
# 7.74744402556403
# 443.7888633578432
# 0.015609222859301419
# 0.16214175843338655
# 0.9515627413156754
# 0.0022483366315379
# 0.006771660525232169
# Image number:  104
# Calculating Statistical features for Red Channel:
# 137.50257873535156
# 10.494011760852665
# 141.0
# 4896.454186465358
# 69.9746681768864
# -0.2816390324653043
# -1.188836901448904
# 7.707114888917742
# 520.3549172794118
# 0.021687919935976283
# 0.22015867533366756
# 0.9467494758506281
# 0.0019181589503293839
# 0.007934864082931183
# Calculating Statistical Features for Green Channel:
# 140.5836639404297
# 10.507501011879487
# 152.0
# 4516.086323098978
# 67.20183273616114
# -0.48450686000392695
# -0.9252752641556774
# 7.70024194754864
# 519.5190104166668
# 0.02136111056818823
# 0.22131380525150812
# 0.9423108920039036
# 0.0019212382636754457
# 0.007921692014441628
# Calculating Statistical Features for Blue Channel:
# 121.13729858398438
# 10.204029738313713
# 118.0
# 5242.791177175008
# 72.40712103912851
# -0.035392266696798756
# -1.2040474859945605
# 7.701205688610897
# 512.5350949754902
# 0.021300759408511172
# 0.21629281579385415
# 0.9509965914372583
# 0.0019473673565606488
# 0.00781493445663931
# Image number:  105
# Calculating Statistical features for Red Channel:
# 114.32176208496094
# 10.328987027896828
# 126.0
# 4041.949249312049
# 63.576326170297456
# -0.2374504072762272
# -1.0519617391421494
# 7.696173926917948
# 722.4346200980393
# 0.019037904900665314
# 0.17655771187754055
# 0.9106107578294327
# 0.0013823312969957818
# 0.011021762680647603
# Calculating Statistical Features for Green Channel:
# 113.3245849609375
# 10.211012217591971
# 128.0
# 3716.7914951890707
# 60.965494299554976
# -0.3783674193551742
# -0.9780911508362515
# 7.60790482529559
# 722.3268995098041
# 0.01850064065985466
# 0.17827397282174529
# 0.9027804185909812
# 0.0013825361375084944
# 0.011019956402148319
# Calculating Statistical Features for Blue Channel:
# 99.04875183105469
# 10.120139379936225
# 96.0
# 4585.035419279477
# 67.71288960958229
# 0.11467285562912186
# -1.252589018078444
# 7.715695702785763
# 698.4189338235296
# 0.019503951751551663
# 0.17544732538933402
# 0.923681393149374
# 0.0014297981343555446
# 0.010655151436256472
# Image number:  106
# Calculating Statistical features for Red Channel:
# 124.6097412109375
# 10.0838585919063
# 135.0
# 2985.455974444747
# 54.63932626272717
# -0.5988028446712186
# -0.4914362795831986
# 7.358755503542205
# 398.2975949754903
# 0.02457023799354806
# 0.1825650638853276
# 0.9334223657572547
# 0.002504551868129466
# 0.00607749688460555
# Calculating Statistical Features for Green Channel:
# 118.62008666992188
# 9.969114290953522
# 130.0
# 2688.8301531663164
# 51.85393093263342
# -0.7751463322398877
# -0.34227324403616644
# 7.214227256716394
# 394.9955422794118
# 0.024237128286562673
# 0.18343187396449429
# 0.9267037288958148
# 0.0025254355227037045
# 0.006027094667622736
# Calculating Statistical Features for Blue Channel:
# 80.51429748535156
# 10.209083581460296
# 74.0
# 3061.7592255135532
# 55.3331656921376
# 0.32451159459564444
# -0.9872449574644895
# 7.546578733812074
# 390.693612132353
# 0.020374534668112978
# 0.18416237589569545
# 0.9361154205222566
# 0.002553148655582055
# 0.005961427224888789
# Image number:  107
# Calculating Statistical features for Red Channel:
# 113.98031616210938
# 9.800338303312545
# 112.0
# 399.3896271949634
# 19.984734854257223
# 0.22516234869909107
# 0.36313784237358604
# 6.34320764237526
# 166.44761029411765
# 0.022216974597268437
# 0.1604031924986405
# 0.791799046975399
# 0.005972809620889261
# 0.0025396590393719793
# Calculating Statistical Features for Green Channel:
# 110.00932312011719
# 9.790558015001862
# 110.0
# 513.2452591487672
# 22.654916886821
# -0.13229837542607287
# -0.2667328162186946
# 6.516135704241857
# 167.0358455882353
# 0.02134320784924084
# 0.16507362462842884
# 0.8375005196716918
# 0.005951867165228349
# 0.002548638906033394
# Calculating Statistical Features for Blue Channel:
# 81.17440795898438
# 10.563635409574028
# 85.0
# 929.2551043247804
# 30.483685871704893
# 0.026263681258190518
# -1.0871085709666002
# 6.773157979505094
# 165.01770833333333
# 0.02074932827473229
# 0.15945855279392032
# 0.9111331220875103
# 0.006024206744471301
# 0.0025178236486400976
# Image number:  108
# Calculating Statistical features for Red Channel:
# 100.11643981933594
# 9.995980790198018
# 107.0
# 762.5517036092933
# 27.614338732066233
# -0.7686822495287118
# 0.03742554346453053
# 6.651727575414883
# 90.76323529411765
# 0.02760040901172262
# 0.24264596854224854
# 0.9406414533783584
# 0.010900889291848775
# 0.0013849268836907034
# Calculating Statistical Features for Green Channel:
# 101.17263793945312
# 9.936234687527515
# 109.0
# 829.2128108879551
# 28.796055474456136
# -0.842188273701487
# 0.16165694449969514
# 6.690914145674649
# 90.58330269607843
# 0.027352257594768392
# 0.2431636802555205
# 0.945521700531315
# 0.010922282988825492
# 0.0013821645479209603
# Calculating Statistical Features for Blue Channel:
# 79.911376953125
# 9.930878358468757
# 89.0
# 1620.9426159262657
# 40.260931632617066
# -0.2988979859633592
# -1.2735283053656397
# 7.036950813641559
# 85.30759803921568
# 0.023474695750747388
# 0.24018223116977838
# 0.9736957536362507
# 0.011589617663719812
# 0.0013016609034455545
# Image number:  109
# Calculating Statistical features for Red Channel:
# 104.18647766113281
# 10.154066021190491
# 105.0
# 652.0719918289687
# 25.53570033950447
# 0.016477657965373937
# 0.4303018687019402
# 6.703614425255705
# 596.7728400735294
# 0.014159947934813469
# 0.06499208914613185
# 0.5423656298910031
# 0.001672915899422641
# 0.009106026560219234
# Calculating Statistical Features for Green Channel:
# 113.14057922363281
# 9.682484368179432
# 118.0
# 852.6199927309062
# 29.19965740776604
# -0.39724925733240846
# -0.21192954861532565
# 6.846139180134727
# 598.457398897059
# 0.013257491060157634
# 0.06505102856034804
# 0.6492020998564834
# 0.0016682121501004174
# 0.009131729537069724
# Calculating Statistical Features for Blue Channel:
# 99.8934326171875
# 10.354116724969682
# 99.0
# 630.6192281097174
# 25.11213308561655
# 0.3085763680249817
# 0.4759620336869377
# 6.6806419088861615
# 595.2760876225491
# 0.014032013254822557
# 0.06515776469969596
# 0.5279918068468075
# 0.0016771149372873367
# 0.009083185987697428
# Image number:  110
# Calculating Statistical features for Red Channel:
# 124.48387145996094
# 10.382807356328673
# 133.0
# 2849.4785911885556
# 53.380507595830856
# -0.37520349393900204
# -0.9375453683698494
# 7.599413648555085
# 561.1037837009803
# 0.011263264985961358
# 0.09940243398142704
# 0.9015586309613166
# 0.0017790665480201318
# 0.008561226520246924
# Calculating Statistical Features for Green Channel:
# 127.423828125
# 10.209027532731142
# 136.0
# 2308.6266441345215
# 48.04817003939402
# -0.5808337868145463
# -0.4389761974549167
# 7.480799113893858
# 560.6914675245098
# 0.01165380125872558
# 0.09973204968781253
# 0.8786156958700188
# 0.0017803737566625753
# 0.008554762480307839
# Calculating Statistical Features for Blue Channel:
# 98.19989013671875
# 10.04917869438297
# 95.0
# 4076.638663318008
# 63.84856038563444
# -0.040109058094444545
# -1.3691648804548053
# 7.535818350413676
# 537.0416053921568
# 0.02716858663757572
# 0.12010067316584747
# 0.9340944259548234
# 0.0018586861831023293
# 0.008193885014177239
# Image number:  111
# Calculating Statistical features for Red Channel:
# 138.0802459716797
# 10.075583345928026
# 144.0
# 1788.8903959111776
# 42.29527628366054
# -1.14185108583675
# 1.258711935072741
# 7.085816621128526
# 572.4288602941176
# 0.01455413112119561
# 0.10187542946319626
# 0.8399171581791223
# 0.0017439397469719634
# 0.0087340694489312
# Calculating Statistical Features for Green Channel:
# 129.6004638671875
# 10.05885846132263
# 137.0
# 1778.552742704749
# 42.172891087815515
# -1.1725575007417168
# 1.1911051665261185
# 7.06250679059575
# 572.8066942401961
# 0.014544244191691598
# 0.10294852826758973
# 0.8388893396857136
# 0.0017427913574749386
# 0.008739846787028377
# Calculating Statistical Features for Blue Channel:
# 86.9515380859375
# 10.169863172302732
# 72.0
# 2688.55145393312
# 51.85124351385529
# 0.214890726745286
# -1.1664226542827507
# 7.43661663396626
# 565.9011182598039
# 0.013812374090664966
# 0.10364544075389616
# 0.8946012928100033
# 0.001764019038030116
# 0.008634259672040569
# Image number:  112
# Calculating Statistical features for Red Channel:
# 100.30729675292969
# 10.629064164115428
# 94.0
# 2880.974004374584
# 53.67470544283018
# 0.13829984747172833
# -1.5257270261508573
# 7.22750848756723
# 111.47879901960785
# 0.025113561729372555
# 0.2641370206589966
# 0.9806571554198933
# 0.008892549816649341
# 0.0016999484034328908
# Calculating Statistical Features for Green Channel:
# 106.30726623535156
# 10.527430716245611
# 96.0
# 2773.529443051433
# 52.66430900573398
# 0.15180653429758784
# -1.2816249416608907
# 7.380854351856782
# 111.65758272058827
# 0.023399252320558027
# 0.2648866170531136
# 0.9798700291402075
# 0.008878299368874359
# 0.0017021397298387397
# Calculating Statistical Features for Blue Channel:
# 92.00436401367188
# 10.036019115540784
# 76.0
# 5463.87180712726
# 73.91800732654568
# 0.2256680883837932
# -1.5858658839997757
# 7.353607075904358
# 120.11377144607842
# 0.027159559270324436
# 0.2714599318437526
# 0.9890168656520045
# 0.008258551332948363
# 0.0018306310631238823
# Image number:  113
# Calculating Statistical features for Red Channel:
# 110.10208129882812
# 10.34305222108285
# 124.0
# 3328.619797914289
# 57.69419206397026
# -0.20740759868156808
# -1.2030692527843312
# 7.577033933379897
# 584.8922794117648
# 0.015192109276663241
# 0.1725770879070269
# 0.9121895934332227
# 0.0017068426495465598
# 0.008924036655948854
# Calculating Statistical Features for Green Channel:
# 105.12187194824219
# 10.307616771154066
# 120.0
# 3209.142907848349
# 56.64929750533848
# -0.29095555765671843
# -1.1987615979245088
# 7.523758869649416
# 581.463480392157
# 0.015946301216248703
# 0.173269693083334
# 0.9094352296569151
# 0.0017168928383579773
# 0.008871627029236325
# Calculating Statistical Features for Blue Channel:
# 98.54969787597656
# 9.783306649045496
# 117.0
# 4854.990450042998
# 69.67776151716556
# -0.14650357400076877
# -1.5475813208066767
# 7.381537672507203
# 556.9776501225491
# 0.026932368952374445
# 0.1859488731660528
# 0.9426235685607409
# 0.001792272987883532
# 0.008498012843820733
# Image number:  114
# Calculating Statistical features for Red Channel:
# 154.71893310546875
# 10.548595056499972
# 164.0
# 3522.9105338715017
# 59.3541113476691
# -0.6299063473240316
# -0.5896805744296052
# 7.575360158197838
# 246.11545649509804
# 0.022331595764879808
# 0.2091647257023344
# 0.9651142401078189
# 0.0040470571587429005
# 0.0037545006509916118
# Calculating Statistical Features for Green Channel:
# 156.0648193359375
# 10.584846288315463
# 168.0
# 3614.2876990884542
# 60.11894625730273
# -0.7899619888475298
# -0.3391852098182033
# 7.551020464040819
# 246.6340073529412
# 0.022314408575433205
# 0.21049929981742527
# 0.9659390606257472
# 0.004038581490675738
# 0.0037622507256826316
# Calculating Statistical Features for Blue Channel:
# 131.93356323242188
# 10.488936635715122
# 139.0
# 4640.505809544586
# 68.12125813242578
# -0.23876819115354533
# -1.0991043713570858
# 7.747358970840207
# 247.84152879901967
# 0.02062651906403643
# 0.20661106865098722
# 0.973305638315098
# 0.004018954962533135
# 0.0037806475511367147
# Image number:  115
# Calculating Statistical features for Red Channel:
# 115.37763977050781
# 9.70188495372283
# 121.0
# 941.1775938922074
# 30.678617861504247
# -0.6922854681644206
# 0.15903849937093772
# 6.879160333684583
# 319.563924632353
# 0.014499289256268645
# 0.08293393143654776
# 0.830456867247633
# 0.0031196437146304673
# 0.004876158398037912
# Calculating Statistical Features for Green Channel:
# 118.09385681152344
# 9.665719435310981
# 121.0
# 721.4663343315478
# 26.860125359565018
# -0.5860809235420722
# 0.5109614033002199
# 6.743400003111438
# 319.50180759803925
# 0.015133920128795879
# 0.08292372044497992
# 0.7789119841394427
# 0.0031202545445150128
# 0.004875210555229495
# Calculating Statistical Features for Blue Channel:
# 109.44195556640625
# 9.849990271548972
# 117.0
# 1266.7697326503694
# 35.59170876272126
# -0.6735562422061163
# -0.19046536080277976
# 7.071358922347462
# 319.7756587009804
# 0.01336743140541264
# 0.08238413576013899
# 0.8739163086246918
# 0.0031175734405749717
# 0.0048793871839083545
# Image number:  116
# Calculating Statistical features for Red Channel:
# 98.25868225097656
# 9.330811386888886
# 110.0
# 3273.9672784393188
# 57.218592069705096
# -0.3870218450456011
# -0.7491077443059249
# 7.03940807435442
# 1507.8976102941176
# 0.12392831904700542
# 0.16291946741470653
# 0.7688286601147909
# 0.0006627899279704714
# 0.02300867698182914
# Calculating Statistical Features for Green Channel:
# 107.84495544433594
# 9.343651200094289
# 121.0
# 3542.86705920822
# 59.521988031384
# -0.5907827179600267
# -0.5918558111208068
# 6.943641852234343
# 1507.0651807598035
# 0.12983847774195306
# 0.16417858318665116
# 0.7864378541413389
# 0.000663158407366878
# 0.02299596825650736
# Calculating Statistical Features for Blue Channel:
# 89.26226806640625
# 9.41355029726929
# 93.0
# 3758.62024134025
# 61.307587143356486
# 0.022856806007080354
# -1.0126840101784909
# 7.17615455292592
# 1494.2747855392156
# 0.12397128496134042
# 0.16253829187192811
# 0.8007090028243738
# 0.00066882885021788
# 0.022800807233259616
# Image number:  117
# Calculating Statistical features for Red Channel:
# 103.59967041015625
# 9.474245195343235
# 115.0
# 1008.2485191784799
# 31.752929300750818
# -0.9556836335615951
# 0.011433057655129808
# 6.615716044894958
# 133.83950674019607
# 0.02525009840659961
# 0.17094502697927094
# 0.93373639400488
# 0.007417613128684654
# 0.00204222755938101
# Calculating Statistical Features for Green Channel:
# 108.45834350585938
# 9.443066704681403
# 116.0
# 665.752201504074
# 25.802174356128866
# -1.0970849470230302
# 1.0383729099763919
# 6.482152308062531
# 132.06429227941177
# 0.026185902108512352
# 0.17029368893154098
# 0.9009758249622793
# 0.007516643368058367
# 0.0020151392018951703
# Calculating Statistical Features for Blue Channel:
# 97.71464538574219
# 9.714584586410448
# 112.0
# 1360.6079495751765
# 36.886419581943386
# -0.7254048860056217
# -0.6944260031597258
# 6.846569940941493
# 131.74247855392156
# 0.022213816272045103
# 0.16999732163494416
# 0.9516400435765173
# 0.007534644403977928
# 0.002010230690735703
# Image number:  118
# Calculating Statistical features for Red Channel:
# 122.03155517578125
# 10.272951806484803
# 134.0
# 3995.688548948616
# 63.211459000315884
# -0.457801730515104
# -0.9760209837536387
# 7.608580082918652
# 560.7069240196079
# 0.02047264497684398
# 0.20067348354572398
# 0.9298497607070828
# 0.0017803527173437634
# 0.008553406958128456
# Calculating Statistical Features for Green Channel:
# 119.49165344238281
# 10.16732344043322
# 132.0
# 3667.4317235478666
# 60.55932400174119
# -0.5635856090295639
# -0.8820040427104376
# 7.486235629981362
# 559.5209865196077
# 0.02073036522518408
# 0.19927311857441965
# 0.9237115605670677
# 0.0017841205048879816
# 0.008535243686516324
# Calculating Statistical Features for Blue Channel:
# 109.07658386230469
# 10.003604239388936
# 114.0
# 4746.406106957933
# 68.89416598637314
# -0.13101652566376812
# -1.3028001032965013
# 7.6190055045905165
# 540.6339613970589
# 0.02180346045515685
# 0.19941642890937578
# 0.9430161630514329
# 0.0018463396460849963
# 0.008246833793944273
# Image number:  119

# %%
#change the specific channels to csv data
import pandas as pd
#Convert red channel
red_file = pd.read_excel('RedChannel30.xlsx')
red_file.to_csv('RedData30.csv')

#Convert green channel
green_file = pd.read_excel('GreenChannel30.xlsx')
green_file.to_csv('GreenData30.csv')

#Convert blue channel
blue_file = pd.read_excel('BlueChannel30.xlsx')
blue_file.to_csv('BlueData30.csv')

# %%
#change the main file which contains features of all the three channels into csv
file = pd.read_excel('Output30.xlsx')
file.to_csv('Output30.csv')

# %% [markdown]
# # SVM

# %% [markdown]
# ## Apply SVM on Red Channel

# %%
# #read the data
# redData = pd.read_csv('RedData.csv')
# labelled = pd.read_csv('Labels1.csv')

# #classify data into dependent and indepedent variables
# redX = redData.iloc[:, :]
# redY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# redx_train, redx_test, redy_train, redy_test = train_test_split(redX, redY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# redSVC = SVC()

# #fit the model
# redSVC.fit(redx_train, redy_train)
# pred_r = redSVC.predict(redx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(redy_test, pred_r))

# %% [markdown]
# ## Apply SVM on Green Channel

# %%
# #read the data
# greenData = pd.read_csv('GreenData.csv')

# #classify data into dependent and indepedent variables
# greenX = greenData.iloc[:, :]
# greenY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# greenx_train, greenx_test, greeny_train, greeny_test = train_test_split(greenX, greenY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# greenSVC = SVC()

# #fit the model
# greenSVC.fit(greenx_train, greeny_train)
# pred_g = greenSVC.predict(greenx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for green Channel is ", accuracy_score(greeny_test, pred_g))

# %% [markdown]
# ## Apply SVM on Blue Channel

# %%
# #read the data
# blueData = pd.read_csv('BlueData.csv')

# #classify data into dependent and indepedent variables
# blueX = blueData.iloc[:, :]
# blueY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# bluex_train, bluex_test, bluey_train, bluey_test = train_test_split(blueX, blueY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# blueSVC = SVC()

# #fit the model
# blueSVC.fit(bluex_train, bluey_train)
# pred_b = blueSVC.predict(bluex_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(bluey_test, pred_b))

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Apply Random Forest on red channel

# %%
# #read the data
# RedData = pd.read_csv('RedData.csv')
# labelled = pd.read_csv('Labels1.csv')

# #classify data into dependent and indepedent variables
# RedX = RedData.iloc[:, :]
# RedY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Redx_train, Redx_test, Redy_train, Redy_test = train_test_split(RedX, RedY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# RedRF = RandomForestClassifier()

# #fit the model
# RedRF.fit(Redx_train, Redy_train)
# pred_R = RedRF.predict(Redx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(Redy_test, pred_R))

# %% [markdown]
# ## Apply Random Forest on green channel

# %%
# #read the data
# GreenData = pd.read_csv('GreenData.csv')

# #classify data into dependent and indepedent variables
# GreenX = GreenData.iloc[:, :]
# GreenY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Greenx_train, Greenx_test, Greeny_train, Greeny_test = train_test_split(GreenX, GreenY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# GreenRF = RandomForestClassifier()

# #fit the model
# GreenRF.fit(Greenx_train, Greeny_train)
# pred_G = GreenRF.predict(Greenx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for green Channel is ", accuracy_score(Greeny_test, pred_G))

# %% [markdown]
# ## Apply Random Forest on blue channel

# %%
# #read the data
# BlueData = pd.read_csv('BlueData.csv')

# #classify data into dependent and indepedent variables
# BlueX = BlueData.iloc[:, :]
# BlueY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Bluex_train, Bluex_test, Bluey_train, Bluey_test = train_test_split(BlueX, BlueY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# BlueRF = RandomForestClassifier()

# #fit the model
# BlueRF.fit(Bluex_train, Bluey_train)
# pred_B = BlueRF.predict(Bluex_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(Bluey_test, pred_B))
