# %%
#import the required libraries
import skimage.feature as skf
import openpyxl
import numpy as np
import math
from PIL import Image
from numpy import asarray
from scipy.stats import skew, kurtosis
import skimage.feature
import xlsxwriter
import os


#creates general file for features of all the three channels
outWorkbook = xlsxwriter.Workbook("Output100.xlsx")
outSheet = outWorkbook.add_worksheet()

#Writes headers for general file 
outSheet.write("A1", "Mean_R")
outSheet.write("B1", "RMS_R")
outSheet.write("C1", "Median_R")
outSheet.write("D1", "Variance_R")
outSheet.write("E1", "Std_R")
outSheet.write("F1", "Skewness_R")
outSheet.write("G1", "Kurtosis_R")
outSheet.write("H1", "Contrast_R")
outSheet.write("I1", "Entropy_R")
outSheet.write("J1", "Energy_R")
outSheet.write("K1", "Homogeneity_R")
outSheet.write("L1", "Correlation_R")
outSheet.write("M1", "IDM_R")
outSheet.write("N1", "Smoothness_R")
outSheet.write("O1", "Mean_G")
outSheet.write("P1", "RMS_G")
outSheet.write("Q1", "Median_G")
outSheet.write("R1", "Variance_G")
outSheet.write("S1", "Std_G")
outSheet.write("T1", "Skewness_G")
outSheet.write("U1", "Kurtosis_G")
outSheet.write("V1", "Contrast_G")
outSheet.write("W1", "Entropy_G")
outSheet.write("X1", "Energy_G")
outSheet.write("Y1", "Homogeneity_G")
outSheet.write("Z1", "Correlation_G")
outSheet.write("AA1", "IDM_G")
outSheet.write("AB1", "Smoothness_G")
outSheet.write("AC1", "Mean_B")
outSheet.write("AD1", "RMS_B")
outSheet.write("AE1", "Median_B")
outSheet.write("AF1", "Variance_B")
outSheet.write("AG1", "Std_B")
outSheet.write("AH1", "Skewness_B")
outSheet.write("AI1", "Kurtosis_B")
outSheet.write("AJ1", "Contrast_B")
outSheet.write("AK1", "Entropy_B")
outSheet.write("AL1", "Energy_B")
outSheet.write("AM1", "Homogeneity_B")
outSheet.write("AN1", "Correlation_B")
outSheet.write("AO1", "IDM_B")
outSheet.write("AP1", "Smoothness_B")
outWorkbook.close()

# %%
#creates a file for red channel
outWorkbookR = xlsxwriter.Workbook("RedChannel100.xlsx")
outSheetR = outWorkbookR.add_worksheet()

#writes headers for red file
outSheetR.write("A1", "Mean_R")
outSheetR.write("B1", "RMS_R")
outSheetR.write("C1", "Median_R")
outSheetR.write("D1", "Variance_R")
outSheetR.write("E1", "Std_R")
outSheetR.write("F1", "Skewness_R")
outSheetR.write("G1", "Kurtosis_R")
outSheetR.write("H1", "Contrast_R")
outSheetR.write("I1", "Entropy_R")
outSheetR.write("J1", "Energy_R")
outSheetR.write("K1", "Homogeneity_R")
outSheetR.write("L1", "Correlation_R")
outSheetR.write("M1", "IDM_R")
outSheetR.write("N1", "Smoothness_R")
outWorkbookR.close()

# %%
#creates file for green channel
outWorkbookG = xlsxwriter.Workbook("GreenChannel100.xlsx")
outSheetG = outWorkbookG.add_worksheet()

#writes headers for green file
outSheetG.write("A1", "Mean_G")
outSheetG.write("B1", "RMS_G")
outSheetG.write("C1", "Median_G")
outSheetG.write("D1", "Variance_G")
outSheetG.write("E1", "Std_G")
outSheetG.write("F1", "Skewness_G")
outSheetG.write("G1", "Kurtosis_G")
outSheetG.write("H1", "Contrast_G")
outSheetG.write("I1", "Entropy_G")
outSheetG.write("J1", "Energy_G")
outSheetG.write("K1", "Homogeneity_G")
outSheetG.write("L1", "Correlation_G")
outSheetG.write("M1", "IDM_G")
outSheetG.write("N1", "Smoothness_G")
outWorkbookG.close()

# %%
#creates a file for blue channel
outWorkbookB = xlsxwriter.Workbook("BlueChannel100.xlsx")
outSheetB = outWorkbookB.add_worksheet()

#writes headers for blue file
outSheetB.write("A1", "Mean_B")
outSheetB.write("B1", "RMS_B")
outSheetB.write("C1", "Median_B")
outSheetB.write("D1", "Variance_B")
outSheetB.write("E1", "Std_B")
outSheetB.write("F1", "Skewness_B")
outSheetB.write("G1", "Kurtosis_B")
outSheetB.write("H1", "Contrast_B")
outSheetB.write("I1", "Entropy_B")
outSheetB.write("J1", "Energy_B")
outSheetB.write("K1", "Homogeneity_B")
outSheetB.write("L1", "Correlation_B")
outSheetB.write("M1", "IDM_B")
outSheetB.write("N1", "Smoothness_B")
outWorkbookB.close()

# %%
#import required libaray to read and make a list of all the needy images
import glob

#declare an empty list
Image_list = []

#using for loop to append to the list declared above
for filename in glob.glob('/home/uca/Desktop/Undergrad/Arfan_FinalYearProject/4_Data/data100/*.*'):
    im = Image.open(filename)
    
    #append each image to the list declared above
    Image_list.append(im)
    
#prints number of images used
print(len(Image_list))
# Out:
# 400

# %%
#uses for loop to read each image and array of each image
for i in range(0, len(Image_list)):
    Image = Image_list[i]
    image = asarray(Image)
    
    #Apply image enhancement 
#     #apply image inverse
#     # Invert the colors
#     image = 255 - image

#     # Apply contrast stretching for image enhancement
#     min_val = np.min(image)
#     max_val = np.max(image)
#     image = (image - min_val) / (max_val - min_val)
    
    
    
    #Here i am extracting the single channel like red, green, and blue from the whole image array
    R = image[:, :, 0]
    G = image[:, :, 1]
    B = image[:, :, 2]


    #selecting features from Red Channel
    print("Calculating Statistical features for Red Channel: ")
    
    #calculates mean
    Mean_R = np.mean(R);
    print(Mean_R)
    
    #calculating root mean square
    RMS_R = np.sqrt(np.mean(R**2))
    print(RMS_R)
    
    #calculating median
    Median_R = np.median(R)
    print(Median_R)
    
    #calculating variance of the pixels
    Variance_R = np.var(R)
    print(Variance_R)
    
    #calculating standard deviation
    Std_R = math.sqrt(Variance_R)
    print(Std_R)
    
    #calculates skewness
    Skewness_R = skew(R.reshape(-1))
    print(Skewness_R)
    
    #calculates kurtosis
    Kurtosis_R = kurtosis(R.reshape(-1))
    print(Kurtosis_R)
    
    #calculates entropy
    Entropy_R = skimage.measure.shannon_entropy(R)
    print(Entropy_R)
    
    #returns an image array where lowest pixel value is 0 and highest 8 instead of 0 and 255
    R = skimage.img_as_ubyte(R)
    
    #calculates contrast
    g1 = skf.graycomatrix(R, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_R = skf.graycoprops(g1, 'contrast')[0][0]
    print(Contrast_R)
    
    #calculates energy
    Energy_R = skf.graycoprops(g1, 'energy')[0][0]
    print(Energy_R)
    
    #calculating homogeniety
    Homogeneity_R = skf.graycoprops(g1, 'homogeneity')[0][0]
    print(Homogeneity_R)
    
    #finding correlation
    Correlation_R = skf.graycoprops(g1, 'correlation')[0][0]
    print(Correlation_R)
    
    #glcm_R = skf.graycomatrix(R, distances=[1], angles=[0], levels=256, symmetric= False, normed=True)
    
    #calculate inverse difference moment (IDM)
    IDM_R = 1 / (1 + Contrast_R - Energy_R)
    print(IDM_R)
    
    #calculates smoothness
    diff_R = np.diff(R.astype(float))
    variance_R = np.var(diff_R)
    Smoothness_R = variance_R / (R.shape[0] * R.shape[1])
    print(Smoothness_R)
    

    #selecting features from Green Channel
    print("Calculating Statistical Features for Green Channel: ")
    
    #calculates mean
    Mean_G = np.mean(G);
    print(Mean_G)
    
    #calculates root mean square
    RMS_G = np.sqrt(np.mean(G**2))
    print(RMS_G)
    
    #calculates median
    Median_G = np.median(G)
    print(Median_G)
    
    #claculates variance
    Variance_G = np.var(G)
    print(Variance_G)
    
    #calculates standard deviation
    Std_G = math.sqrt(Variance_G)
    print(Std_G)
    
    #calculates skewness
    Skewness_G = skew(G.reshape(-1))
    print(Skewness_G)
    
    #calculates kurtosis
    Kurtosis_G = kurtosis(G.reshape(-1))
    print(Kurtosis_G)
    
    #calculates entropy
    Entropy_G = skimage.measure.shannon_entropy(G)
    print(Entropy_G)
    
    #converts images pixels to range of 0 to 8 instead of 0 to 255
    G = skimage.img_as_ubyte(G)
    
    #calculates contrast
    g2 = skf.graycomatrix(G, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_G = skf.graycoprops(g2, 'contrast')[0][0]
    print(Contrast_G)
    
    #calculates energy
    Energy_G = skf.graycoprops(g2, 'energy')[0][0]
    print(Energy_G)
    
    #calculates homogeniety
    Homogeneity_G = skf.graycoprops(g2, 'homogeneity')[0][0]
    print(Homogeneity_G)
    
    #calculates correlation
    Correlation_G = skf.graycoprops(g2, 'correlation')[0][0]
    print(Correlation_G)
    #glcm_G = skf.graycomatrix(G, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
    
    #calculates inverse difference moment (IDM)
    IDM_G = 1 / (1 + Contrast_G - Energy_G)
    print(IDM_G)
    
    #calculates smoothness
    diff_G = np.diff(G.astype(float))
    variance_G = np.var(diff_G)
    Smoothness_G = variance_G / (G.shape[0] * G.shape[1])
    print(Smoothness_G)

    #selecting features from Blue Channel
    print("Calculating Statistical Features for Blue Channel: ")
    
    #calculates mean
    Mean_B = np.mean(B);
    print(Mean_B)
    
    #calculates root mean square
    RMS_B = np.sqrt(np.mean(B**2))
    print(RMS_B)
    
    #calculates median
    Median_B = np.median(B)
    print(Median_B)
    
    #calculates variance
    Variance_B = np.var(B)
    print(Variance_B)
    
    #calculates standard deviation
    Std_B = math.sqrt(Variance_B)
    print(Std_B)
    
    #calculates skewness
    Skewness_B = skew(B.reshape(-1))
    print(Skewness_B)
    
    #calculates kurtosis
    Kurtosis_B = kurtosis(B.reshape(-1))
    print(Kurtosis_B)
    
    #calculates entropy
    Entropy_B = skimage.measure.shannon_entropy(B)
    print(Entropy_B)
    
    #converts range of pixels values from 0-255 to 0-8
    B = skimage.img_as_ubyte(B)
    
    #calculates contrast
    g3 = skf.graycomatrix(B, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_B = skf.graycoprops(g3, 'contrast')[0][0]
    print(Contrast_B)
    
    #calculates energy
    Energy_B = skf.graycoprops(g3, 'energy')[0][0]
    print(Energy_B)
    
    #calculates homogeniety
    Homogeneity_B = skf.graycoprops(g3, 'homogeneity')[0][0]
    print(Homogeneity_B)
    
    #calculates correlation
    Correlation_B = skf.graycoprops(g3, 'correlation')[0][0]
    print(Correlation_B)
    
    #glcm_B = skf.graycomatrix(B, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
    
    #calculates inverse difference moment (IDM)
    IDM_B = 1 / (1 + Contrast_B - Energy_B)
    print(IDM_B)
    
    #calculates smoothness
    diff_B = np.diff(B.astype(float))
    variance_B = np.var(diff_B)
    Smoothness_B = variance_B / (B.shape[0] * B.shape[1])
    print(Smoothness_B)
    
    #count the number of images
    print("Image number: ", i)


    #Declares data for all the three channels
    values_R = [Mean_R, RMS_R, Median_R, Variance_R, Std_R, Skewness_R, Kurtosis_R, Entropy_R, Contrast_R, Energy_R, Homogeneity_R, Correlation_R, IDM_R, Smoothness_R]
    values_G = [Mean_G, RMS_G, Median_G, Variance_G, Std_G, Skewness_G, Kurtosis_G, Entropy_G, Contrast_G, Energy_G, Homogeneity_G, Correlation_G, IDM_G, Smoothness_G]
    values_B = [Mean_B, RMS_B, Median_B, Variance_B, Std_B, Skewness_B, Kurtosis_B, Entropy_B, Contrast_B, Energy_B, Homogeneity_B, Correlation_B, IDM_B, Smoothness_B]

    #Writes red channels into a file
    outWorkbookR = openpyxl.load_workbook("RedChannel100.xlsx")
    outSheetR = outWorkbookR.active
    outSheetR.append(values_R)
    outWorkbookR.save(filename="RedChannel100.xlsx")

    #Writes green channels into a file
    outWorkbookG = openpyxl.load_workbook("GreenChannel100.xlsx")
    outSheetG = outWorkbookG.active
    outSheetG.append(values_G)
    outWorkbookG.save(filename="GreenChannel100.xlsx")

    #writes blue chanels into a file
    outWorkbookB = openpyxl.load_workbook("BlueChannel100.xlsx")
    outSheetB = outWorkbookB.active
    outSheetB.append(values_B)
    outWorkbookB.save(filename="BlueChannel100.xlsx")
    
    #creates a general fle where all the three channels data will be merged
    outWorkbook = xlsxwriter.Workbook("Output100.xlsx")
    outSheet = outWorkbook.add_worksheet()
        
    #declares data for general file
    values = [Mean_R, RMS_R, Median_R, Variance_R, Std_R, Skewness_R, Kurtosis_R, Entropy_R, Contrast_R, Energy_R, Homogeneity_R, Correlation_R, IDM_R, Smoothness_R, Mean_G, RMS_G, Median_R, Variance_G, Std_G, Skewness_G, Kurtosis_G, Entropy_G, Contrast_G, Energy_G, Homogeneity_G, Correlation_G, IDM_G, Smoothness_G, Mean_B, RMS_B, Median_R, Variance_B, Std_B, Skewness_B, Kurtosis_B, Entropy_B, Contrast_B, Energy_B, Homogeneity_B, Correlation_B, IDM_B, Smoothness_B]
    
     
    #writes into the general file
    outWorkbook = openpyxl.load_workbook("Output100.xlsx") 
    outSheet = outWorkbook.active
    outSheet.append(values)
    
    #here the general file is being saved
    outWorkbook.save(filename="Output100.xlsx")
# Out:
# Calculating Statistical features for Red Channel:
# 120.36869812011719
# 9.419293962653613
# 119.0
# 317.59179912297986
# 17.8211054405438
# 0.26989309511357346
# 1.2634802077519804
# 6.119325387471112
# 58.59505208333333
# 0.03348932253307087
# 0.2265109103982316
# 0.9080036696911954
# 0.016789351280388807
# 0.0008940785365291612
# Calculating Statistical Features for Green Channel:
# 115.98269653320312
# 9.943133598706131
# 111.0
# 515.6339168986306
# 22.707573998528126
# -0.010704558096304367
# -0.3204035988811742
# 6.393818820558991
# 60.00597426470588
# 0.02968083588622444
# 0.23035262900155445
# 0.9419342761586987
# 0.016399816121446354
# 0.0009156063284405559
# Calculating Statistical Features for Blue Channel:
# 75.81085205078125
# 10.783691129885241
# 76.0
# 957.213643219322
# 30.938869456063227
# -0.04939621880494377
# -1.4933183165053265
# 6.5091193914290955
# 57.16738664215687
# 0.028198010797226666
# 0.22360286712178862
# 0.9701166388339434
# 0.017200102435908624
# 0.0008722972616041992
# Image number:  0
# Calculating Statistical features for Red Channel:
# 112.92048645019531
# 10.524203787291716
# 102.0
# 4027.921823957702
# 63.46591072345612
# 0.09861378055307887
# -1.313662508378009
# 7.656055420679392
# 660.7461090686276
# 0.014410082294130589
# 0.11954625604664161
# 0.917964926541872
# 0.0015111864846913624
# 0.010082185458820149
# Calculating Statistical Features for Green Channel:
# 115.48297119140625
# 10.369792320651243
# 113.0
# 3186.9933013282716
# 56.453461375971195
# -0.0854188084190785
# -1.0377381195752389
# 7.610032742042837
# 659.7273590686273
# 0.01418714979891348
# 0.12076201704259344
# 0.8965450381029695
# 0.0015135160649148592
# 0.010066640544561
# Calculating Statistical Features for Blue Channel:
# 97.75611877441406
# 10.33251416640807
# 84.0
# 4055.666153661674
# 63.68411225464067
# 0.25463797082140166
# -1.295199390106156
# 7.596162356270623
# 648.713648897059
# 0.013822920319940521
# 0.12223027161350741
# 0.9199783233678156
# 0.0015391723377740332
# 0.009898582645951528
# Image number:  1
# Calculating Statistical features for Red Channel:
# 125.46519470214844
# 9.349197075787528
# 126.0
# 387.1853730638977
# 19.677026530039992
# -0.09180994203514373
# 0.458678694287018
# 6.3107670381195184
# 137.4117034313726
# 0.025274853297148493
# 0.1787027132194824
# 0.8229590629389509
# 0.007226142117222252
# 0.0020967158128502783
# Calculating Statistical Features for Green Channel:
# 121.87239074707031
# 9.627337283431245
# 122.0
# 493.0911530123558
# 22.205655878905173
# -0.3241855814829493
# 0.11021102249804082
# 6.489383304161392
# 138.40859375000002
# 0.023257329242413107
# 0.1815558516484353
# 0.8599462187900104
# 0.007174355823064023
# 0.002111929296549898
# Calculating Statistical Features for Blue Channel:
# 91.58193969726562
# 9.725920849819472
# 96.0
# 994.9629514133558
# 31.543033326130125
# -0.0751445644301865
# -1.3463302194631097
# 6.723367372769745
# 135.74401041666664
# 0.021323177256501614
# 0.175715058940652
# 0.9317743200787117
# 0.007314075082864165
# 0.0020712754801195006
# Image number:  2
# Calculating Statistical features for Red Channel:
# 112.43881225585938
# 10.220066930622629
# 121.0
# 2856.740610308014
# 53.44848557543996
# -0.28615939638873616
# -0.6938157036208437
# 7.572682047231733
# 1885.141727941177
# 0.013414622730709085
# 0.06915583017039283
# 0.6702172724644437
# 0.0005301866224788303
# 0.028764433144752518
# Calculating Statistical Features for Green Channel:
# 113.67190551757812
# 10.222888353545807
# 120.0
# 2905.9319047918543
# 53.90669628897559
# -0.26870314124605527
# -0.5722500540486766
# 7.609324303804286
# 1885.3375153186282
# 0.013962540278464008
# 0.06898129058269083
# 0.6758455200008564
# 0.0005301317467658762
# 0.028767309171136544
# Calculating Statistical Features for Blue Channel:
# 110.71701049804688
# 10.141899416741268
# 122.0
# 3345.820460154675
# 57.84306752027139
# -0.3443092932756351
# -0.8149987956499709
# 7.621533586511847
# 1880.5153952205883
# 0.012564412568331067
# 0.06790944086496271
# 0.7189644863018294
# 0.0005314900321306162
# 0.028693666254030234
# Image number:  3
# Calculating Statistical features for Red Channel:
# 161.76754760742188
# 10.62606985652283
# 176.0
# 3823.1660891762003
# 61.83175631644471
# -0.7024099849269352
# -0.6542002708199552
# 7.572791101322501
# 524.6831801470588
# 0.02086677094232705
# 0.17838734198605513
# 0.9315402577218901
# 0.0019023619813591057
# 0.008005992660369839
# Calculating Statistical Features for Green Channel:
# 149.8943634033203
# 10.539540997523401
# 162.0
# 4043.5508068518247
# 63.588920472451996
# -0.5931205372445851
# -0.8177643943360211
# 7.654014746492066
# 520.7397518382354
# 0.019502399635873885
# 0.17899888694935245
# 0.9357562132048537
# 0.001916736030614216
# 0.00794583857417184
# Calculating Statistical Features for Blue Channel:
# 128.31356811523438
# 10.428568233482036
# 129.0
# 5658.242647937499
# 75.22129118765177
# -0.19624436524625238
# -1.4136332867829375
# 7.663484874420639
# 506.95715379901964
# 0.021466114590114455
# 0.1859169479850185
# 0.9552706261382559
# 0.0019687531792829654
# 0.007735535921622032
# Image number:  4
# Calculating Statistical features for Red Channel:
# 107.71800231933594
# 10.012334464582377
# 107.0
# 733.2077240122017
# 27.077808700339872
# 0.069568818517531
# -0.8078657833700089
# 6.729014453055395
# 344.2814338235295
# 0.01473395566440381
# 0.08979731156599376
# 0.7653845970999722
# 0.002896311750836973
# 0.005253303137488638
# Calculating Statistical Features for Green Channel:
# 126.04469299316406
# 9.235666252519614
# 128.0
# 385.638368136948
# 19.637677259211387
# -0.03923258056397598
# 0.7997779008366002
# 6.309263025104361
# 343.62417279411767
# 0.018496403750818246
# 0.08999656253057275
# 0.5548428323401925
# 0.0029018674633415125
# 0.005243272463397561
# Calculating Statistical Features for Blue Channel:
# 103.40652465820312
# 9.959011762378992
# 107.0
# 1083.1280421456322
# 32.91091068544947
# -0.1280706935050287
# -1.0623306795852236
# 6.940238999769689
# 345.12613357843145
# 0.01382818193352088
# 0.0889593002616698
# 0.8408266469673926
# 0.002889235616325239
# 0.0052661920002719294
# Image number:  5
# Calculating Statistical features for Red Channel:
# 124.84007263183594
# 9.53504903155614
# 122.0
# 352.24842531210743
# 18.76828242839785
# 0.24618439401759598
# 0.7101192628628317
# 6.224475964270785
# 116.64008884803923
# 0.026966667417394133
# 0.17346160910123312
# 0.8346185848972543
# 0.008502452629939298
# 0.0017796188429311656
# Calculating Statistical Features for Green Channel:
# 120.26356506347656
# 9.840617526146335
# 119.0
# 520.012671518838
# 22.803786341720492
# 0.08243173527599752
# -0.41124025370629314
# 6.454119397640516
# 117.63506433823531
# 0.024220682918550125
# 0.17547239227235786
# 0.8870951659566616
# 0.008430932359827075
# 0.0017947849159489534
# Calculating Statistical Features for Blue Channel:
# 92.07901000976562
# 10.195909644868776
# 101.0
# 934.95936410781
# 30.577105227732236
# -0.18592347159057185
# -1.0884963441952835
# 6.733252785198883
# 115.20016850490195
# 0.02243040453549408
# 0.17283920207172457
# 0.938352246291099
# 0.008607501026884304
# 0.0017575961628929497
# Image number:  6
# Calculating Statistical features for Red Channel:
# 122.25822448730469
# 10.43009640467154
# 129.0
# 3633.9634562225547
# 60.28236438812395
# -0.25700123543651615
# -1.1167786667040849
# 7.639975038635869
# 392.9122395833333
# 0.0166168347902153
# 0.17753192600488255
# 0.9459260448786163
# 0.0025387436220340653
# 0.005995359904817043
# Calculating Statistical Features for Green Channel:
# 116.39453125
# 10.385517718028522
# 128.0
# 3476.050979614258
# 58.958044231591145
# -0.298999447040279
# -1.0942376302809886
# 7.629959449891119
# 389.7143841911766
# 0.015938279163734227
# 0.1813751329000323
# 0.9439377775331713
# 0.002559518755355389
# 0.005946568648016846
# Calculating Statistical Features for Blue Channel:
# 80.1575927734375
# 10.141515754406488
# 70.0
# 3593.9348813146353
# 59.9494360383368
# 0.6264304895030277
# -0.6127376532187085
# 7.5004095681790135
# 382.38247549019616
# 0.02539807181076692
# 0.19078853617914537
# 0.9465285560712773
# 0.0026085340767261415
# 0.005834693520035206
# Image number:  7
# Calculating Statistical features for Red Channel:
# 139.56663513183594
# 10.550668443954526
# 129.0
# 3201.9787750912365
# 56.586029858006796
# -0.03389325522319979
# -1.159049731504249
# 7.532185619444447
# 434.16452205882365
# 0.015422290183171391
# 0.1459528185840911
# 0.9321706560357219
# 0.0022980628950667226
# 0.006624824287615478
# Calculating Statistical Features for Green Channel:
# 145.10888671875
# 10.152392596794764
# 146.0
# 2173.298476934433
# 46.61864945420913
# -0.5383192439068311
# -0.1029353646754827
# 7.3855507118612955
# 430.43123468137264
# 0.015594137026949978
# 0.14740600834721565
# 0.9010178194323557
# 0.0023179502688827733
# 0.006567857585405529
# Calculating Statistical Features for Blue Channel:
# 118.21952819824219
# 10.56293409911406
# 105.0
# 3447.363260617247
# 58.714250915916885
# 0.0755161679850486
# -1.0791212466459312
# 7.588545927673777
# 433.5403339460784
# 0.01499453423401956
# 0.1453347678836215
# 0.9370507542537724
# 0.0023013617602912614
# 0.00661529951885712
# Image number:  8
# Calculating Statistical features for Red Channel:
# 133.03192138671875
# 10.632423589966889
# 152.0
# 2375.196948554367
# 48.73599233168816
# -0.8762749326318271
# -0.17459369922977164
# 7.261113380161665
# 606.8065104166666
# 0.013754046143697232
# 0.07497618741395073
# 0.8724933118434339
# 0.0016452976602938972
# 0.009259129852677385
# Calculating Statistical Features for Green Channel:
# 127.60919189453125
# 10.189246279587797
# 140.0
# 1627.4414462707937
# 40.34155978976016
# -1.0887262993231437
# 0.8640998753561697
# 7.092263281779638
# 605.3710018382354
# 0.013920224811514528
# 0.07561117598065761
# 0.8143647264451307
# 0.0016491932399620899
# 0.009237226147153792
# Calculating Statistical Features for Blue Channel:
# 116.52691650390625
# 10.344688165536335
# 140.0
# 2915.6074908338487
# 53.99636553356021
# -0.6272474064269943
# -0.941867459202383
# 7.2648769520320755
# 601.6162224264705
# 0.0136573446190482
# 0.0770317310089391
# 0.8969824194197774
# 0.0016594685418641888
# 0.009179928917971307
# Image number:  9
# Calculating Statistical features for Red Channel:
# 100.91871643066406
# 10.387772017863945
# 98.0
# 619.2481689823326
# 24.884697486253124
# 0.5102233437481345
# 0.3839765457494644
# 6.641109138814187
# 462.6663602941176
# 0.015609523525246284
# 0.08153030330615042
# 0.6260400619065
# 0.0021567958174078003
# 0.0070597236955403046
# Calculating Statistical Features for Green Channel:
# 114.62034606933594
# 9.479298573229439
# 119.0
# 663.8966496360954
# 25.766191989428616
# -0.3986543681971422
# 0.034911056726128376
# 6.672356079088139
# 463.34641544117665
# 0.015611086894812594
# 0.08151038614856995
# 0.6509432308459246
# 0.0021536369989293355
# 0.007070095373051917
# Calculating Statistical Features for Blue Channel:
# 92.28219604492188
# 10.264807449370702
# 86.0
# 888.9992838492617
# 29.8160910222863
# 0.5759347178844006
# -0.1846418631238662
# 6.8427625849269855
# 462.05894607843135
# 0.014581289633738769
# 0.08053459136614223
# 0.7399484304484802
# 0.0021596202784070527
# 0.007050449176835056
# Image number:  10
# Calculating Statistical features for Red Channel:
# 119.50807189941406
# 10.11009268004124
# 130.0
# 1939.4995686335023
# 44.039749870242254
# -0.6698518427917979
# -0.29812058542426056
# 7.3201117731926715
# 1043.694607843137
# 0.010486962741291933
# 0.060738942286438904
# 0.7313566910144735
# 0.0009572271464768329
# 0.015925515428119583
# Calculating Statistical Features for Green Channel:
# 124.35292053222656
# 10.01206166502083
# 131.0
# 1711.717533889925
# 41.37290821165374
# -0.6929796504625367
# 0.37442685134649434
# 7.258588809003603
# 1043.4440716911765
# 0.011018001995982208
# 0.06057651281253956
# 0.69593692771215
# 0.0009574572505798886
# 0.01592169272159081
# Calculating Statistical Features for Blue Channel:
# 112.96849060058594
# 10.066213739913195
# 125.0
# 2395.745665482944
# 48.946354976473415
# -0.6731771238869382
# -0.46477250980328044
# 7.4125201066896125
# 1045.3031556372548
# 0.010880712275303276
# 0.06258798530444488
# 0.7821224689370117
# 0.000955755885774557
# 0.015950059077785888
# Image number:  11
# Calculating Statistical features for Red Channel:
# 127.92608642578125
# 10.379048120737187
# 136.0
# 3788.7504266761243
# 61.55282630940779
# -0.33281529647633346
# -1.0313487410418432
# 7.744568233505179
# 845.8634037990196
# 0.012501013691596136
# 0.12898201207077936
# 0.888469000418574
# 0.0011808454082188002
# 0.01290576531199444
# Calculating Statistical Features for Green Channel:
# 125.93740844726562
# 10.254790884459048
# 134.0
# 3597.297077170573
# 59.977471413611404
# -0.4598968584729276
# -0.8667001937164911
# 7.673543018091773
# 846.2354166666668
# 0.012884905413996395
# 0.1287645788313988
# 0.882470698501669
# 0.001180327437610925
# 0.012911302778455947
# Calculating Statistical Features for Blue Channel:
# 115.60108947753906
# 10.25069890314459
# 123.5
# 5165.316502108937
# 71.87013637185431
# -0.10503550750624895
# -1.3613910791829054
# 7.756433438382587
# 824.5559129901959
# 0.015158244355937016
# 0.13187944182595293
# 0.9201829292108302
# 0.00121132723521066
# 0.012580561783953911
# Image number:  12
# Calculating Statistical features for Red Channel:
# 129.4295654296875
# 10.34738270566146
# 143.0
# 1233.8488902896643
# 35.12618525102981
# -1.0534320599446902
# 0.1467675172824996
# 6.786463195128323
# 91.97971813725493
# 0.02613287803925491
# 0.2020307253706358
# 0.962810244284232
# 0.010758057338093445
# 0.0014034542967148215
# Calculating Statistical Features for Green Channel:
# 136.39674377441406
# 10.186706886544975
# 143.0
# 660.5254099292215
# 25.700688899895688
# -0.9785115982309602
# 0.675056508682883
# 6.544677642458993
# 88.95828737745099
# 0.02709907194251082
# 0.203680734758389
# 0.9328078059953576
# 0.011119612882272433
# 0.0013573374453665647
# Calculating Statistical Features for Blue Channel:
# 124.92471313476562
# 10.443036284335006
# 142.0
# 1796.9121175324544
# 42.390000206799414
# -0.8002252962023695
# -0.5039158032929545
# 7.074240360602454
# 93.55954350490198
# 0.02311706250092483
# 0.19880475590885988
# 0.9740194278390978
# 0.010577933159016518
# 0.001427564650100127
# Image number:  13
# Calculating Statistical features for Red Channel:
# 124.22413635253906
# 10.389459667970362
# 130.0
# 2875.476694658166
# 53.62347149018017
# -0.445029659592588
# -0.8011312194995197
# 7.545231227003502
# 685.5766697303924
# 0.01203032195262792
# 0.09578713664309471
# 0.8806892215816245
# 0.0014565270953389377
# 0.010460614276382469
# Calculating Statistical Features for Green Channel:
# 126.78421020507812
# 10.375252961901097
# 139.0
# 2519.4177291980013
# 50.19380170098696
# -0.7722419218299422
# -0.2478562881969224
# 7.425973479789087
# 683.2443780637255
# 0.012104623936972064
# 0.09700888809000141
# 0.8643396172861605
# 0.0014614920090991563
# 0.010424988080744919
# Calculating Statistical Features for Blue Channel:
# 110.65817260742188
# 10.415933405181308
# 115.0
# 3072.694097637199
# 55.431887011333096
# -0.3747424950835545
# -0.9669539645793805
# 7.543503738545712
# 681.3231311274511
# 0.012322386189407614
# 0.09692602978657198
# 0.889045570062217
# 0.0014656077365164662
# 0.01039561786677048
# Image number:  14
# Calculating Statistical features for Red Channel:
# 118.76385498046875
# 10.287134405525368
# 134.0
# 3789.964071955532
# 61.56268408667325
# -0.3985534349801785
# -1.1378506933744439
# 7.5451283579071
# 502.32999387254915
# 0.018319029002036934
# 0.16740403774049634
# 0.9337840590240412
# 0.001986840460855288
# 0.007664935737547509
# Calculating Statistical Features for Green Channel:
# 110.1761474609375
# 10.015311154404102
# 123.0
# 3713.8940819352865
# 60.94172693594502
# -0.28839925701958397
# -1.2059368826138805
# 7.550010607542407
# 497.8273590686276
# 0.017956084488264756
# 0.16916101765130345
# 0.9330205710304132
# 0.0020047737553010748
# 0.007596234279666461
# Calculating Statistical Features for Blue Channel:
# 97.18260192871094
# 9.96005127797849
# 98.0
# 4210.09997257567
# 64.8852831740424
# 0.00622902480795225
# -1.4144332314339016
# 7.522875754515309
# 485.3825214460785
# 0.021771924968354603
# 0.17665320360720996
# 0.9423426078243755
# 0.0020560869703910916
# 0.007406345200404433
# Image number:  15
# Calculating Statistical features for Red Channel:
# 101.2430419921875
# 9.427167680619435
# 113.0
# 1048.2140323966742
# 32.376133685118646
# -0.49192276291621423
# -0.9118658411873963
# 6.774979849279119
# 25.611672794117652
# 0.028985668687144642
# 0.27705482388333286
# 0.9877946730838341
# 0.03761846931732282
# 0.00039080220316520617
# Calculating Statistical Features for Green Channel:
# 105.47407531738281
# 9.741915750269634
# 111.0
# 715.8118584284093
# 26.754660499217877
# -1.0845652215801185
# 1.2695776667953735
# 6.558146822562509
# 26.163051470588236
# 0.0327775746806069
# 0.27726227085451327
# 0.9817762854667367
# 0.036859192938366966
# 0.0003992146170944812
# Calculating Statistical Features for Blue Channel:
# 85.89431762695312
# 9.8267151711387
# 98.0
# 1418.1484992047772
# 37.65831248482567
# -0.33157213637484106
# -1.270173384483947
# 6.88608065572089
# 26.435646446078433
# 0.0271906974934572
# 0.2746801363414847
# 0.9906818792404081
# 0.036485090921316396
# 0.00040337450905090366
# Image number:  16
# Calculating Statistical features for Red Channel:
# 111.36286926269531
# 10.182071292505473
# 114.0
# 1970.5445191354956
# 44.39081570702994
# -0.15710980814447623
# -0.41185652441260157
# 7.479765700619866
# 1865.880131740196
# 0.008332375864112809
# 0.03884540058919834
# 0.5269829565690883
# 0.000535655421192017
# 0.028471062643473533
# Calculating Statistical Features for Green Channel:
# 121.53947448730469
# 10.042798581308228
# 124.0
# 1710.7873821945395
# 41.361665611947245
# -0.38054190830811996
# 0.3539408130828763
# 7.352615146045012
# 1863.8656403186271
# 0.00899045533870403
# 0.03847204646212494
# 0.45581327226563
# 0.0005362342462479941
# 0.028440321263313292
# Calculating Statistical Features for Blue Channel:
# 109.25843811035156
# 10.294605242296887
# 111.0
# 2647.072598781204
# 51.449709413962715
# -0.08873449957721581
# -0.7137244486937706
# 7.658855049577536
# 1861.1678462009804
# 0.007648767248828986
# 0.03819582994064633
# 0.6486597501642966
# 0.000537010726240478
# 0.028399138511804832
# Image number:  17
# Calculating Statistical features for Red Channel:
# 121.79817199707031
# 10.387924784250327
# 124.0
# 3850.5947482453194
# 62.053160662816516
# -0.2941133465670334
# -1.1758143597534085
# 7.551919637252037
# 450.02098651960796
# 0.019859571049388635
# 0.18905153667037708
# 0.9415578539029903
# 0.0022172893597094284
# 0.006866703570542175
# Calculating Statistical Features for Green Channel:
# 119.53323364257812
# 10.297322519675625
# 126.0
# 3487.067468523048
# 59.05139683803464
# -0.3988090001021353
# -1.0005380299083806
# 7.562548869673953
# 447.77267156862746
# 0.018600939454971266
# 0.1906364438597412
# 0.9358035664592012
# 0.0022283920424341934
# 0.006832349616396845
# Calculating Statistical Features for Blue Channel:
# 104.97822570800781
# 10.354344408030727
# 98.0
# 4219.538481568685
# 64.95797473419783
# -0.023187978712103787
# -1.3678708719117878
# 7.574828734483309
# 439.6966452205884
# 0.019137729934393027
# 0.19328926738826613
# 0.94785733891079
# 0.0022692331308087205
# 0.006709088518730766
# Image number:  18
# Calculating Statistical features for Red Channel:
# 150.33631896972656
# 10.317920716648246
# 154.0
# 1090.8999052976724
# 33.02877389939978
# -1.4558644566674708
# 3.882922224799808
# 6.846726958950286
# 556.6923406862745
# 0.01406086458301877
# 0.07241195132530949
# 0.7454485151275945
# 0.0017931485521002067
# 0.008494450809825778
# Calculating Statistical Features for Green Channel:
# 140.58241271972656
# 10.02003075021986
# 145.0
# 1071.9550001358148
# 32.74072387922745
# -1.4456356781691544
# 3.6429028878812186
# 6.836898331072875
# 556.4772365196079
# 0.013902108055175928
# 0.07278235562418309
# 0.7409732690291229
# 0.0017938399501297789
# 0.008491168120336711
# Calculating Statistical Features for Blue Channel:
# 105.45411682128906
# 10.347958541262122
# 117.0
# 2785.025116413599
# 52.77333717336435
# -0.17272699586741683
# -1.3043310737361014
# 7.424342167978275
# 558.9618259803922
# 0.011582503258284948
# 0.0739578183535619
# 0.8997694292211146
# 0.0017858729621944274
# 0.008529079027433823
# Image number:  19
# Calculating Statistical features for Red Channel:
# 114.43408203125
# 9.858793069197162
# 121.0
# 977.4976079463959
# 31.26495814720365
# -0.7660908866353402
# -0.25675483564840107
# 6.7937294429855255
# 59.925903799019615
# 0.027902407892497347
# 0.2649890977086533
# 0.9694020548148191
# 0.016420900147072818
# 0.0009143953799581252
# Calculating Statistical Features for Green Channel:
# 112.35963439941406
# 9.603360509793157
# 115.0
# 655.4902157110628
# 25.60254314928622
# -0.7927900323574432
# 0.8101548640283247
# 6.625344255211416
# 59.93391544117647
# 0.028968800358927366
# 0.2662596387166156
# 0.9543839091417433
# 0.01641902760209982
# 0.0009145187276176697
# Calculating Statistical Features for Blue Channel:
# 101.24948120117188
# 9.803678981996057
# 110.0
# 1429.8656155755743
# 37.81356390999894
# -0.6842000367841496
# -0.5347243397622701
# 7.04235236278334
# 61.469087009803914
# 0.02542195340683842
# 0.26426578139719514
# 0.9785403926695083
# 0.01601443475646141
# 0.0009379434884482509
# Image number:  20
# Calculating Statistical features for Red Channel:
# 130.51319885253906
# 10.240798169261744
# 128.0
# 755.917153671151
# 27.493947582534435
# 0.20087446860345468
# -0.8223630882855173
# 6.7301881743006
# 81.49497549019608
# 0.022913748159420173
# 0.2106422142204408
# 0.9461901836971094
# 0.012125318306311871
# 0.001243482715035232
# Calculating Statistical Features for Green Channel:
# 134.37063598632812
# 9.891535182251477
# 135.0
# 890.3277778914198
# 29.838360844580922
# -0.19317396148918006
# -0.6725394939161333
# 6.84304367409533
# 82.78619791666668
# 0.021766686173379634
# 0.2149185308858003
# 0.9534911506241686
# 0.011938241390887205
# 0.001263175714830483
# Calculating Statistical Features for Blue Channel:
# 83.70770263671875
# 10.491060356899553
# 78.0
# 994.6297416947782
# 31.5377510563892
# 0.5874715486146798
# -0.5291923536138103
# 6.847998086475342
# 80.90337009803919
# 0.022883568455763354
# 0.2071226402095868
# 0.9592750362246647
# 0.012212922057304825
# 0.0012344433952757414
# Image number:  21
# Calculating Statistical features for Red Channel:
# 93.634521484375
# 9.430017599855992
# 102.0
# 1995.1656808257103
# 44.66727751750391
# -1.1053563356773486
# 0.25979759047727624
# 6.15423222808657
# 226.42761948529412
# 0.13034052005639296
# 0.24985196402381787
# 0.9428598561142576
# 0.0043995247305751405
# 0.0034549400910716503
# Calculating Statistical Features for Green Channel:
# 109.49676513671875
# 8.599838042397586
# 130.0
# 2503.396107699722
# 50.033949551276905
# -1.4332843263478006
# 0.6443100999799327
# 5.975017941947265
# 226.24365808823524
# 0.13223166811145
# 0.250017579864148
# 0.9544855016754953
# 0.0044031250023948264
# 0.003452138418603154
# Calculating Statistical Features for Blue Channel:
# 89.19485473632812
# 9.568641435741087
# 95.0
# 1962.2352249911055
# 44.297124342231356
# -0.8716436874436263
# -0.05468416658443376
# 6.2794192628886085
# 226.41605392156856
# 0.12988498092699866
# 0.24896676315863497
# 0.941932340599526
# 0.004399739784699181
# 0.0034547616533937937
# Image number:  22
# Calculating Statistical features for Red Channel:
# 136.00559997558594
# 10.151533610423337
# 142.0
# 1273.9405661744531
# 35.69230401885613
# -0.8046153102729148
# 1.2655534423536539
# 7.06105860043076
# 483.4251991421568
# 0.013509084049181386
# 0.07293002482130467
# 0.8107632819966132
# 0.0020643597595261273
# 0.007376431898453467
# Calculating Statistical Features for Green Channel:
# 134.5765380859375
# 9.631280608626735
# 137.0
# 955.7997754663229
# 30.916011635822674
# -1.332387942357698
# 3.4647613809697386
# 6.740045473609355
# 482.08157169117646
# 0.015076315774470737
# 0.07372551843823258
# 0.748506918479511
# 0.00207010837964011
# 0.0073559266356847995
# Calculating Statistical Features for Blue Channel:
# 101.59294128417969
# 10.27852402002707
# 111.0
# 2442.096556009492
# 49.417573352092994
# -0.16315755019314182
# -1.3513162978077935
# 7.301233413241136
# 469.7413143382354
# 0.012212299570807356
# 0.07414072858770436
# 0.9038514579413464
# 0.002124364088961431
# 0.007167592205816894
# Image number:  23
# Calculating Statistical features for Red Channel:
# 79.36456298828125
# 10.507567085888775
# 76.0
# 442.97979524359107
# 21.047085195902806
# 0.6840982934746904
# 0.348199007359141
# 6.360533488996575
# 346.13601409313725
# 0.018386041807157263
# 0.08988764895091612
# 0.6092962836419485
# 0.002880867807301693
# 0.0052816036761756625
# Calculating Statistical Features for Green Channel:
# 91.46699523925781
# 10.67550968141605
# 92.0
# 355.7396638595965
# 18.861062108470893
# 0.13021337269382854
# 0.7508260720535245
# 6.261837282185177
# 346.46606924019613
# 0.01900916373199622
# 0.09038367453612597
# 0.512853127633235
# 0.0028781363117014887
# 0.005286640558432629
# Calculating Statistical Features for Blue Channel:
# 75.65382385253906
# 10.614064771409664
# 72.0
# 557.9619949606713
# 23.62121916753391
# 0.5812440553548203
# -0.10584391552358907
# 6.517245524712671
# 345.7120863970588
# 0.017185274422507307
# 0.0895733681519196
# 0.6902651091884492
# 0.002884380464673377
# 0.005275135903068887
# Image number:  24
# Calculating Statistical features for Red Channel:
# 177.86785888671875
# 10.618235151126076
# 186.0
# 1354.0451302789152
# 36.79735221831749
# -1.664444773602731
# 3.8470064171624347
# 6.941115993928887
# 789.7626531862746
# 0.013207659825272649
# 0.062061835773210776
# 0.709078322296925
# 0.0012646230808726524
# 0.012050799462745185
# Calculating Statistical Features for Green Channel:
# 169.62513732910156
# 10.579820505505324
# 177.0
# 1406.3782005121466
# 37.501709301205814
# -1.6763676615632321
# 3.84348361979949
# 6.966841756373001
# 793.805361519608
# 0.013101340646059723
# 0.06253223719156656
# 0.7185237806559581
# 0.0012581904103782186
# 0.012112488523884742
# Calculating Statistical Features for Blue Channel:
# 136.52023315429688
# 10.519765506350117
# 155.0
# 3448.543749555014
# 58.7243028869225
# -0.4805204905031241
# -0.9565562412964832
# 7.610044797582549
# 789.1715533088235
# 0.010388966196511413
# 0.06338103743328974
# 0.8857260502751616
# 0.0012655646026743773
# 0.012041793785260983
# Image number:  25
# Calculating Statistical features for Red Channel:
# 108.99134826660156
# 10.672610613602012
# 132.0
# 3998.993745337939
# 63.237597561402815
# -0.29369828103591805
# -1.4683082542838046
# 7.427322311430355
# 400.18926164215685
# 0.015606832358970146
# 0.13000113839137056
# 0.9499758453483986
# 0.002492686117372573
# 0.006105383645649319
# Calculating Statistical Features for Green Channel:
# 94.14472961425781
# 10.041991760141121
# 113.0
# 3525.52164061903
# 59.376103279173094
# -0.22053290204455123
# -1.522388376481715
# 7.298963796158421
# 395.0346660539216
# 0.018914032822625118
# 0.13494067972627422
# 0.9439775273260451
# 0.0025251520801796838
# 0.0060267432896482665
# Calculating Statistical Features for Blue Channel:
# 81.40144348144531
# 9.517219597764376
# 74.0
# 3606.3824680091348
# 60.053163680268625
# -0.0033235558502466554
# -1.6432508000052763
# 7.132044669527443
# 380.45790441176473
# 0.022927743371339012
# 0.1395384407020606
# 0.9472351831629366
# 0.002621678821209325
# 0.00580426933992223
# Image number:  26
# Calculating Statistical features for Red Channel:
# 104.8831787109375
# 10.194297722486208
# 101.0
# 569.0831545442343
# 23.855463829995724
# 0.2595242134688487
# -0.6777202116777952
# 6.531012524817591
# 211.70356924019612
# 0.018209460637244216
# 0.1081809481784462
# 0.8139932720894537
# 0.004701781077157666
# 0.0032303280762859734
# Calculating Statistical Features for Green Channel:
# 121.72735595703125
# 9.17886133250351
# 126.0
# 476.7648070715368
# 21.834944631748822
# -0.5970948880465162
# 0.03507687438500984
# 6.386078527518509
# 212.57651654411762
# 0.02044297091209129
# 0.10812669616070548
# 0.7772280596967774
# 0.004682610909950107
# 0.0032436537481335976
# Calculating Statistical Features for Blue Channel:
# 105.84786987304688
# 10.273792472479583
# 101.0
# 650.4198801061139
# 25.503330764943506
# 0.26933053551252684
# -0.8016198825813161
# 6.606258954617881
# 211.20729166666666
# 0.01755661737161394
# 0.10796037412544067
# 0.8376558637980891
# 0.004712763318959251
# 0.00322276108261944
# Image number:  27
# Calculating Statistical features for Red Channel:
# 142.0926055908203
# 10.317740293809871
# 150.0
# 1469.1042324320879
# 38.328895528466354
# -1.4930434224998754
# 2.498393939168091
# 6.897515143102889
# 602.9386795343139
# 0.01460581122160877
# 0.0775889917551283
# 0.7953069020146334
# 0.001655837287351645
# 0.009200104297475689
# Calculating Statistical Features for Green Channel:
# 133.47518920898438
# 10.018149118853149
# 142.0
# 1429.0887398933992
# 37.80329006704839
# -1.555728642034762
# 2.529383144963276
# 6.853445178479542
# 603.1371936274512
# 0.015006438949440707
# 0.07804224617080208
# 0.7895742960374065
# 0.0016552942785529148
# 0.00920313202088175
# Calculating Statistical Features for Blue Channel:
# 107.08772277832031
# 10.31621692603636
# 129.0
# 3040.581461818656
# 55.141467715492084
# -0.36578047394867264
# -1.272067270046247
# 7.350563792784835
# 582.1402113970589
# 0.013555384100081065
# 0.07986486647534426
# 0.9043633866118733
# 0.0017148933078061466
# 0.008882735234920489
# Image number:  28
# Calculating Statistical features for Red Channel:
# 125.17044067382812
# 10.548483673613948
# 138.0
# 2877.9125393321738
# 53.646179168065395
# -0.4111759635555831
# -0.9385014302204953
# 7.571326140655356
# 486.7482996323531
# 0.013816450882445328
# 0.12948694949576364
# 0.9154248141256963
# 0.0020502958771277434
# 0.007427157297417499
# Calculating Statistical Features for Green Channel:
# 126.33132934570312
# 10.402134720252437
# 139.0
# 2229.6699449857697
# 47.21938103137069
# -0.6813404200943263
# -0.323267634824695
# 7.4103096667374455
# 483.9544577205883
# 0.014827371057739819
# 0.13008999107914737
# 0.891531026202592
# 0.002062112348457124
# 0.007384509887830603
# Calculating Statistical Features for Blue Channel:
# 104.76106262207031
# 10.449063959133866
# 108.0
# 3209.564414666733
# 56.65301770132579
# -0.14095535268823453
# -1.2531176178146108
# 7.593407550243485
# 482.46409313725496
# 0.01351710686531916
# 0.13156932475511335
# 0.924776992190562
# 0.0020684637677153995
# 0.007361763254214782
# Image number:  29
# Calculating Statistical features for Red Channel:
# 154.42401123046875
# 10.303834545821097
# 162.0
# 2364.1554805897176
# 48.622582002498774
# -0.8839206870333872
# 0.5813794280736997
# 7.461835982003771
# 1022.571063112745
# 0.012685322002277694
# 0.09574512592948904
# 0.7842665718650093
# 0.0009769838454728968
# 0.015603195066370075
# Calculating Statistical Features for Green Channel:
# 141.47128295898438
# 10.208940843424026
# 149.0
# 2506.7509148335084
# 50.06746363491472
# -0.794437169098716
# 0.08801537036341012
# 7.478527727682005
# 1021.1072150735296
# 0.012808589526885957
# 0.09761895652672777
# 0.7967905900158112
# 0.0009783832037981626
# 0.01558085851001409
# Calculating Statistical Features for Blue Channel:
# 118.49748229980469
# 10.29767000084432
# 117.0
# 3662.787133553764
# 60.52096441361261
# -0.09119016088830273
# -1.03613394649556
# 7.720536553249934
# 998.4210018382355
# 0.011906919913901862
# 0.0995948105168713
# 0.8637707860555282
# 0.0010005912544569415
# 0.015234693752935458
# Image number:  30
# Calculating Statistical features for Red Channel:
# 102.11123657226562
# 10.290038274725342
# 103.0
# 1136.8872846281156
# 33.717759187527804
# 0.10612960890348397
# 0.7479289648348284
# 7.048247986810831
# 280.18889399509806
# 0.019051187645783903
# 0.15769968608862392
# 0.8770410584306496
# 0.0035565691896936803
# 0.004275254964143159
# Calculating Statistical Features for Green Channel:
# 100.98268127441406
# 10.00472376833384
# 107.0
# 1291.8230490607675
# 35.94193997352908
# -0.46701368416071765
# -0.013511302414087822
# 7.121682321349277
# 279.6571384803922
# 0.017895658295418053
# 0.157498114562436
# 0.8919715515965558
# 0.003563293536370897
# 0.004267046848918579
# Calculating Statistical Features for Blue Channel:
# 102.05632019042969
# 10.412252075614228
# 108.0
# 3108.5475024746265
# 55.754349628299195
# -0.20182203696963974
# -1.3403949456250024
# 7.479742025925365
# 272.1224111519608
# 0.017068003432072754
# 0.16192437869271067
# 0.9562553648818809
# 0.0036615907564142695
# 0.004151885576602766
# Image number:  31
# Calculating Statistical features for Red Channel:
# 139.43972778320312
# 10.262284523563851
# 146.0
# 1358.3299243887886
# 36.85552773179064
# -1.1810160155585907
# 1.7560814642491618
# 6.999138795324693
# 423.92732843137264
# 0.016485675985698913
# 0.11686245739859509
# 0.8443509985165036
# 0.002353434884163878
# 0.006468418521254464
# Calculating Statistical Features for Green Channel:
# 136.61875915527344
# 9.773675587877383
# 141.0
# 1263.9253188704606
# 35.551727368307446
# -1.319824446909889
# 2.386583458552521
# 6.894941795277181
# 426.3853860294118
# 0.016718553778936697
# 0.11836269538479295
# 0.831796113785883
# 0.002339900128633124
# 0.006505901988800537
# Calculating Statistical Features for Blue Channel:
# 116.46540832519531
# 10.28958673090292
# 135.0
# 2759.6061337383
# 52.53195345442904
# -0.48555942167875554
# -0.8975677816105176
# 7.414815637003398
# 409.02542892156856
# 0.014823841403939348
# 0.11917869812053196
# 0.9260053586640128
# 0.0024389613039508613
# 0.006240974891886418
# Image number:  32
# Calculating Statistical features for Red Channel:
# 157.87574768066406
# 10.100717318905886
# 154.0
# 1159.8079408777412
# 34.0559530901389
# 0.544262717534814
# 0.4657093093729503
# 7.035302029391104
# 215.92440257352942
# 0.018987251799003155
# 0.16217494691191064
# 0.9071258927540354
# 0.0046103044431450675
# 0.003294524882717065
# Calculating Statistical Features for Green Channel:
# 154.49996948242188
# 10.179597562918131
# 152.0
# 970.250823973678
# 31.148849480738097
# 0.29879933151351307
# 0.8126112592760757
# 6.950287218202124
# 216.22706801470588
# 0.01953966442159695
# 0.16076989857517718
# 0.8888125983562131
# 0.004603891990278205
# 0.003299177651995738
# Calculating Statistical Features for Blue Channel:
# 142.43954467773438
# 10.203584108640912
# 146.0
# 1053.3743969118223
# 32.45572980094304
# -0.8585270007119492
# 1.3649461400467393
# 6.967186495167279
# 212.0336856617647
# 0.019654557175556128
# 0.159178975076395
# 0.8994824560391186
# 0.004694526434782146
# 0.0032351974443407564
# Image number:  33
# Calculating Statistical features for Red Channel:
# 125.06719970703125
# 10.4734422786428
# 142.0
# 3328.634644355625
# 57.69432072878252
# -0.6796245154471977
# -0.7562039018619511
# 7.468792677478516
# 595.882337622549
# 0.015896248280730697
# 0.1589528826664807
# 0.9106113733169283
# 0.0016754166940555878
# 0.009091757735014049
# Calculating Statistical Features for Green Channel:
# 110.29142761230469
# 10.287416968120645
# 127.0
# 3241.1280368657317
# 56.930905814555
# -0.5333332405007735
# -1.010728888144045
# 7.45152219236288
# 585.5884957107843
# 0.015979979229936627
# 0.1631158509722673
# 0.9097354000860756
# 0.0017048190516612122
# 0.008934751313687463
# Calculating Statistical Features for Blue Channel:
# 96.0379638671875
# 10.089207811211567
# 92.0
# 4060.7086417526007
# 63.72368980020382
# 0.03499216757469429
# -1.3765735632293188
# 7.511852789224164
# 543.2216911764706
# 0.02829024110791925
# 0.17889741503447587
# 0.9330511748021847
# 0.0018375820035325574
# 0.008288481344584545
# Image number:  34
# Calculating Statistical features for Red Channel:
# 106.4656982421875
# 10.189490375447052
# 102.0
# 537.3026869148016
# 23.179790484704593
# 0.41767584919312906
# -0.34334603140218345
# 6.493975815009963
# 293.35603553921567
# 0.018305317545318046
# 0.09832898198988631
# 0.7269554323477044
# 0.003397457740966081
# 0.004476257141426017
# Calculating Statistical Features for Green Channel:
# 123.05865478515625
# 9.085369850066645
# 127.0
# 461.7793965302408
# 21.48905294633155
# -0.6200209896521812
# 0.5387231036453799
# 6.367945256217013
# 294.03210784313734
# 0.01965581075509406
# 0.09855171814604428
# 0.6813521118110413
# 0.003389687428821595
# 0.004486573420992061
# Calculating Statistical Features for Blue Channel:
# 102.31411743164062
# 10.267652244655908
# 96.0
# 697.4296505516395
# 26.408893398846523
# 0.428852859495829
# -0.6703126984409709
# 6.627410570173655
# 292.6889093137256
# 0.017327405947521236
# 0.09805071840835486
# 0.790202422132879
# 0.0034051643455035793
# 0.004466077496284409
# Image number:  35
# Calculating Statistical features for Red Channel:
# 86.81344604492188
# 9.55652386788732
# 94.0
# 1872.6589842429385
# 43.27423002484202
# -0.7927084367656198
# 0.1082609120088498
# 6.3450666910212155
# 451.3748314950981
# 0.1303455285721056
# 0.20138295320265442
# 0.878716432958254
# 0.0022111933501252627
# 0.006887385298518385
# Calculating Statistical Features for Green Channel:
# 100.62773132324219
# 8.622642305415924
# 117.0
# 2341.6713678145315
# 48.390819044675524
# -1.1052852658868217
# 0.18318010722131683
# 6.346516597760602
# 451.34419424019603
# 0.13034587782878373
# 0.2020363081846203
# 0.90301829385738
# 0.002211343159041608
# 0.006886925165470216
# Calculating Statistical Features for Blue Channel:
# 83.25753784179688
# 9.631778064388767
# 87.0
# 1883.715259953402
# 43.401788672281725
# -0.5380052083956448
# -0.10609014711813547
# 6.469987336849054
# 451.8996783088235
# 0.1278309162768456
# 0.2001047403649396
# 0.8793391312820288
# 0.0022086178850537373
# 0.006895398630347763
# Image number:  36
# Calculating Statistical features for Red Channel:
# 116.87791442871094
# 10.34771818356324
# 129.0
# 2640.390109151369
# 51.38472641896003
# -0.37929973813931955
# -0.9491896484082618
# 7.5246830143012895
# 776.0901194852942
# 0.010084940171771679
# 0.06578655124754416
# 0.8531812914138989
# 0.0012868687336502831
# 0.011842124680485414
# Calculating Statistical Features for Green Channel:
# 118.18022155761719
# 10.044855606005882
# 127.0
# 1865.1273254880216
# 43.18711990267494
# -0.5226178090249031
# -0.3948103697502101
# 7.3231534487803
# 774.2258731617648
# 0.010820569244176662
# 0.06599875896524968
# 0.7928189306646807
# 0.0012899646319505021
# 0.011813670290069729
# Calculating Statistical Features for Blue Channel:
# 98.729248046875
# 10.170682353756586
# 106.0
# 3005.8182033896446
# 54.82534271110072
# -0.18146604920477696
# -1.1824091135534756
# 7.559954530585738
# 758.5273284313727
# 0.012094034544212814
# 0.07031592659867107
# 0.8738482641568075
# 0.0013166292849861707
# 0.0115741298770083
# Image number:  37
# Calculating Statistical features for Red Channel:
# 122.41163635253906
# 10.196441658017347
# 135.0
# 1720.4993329790886
# 41.47890226342892
# -0.9173556680541459
# 0.2320267308048849
# 7.16918530191948
# 640.2490655637255
# 0.0148390936083754
# 0.10419304890406003
# 0.8142485803245297
# 0.0015594925515826348
# 0.009769332416177294
# Calculating Statistical Features for Green Channel:
# 121.67938232421875
# 9.966146003451353
# 133.0
# 1471.893389608711
# 38.36526279864001
# -1.185363935355902
# 1.089850755797383
# 6.999863273789057
# 636.5577512254905
# 0.015721300700119428
# 0.1042630367589495
# 0.7841864654872249
# 0.0015685240392981903
# 0.009712992137908842
# Calculating Statistical Features for Blue Channel:
# 112.92546081542969
# 10.48690924452623
# 125.0
# 2774.499158875784
# 52.67351477617365
# -0.44955140755936085
# -0.9902949385751634
# 7.427285159259227
# 635.1384037990194
# 0.013824295321919141
# 0.10463706960912167
# 0.8856308019053966
# 0.0015720191173562213
# 0.009691345474662338
# Image number:  38
# Calculating Statistical features for Red Channel:
# 101.7723388671875
# 10.239432493219686
# 101.0
# 598.9557692855597
# 24.47357287536006
# 0.15600654557207919
# 0.20724818166738812
# 6.651923049476547
# 579.1162837009804
# 0.013530155474728259
# 0.0564688353288193
# 0.5164830928197384
# 0.0017238325346469088
# 0.00883661259301952
# Calculating Statistical Features for Green Channel:
# 112.50590515136719
# 9.685402526210595
# 115.0
# 637.6111406662967
# 25.25096316314086
# -0.26332090071454495
# 0.24889058275410347
# 6.676872132497195
# 580.0833486519608
# 0.013802992899998348
# 0.05652789994445771
# 0.5452237240341941
# 0.0017209643965521884
# 0.008851369305272822
# Calculating Statistical Features for Blue Channel:
# 102.13362121582031
# 10.292227499400413
# 99.0
# 627.524457992753
# 25.050438279454372
# 0.3217908533339338
# 0.05517007645361671
# 6.667604529592847
# 577.6894761029411
# 0.01354317418523021
# 0.055998385939411845
# 0.5395469999962983
# 0.0017280829270691577
# 0.008814841706054382
# Image number:  39
# Calculating Statistical features for Red Channel:
# 99.21760559082031
# 10.298022656310424
# 99.0
# 592.4589802043047
# 24.340480278833954
# 0.14896618280301266
# 0.034951886765597795
# 6.645588123894274
# 492.62719056372566
# 0.014425202620702019
# 0.07112040546292016
# 0.5841841919350427
# 0.002025879535891753
# 0.007516893551941647
# Calculating Statistical Features for Green Channel:
# 107.85263061523438
# 9.699955765141567
# 111.0
# 627.9070237195119
# 25.058073024865898
# -0.3970655838349588
# 0.08523269680272616
# 6.638276446963244
# 493.8638480392157
# 0.014964738852892331
# 0.07109510821263493
# 0.6067653779880765
# 0.00202081894846476
# 0.007535764150828501
# Calculating Statistical Features for Blue Channel:
# 91.55244445800781
# 10.370181515906632
# 89.0
# 658.1671409362461
# 25.654768385940383
# 0.31335913612710437
# -0.21598599789535644
# 6.6965760041024165
# 491.9163756127452
# 0.014170632920382736
# 0.07085908165823847
# 0.626350615361379
# 0.0020288000132621265
# 0.007506048152279087
# Image number:  40
# Calculating Statistical features for Red Channel:
# 133.33810424804688
# 10.086569863018969
# 137.0
# 2212.6497846385464
# 47.03881147136422
# -0.7131445048269448
# 0.17890613500954844
# 7.379283710808111
# 744.8703125
# 0.012968645414571597
# 0.09593724752284485
# 0.8319889142363216
# 0.0013407389606596984
# 0.011365774561454475
# Calculating Statistical Features for Green Channel:
# 136.77053833007812
# 10.22324209608078
# 146.0
# 2036.9517113557085
# 45.132601424643234
# -1.1106893168211163
# 0.9609111643849015
# 7.216989036353122
# 743.7434436274511
# 0.013865261961641628
# 0.09672369150546171
# 0.8178539284445443
# 0.0013427692803537768
# 0.011348567661263196
# Calculating Statistical Features for Blue Channel:
# 116.33546447753906
# 10.269174644341023
# 116.0
# 3454.8320589212235
# 58.77781944680513
# -0.1764712223311879
# -1.0045163437378384
# 7.6980692091402965
# 742.8867034313728
# 0.011285265177101642
# 0.09476133477027064
# 0.892562620915344
# 0.0013443111246574104
# 0.011335505665434254
# Image number:  41
# Calculating Statistical features for Red Channel:
# 116.97737121582031
# 10.65330057354769
# 132.0
# 2874.037436546525
# 53.61004977190867
# -0.41964452740451075
# -1.2558934419480496
# 7.357073668096009
# 254.59371936274508
# 0.017002047925898465
# 0.15655957860103245
# 0.9557352428097002
# 0.003912719478152624
# 0.003883961322246515
# Calculating Statistical Features for Green Channel:
# 103.55465698242188
# 10.349180150386612
# 118.0
# 2601.4994845381007
# 51.004896672163746
# -0.39432047780502905
# -1.2806717263979244
# 7.293367444941184
# 251.76167279411766
# 0.01697768394011374
# 0.15754062329630697
# 0.9516451598163828
# 0.003956561776950752
# 0.003840709332418254
# Calculating Statistical Features for Blue Channel:
# 81.00761413574219
# 10.28573334404527
# 62.0
# 3155.250262459507
# 56.171614383596875
# 0.2067274564827926
# -1.5395683347114486
# 7.2292533303766975
# 242.0161151960785
# 0.017259858587359345
# 0.1581501941759318
# 0.9616336978062382
# 0.004115245722499972
# 0.003691951161059266
# Image number:  42
# Calculating Statistical features for Red Channel:
# 122.25898742675781
# 10.42879429110628
# 129.0
# 3633.796618750086
# 60.28098057223428
# -0.2569661336955675
# -1.1167553422484386
# 7.6400174902775815
# 392.9734528186275
# 0.016614659883922966
# 0.17758977749055582
# 0.9459151321729853
# 0.0025383491366052983
# 0.005996293944662228
# Calculating Statistical Features for Green Channel:
# 116.3819580078125
# 10.38542662492209
# 128.0
# 3477.0149051994085
# 58.966218338972766
# -0.29892146018959087
# -1.0944832988463684
# 7.630347331784144
# 389.7744332107844
# 0.01593582022191618
# 0.18159131530415032
# 0.9439446609814159
# 0.0025591254103951105
# 0.005947484923340452
# Calculating Statistical Features for Blue Channel:
# 80.21109008789062
# 10.159330962973614
# 70.0
# 3588.8188137775287
# 59.906750986658665
# 0.6281320880768471
# -0.6116421772024694
# 7.503924563617762
# 382.5021446078432
# 0.024205942333762324
# 0.18987829338144527
# 0.9464354268564225
# 0.0026077119416046905
# 0.005836519525858679
# Image number:  43
# Calculating Statistical features for Red Channel:
# 115.33616638183594
# 10.711828549506542
# 95.0
# 1754.5580889654811
# 41.88744548149817
# 0.7458646767101095
# -0.8333167165904447
# 6.887432444827896
# 85.09728860294119
# 0.024530350992264284
# 0.22971873146100502
# 0.9757934017585692
# 0.011618077778718764
# 0.0012984814592778555
# Calculating Statistical Features for Green Channel:
# 118.90875244140625
# 10.693636019537946
# 98.0
# 1869.7851003967226
# 43.241011787384465
# 0.652080567006362
# -0.942103399190362
# 6.94523063096646
# 86.1826899509804
# 0.023900966717926343
# 0.2300102907406658
# 0.9769946151802746
# 0.011473312234530492
# 0.0013150418115803386
# Calculating Statistical Features for Blue Channel:
# 82.34539794921875
# 10.787786741191981
# 86.0
# 520.396935608238
# 22.81221023066897
# -0.48123555165062576
# 0.32657048581746695
# 6.455745510844095
# 82.43351715686275
# 0.026580877762296316
# 0.22015196600574394
# 0.9208982589899702
# 0.011989410528804824
# 0.0012578323775073832
# Image number:  44
# Calculating Statistical features for Red Channel:
# 127.72996520996094
# 10.254095236353665
# 139.0
# 3593.1907378283795
# 59.94322929095812
# -0.5732976466821345
# -0.7488886401588717
# 7.60322761069019
# 703.8840533088236
# 0.015126537667769398
# 0.1449172757305078
# 0.9020182143137743
# 0.001418703480916335
# 0.010738362546939287
# Calculating Statistical Features for Green Channel:
# 126.01956176757812
# 10.16180887534993
# 137.0
# 3334.5550677767023
# 57.74560648029166
# -0.6645148003338599
# -0.5579557476825401
# 7.534789925544603
# 702.3130974264706
# 0.015090473125885163
# 0.14568838055692293
# 0.894645164336062
# 0.001421872364365079
# 0.010714316866924554
# Calculating Statistical Features for Blue Channel:
# 119.81529235839844
# 10.218759705891797
# 131.0
# 4269.132829498267
# 65.33860137390658
# -0.3435892021140957
# -1.1072270368208001
# 7.708467192802759
# 688.2869485294117
# 0.014113685866652657
# 0.14434866601154656
# 0.9193587319382875
# 0.001450804310642803
# 0.010500324585935856
# Image number:  45
# Calculating Statistical features for Red Channel:
# 121.8343505859375
# 9.733376441058846
# 122.0
# 738.1608842462301
# 27.169116368520896
# 0.07303898115464125
# 0.34005456025732395
# 6.803133625300272
# 834.2752297794118
# 0.012253944509166715
# 0.047242677008630274
# 0.4349337722973791
# 0.0011972277341760916
# 0.012729973856159921
# Calculating Statistical Features for Green Channel:
# 129.90524291992188
# 9.914381089739194
# 133.0
# 899.0400018086657
# 29.98399576121678
# -0.26922233553005454
# -0.04602220972750848
# 6.924456244539736
# 835.8869025735296
# 0.011701586575679384
# 0.047191761201574006
# 0.5354361702124637
# 0.001194921296294439
# 0.012754570900221592
# Calculating Statistical Features for Blue Channel:
# 119.25277709960938
# 9.882594797503367
# 118.0
# 738.3041152125224
# 27.171752155731923
# 0.23656350388978142
# 0.3045413909077963
# 6.799257284633576
# 832.8857996323529
# 0.012131830704000791
# 0.0474824084969191
# 0.4359621322881095
# 0.0011992224225479044
# 0.0127087827619761
# Image number:  46
# Calculating Statistical features for Red Channel:
# 128.1965789794922
# 10.30284008387713
# 137.0
# 2510.195807998767
# 50.10185433692816
# -0.5924182971926633
# -0.25949576290650755
# 7.50387587100593
# 598.7592064950982
# 0.013297115710033757
# 0.11540750318255026
# 0.8804039224632778
# 0.001667372772971126
# 0.009133845440486947
# Calculating Statistical Features for Green Channel:
# 122.29560852050781
# 10.159726718621437
# 133.0
# 2169.1369960957672
# 46.573994847938124
# -0.8598802370826272
# 0.1892072618041536
# 7.308477508906545
# 596.7734375
# 0.014243259474417855
# 0.11536166187344786
# 0.8619701213684712
# 0.0016729144605973575
# 0.009103559921755213
# Calculating Statistical Features for Blue Channel:
# 75.44540405273438
# 10.138936564944508
# 68.0
# 2636.1015419876203
# 51.34297948101201
# 0.38963611661332287
# -0.9217125609686909
# 7.432849403744239
# 590.2471966911767
# 0.01683469067673001
# 0.1220488956657721
# 0.8874887288773089
# 0.0016913881022895684
# 0.009003776136477097
# Image number:  47
# Calculating Statistical features for Red Channel:
# 106.37425231933594
# 10.213839876579918
# 103.0
# 454.450343526667
# 21.31784096775907
# 0.4671313361767158
# -0.22514535690060145
# 6.397085158265107
# 301.2428155637255
# 0.017834566865464915
# 0.09530326099929547
# 0.6686495248121744
# 0.003308793325758831
# 0.004596597313653908
# Calculating Statistical Features for Green Channel:
# 126.06645202636719
# 9.742019125700166
# 130.0
# 521.7737976291683
# 22.842368476783843
# -0.21484826941955049
# -0.3532631533396402
# 6.50422755251918
# 302.53040747549016
# 0.01751195849633898
# 0.0948388947143566
# 0.7102478311313928
# 0.0032947529240780135
# 0.0046162433479688784
# Calculating Statistical Features for Blue Channel:
# 100.96412658691406
# 10.077533745980075
# 100.0
# 737.6533914429601
# 27.159775246547238
# 0.21133436251859256
# -0.8134498369052672
# 6.722736689613686
# 301.26269914215686
# 0.01560562945303651
# 0.09464391095518827
# 0.795907687809964
# 0.0033085512531420545
# 0.004596900142946269
# Image number:  48
# Calculating Statistical features for Red Channel:
# 113.01593017578125
# 9.794740970724737
# 114.0
# 754.5161646865308
# 27.468457632101057
# -0.09447896537801033
# 0.3508767321315962
# 6.805700311591662
# 614.191544117647
# 0.013544698860903285
# 0.06533138107657373
# 0.5928523058571885
# 0.001625545778530425
# 0.009371740992171335
# Calculating Statistical Features for Green Channel:
# 121.23387145996094
# 9.77762309828664
# 126.0
# 907.5245430318173
# 30.125148016761965
# -0.45495939393760226
# -0.09534438580668425
# 6.891800460513397
# 615.9142156862746
# 0.012941964862673678
# 0.06537550717544706
# 0.660719857273873
# 0.0016210049202323297
# 0.009398029001787026
# Calculating Statistical Features for Blue Channel:
# 109.39146423339844
# 10.036792210461297
# 109.0
# 733.154906999087
# 27.076833400512086
# 0.13137575014552086
# 0.3732109964228907
# 6.796801764481261
# 613.1182598039214
# 0.013425166791728027
# 0.0656354310283965
# 0.5817709834534542
# 0.0016283864636742246
# 0.009355362358330099
# Image number:  49
# Calculating Statistical features for Red Channel:
# 118.7208251953125
# 10.193800773938541
# 125.0
# 2397.7167391628027
# 48.96648587720792
# -0.24101334230552066
# -0.5666030429773974
# 7.515144692100382
# 2304.2782322303924
# 0.011871985689334227
# 0.05645048534278267
# 0.5201663772870521
# 0.00043378935174061636
# 0.03516040202566436
# Calculating Statistical Features for Green Channel:
# 117.33087158203125
# 10.180604812852168
# 122.0
# 2401.2362881563604
# 49.00241104431863
# -0.21621202270790946
# -0.31933057864889847
# 7.51978949730567
# 2303.338740808824
# 0.011936130601912625
# 0.05620166920087086
# 0.5212666336546443
# 0.0004339662230070013
# 0.03514601827592663
# ...
# -0.6157524292446466
# -0.8439657263279816
# 7.606958538135421
# 895.4917279411764
# 0.013796156931494776
# 0.131396554593671
# 0.8886183427480457
# 0.0011154764267422813
# 0.0136639138706736
# Calculating Statistical Features for Green Channel:
# 120.39268493652344
# 9.987060567763654
# 135.0
# 4229.209980059182
# 65.03237639867686
# -0.500835560448712
# -1.0301441072831685
# 7.568255593712511
# 885.763204656863
# 0.014330426559543169
# 0.1336449183984563
# 0.8954495792143237
# 0.0011277149924413476
# 0.013515424726660528
# Calculating Statistical Features for Blue Channel:
# 110.66998291015625
# 9.969576523337764
# 124.0
# 5326.352026220411
# 72.98186093969112
# -0.18846827935249835
# -1.3960674925584038
# 7.518793821622881
# 815.9468137254903
# 0.03077317429953998
# 0.15359135061776366
# 0.9234580056187628
# 0.0012241160050245536
# 0.012450020351761903
# Image number:  383
# Calculating Statistical features for Red Channel:
# 122.04054260253906
# 10.254979110540264
# 119.0
# 1471.5049328354653
# 38.36019985395625
# 0.5813990841408538
# 0.014479678515763705
# 7.208230644288381
# 69.7537530637255
# 0.01986563172370108
# 0.20821676065844189
# 0.9763004140469378
# 0.014137495284156754
# 0.001064356124194705
# Calculating Statistical Features for Green Channel:
# 122.99809265136719
# 10.268550554638374
# 120.0
# 1318.6545221188571
# 36.31328299835829
# 0.5195928239532335
# -0.08709489252200253
# 7.138828623061232
# 68.67954963235294
# 0.020372772439605787
# 0.20892065654647954
# 0.9739588873751276
# 0.014355610345655238
# 0.001047965825769172
# Calculating Statistical Features for Blue Channel:
# 110.01985168457031
# 10.163919129705594
# 105.0
# 824.0585811303463
# 28.706420555867748
# 1.4012556556671258
# 2.9978564086325
# 6.6710051361145934
# 65.12279411764708
# 0.02538344178881833
# 0.20493217008570155
# 0.9605621619887066
# 0.01512918569388445
# 0.000993694949598667
# Image number:  384
# Calculating Statistical features for Red Channel:
# 139.10211181640625
# 9.971971523447765
# 142.0
# 1812.7106730304658
# 42.57594007218708
# -0.7651330781504536
# 0.5055707789645956
# 7.291190079461428
# 484.6345741421569
# 0.012114429286048221
# 0.08616298584416013
# 0.8667765658914512
# 0.0020592128308712493
# 0.007394929650833673
# Calculating Statistical Features for Green Channel:
# 129.17408752441406
# 10.053062799727924
# 132.0
# 1556.6035588902887
# 39.4538155175173
# -0.9730511836119937
# 1.0811701269595515
# 7.100154724555347
# 483.9126378676471
# 0.013123102555720446
# 0.08689457008365153
# 0.8450292759852857
# 0.0020622829463635326
# 0.007383915939203957
# Calculating Statistical Features for Blue Channel:
# 83.014892578125
# 10.050851844631596
# 70.0
# 2350.398795545101
# 48.48091166165403
# 0.17612239848828382
# -1.194684404775678
# 7.324083230177361
# 476.9933823529413
# 0.014054972167066797
# 0.09043961121371327
# 0.8985014650320107
# 0.0020921406904348535
# 0.007278341405474649
# Image number:  385
# Calculating Statistical features for Red Channel:
# 85.18382263183594
# 10.433798493404813
# 87.0
# 1093.627387828892
# 33.07003761456724
# 0.0062662106900872264
# -0.47783940281129755
# 7.050016603549255
# 312.9692708333334
# 0.014719838021723105
# 0.12229928719034255
# 0.8569765897285048
# 0.003185174404479116
# 0.004775375072779517
# Calculating Statistical Features for Green Channel:
# 86.96078491210938
# 10.520434159867614
# 89.0
# 1131.9115786319599
# 33.64389363067182
# 0.10938349353601341
# -0.36464512361379775
# 7.0814280970662224
# 316.0725490196079
# 0.014535173919755732
# 0.12177279374314655
# 0.8604753124248148
# 0.0031539969227420287
# 0.004822871373369802
# Calculating Statistical Features for Blue Channel:
# 75.852783203125
# 10.565809103967588
# 80.0
# 1061.7337898612022
# 32.5842567793283
# -0.19220452523273188
# -0.8321284005272807
# 6.982923814221371
# 313.4683363970589
# 0.014682646701764276
# 0.12044407133932011
# 0.8523605914005379
# 0.0031801188762586104
# 0.00478297867058135
# Image number:  386
# Calculating Statistical features for Red Channel:
# 90.40139770507812
# 10.622857090888377
# 87.0
# 407.545666991733
# 20.18776032629011
# 0.6280248268496765
# 0.6136356408690427
# 6.322576004200564
# 437.72565870098043
# 0.017946280384225282
# 0.08248854792766146
# 0.4628273033599021
# 0.0022794219743310184
# 0.006679161938361361
# Calculating Statistical Features for Green Channel:
# 102.24934387207031
# 10.272628740741933
# 104.0
# 446.6610789762344
# 21.13435778480705
# -0.08222759794167707
# 0.36340391606282596
# 6.4148943348834235
# 438.4828890931373
# 0.017383085442116922
# 0.08308139470425152
# 0.5093599901256343
# 0.0022754914466085303
# 0.006690716202503663
# Calculating Statistical Features for Blue Channel:
# 87.7611083984375
# 10.394389590588641
# 84.0
# 533.6444688886404
# 23.100746067792713
# 0.5510336814255956
# -0.05135202283347917
# 6.501426028956526
# 436.84214154411757
# 0.01631999723494628
# 0.08249853668980837
# 0.590593427458215
# 0.002284013301149986
# 0.0066656805364316936
# Image number:  387
# Calculating Statistical features for Red Channel:
# 118.349853515625
# 10.103538089876919
# 124.0
# 2211.3819360136986
# 47.02533291762748
# -0.36458467002516165
# -0.19589850112173268
# 7.49467969324481
# 1678.4882199754904
# 0.009868620767150218
# 0.049588005525792005
# 0.6207876557684456
# 0.0005954229771365416
# 0.025611323481540223
# Calculating Statistical Features for Green Channel:
# 124.02473449707031
# 10.150395698538755
# 129.0
# 2197.7785782681312
# 46.88047118223249
# -0.5004829926228634
# 0.10127109511967003
# 7.476591985762616
# 1681.5467218137258
# 0.009947747296969388
# 0.04989041160247396
# 0.6178415439342066
# 0.0005943406500311765
# 0.02565789877176743
# Calculating Statistical Features for Blue Channel:
# 113.54345703125
# 10.161188703068898
# 120.0
# 3143.58624625206
# 56.06769342724971
# -0.2578460230370382
# -0.6401292060936212
# 7.700124341577813
# 1668.8921109068626
# 0.008696124542564044
# 0.0493627968240571
# 0.7346527927508443
# 0.0005988442014260956
# 0.025464780774480965
# Image number:  388
# Calculating Statistical features for Red Channel:
# 145.5220947265625
# 10.455069185791526
# 151.0
# 3635.276855573058
# 60.29325713189708
# -0.33144041953587905
# -0.8923083161285055
# 7.652004241421537
# 757.7420343137256
# 0.019521593874089794
# 0.15455831483528049
# 0.8957568109536104
# 0.0013180049138323605
# 0.011561434552866946
# Calculating Statistical Features for Green Channel:
# 148.38494873046875
# 10.53466017208938
# 157.0
# 3316.0071489475667
# 57.58478226882139
# -0.5483380976057646
# -0.596530627497168
# 7.619748317621083
# 755.9146292892158
# 0.01876935105733712
# 0.15476588289924004
# 0.8860563223155413
# 0.0013211857177838234
# 0.011533331159485797
# Calculating Statistical Features for Blue Channel:
# 130.8228759765625
# 10.429013028285112
# 133.0
# 4168.666777715087
# 64.56521337156013
# -0.1540478207157619
# -1.0247643212173785
# 7.730390441837109
# 758.9359834558825
# 0.018427385607976507
# 0.15185693344873763
# 0.9089004670409268
# 0.0013159322245050536
# 0.01157939792770401
# Image number:  389
# Calculating Statistical features for Red Channel:
# 112.97370910644531
# 10.578117066328266
# 116.0
# 2095.763392651221
# 45.779508436102944
# -0.3741512729504144
# -1.0031417621026164
# 7.270348382301273
# 293.7671568627451
# 0.023888975898604208
# 0.2117498622541257
# 0.929985587136107
# 0.0033927831742162316
# 0.004481699232603554
# Calculating Statistical Features for Green Channel:
# 113.95159912109375
# 10.467204876646273
# 121.0
# 2160.4665294252336
# 46.48081894099149
# -0.553994648922002
# -0.753355881056391
# 7.284571308137622
# 292.53866421568625
# 0.023478284151941142
# 0.21224567987367865
# 0.9323787203303898
# 0.0034069787456696065
# 0.004462862010172975
# Calculating Statistical Features for Blue Channel:
# 110.05438232421875
# 10.518470141200579
# 113.0
# 2839.3313015960157
# 53.28537605756401
# -0.36592007882005945
# -1.0328901100891377
# 7.427538913578193
# 283.6759803921569
# 0.02239435590671443
# 0.2114346877070722
# 0.9500912190268497
# 0.0035130419887724573
# 0.004327591247383973
# Image number:  390
# Calculating Statistical features for Red Channel:
# 98.26638793945312
# 9.093051949153265
# 111.0
# 2106.6037200829014
# 45.897752887073906
# -1.251133725166039
# 0.4333594010806423
# 6.15911767303686
# 218.102650122549
# 0.1300083491636454
# 0.23452938574963353
# 0.9478559995911343
# 0.004566780543456654
# 0.0033278624190612675
# Calculating Statistical Features for Green Channel:
# 110.35316467285156
# 8.692889620606872
# 130.0
# 2532.3352203925606
# 50.322313345001945
# -1.437256441483532
# 0.665572155005818
# 6.03556987013521
# 218.52596507352942
# 0.131254884420108
# 0.23507157640660536
# 0.9565327539597702
# 0.004557995036152151
# 0.003334336613617502
# Calculating Statistical Features for Blue Channel:
# 95.34661865234375
# 9.346342919910573
# 106.0
# 2100.5248750410974
# 45.831483447965084
# -1.0689493488693569
# 0.16212279684770436
# 6.301029331430142
# 218.08530943627449
# 0.1286938870537098
# 0.23409108570558068
# 0.9477333098328102
# 0.004567114802590667
# 0.0033275990612319354
# Image number:  391
# Calculating Statistical features for Red Channel:
# 116.72386169433594
# 10.216930355716176
# 123.0
# 2663.7382770550903
# 51.61141615045154
# -0.22673178457744442
# -0.5924865840356306
# 7.604618103691769
# 2031.2682444852949
# 0.009107333065443856
# 0.04821207613735383
# 0.6194067935284004
# 0.0004920632323500256
# 0.030994577948680747
# Calculating Statistical Features for Green Channel:
# 116.152587890625
# 10.187046157931558
# 120.0
# 2675.1139544844627
# 51.72150379179305
# -0.15507052438265248
# -0.3889868985530325
# 7.637734288138986
# 2029.1000765931374
# 0.008814615638120528
# 0.0477410521628194
# 0.6215698155553687
# 0.0004925886923063282
# 0.03096143972971869
# Calculating Statistical Features for Blue Channel:
# 108.29264831542969
# 10.094423442849754
# 119.0
# 3205.2950179742184
# 56.615324939226646
# -0.30251310074134513
# -0.8654207012747097
# 7.635664246643764
# 2020.32493872549
# 0.008890770900296389
# 0.04711444266869304
# 0.6851614994929133
# 0.0004947271857916134
# 0.030827545729200462
# Image number:  392
# Calculating Statistical features for Red Channel:
# 106.64942932128906
# 10.004841204845766
# 107.0
# 670.0820104775485
# 25.885942333195995
# -0.08527941879088335
# -0.15867166557325785
# 6.729080968295944
# 449.12840073529424
# 0.013728003178345272
# 0.0674957042653762
# 0.6649048258038173
# 0.002221656081394055
# 0.006853138853920074
# Calculating Statistical Features for Green Channel:
# 114.52992248535156
# 9.48812203962761
# 119.0
# 730.6166278382298
# 27.02992097358462
# -0.45937494137718154
# -0.08941612259624154
# 6.716942649726652
# 450.18126531862754
# 0.014650855741216046
# 0.06800385756321255
# 0.6921569076784189
# 0.0022164760599374124
# 0.0068692100142271634
# Calculating Statistical Features for Blue Channel:
# 103.01414489746094
# 10.100977149755503
# 101.0
# 694.8461591748055
# 26.35993473388744
# 0.10165408056217726
# -0.31354636628349253
# 6.736972536136812
# 448.56689644607854
# 0.013698759148137236
# 0.06780169108911227
# 0.6773014739765757
# 0.0022244308463275613
# 0.006844578058022387
# Image number:  393
# Calculating Statistical features for Red Channel:
# 118.11103820800781
# 10.008485627001642
# 115.0
# 489.5930629724171
# 22.126749941471683
# 0.317481357658949
# -0.11835086456596233
# 6.473479724893348
# 283.2712009803921
# 0.018745982184383874
# 0.10764314102138567
# 0.7105606968524817
# 0.0035179995191468275
# 0.0043223749916257185
# Calculating Statistical Features for Green Channel:
# 129.55577087402344
# 9.451466312382516
# 133.0
# 465.9058861916419
# 21.584853165857808
# -0.5415492186119877
# 0.33375731205116255
# 6.3793384281262275
# 283.87625612745103
# 0.02039478359882301
# 0.10828049118045541
# 0.695251169750481
# 0.003510547388010003
# 0.004331607594126488
# Calculating Statistical Features for Blue Channel:
# 115.08418273925781
# 10.239169469769706
# 110.0
# 617.9636621677782
# 24.85887491757779
# 0.37009465626863064
# -0.3987583972192983
# 6.6028518141548656
# 282.9795955882353
# 0.017768577767642405
# 0.10703996158469233
# 0.7710001759764019
# 0.0035216001056477815
# 0.004317925153590197
# Image number:  394
# Calculating Statistical features for Red Channel:
# 122.01716613769531
# 10.521383400817223
# 139.0
# 3191.8192701430526
# 56.496188102765416
# -0.48211174911567456
# -1.1133629716076392
# 7.497161957177197
# 436.96352634803935
# 0.014152239801315377
# 0.13020655545842483
# 0.9314632537679477
# 0.0022833689442671805
# 0.006665251941825824
# Calculating Statistical Features for Green Channel:
# 114.71968078613281
# 10.368930741954317
# 128.0
# 2244.3080025592353
# 47.37412798732274
# -0.5715153818350311
# -0.8128245225126549
# 7.356843567471339
# 434.5159313725491
# 0.014235019498006039
# 0.1309402988095104
# 0.9029682560609783
# 0.002296202307302434
# 0.006628014444388228
# Calculating Statistical Features for Blue Channel:
# 95.2628173828125
# 10.244876232228084
# 102.0
# 3155.1171758025885
# 56.170429727772145
# -0.18254171887891635
# -1.3818290336389238
# 7.45583464817577
# 429.86151960784315
# 0.01440376253950189
# 0.131266360955494
# 0.9317856939162867
# 0.002321008922243898
# 0.006556905743489469
# Image number:  395
# Calculating Statistical features for Red Channel:
# 145.7308349609375
# 10.562819255992485
# 168.0
# 4648.671110972762
# 68.18116390157007
# -0.7236505723095366
# -0.8580478781710017
# 7.602310212593033
# 309.882368259804
# 0.022085891106961526
# 0.2598108706856319
# 0.9667665747435569
# 0.003216879275731809
# 0.004728405505002709
# Calculating Statistical Features for Green Channel:
# 140.5101776123047
# 10.53310516045905
# 162.0
# 4629.23472917988
# 68.03847976828906
# -0.7179113045257738
# -0.8527803328168075
# 7.572906203549927
# 309.87824754901965
# 0.02193253011229179
# 0.2593336489020356
# 0.9666234133559103
# 0.003216920331630311
# 0.004728345286555127
# Calculating Statistical Features for Blue Channel:
# 136.3037872314453
# 10.452857135254412
# 167.0
# 6362.055433654925
# 79.76249390318061
# -0.47900543971090886
# -1.3099849886155852
# 7.650384199556731
# 304.30361519607845
# 0.022486242403177464
# 0.2566989527444229
# 0.9761367078190328
# 0.003275669227991307
# 0.0046432901226250494
# Image number:  396
# Calculating Statistical features for Red Channel:
# 170.1273193359375
# 10.404503478155656
# 167.0
# 940.7887519448996
# 30.67227986219641
# 0.08676398531128944
# -0.7451372831822134
# 6.920163346332597
# 98.01447610294117
# 0.019511361702206662
# 0.18814227110637113
# 0.9479423853925154
# 0.010101523876632318
# 0.0014953897799723644
# Calculating Statistical Features for Green Channel:
# 176.6912078857422
# 10.607482831313071
# 178.0
# 718.0638728940394
# 26.796713845060168
# -0.3421689160443244
# -0.20768608457682003
# 6.757870975793732
# 99.46784620098042
# 0.021826351098072804
# 0.1930695256510372
# 0.9308086386402068
# 0.009955596065374325
# 0.0015175516851803506
# Calculating Statistical Features for Blue Channel:
# 132.56631469726562
# 10.556748850335623
# 133.0
# 2403.6249663745984
# 49.02677805418788
# 0.11222966511979687
# -1.1807913806108659
# 7.44484804332395
# 102.88719362745098
# 0.01625556851067498
# 0.18033054188355976
# 0.9785899077436582
# 0.009627331943729651
# 0.0015697650884101595
# Image number:  397
# Calculating Statistical features for Red Channel:
# 136.1082000732422
# 10.071902603078449
# 141.0
# 1649.2003136181738
# 40.61034737130642
# -0.8880922090526485
# 1.2362349027803257
# 7.235152940291849
# 898.8067401960784
# 0.0109732280194814
# 0.06162337443474059
# 0.7280825293078097
# 0.0011113633078866196
# 0.013714698402985202
# Calculating Statistical Features for Green Channel:
# 129.0299072265625
# 9.811770661091675
# 133.0
# 1260.1046658605337
# 35.4979529812711
# -1.0378545039394191
# 2.293167514307471
# 7.0084479295700985
# 900.1107996323532
# 0.012055302377524295
# 0.06190037470563756
# 0.6435965923070701
# 0.001109756290631127
# 0.013734592475403087
# Calculating Statistical Features for Blue Channel:
# 120.52578735351562
# 10.01757184179224
# 131.0
# 2244.632422170602
# 47.377551880300885
# -0.6924506381116184
# -0.03154220348670078
# 7.430000944841996
# 898.0696231617646
# 0.010444271201761189
# 0.06291361621075796
# 0.8003777203760872
# 0.00111227383411401
# 0.013703444969193328
# Image number:  398
# Calculating Statistical features for Red Channel:
# 98.08139038085938
# 10.070171583090858
# 99.0
# 1280.6406229203567
# 35.78603949755207
# -0.10050384265719937
# -0.8296393108420479
# 7.138684545825266
# 451.8520680147058
# 0.01432634861106148
# 0.12083461861453605
# 0.8236141369005517
# 0.0022082965000239795
# 0.00689445480214119
# Calculating Statistical Features for Green Channel:
# 112.3504638671875
# 9.778811409772183
# 115.0
# 829.3538901656866
# 28.798504998796147
# -0.44275638871225753
# 0.7993411744751584
# 6.845490128032465
# 454.683394607843
# 0.016527045589726088
# 0.12217210899890328
# 0.726294008895272
# 0.002194585718619052
# 0.006937718633741358
# Calculating Statistical Features for Blue Channel:
# 104.78762817382812
# 10.470608218943605
# 105.0
# 2155.8077119281515
# 46.43067641040944
# -0.097444937953016
# -1.1253889811200384
# 7.4036118460335185
# 445.5092984068629
# 0.013281170491315034
# 0.12107012059181557
# 0.8966905555550282
# 0.0022396616350344903
# 0.006797768638187483
# Image number:  399

# %%
#change the specific channels to csv data
import pandas as pd
#Convert red channel
red_file = pd.read_excel('RedChannel100.xlsx')
red_file.to_csv('RedData100.csv')

#Convert green channel
green_file = pd.read_excel('GreenChannel100.xlsx')
green_file.to_csv('GreenData100.csv')

#Convert blue channel
blue_file = pd.read_excel('BlueChannel100.xlsx')
blue_file.to_csv('BlueData100.csv')

# %%
#change the main file which contains features of all the three channels into csv
file = pd.read_excel('Output100.xlsx')
file.to_csv('Output100.csv')

# %% [markdown]
# # SVM

# %% [markdown]
# ## Apply SVM on Red Channel

# %%
# #read the data
# redData = pd.read_csv('RedData.csv')
# labelled = pd.read_csv('Labels1.csv')

# #classify data into dependent and indepedent variables
# redX = redData.iloc[:, :]
# redY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# redx_train, redx_test, redy_train, redy_test = train_test_split(redX, redY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# redSVC = SVC()

# #fit the model
# redSVC.fit(redx_train, redy_train)
# pred_r = redSVC.predict(redx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(redy_test, pred_r))

# %% [markdown]
# ## Apply SVM on Green Channel

# %%
# #read the data
# greenData = pd.read_csv('GreenData.csv')

# #classify data into dependent and indepedent variables
# greenX = greenData.iloc[:, :]
# greenY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# greenx_train, greenx_test, greeny_train, greeny_test = train_test_split(greenX, greenY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# greenSVC = SVC()

# #fit the model
# greenSVC.fit(greenx_train, greeny_train)
# pred_g = greenSVC.predict(greenx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for green Channel is ", accuracy_score(greeny_test, pred_g))

# %% [markdown]
# ## Apply SVM on Blue Channel

# %%
# #read the data
# blueData = pd.read_csv('BlueData.csv')

# #classify data into dependent and indepedent variables
# blueX = blueData.iloc[:, :]
# blueY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# bluex_train, bluex_test, bluey_train, bluey_test = train_test_split(blueX, blueY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# blueSVC = SVC()

# #fit the model
# blueSVC.fit(bluex_train, bluey_train)
# pred_b = blueSVC.predict(bluex_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(bluey_test, pred_b))

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Apply Random Forest on red channel

# %%
# #read the data
# RedData = pd.read_csv('RedData.csv')
# labelled = pd.read_csv('Labels1.csv')

# #classify data into dependent and indepedent variables
# RedX = RedData.iloc[:, :]
# RedY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Redx_train, Redx_test, Redy_train, Redy_test = train_test_split(RedX, RedY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# RedRF = RandomForestClassifier()

# #fit the model
# RedRF.fit(Redx_train, Redy_train)
# pred_R = RedRF.predict(Redx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(Redy_test, pred_R))

# %% [markdown]
# ## Apply Random Forest on green channel

# %%
# #read the data
# GreenData = pd.read_csv('GreenData.csv')

# #classify data into dependent and indepedent variables
# GreenX = GreenData.iloc[:, :]
# GreenY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Greenx_train, Greenx_test, Greeny_train, Greeny_test = train_test_split(GreenX, GreenY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# GreenRF = RandomForestClassifier()

# #fit the model
# GreenRF.fit(Greenx_train, Greeny_train)
# pred_G = GreenRF.predict(Greenx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for green Channel is ", accuracy_score(Greeny_test, pred_G))

# %% [markdown]
# ## Apply Random Forest on blue channel

# %%
# #read the data
# BlueData = pd.read_csv('BlueData.csv')

# #classify data into dependent and indepedent variables
# BlueX = BlueData.iloc[:, :]
# BlueY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Bluex_train, Bluex_test, Bluey_train, Bluey_test = train_test_split(BlueX, BlueY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# BlueRF = RandomForestClassifier()

# #fit the model
# BlueRF.fit(Bluex_train, Bluey_train)
# pred_B = BlueRF.predict(Bluex_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(Bluey_test, pred_B))
