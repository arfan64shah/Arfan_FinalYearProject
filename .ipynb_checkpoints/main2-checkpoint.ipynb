# %%
#import the required libraries
import skimage.feature as skf
import openpyxl
import numpy as np
import math
from PIL import Image
from numpy import asarray
from scipy.stats import skew, kurtosis
import skimage.feature
import xlsxwriter
import os


#creates general file for features of all the three channels
outWorkbook = xlsxwriter.Workbook("Output.xlsx")
outSheet = outWorkbook.add_worksheet()

#Writes headers for general file 
outSheet.write("A1", "Mean_R")
outSheet.write("B1", "RMS_R")
outSheet.write("C1", "Median_R")
outSheet.write("D1", "Variance_R")
outSheet.write("E1", "Std_R")
outSheet.write("F1", "Skewness_R")
outSheet.write("G1", "Kurtosis_R")
outSheet.write("H1", "Contrast_R")
outSheet.write("I1", "Entropy_R")
outSheet.write("J1", "Energy_R")
outSheet.write("K1", "Homogeneity_R")
outSheet.write("L1", "Correlation_R")
outSheet.write("M1", "IDM_R")
outSheet.write("N1", "Smoothness_R")
outSheet.write("O1", "Mean_G")
outSheet.write("P1", "RMS_G")
outSheet.write("Q1", "Median_G")
outSheet.write("R1", "Variance_G")
outSheet.write("S1", "Std_G")
outSheet.write("T1", "Skewness_G")
outSheet.write("U1", "Kurtosis_G")
outSheet.write("V1", "Contrast_G")
outSheet.write("W1", "Entropy_G")
outSheet.write("X1", "Energy_G")
outSheet.write("Y1", "Homogeneity_G")
outSheet.write("Z1", "Correlation_G")
outSheet.write("AA1", "IDM_G")
outSheet.write("AB1", "Smoothness_G")
outSheet.write("AC1", "Mean_B")
outSheet.write("AD1", "RMS_B")
outSheet.write("AE1", "Median_B")
outSheet.write("AF1", "Variance_B")
outSheet.write("AG1", "Std_B")
outSheet.write("AH1", "Skewness_B")
outSheet.write("AI1", "Kurtosis_B")
outSheet.write("AJ1", "Contrast_B")
outSheet.write("AK1", "Entropy_B")
outSheet.write("AL1", "Energy_B")
outSheet.write("AM1", "Homogeneity_B")
outSheet.write("AN1", "Correlation_B")
outSheet.write("AO1", "IDM_B")
outSheet.write("AP1", "Smoothness_B")
outWorkbook.close()

# %%
#creates a file for red channel
outWorkbookR = xlsxwriter.Workbook("RedChannel.xlsx")
outSheetR = outWorkbookR.add_worksheet()

#writes headers for red file
outSheetR.write("A1", "Mean_R")
outSheetR.write("B1", "RMS_R")
outSheetR.write("C1", "Median_R")
outSheetR.write("D1", "Variance_R")
outSheetR.write("E1", "Std_R")
outSheetR.write("F1", "Skewness_R")
outSheetR.write("G1", "Kurtosis_R")
outSheetR.write("H1", "Contrast_R")
outSheetR.write("I1", "Entropy_R")
outSheetR.write("J1", "Energy_R")
outSheetR.write("K1", "Homogeneity_R")
outSheetR.write("L1", "Correlation_R")
outSheetR.write("M1", "IDM_R")
outSheetR.write("N1", "Smoothness_R")
outWorkbookR.close()

# %%
#creates file for green channel
outWorkbookG = xlsxwriter.Workbook("GreenChannel.xlsx")
outSheetG = outWorkbookG.add_worksheet()

#writes headers for green file
outSheetG.write("A1", "Mean_G")
outSheetG.write("B1", "RMS_G")
outSheetG.write("C1", "Median_G")
outSheetG.write("D1", "Variance_G")
outSheetG.write("E1", "Std_G")
outSheetG.write("F1", "Skewness_G")
outSheetG.write("G1", "Kurtosis_G")
outSheetG.write("H1", "Contrast_G")
outSheetG.write("I1", "Entropy_G")
outSheetG.write("J1", "Energy_G")
outSheetG.write("K1", "Homogeneity_G")
outSheetG.write("L1", "Correlation_G")
outSheetG.write("M1", "IDM_G")
outSheetG.write("N1", "Smoothness_G")
outWorkbookG.close()

# %%
#creates a file for blue channel
outWorkbookB = xlsxwriter.Workbook("BlueChannel.xlsx")
outSheetB = outWorkbookB.add_worksheet()

#writes headers for blue file
outSheetB.write("A1", "Mean_B")
outSheetB.write("B1", "RMS_B")
outSheetB.write("C1", "Median_B")
outSheetB.write("D1", "Variance_B")
outSheetB.write("E1", "Std_B")
outSheetB.write("F1", "Skewness_B")
outSheetB.write("G1", "Kurtosis_B")
outSheetB.write("H1", "Contrast_B")
outSheetB.write("I1", "Entropy_B")
outSheetB.write("J1", "Energy_B")
outSheetB.write("K1", "Homogeneity_B")
outSheetB.write("L1", "Correlation_B")
outSheetB.write("M1", "IDM_B")
outSheetB.write("N1", "Smoothness_B")
outWorkbookB.close()

# %%
#import required libaray to read and make a list of all the needy images
import glob

#declare an empty list
Image_list = []

#using for loop to append to the list declared above
for filename in glob.glob('/home/uca/Desktop/Undergrad/Arfan_FinalYearProject/data1/*.*'):
    im = Image.open(filename)
    
    #append each image to the list declared above
    Image_list.append(im)
    
#prints number of images used
print(len(Image_list))
# Out:
# 300

# %%
#uses for loop to read each image and array of each image
for i in range(0, len(Image_list)):
    Image = Image_list[i]
    image = asarray(Image)
    
    #Apply image enhancement 
#     #apply image inverse
#     # Invert the colors
#     image = 255 - image

    # Apply contrast stretching for image enhancement
    min_val = np.min(image)
    max_val = np.max(image)
    image = (image - min_val) / (max_val - min_val)
    
    
    
    #Here i am extracting the single channel like red, green, and blue from the whole image array
    R = image[:, :, 0]
    G = image[:, :, 1]
    B = image[:, :, 2]


    #selecting features from Red Channel
    print("Calculating Statistical features for Red Channel: ")
    
    #calculates mean
    Mean_R = np.mean(R);
    print(Mean_R)
    
    #calculating root mean square
    RMS_R = np.sqrt(np.mean(R**2))
    print(RMS_R)
    
    #calculating median
    Median_R = np.median(R)
    print(Median_R)
    
    #calculating variance of the pixels
    Variance_R = np.var(R)
    print(Variance_R)
    
    #calculating standard deviation
    Std_R = math.sqrt(Variance_R)
    print(Std_R)
    
    #calculates skewness
    Skewness_R = skew(R.reshape(-1))
    print(Skewness_R)
    
    #calculates kurtosis
    Kurtosis_R = kurtosis(R.reshape(-1))
    print(Kurtosis_R)
    
    #calculates entropy
    Entropy_R = skimage.measure.shannon_entropy(R)
    print(Entropy_R)
    
    #returns an image array where lowest pixel value is 0 and highest 8 instead of 0 and 255
    R = skimage.img_as_ubyte(R)
    
    #calculates contrast
    g1 = skf.graycomatrix(R, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_R = skf.graycoprops(g1, 'contrast')[0][0]
    print(Contrast_R)
    
    #calculates energy
    Energy_R = skf.graycoprops(g1, 'energy')[0][0]
    print(Energy_R)
    
    #calculating homogeniety
    Homogeneity_R = skf.graycoprops(g1, 'homogeneity')[0][0]
    print(Homogeneity_R)
    
    #finding correlation
    Correlation_R = skf.graycoprops(g1, 'correlation')[0][0]
    print(Correlation_R)
    
    #glcm_R = skf.graycomatrix(R, distances=[1], angles=[0], levels=256, symmetric= False, normed=True)
    
    #calculate inverse difference moment (IDM)
    IDM_R = 1 / (1 + Contrast_R - Energy_R)
    print(IDM_R)
    
    #calculates smoothness
    diff_R = np.diff(R.astype(float))
    variance_R = np.var(diff_R)
    Smoothness_R = variance_R / (R.shape[0] * R.shape[1])
    print(Smoothness_R)
    

    #selecting features from Green Channel
    print("Calculating Statistical Features for Green Channel: ")
    
    #calculates mean
    Mean_G = np.mean(G);
    print(Mean_G)
    
    #calculates root mean square
    RMS_G = np.sqrt(np.mean(G**2))
    print(RMS_G)
    
    #calculates median
    Median_G = np.median(G)
    print(Median_G)
    
    #claculates variance
    Variance_G = np.var(G)
    print(Variance_G)
    
    #calculates standard deviation
    Std_G = math.sqrt(Variance_G)
    print(Std_G)
    
    #calculates skewness
    Skewness_G = skew(G.reshape(-1))
    print(Skewness_G)
    
    #calculates kurtosis
    Kurtosis_G = kurtosis(G.reshape(-1))
    print(Kurtosis_G)
    
    #calculates entropy
    Entropy_G = skimage.measure.shannon_entropy(G)
    print(Entropy_G)
    
    #converts images pixels to range of 0 to 8 instead of 0 to 255
    G = skimage.img_as_ubyte(G)
    
    #calculates contrast
    g2 = skf.graycomatrix(G, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_G = skf.graycoprops(g2, 'contrast')[0][0]
    print(Contrast_G)
    
    #calculates energy
    Energy_G = skf.graycoprops(g2, 'energy')[0][0]
    print(Energy_G)
    
    #calculates homogeniety
    Homogeneity_G = skf.graycoprops(g2, 'homogeneity')[0][0]
    print(Homogeneity_G)
    
    #calculates correlation
    Correlation_G = skf.graycoprops(g2, 'correlation')[0][0]
    print(Correlation_G)
    #glcm_G = skf.graycomatrix(G, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
    
    #calculates inverse difference moment (IDM)
    IDM_G = 1 / (1 + Contrast_G - Energy_G)
    print(IDM_G)
    
    #calculates smoothness
    diff_G = np.diff(G.astype(float))
    variance_G = np.var(diff_G)
    Smoothness_G = variance_G / (G.shape[0] * G.shape[1])
    print(Smoothness_G)

    #selecting features from Blue Channel
    print("Calculating Statistical Features for Blue Channel: ")
    
    #calculates mean
    Mean_B = np.mean(B);
    print(Mean_B)
    
    #calculates root mean square
    RMS_B = np.sqrt(np.mean(B**2))
    print(RMS_B)
    
    #calculates median
    Median_B = np.median(B)
    print(Median_B)
    
    #calculates variance
    Variance_B = np.var(B)
    print(Variance_B)
    
    #calculates standard deviation
    Std_B = math.sqrt(Variance_B)
    print(Std_B)
    
    #calculates skewness
    Skewness_B = skew(B.reshape(-1))
    print(Skewness_B)
    
    #calculates kurtosis
    Kurtosis_B = kurtosis(B.reshape(-1))
    print(Kurtosis_B)
    
    #calculates entropy
    Entropy_B = skimage.measure.shannon_entropy(B)
    print(Entropy_B)
    
    #converts range of pixels values from 0-255 to 0-8
    B = skimage.img_as_ubyte(B)
    
    #calculates contrast
    g3 = skf.graycomatrix(B, [1], [0], levels=256, symmetric=False, normed=True)
    Contrast_B = skf.graycoprops(g3, 'contrast')[0][0]
    print(Contrast_B)
    
    #calculates energy
    Energy_B = skf.graycoprops(g3, 'energy')[0][0]
    print(Energy_B)
    
    #calculates homogeniety
    Homogeneity_B = skf.graycoprops(g3, 'homogeneity')[0][0]
    print(Homogeneity_B)
    
    #calculates correlation
    Correlation_B = skf.graycoprops(g3, 'correlation')[0][0]
    print(Correlation_B)
    
    #glcm_B = skf.graycomatrix(B, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
    
    #calculates inverse difference moment (IDM)
    IDM_B = 1 / (1 + Contrast_B - Energy_B)
    print(IDM_B)
    
    #calculates smoothness
    diff_B = np.diff(B.astype(float))
    variance_B = np.var(diff_B)
    Smoothness_B = variance_B / (B.shape[0] * B.shape[1])
    print(Smoothness_B)
    
    #count the number of images
    print("Image number: ", i)


    #Declares data for all the three channels
    values_R = [Mean_R, RMS_R, Median_R, Variance_R, Std_R, Skewness_R, Kurtosis_R, Entropy_R, Contrast_R, Energy_R, Homogeneity_R, Correlation_R, IDM_R, Smoothness_R]
    values_G = [Mean_G, RMS_G, Median_G, Variance_G, Std_G, Skewness_G, Kurtosis_G, Entropy_G, Contrast_G, Energy_G, Homogeneity_G, Correlation_G, IDM_G, Smoothness_G]
    values_B = [Mean_B, RMS_B, Median_B, Variance_B, Std_B, Skewness_B, Kurtosis_B, Entropy_B, Contrast_B, Energy_B, Homogeneity_B, Correlation_B, IDM_B, Smoothness_B]

    #Writes red channels into a file
    outWorkbookR = openpyxl.load_workbook("RedChannel.xlsx")
    outSheetR = outWorkbookR.active
    outSheetR.append(values_R)
    outWorkbookR.save(filename="RedChannel.xlsx")

    #Writes green channels into a file
    outWorkbookG = openpyxl.load_workbook("GreenChannel.xlsx")
    outSheetG = outWorkbookG.active
    outSheetG.append(values_G)
    outWorkbookG.save(filename="GreenChannel.xlsx")

    #writes blue chanels into a file
    outWorkbookB = openpyxl.load_workbook("BlueChannel.xlsx")
    outSheetB = outWorkbookB.active
    outSheetB.append(values_B)
    outWorkbookB.save(filename="BlueChannel.xlsx")
    
    #creates a general fle where all the three channels data will be merged
    outWorkbook = xlsxwriter.Workbook("Output.xlsx")
    outSheet = outWorkbook.add_worksheet()
        
    #declares data for general file
    values = [Mean_R, RMS_R, Median_R, Variance_R, Std_R, Skewness_R, Kurtosis_R, Entropy_R, Contrast_R, Energy_R, Homogeneity_R, Correlation_R, IDM_R, Smoothness_R, Mean_G, RMS_G, Median_R, Variance_G, Std_G, Skewness_G, Kurtosis_G, Entropy_G, Contrast_G, Energy_G, Homogeneity_G, Correlation_G, IDM_G, Smoothness_G, Mean_B, RMS_B, Median_R, Variance_B, Std_B, Skewness_B, Kurtosis_B, Entropy_B, Contrast_B, Energy_B, Homogeneity_B, Correlation_B, IDM_B, Smoothness_B]
    
     
    #writes into the general file
    outWorkbook = openpyxl.load_workbook("Output.xlsx") 
    outSheet = outWorkbook.active
    outSheet.append(values)
    
    #here the general file is being saved
    outWorkbook.save(filename="Output.xlsx")
# Out:
# Calculating Statistical features for Red Channel:
# 0.506446928136489
# 0.5387098500982026
# 0.5294117647058824
# 0.033719811573941855
# 0.18362954983864077
# -0.47131629637956063
# 0.045042336343078304
# 7.462802773240141
# 840.6794424019608
# 0.010674544578893828
# 0.06640493393896678
# 0.8085263267147845
# 0.0011881158457924944
# 0.012827307679051277
# Calculating Statistical Features for Green Channel:
# 0.49573693368949145
# 0.5258395760885811
# 0.5019607843137255
# 0.030752152357159508
# 0.17536291614009933
# -0.4586023226862098
# 0.3206539497972263
# 7.39672433040854
# 841.5121476715686
# 0.010913293812039641
# 0.0675521518684684
# 0.7898941145433732
# 0.0011869418811458084
# 0.01283994408976394
# Calculating Statistical Features for Blue Channel:
# 0.4298431396484375
# 0.4769521751339445
# 0.4666666666666667
# 0.042718252662174695
# 0.20668394389060485
# -0.29869935493052685
# -0.5286577230480627
# 7.575893392077435
# 828.4843903186273
# 0.011287905644787977
# 0.07084914432101044
# 0.8509681817418654
# 0.001205584601949051
# 0.0126411209218469
# Image number:  0
# Calculating Statistical features for Red Channel:
# 0.5601259717754289
# 0.5775182165396769
# 0.5803921568627451
# 0.019786186177800567
# 0.14066337895060166
# -1.3946363720662127
# 3.0941936766025204
# 6.92582097268021
# 844.8405330882355
# 0.013029102766229678
# 0.05854030413322417
# 0.6723772500089913
# 0.0011822741578963593
# 0.012891169357794217
# Calculating Statistical Features for Green Channel:
# 0.5235053567325368
# 0.5430404160912025
# 0.5411764705882353
# 0.020835034980845768
# 0.14434346185693958
# -1.2331298545416893
# 2.372880618961508
# 7.0168190196808355
# 846.4646446078434
# 0.01203654267575435
# 0.05858996553292083
# 0.6883406915433656
# 0.0011800069885714503
# 0.01291595956261217
# Calculating Statistical Features for Blue Channel:
# 0.43231614056755513
# 0.4738939498786776
# 0.48627450980392156
# 0.03767823033638854
# 0.19410881055837867
# -0.42162485324416105
# -0.751318036416956
# 7.454337071959962
# 830.9713848039218
# 0.011768275697929985
# 0.06350054242930456
# 0.8306198855451331
# 0.001201981418488809
# 0.012679581458579
# Image number:  1
# Calculating Statistical features for Red Channel:
# 0.5080929026884191
# 0.535066136566947
# 0.5372549019607843
# 0.02813737273833548
# 0.16774198263504422
# -0.6844910852995458
# 0.28204842676674335
# 7.344414849514326
# 1102.9429227941177
# 0.009797983802379727
# 0.04487487840909713
# 0.6992516412613111
# 0.0009058519737523287
# 0.01682954772772616
# Calculating Statistical Features for Green Channel:
# 0.4990589815027573
# 0.5186590541883673
# 0.5098039215686274
# 0.019947347473002246
# 0.14123507876233243
# -0.6047149354561403
# 0.9868495202783198
# 7.130502807895366
# 1102.5441942401962
# 0.01047556696814152
# 0.04490928151606074
# 0.5759318551108371
# 0.0009061798321869983
# 0.01682345700181694
# Calculating Statistical Features for Blue Channel:
# 0.4890424541398591
# 0.52934228356658
# 0.5333333333333333
# 0.04104073122034536
# 0.20258512092536649
# -0.6471858837229126
# -0.26082665267980865
# 7.536180518590864
# 1099.291835171569
# 0.009446762935377813
# 0.0472297563317322
# 0.7944726218972304
# 0.0009088575901376786
# 0.016773816211913917
# Image number:  2
# Calculating Statistical features for Red Channel:
# 0.5414843989353553
# 0.5663219701495615
# 0.5647058823529412
# 0.02751521958369777
# 0.165877121941809
# -1.1419658827967305
# 1.2589400630039584
# 7.085798648790948
# 572.447181372549
# 0.014553163692177615
# 0.10188017177948244
# 0.8399378214567922
# 0.0017438840254408716
# 0.008734349006402383
# Calculating Statistical Features for Green Channel:
# 0.5082672119140624
# 0.5344920762657361
# 0.5372549019607843
# 0.027346220883962963
# 0.1653669280236014
# -1.1727576377794258
# 1.192276531186221
# 7.062312054098127
# 572.820419730392
# 0.01454735776701356
# 0.10301365458227313
# 0.8388521968647333
# 0.0017427496791991837
# 0.00874005622138806
# Calculating Statistical Features for Blue Channel:
# 0.34083042518765316
# 0.39693923128002007
# 0.2823529411764706
# 0.04139537459557682
# 0.2034585328649964
# 0.21411141818565277
# -1.1662211009830696
# 7.435953148869403
# 565.7875765931371
# 0.013981921438363328
# 0.10404721150665455
# 0.8947472586582648
# 0.0017643729513885447
# 0.008632527163699097
# Image number:  3
# Calculating Statistical features for Red Channel:
# 0.5924559948491117
# 0.6194025693317594
# 0.6274509803921569
# 0.032655437062134605
# 0.18070815438749466
# -1.0248128278109503
# 0.6102556432233777
# 7.303880325533995
# 604.2432444852943
# 0.017877632371006476
# 0.15149509016789517
# 0.8580817701735522
# 0.0016522770768843391
# 0.009219879040584793
# Calculating Statistical Features for Green Channel:
# 0.5945360370710785
# 0.6187222523799087
# 0.6235294117647059
# 0.029344126213884773
# 0.17130127324069944
# -1.1162386983121955
# 1.1357941146459938
# 7.226986676063594
# 604.7030330882354
# 0.01822937263024196
# 0.15117349785893383
# 0.8419483543691071
# 0.0016510237566890362
# 0.009226826041269445
# Calculating Statistical Features for Blue Channel:
# 0.5267334582758885
# 0.580028779414628
# 0.5686274509803921
# 0.058985248881946103
# 0.24286878943566648
# -0.3860867591297003
# -0.9921251398728383
# 7.675356928355379
# 604.8604166666667
# 0.016679544544523833
# 0.1485548866294219
# 0.9212388936559259
# 0.0016505906370348868
# 0.009229177224397178
# Image number:  4
# Calculating Statistical features for Red Channel:
# 0.550792080748315
# 0.5794720071876429
# 0.5647058823529412
# 0.03241589089901742
# 0.180044135975092
# -0.8218064538134185
# 0.3637624938604498
# 7.349011056583155
# 592.7416207107844
# 0.012429666845388538
# 0.09201926266356074
# 0.859669169597819
# 0.0016842695543429914
# 0.00904435051178652
# Calculating Statistical Features for Green Channel:
# 0.5399004169538909
# 0.5651005865646086
# 0.5450980392156862
# 0.02784621270867949
# 0.16687184516472361
# -0.7462077692431848
# 0.554441437648169
# 7.254565561700843
# 592.7123468137254
# 0.01263497998798038
# 0.0923105415755043
# 0.8366143394236231
# 0.0016843531840555195
# 0.009043888803707526
# Calculating Statistical Features for Blue Channel:
# 0.5108810125612745
# 0.5488507350357552
# 0.5254901960784314
# 0.04023772035365561
# 0.20059342051437182
# -0.7295569646060721
# -0.08442971169386038
# 7.458254801149158
# 592.6002144607845
# 0.012158899396030043
# 0.0933013561556656
# 0.8869762914494788
# 0.0016846700175835675
# 0.009042211318648533
# Image number:  5
# Calculating Statistical features for Red Channel:
# 0.49709329044117645
# 0.5237291285546064
# 0.5411764705882353
# 0.027190460694931598
# 0.16489530222214216
# -1.0341619489466745
# 0.5712596686889877
# 7.15307515556945
# 500.56315870098035
# 0.016911639825306187
# 0.14543885516501695
# 0.858692914624816
# 0.0019938340798272727
# 0.007637783708229879
# Calculating Statistical Features for Green Channel:
# 0.4944726682176777
# 0.5134475289476458
# 0.5137254901960784
# 0.019125145368134082
# 0.13829369243799255
# -1.2482764748217228
# 2.1875969363702428
# 6.913317765375234
# 499.57098651960786
# 0.017991008949084966
# 0.1462365282685066
# 0.7995454367557489
# 0.0019977904616869002
# 0.007622580021356263
# Calculating Statistical Features for Blue Channel:
# 0.4677150950712316
# 0.5098757568657303
# 0.5372549019607843
# 0.04121587728191008
# 0.20301693841133078
# -0.8877822217189699
# -0.2385300650333475
# 7.311122264413923
# 499.22287071078426
# 0.018561423548750074
# 0.15061498789784242
# 0.9070151882863146
# 0.001999183096652939
# 0.007617287127578955
# Image number:  6
# Calculating Statistical features for Red Channel:
# 0.5438762464021382
# 0.553126626234762
# 0.543859649122807
# 0.010147693249370895
# 0.10073575953637762
# 0.3641192548369109
# 0.1658065987664763
# 6.505617722748265
# 143.30150122549017
# 0.02343713955893546
# 0.1756740765177531
# 0.8916039428980582
# 0.0069310605623624484
# 0.002186500087039533
# Calculating Statistical Features for Green Channel:
# 0.5058415730794271
# 0.517388942512786
# 0.4956140350877193
# 0.011815620779029586
# 0.10869968159580591
# 0.8238086441184754
# 0.8184050611066076
# 6.549228869835122
# 144.83693321078437
# 0.023927774534781374
# 0.17590557255430386
# 0.9059831496683071
# 0.006858098816413236
# 0.0022099254822543963
# Calculating Statistical Features for Blue Channel:
# 0.48331792731034123
# 0.49429208506432515
# 0.49122807017543857
# 0.010728446497673735
# 0.10357821439701369
# -0.6957138177921095
# 0.7513564953071108
# 6.516835399840567
# 141.59981617647057
# 0.023842812519204448
# 0.17559869399768432
# 0.8987397155765228
# 0.007013804474946955
# 0.002160524409844389
# Image number:  7
# Calculating Statistical features for Red Channel:
# 0.40608436734068626
# 0.4361377959889415
# 0.40784313725490196
# 0.02531166369160612
# 0.15909639748154614
# -0.1483174910190531
# -0.43698337028120937
# 7.3491545217703855
# 638.7619025735295
# 0.010544135201863673
# 0.0656294324691785
# 0.8062022214853349
# 0.0015631072709889377
# 0.009746511528284211
# Calculating Statistical Features for Green Channel:
# 0.4168880088656556
# 0.4391535218107548
# 0.41568627450980394
# 0.019060203782818072
# 0.13805869687498165
# -0.08940294276665205
# -0.23598708165160476
# 7.158574910406904
# 643.2197150735295
# 0.011193819074736789
# 0.06490702513405995
# 0.7408728625866412
# 0.0015522924131036319
# 0.00981450852998867
# Calculating Statistical Features for Blue Channel:
# 0.42155654009650734
# 0.4553517741438157
# 0.4235294117647059
# 0.02963532171778235
# 0.17214912639273644
# -0.14222057920533004
# -0.4763443635732263
# 7.4556746519134744
# 639.7174325980393
# 0.010165545516194419
# 0.0654383364034082
# 0.8342181041067811
# 0.0015607751799044652
# 0.009761061195179575
# Image number:  8
# Calculating Statistical features for Red Channel:
# 0.4828883152382047
# 0.5078478080932673
# 0.47843137254901963
# 0.024728271191544412
# 0.15725225337509288
# -0.26896306393346
# 0.5611935204998244
# 7.306792452685015
# 1380.8704503676474
# 0.00979903753958673
# 0.04317859480120035
# 0.5708238662215863
# 0.0007236619691265191
# 0.02107040283611773
# Calculating Statistical Features for Green Channel:
# 0.493421906115962
# 0.51637340053951
# 0.49019607843137253
# 0.023176311349628012
# 0.1522376804527316
# -0.21506168468510573
# 0.5841116893155269
# 7.268773314294593
# 1381.5394148284315
# 0.009724517599909107
# 0.0428072160419723
# 0.5418910088645547
# 0.0007233117718977678
# 0.021080603945347946
# Calculating Statistical Features for Blue Channel:
# 0.5025583902994791
# 0.5329180729888574
# 0.5019607843137255
# 0.031436736857753445
# 0.1773040802061629
# -0.36455606035769017
# 0.4078548129790085
# 7.46147936578936
# 1377.1121629901959
# 0.009349785472505364
# 0.0437369561388119
# 0.663329781796615
# 0.000725635264958599
# 0.021013047520525293
# Image number:  9
# Calculating Statistical features for Red Channel:
# 0.4055813489207234
# 0.4537354979915122
# 0.4103585657370518
# 0.041379671545252045
# 0.20341993890779744
# -0.08091392590243747
# -1.2524590320755338
# 7.508225819747867
# 607.4640165441176
# 0.01034212715626943
# 0.07640514777104747
# 0.8872476136794548
# 0.0016435104956153484
# 0.009268499213893515
# Calculating Statistical Features for Green Channel:
# 0.4265919719559263
# 0.4551354727498043
# 0.44223107569721115
# 0.025167588017942055
# 0.15864295766891784
# -0.28208622629041863
# -0.8399038505260861
# 7.2616362323862775
# 606.0366268382353
# 0.011054637377099604
# 0.07655980471791936
# 0.8146205788398097
# 0.001647377055919336
# 0.009246743936625175
# Calculating Statistical Features for Blue Channel:
# 0.35831740177960025
# 0.4058030229042294
# 0.36254980079681276
# 0.036284732980127035
# 0.19048551908249362
# -0.07672172849916381
# -1.221547614834091
# 7.415186662827509
# 604.8009497549019
# 0.010708498544630508
# 0.0770729398801627
# 0.8717515766857723
# 0.0016507363966875488
# 0.009227952778737551
# Image number:  10
# Calculating Statistical features for Red Channel:
# 0.48459915460324754
# 0.5152416164500007
# 0.49411764705882355
# 0.030637582679827344
# 0.17503594682186668
# -0.27888105180219613
# 0.010543446258350464
# 7.445325916820694
# 2210.9576286764714
# 0.009221661046876295
# 0.041643931739689985
# 0.44571903613387803
# 0.00045209011061397093
# 0.03373643443658691
# Calculating Statistical Features for Green Channel:
# 0.47258432425704655
# 0.5044546427585996
# 0.4823529411764706
# 0.031138543067217125
# 0.1764611658898839
# -0.2828237482969442
# 0.11162721486360372
# 7.4369999602773325
# 2212.588541666666
# 0.009240929474327794
# 0.04155027484601793
# 0.4543346628651441
# 0.0004517570252246976
# 0.03376129121218494
# Calculating Statistical Features for Blue Channel:
# 0.4566412233838848
# 0.493163540265677
# 0.47058823529411764
# 0.03468907055384503
# 0.18625002162105922
# -0.275533111713179
# -0.12745434275397427
# 7.529555243331948
# 2211.1850490196084
# 0.008515724064841452
# 0.03973015946849956
# 0.5103184433968952
# 0.0004520434897256011
# 0.03373987647758131
# Image number:  11
# Calculating Statistical features for Red Channel:
# 0.5322906494140625
# 0.5735478095748904
# 0.5764705882352941
# 0.04562375441451028
# 0.21359717791794508
# -0.39246080340676304
# -0.7376780137890386
# 7.662302093172466
# 1146.3076746323532
# 0.0088750791945392
# 0.0563004242029845
# 0.8070273922917492
# 0.0008716125218552242
# 0.017491073099200238
# Calculating Statistical Features for Green Channel:
# 0.5376603070427389
# 0.5669518527839283
# 0.5647058823529412
# 0.03235579760583681
# 0.17987717366535647
# -0.7792810338779673
# 0.5661875331958988
# 7.391318343167921
# 1147.044561887255
# 0.009864315931691415
# 0.05670569221071127
# 0.7278497628658855
# 0.0008710538123242339
# 0.01750225818518339
# Calculating Statistical Features for Blue Channel:
# 0.42481126972273275
# 0.4923776674077146
# 0.40784313725490196
# 0.06197115247842154
# 0.24894005800276808
# 0.04616571990321581
# -1.2831124142486308
# 7.745897632659094
# 1144.0283394607843
# 0.009604400714146756
# 0.058127680370851795
# 0.8580670131431076
# 0.0008733481552575101
# 0.017456199782744757
# Image number:  12
# Calculating Statistical features for Red Channel:
# 0.5162482168160232
# 0.5397218057599694
# 0.5333333333333333
# 0.02478740624707838
# 0.1574401671971876
# -0.4695929563347688
# 0.06525588746624722
# 7.3262411233331335
# 1262.3162990196076
# 0.009148953260808279
# 0.0391331610278059
# 0.6091626102111605
# 0.0007915731340137524
# 0.019261404099383296
# Calculating Statistical Features for Green Channel:
# 0.506451056985294
# 0.5279276391534103
# 0.5137254901960784
# 0.022214919060571794
# 0.14904670093823544
# -0.2590207070849574
# 0.4038480390239112
# 7.266452029070702
# 1261.2551164215688
# 0.009440873950686905
# 0.03853643131081654
# 0.5642691073373954
# 0.0007922388005537478
# 0.019245214430598834
# Calculating Statistical Features for Blue Channel:
# 0.45093671013327197
# 0.49056499215498256
# 0.48627450980392156
# 0.037310094982199435
# 0.19315821230845825
# -0.522503709528631
# -0.4869412923752203
# 7.511560236406934
# 1254.3522824754903
# 0.008777640364355618
# 0.040914515511411016
# 0.7419795479988743
# 0.0007965947138359853
# 0.019139893271830345
# Image number:  13
# Calculating Statistical features for Red Channel:
# 0.5677484848920037
# 0.6085811314443061
# 0.5764705882352941
# 0.0480326514528661
# 0.21916352673943285
# -0.21504552033392543
# -0.9744198664665795
# 7.681282607037258
# 893.8368106617647
# 0.011740426335291656
# 0.09942096285708103
# 0.8568176576500592
# 0.0011175368608491254
# 0.013637007789676294
# Calculating Statistical Features for Green Channel:
# 0.5329583261527266
# 0.5730444271818306
# 0.5568627450980392
# 0.044335338108636144
# 0.21055958327427451
# -0.4392507230639676
# -0.6590971598560578
# 7.622914416613166
# 889.9863511029414
# 0.01199793784670054
# 0.10021633748397131
# 0.8456433199024372
# 0.0011223667622391183
# 0.013578834014553367
# Calculating Statistical Features for Blue Channel:
# 0.3654628978056066
# 0.44291653634472355
# 0.3176470588235294
# 0.06261192849513554
# 0.25022375685600984
# 0.3365592256023723
# -1.1329129390973127
# 7.588668191992042
# 863.6598805147061
# 0.01714204377962471
# 0.10887804212284853
# 0.893700553170028
# 0.0011565470401896226
# 0.01317580350900269
# Image number:  14
# Calculating Statistical features for Red Channel:
# 0.4462888808477492
# 0.4636682706182307
# 0.4722222222222222
# 0.01581450000976433
# 0.12575571561469615
# -0.0633081420654647
# 0.12831199920316383
# 6.880019659817431
# 49.506755514705866
# 0.028598174874755536
# 0.28440759660799253
# 0.9760064608195816
# 0.019810548813574143
# 0.0007553855266983475
# Calculating Statistical Features for Green Channel:
# 0.48792708866179935
# 0.5012165365846172
# 0.5
# 0.013145172695899467
# 0.11465239943367721
# -0.05782559801246129
# 0.5161368172439982
# 6.7205437138191915
# 49.11738664215687
# 0.03077866415830163
# 0.2858313741482364
# 0.9714105573844629
# 0.019965416712572504
# 0.0007494511316046661
# Calculating Statistical Features for Blue Channel:
# 0.3630723499116444
# 0.39736920772437806
# 0.38492063492063494
# 0.026080755977136404
# 0.16149537447597812
# -0.42373689147740584
# -1.0130740455416607
# 6.923180881436222
# 48.221522671568636
# 0.02901569641308333
# 0.2819138069218708
# 0.9858302119534181
# 0.020328299196156953
# 0.0007357729794346555
# Image number:  15
# Calculating Statistical features for Red Channel:
# 0.4641170726102941
# 0.4994124924078179
# 0.48627450980392156
# 0.03400818048463972
# 0.1844130702652058
# -0.3645846700251617
# -0.19589850112173135
# 7.49467969324481
# 1678.4882199754904
# 0.009868620767150218
# 0.049588005525792005
# 0.6207876557684456
# 0.0005954229771365416
# 0.025611323481540223
# Calculating Statistical Features for Green Channel:
# 0.4863715078316483
# 0.5199579042100525
# 0.5058823529411764
# 0.03379897852007891
# 0.18384498502836272
# -0.5004829926228637
# 0.10127109511967047
# 7.476591985762616
# 1681.5467218137258
# 0.009947747296969388
# 0.04989041160247396
# 0.6178415439342066
# 0.0005943406500311765
# 0.02565789877176743
# Calculating Statistical Features for Blue Channel:
# 0.44526845894607847
# 0.49659668938550217
# 0.47058823529411764
# 0.04834427137642537
# 0.21987330755784198
# -0.25784602303703896
# -0.6401292060936212
# 7.700124341577813
# 1668.8921109068626
# 0.008696124542564044
# 0.0493627968240571
# 0.7346527927508443
# 0.0005988442014260956
# 0.025464780774480965
# Image number:  16
# Calculating Statistical features for Red Channel:
# 0.5596820527473382
# 0.5812780713812122
# 0.5353982300884956
# 0.0246401961011874
# 0.15697195960166707
# 0.10101632941750978
# -0.6367932538497785
# 7.080246469416725
# 41.583685661764704
# 0.03020993351268311
# 0.3463523432264714
# 0.987045806980335
# 0.023499843030121318
# 0.000634088536569765
# Calculating Statistical Features for Green Channel:
# 0.6341747857828055
# 0.6498203373791491
# 0.6371681415929203
# 0.020088811948883893
# 0.1417350060813626
# -0.22040838791514708
# -0.48598821659396796
# 6.9517446455336005
# 41.40425857843138
# 0.031154277173563637
# 0.3514863387024471
# 0.9841787897260889
# 0.023599875829024772
# 0.0006313537451360189
# Calculating Statistical Features for Blue Channel:
# 0.4037801016748479
# 0.47113174093451293
# 0.415929203539823
# 0.05892674680743449
# 0.24274831988591494
# 0.24434078746010748
# -1.104528144621897
# 7.521059724210283
# 38.61449142156862
# 0.025144013950004523
# 0.33824346850510517
# 0.9949689036647507
# 0.025259320132353557
# 0.0005886831886347373
# Image number:  17
# Calculating Statistical features for Red Channel:
# 0.8642293892654719
# 0.8907126863942743
# 0.9725490196078431
# 0.04647665243353429
# 0.21558444385793307
# -1.7484369397423603
# 1.8902891945163613
# 5.584147174811942
# 1524.9169270833331
# 0.15298037786559582
# 0.22408015864085262
# 0.7483373568360809
# 0.0006554093784685813
# 0.02326837529477716
# Calculating Statistical Features for Green Channel:
# 0.8849985160079656
# 0.9083415439110665
# 0.984313725490196
# 0.04186198705843851
# 0.2046020211494464
# -2.137339949628172
# 3.6137810647288564
# 5.386042654938183
# 1397.512898284314
# 0.1379375248430751
# 0.2518585314777014
# 0.7440214541258695
# 0.0007151157794307833
# 0.021324341898567054
# Calculating Statistical Features for Blue Channel:
# 0.7705025467218137
# 0.8223615929800675
# 0.9098039215686274
# 0.08260441510391343
# 0.2874098382169849
# -1.1964765854022041
# 0.14899050734793118
# 6.400081971322527
# 1559.349525122549
# 0.13892741177176587
# 0.20533995664174892
# 0.8550955564332295
# 0.0006409391151856374
# 0.02379377849055945
# Image number:  18
# Calculating Statistical features for Red Channel:
# 0.5441110859746519
# 0.5644291437556804
# 0.5815217391304348
# 0.022523384440255596
# 0.15007792789166433
# -0.7686822495287122
# 0.03742554346453009
# 6.651727575414883
# 174.4361825980392
# 0.02760040901172262
# 0.19957533095289362
# 0.9405989050460893
# 0.0057009753315397016
# 0.0026616653425190046
# Calculating Statistical Features for Green Channel:
# 0.5498512931492018
# 0.5716894165058629
# 0.592391304347826
# 0.02449234436696465
# 0.15650030149160943
# -0.8421882737014869
# 0.16165694449969514
# 6.690914145674649
# 174.07205882352946
# 0.027352257594768396
# 0.2006997187007963
# 0.9454800276433437
# 0.005712826280886858
# 0.0026560771229266204
# Calculating Statistical Features for Blue Channel:
# 0.43430096170176635
# 0.4863073963017019
# 0.483695652173913
# 0.04787755836266144
# 0.2188094110468319
# -0.2988979859633598
# -1.2735283053656397
# 7.036950813641559
# 163.99892769607843
# 0.02347469575074739
# 0.19826992142717673
# 0.973670901313215
# 0.006061507829276964
# 0.002502368154395937
# Image number:  19
# Calculating Statistical features for Red Channel:
# 0.5000187294155943
# 0.5371048458553055
# 0.5333333333333333
# 0.03846288567486619
# 0.19611956984163054
# -0.7509572885438875
# -0.19219942685548075
# 7.439202896153786
# 746.4041207107845
# 0.01280182746064717
# 0.10746070748731416
# 0.8510247420865938
# 0.0013379871758399582
# 0.011388806702077866
# Calculating Statistical Features for Green Channel:
# 0.5105716480928308
# 0.5429308510110372
# 0.5490196078431373
# 0.03409050114333961
# 0.18463613173845367
# -1.0172989261603582
# 0.4456074561307042
# 7.288186899994101
# 745.9372549019607
# 0.01355623232372235
# 0.10881709379345338
# 0.8320594394901699
# 0.0013388248381743986
# 0.011381641043832052
# Calculating Statistical Features for Blue Channel:
# 0.4994086172066483
# 0.5469128839706111
# 0.5372549019607843
# 0.04970473571279455
# 0.22294558913060952
# -0.5991872579998813
# -0.6412561522048144
# 7.5837654489413815
# 741.8605238970589
# 0.012544524939943248
# 0.10726343675599966
# 0.8853769615431825
# 0.0013461704517864273
# 0.011319450566578071
# Image number:  20
# Calculating Statistical features for Red Channel:
# 0.4602383482689951
# 0.49518832367564974
# 0.47843137254901963
# 0.033392138687327294
# 0.18273515996470766
# -0.20554451011339545
# -0.5360130591198371
# 7.519742400750207
# 1778.2381893382353
# 0.008526794430939054
# 0.04193327667581377
# 0.5911562631116936
# 0.0005620409894528611
# 0.02713373531184243
# Calculating Statistical Features for Green Channel:
# 0.47639160156250004
# 0.5089137134359826
# 0.48627450980392156
# 0.03204420968391766
# 0.17900896537301605
# -0.16901662122688563
# -0.22460073312067852
# 7.508148406950925
# 1778.3708486519606
# 0.008579224621937475
# 0.04186064093130755
# 0.5741594664151413
# 0.0005619991033764221
# 0.027135766265607344
# Calculating Statistical Features for Blue Channel:
# 0.3990531771790748
# 0.4506899651213491
# 0.42745098039215684
# 0.043878006444368844
# 0.20947077706536738
# -0.15540778270465347
# -0.836328724546624
# 7.61736079196738
# 1764.4333026960785
# 0.008641389680866716
# 0.04352609589465395
# 0.6910599784944554
# 0.0005664359527299282
# 0.02692310956660164
# Image number:  21
# Calculating Statistical features for Red Channel:
# 0.49458971210554525
# 0.5255522151315831
# 0.5215686274509804
# 0.03158614750906771
# 0.17772492090044015
# -0.8366589613879684
# 0.6953538904322598
# 7.204871178979123
# 582.6936427696079
# 0.026132545795404142
# 0.13064242464118828
# 0.8582279205475914
# 0.0017133042057053014
# 0.008890650688206167
# Calculating Statistical Features for Green Channel:
# 0.5058951583563112
# 0.5342455304087271
# 0.5333333333333333
# 0.029488375513344968
# 0.1717217968498611
# -1.2398706526803296
# 1.7795257164403466
# 7.010364199440944
# 582.2619485294117
# 0.024060234281203047
# 0.12998476092241068
# 0.848217050046594
# 0.00171456625172811
# 0.008884008427446665
# Calculating Statistical Features for Blue Channel:
# 0.44336637609145224
# 0.5041362302621575
# 0.4980392156862745
# 0.05757959521447209
# 0.23995748626469668
# -0.18630809676569401
# -1.1696569233070566
# 7.655990901607591
# 581.1119178921568
# 0.0157078314365039
# 0.12789923839113565
# 0.9224580843435668
# 0.00171792906862542
# 0.008866347658853605
# Image number:  22
# Calculating Statistical features for Red Channel:
# 0.3876472405627765
# 0.4522296017851473
# 0.3938053097345133
# 0.05424122961481778
# 0.23289746588320318
# -0.20462900961833855
# -0.9583210512858367
# 6.974275371803686
# 707.159819240196
# 0.12028049319113819
# 0.17772816731469046
# 0.8993926748730964
# 0.0014123505048456307
# 0.01079034662014894
# Calculating Statistical Features for Green Channel:
# 0.3887162335151065
# 0.4430436381006332
# 0.4247787610619469
# 0.04518735506327402
# 0.21257317578489066
# -0.570835170952323
# -0.6329580270889106
# 6.733305210709142
# 701.3016850490199
# 0.12183507376388807
# 0.1813478251416959
# 0.8801401193258565
# 0.0014241365656323503
# 0.010700941650910888
# Calculating Statistical Features for Blue Channel:
# 0.3698270004407495
# 0.4320600513436986
# 0.38495575221238937
# 0.049903877712117364
# 0.2233917583800203
# -0.21552770364583015
# -0.9310242024375524
# 6.876531219135358
# 704.0205116421569
# 0.12903853306457258
# 0.18081834479883332
# 0.8911354163156225
# 0.001418658102912298
# 0.010742417123453007
# Image number:  23
# Calculating Statistical features for Red Channel:
# 0.5476269860485281
# 0.5757206695411863
# 0.6224066390041494
# 0.031558973488356734
# 0.17764845478741642
# -1.1206666349178078
# 0.08634703143748945
# 6.852355226646263
# 372.1238970588236
# 0.029504662700108836
# 0.19811070370906653
# 0.9095390887463946
# 0.002680286866756966
# 0.005678116985980202
# Calculating Statistical Features for Green Channel:
# 0.49117655773875124
# 0.5159050136508472
# 0.5518672199170125
# 0.02490357223799189
# 0.15780865704387667
# -1.0606532604509586
# 0.16003179004181067
# 6.822115825010241
# 367.5854473039215
# 0.028718770192119977
# 0.2002539399300193
# 0.8866996523947781
# 0.0027132865108131722
# 0.005608852425706887
# Calculating Statistical Features for Blue Channel:
# 0.4486966588190482
# 0.4826803439863134
# 0.5228215767634855
# 0.03165162283536849
# 0.17790902966226443
# -0.6966484747707467
# -0.8346914579490097
# 6.95097934062423
# 364.1563725490196
# 0.027470813927171336
# 0.19661992853391674
# 0.9116543197024064
# 0.0027387588198249995
# 0.005556528840496167
# Image number:  24
# Calculating Statistical features for Red Channel:
# 0.45261104808134195
# 0.4751404975424525
# 0.4588235294117647
# 0.020901731559598544
# 0.1445743115480705
# -0.40169641372171705
# 0.012282164903373971
# 7.213972516185647
# 507.0899356617649
# 0.01203114116586734
# 0.07645810055220192
# 0.8136984480749836
# 0.001968202102674703
# 0.00773754084550463
# Calculating Statistical Features for Green Channel:
# 0.48040879193474256
# 0.4952601716204966
# 0.49019607843137253
# 0.014490030225364922
# 0.12037454143366413
# -0.408315663061272
# 0.3401205383660444
# 6.9476398875062175
# 507.21778492647064
# 0.012905104939439025
# 0.07632316185543993
# 0.7311294825276365
# 0.001967710346172148
# 0.0077394910185909
# Calculating Statistical Features for Blue Channel:
# 0.44042364382276344
# 0.4799517508308056
# 0.4627450980392157
# 0.03638069708743524
# 0.19073724619862592
# -0.30900158798417565
# -0.7894940763056262
# 7.532901061558092
# 509.42398897058837
# 0.0107618781917941
# 0.07819762565365046
# 0.8924777393832696
# 0.001959196876022527
# 0.0077731616491998265
# Image number:  25
# Calculating Statistical features for Red Channel:
# 0.5162456074699027
# 0.5841614714738521
# 0.5628415300546448
# 0.0747350975225273
# 0.273377207393973
# -0.12101988960393656
# -1.577654460707287
# 7.104566422822408
# 213.2357536764706
# 0.020166378146409272
# 0.14425469614198927
# 0.978094531209932
# 0.004668194376571508
# 0.003251945474004228
# Calculating Statistical Features for Green Channel:
# 0.5561607652674607
# 0.594959881176633
# 0.5519125683060109
# 0.044662463386825675
# 0.2113349554305337
# -0.1198824238490856
# -1.332687065916331
# 6.981955433913828
# 212.00572916666664
# 0.0202977883279579
# 0.14432649182929133
# 0.963519253542057
# 0.004695156816729124
# 0.0032330834626670252
# Calculating Statistical Features for Blue Channel:
# 0.5114256645160946
# 0.5812140955070746
# 0.5628415300546448
# 0.07625361449037789
# 0.2761405701637807
# -0.14421012960915155
# -1.5707777491275234
# 7.105942296854582
# 217.87323835784318
# 0.02050866172938672
# 0.14260264909663675
# 0.9780610913950637
# 0.004569282738161603
# 0.0033224687134895026
# Image number:  26
# Calculating Statistical features for Red Channel:
# 0.5071146647135416
# 0.5345882690220383
# 0.5490196078431373
# 0.028619334208451412
# 0.1691724983809467
# -0.8519877114248265
# 0.4706161792015848
# 7.299577349824515
# 954.9958486519607
# 0.01127459305702425
# 0.05995339653324164
# 0.7439724232998985
# 0.0010460419834539968
# 0.014572072207339762
# Calculating Statistical Features for Green Channel:
# 0.4952582864200368
# 0.5134993641458336
# 0.5137254901960784
# 0.01840082671046429
# 0.13564964692347817
# -1.0810097492929343
# 2.3527096402657808
# 6.967536617396502
# 957.1675398284316
# 0.012869835248118973
# 0.06094700258432604
# 0.6010487136717111
# 0.0010436728341647744
# 0.01460520983979418
# Calculating Statistical Features for Blue Channel:
# 0.4762794045840993
# 0.5104842625304831
# 0.5294117647058824
# 0.033752111060307094
# 0.18371747619730436
# -0.7489900961510217
# -0.04943300789791438
# 7.379880454158567
# 946.0125153186277
# 0.010966917687427602
# 0.06100980225161179
# 0.7849317330854523
# 0.0010559644825170035
# 0.014434975495229674
# Image number:  27
# Calculating Statistical features for Red Channel:
# 0.4769113578048407
# 0.5147179465424957
# 0.5098039215686274
# 0.03749012128966661
# 0.19362365890992406
# -0.4588397635454533
# -0.4258784587737985
# 7.507501643708114
# 928.5470894607845
# 0.010527653577205486
# 0.06799768364695065
# 0.8097107817226971
# 0.0010758049129942749
# 0.01416792774328769
# Calculating Statistical Features for Green Channel:
# 0.49133821375229775
# 0.5244953340167078
# 0.5098039215686274
# 0.03368211511199916
# 0.18352687844563575
# -0.5435504247807614
# -0.04827030064753046
# 7.425679883098469
# 930.9759037990198
# 0.010961267394768085
# 0.0690186312316168
# 0.7877386609179855
# 0.0010730017346828112
# 0.014204859620916936
# Calculating Statistical Features for Blue Channel:
# 0.42786619896982236
# 0.47437649963739714
# 0.4627450980392157
# 0.041963579187345834
# 0.20485013836301363
# -0.34635125975975584
# -0.6278041119178068
# 7.568286465261617
# 926.825306372549
# 0.010158433189625237
# 0.0672075756652833
# 0.8302295296782917
# 0.001077800898401972
# 0.014141494309338455
# Image number:  28
# Calculating Statistical features for Red Channel:
# 0.43048341040517774
# 0.4731034977146095
# 0.4470588235294118
# 0.0385109529157249
# 0.1962420773323726
# -0.04766912203782411
# -0.6774942687896748
# 7.589048907601282
# 2182.907735906863
# 0.008883958715714207
# 0.049591819282497944
# 0.5646134187727062
# 0.00045789666454009527
# 0.03330834167034096
# Calculating Statistical Features for Green Channel:
# 0.42195243087469364
# 0.4624096208059639
# 0.42745098039215684
# 0.035778803492852215
# 0.18915285748000799
# 0.0738013742219271
# -0.4810868745244421
# 7.569676647550031
# 2182.012944240196
# 0.00910199792250451
# 0.04938496870371939
# 0.531670744344052
# 0.0004580843975853243
# 0.033294612698021364
# Calculating Statistical Features for Blue Channel:
# 0.3931863822189032
# 0.4465748913237117
# 0.41568627450980394
# 0.04483360239839549
# 0.21173946821127962
# -0.09520931945267683
# -0.7306002656737607
# 7.625240852556344
# 2177.961167279412
# 0.008994395734123577
# 0.04965390174425845
# 0.6268336562207085
# 0.0004589361861378425
# 0.03323278761067797
# Image number:  29
# Calculating Statistical features for Red Channel:
# 0.4884610643573836
# 0.5304146974272972
# 0.5098039215686274
# 0.042745539853743186
# 0.2067499452327453
# -0.24311970920684872
# -1.2639447483007988
# 7.453896622543446
# 581.5872702205884
# 0.01489476395266935
# 0.13266481560874976
# 0.8954890187774449
# 0.00171652491969976
# 0.00887417729578408
# Calculating Statistical Features for Green Channel:
# 0.511122221105239
# 0.5350660578448369
# 0.5372549019607843
# 0.025049761350061463
# 0.15827116398782648
# -0.744787577539968
# 0.10746505011422425
# 7.222093324163895
# 577.2873621323529
# 0.01505494567706695
# 0.1334494280386845
# 0.8230712682022264
# 0.001729289104064227
# 0.008808498779757206
# Calculating Statistical Features for Blue Channel:
# 0.4850442923751533
# 0.5307397862698654
# 0.5058823529411764
# 0.04641675516406933
# 0.21544548072324313
# -0.3134958329522426
# -1.1379294852184338
# 7.5505966371174695
# 581.9024203431372
# 0.014365769293640912
# 0.13168473537639108
# 0.903707816892727
# 0.0017155952882429745
# 0.008878934637703194
# Image number:  30
# Calculating Statistical features for Red Channel:
# 0.6038045201982771
# 0.6107183420931718
# 0.5982142857142857
# 0.008396994757160837
# 0.09163511748866172
# 0.6847863563740523
# 2.7296298604397125
# 6.126149068477151
# 15.89295343137255
# 0.05219788081343801
# 0.40313374731328994
# 0.9854925378192293
# 0.05937975864549617
# 0.00024250658027761854
# Calculating Statistical Features for Green Channel:
# 0.6566147123064314
# 0.6669504416629003
# 0.6294642857142857
# 0.01368001121708013
# 0.11696158008970352
# 0.1821360049624734
# 0.24138438425841002
# 6.5326607985775915
# 17.176363357843137
# 0.045245536393806775
# 0.4061767957234113
# 0.990364826279928
# 0.055153797457373976
# 0.0002620904851971235
# Calculating Statistical Features for Blue Channel:
# 0.4360695566449846
# 0.46677101115068226
# 0.4955357142857143
# 0.027718518618076837
# 0.16648879427179727
# -0.3382199852096072
# -1.360069708266732
# 6.548996590133405
# 17.297012867647062
# 0.04509385033395282
# 0.3924139862654896
# 0.9952083395481863
# 0.05478875942038951
# 0.0002639308421393109
# Image number:  31
# Calculating Statistical features for Red Channel:
# 0.4618140127144607
# 0.5018832347841284
# 0.49019607843137253
# 0.038614599017948434
# 0.19650597705400322
# -0.216917739332686
# -0.7072969991891243
# 7.565923681613983
# 1815.8102941176473
# 0.010311336701714507
# 0.05328581781748082
# 0.6388575044740455
# 0.0005504183231383108
# 0.027707036017601033
# Calculating Statistical Features for Green Channel:
# 0.4770357618144914
# 0.5138737522110467
# 0.49411764705882355
# 0.03650311516152794
# 0.19105788432181472
# -0.24459795791716807
# -0.42935154852613877
# 7.541785172396784
# 1818.3278492647055
# 0.010307649325801806
# 0.0537210621414899
# 0.6177480654604968
# 0.0005496566581291223
# 0.027745456594496863
# Calculating Statistical Features for Blue Channel:
# 0.4035447662951899
# 0.4567394205388631
# 0.43529411764705883
# 0.04576251986993693
# 0.2139217610948847
# -0.15494298276843577
# -0.8714527427325147
# 7.624639062543745
# 1801.132444852941
# 0.009679215096853032
# 0.054314536301448536
# 0.6975840606655895
# 0.0005549011527225559
# 0.02748308476622072
# Image number:  32
# Calculating Statistical features for Red Channel:
# 0.5066903507008272
# 0.5276795751181916
# 0.5294117647058824
# 0.021710622503587983
# 0.14734524934176868
# -0.7688884837205604
# 1.3371804520956605
# 7.138211776720811
# 623.9564338235296
# 0.016431811194255318
# 0.13690727371539038
# 0.7792290180632931
# 0.001600153609594448
# 0.009520194394351401
# Calculating Statistical Features for Green Channel:
# 0.5222908169615502
# 0.5396156228631428
# 0.5372549019607843
# 0.018397322955614
# 0.1356367315870373
# -1.0502472084757484
# 2.7630446137720774
# 6.963717109646762
# 621.9663602941176
# 0.01729943117440145
# 0.13800553501394977
# 0.7401044490272124
# 0.0016052676901298238
# 0.00948975489626294
# Calculating Statistical Features for Blue Channel:
# 0.5126853793275122
# 0.5510142374986333
# 0.5725490196078431
# 0.040770391750005124
# 0.2019167941257119
# -0.6503713985900321
# -0.35534738177528524
# 7.489522556834413
# 623.4630667892156
# 0.014834601849764689
# 0.13647226397721549
# 0.8825908174455211
# 0.0016014137737200764
# 0.009512660995420098
# Image number:  33
# Calculating Statistical features for Red Channel:
# 0.4699747809048357
# 0.4807311284099027
# 0.4525862068965517
# 0.010226123135710079
# 0.10112429547695291
# 0.27137981895154106
# -0.7015392116886248
# 6.502880935338198
# 219.97513786764708
# 0.018874985916644226
# 0.10867081577819997
# 0.8343881099265236
# 0.004525782555144239
# 0.003356533517247522
# Calculating Statistical Features for Green Channel:
# 0.5304349701980065
# 0.538394071471863
# 0.5474137931034483
# 0.00850691858708956
# 0.0922329582475243
# -0.453765233627176
# -0.0495473969125384
# 6.360755848627695
# 221.01467524509806
# 0.02085883000433164
# 0.10894298054792677
# 0.7999680517585712
# 0.004504629976405092
# 0.003372404448794017
# Calculating Statistical Features for Blue Channel:
# 0.4629521205507476
# 0.47511155753213385
# 0.44396551724137934
# 0.011406326178176263
# 0.10680040345511932
# 0.23294221033014634
# -0.7864841135980813
# 6.574590178716661
# 218.29151348039215
# 0.018241263081635466
# 0.10814551231623107
# 0.8527336744563393
# 0.00456051934596457
# 0.0033308541004197596
# Image number:  34
# Calculating Statistical features for Red Channel:
# 0.5216960832184436
# 0.5358815831732885
# 0.5450980392156862
# 0.015002267938844863
# 0.12248374561077426
# -1.1595913042512176
# 2.2112541211637966
# 6.806612725761921
# 732.0547181372551
# 0.01453874137437327
# 0.05738978661756112
# 0.6256768414040769
# 0.001364181702596614
# 0.011170266544255144
# Calculating Statistical Features for Green Channel:
# 0.49736453785615814
# 0.5060801958623575
# 0.4980392156862745
# 0.008745681127212492
# 0.09351834647390046
# -0.6149162332717764
# 3.5486456382237543
# 6.514517815454268
# 731.7035232843137
# 0.015533178877795631
# 0.05711395678229668
# 0.35799483003026966
# 0.0013648374389978702
# 0.011164901004255575
# Calculating Statistical Features for Blue Channel:
# 0.497868377087163
# 0.5202031237595826
# 0.5372549019607843
# 0.022738369065822057
# 0.15079247018940323
# -1.173242613089973
# 1.1839331915923976
# 6.986746238926713
# 731.1280024509805
# 0.013876613544038614
# 0.058568366508062325
# 0.7533500533551098
# 0.0013659072605055114
# 0.01115611759469526
# Image number:  35
# Calculating Statistical features for Red Channel:
# 0.43653905531939335
# 0.5063038925293671
# 0.4823529411764706
# 0.06577728477124052
# 0.2564708263550467
# -0.1615125185129624
# -1.2588176037796042
# 7.458263901133502
# 632.5669424019607
# 0.04898845804861313
# 0.19456031252765682
# 0.9261082671963679
# 0.0015784872295640324
# 0.009651422087892299
# Calculating Statistical Features for Green Channel:
# 0.4538425221162684
# 0.5225073450552626
# 0.5058823529411764
# 0.06704089075584367
# 0.2589225574488319
# -0.3069096534677067
# -1.1870420628950453
# 7.497355292225539
# 633.1536305147059
# 0.04212120068071292
# 0.19302828627204321
# 0.9274651014220853
# 0.0015770096983128235
# 0.00966033487967425
# Calculating Statistical Features for Blue Channel:
# 0.4122439515356924
# 0.503968639682671
# 0.4117647058823529
# 0.08403931420583956
# 0.2898953504384635
# 0.11306251707518931
# -1.327354684491382
# 7.756113849331491
# 622.4559589460783
# 0.023759689940214348
# 0.18657465744938542
# 0.9430534863174301
# 0.0016040236631877083
# 0.009497025664011357
# Image number:  36
# Calculating Statistical features for Red Channel:
# 0.8188160017424939
# 0.8552603015726823
# 0.9490196078431372
# 0.06101053873663184
# 0.24700311483184142
# -1.3835227670744128
# 0.8029944584536355
# 5.8901817585932825
# 1433.2745404411762
# 0.22874133774551073
# 0.29838476901183486
# 0.8197116818025175
# 0.0006973277984742207
# 0.02187003275032217
# Calculating Statistical Features for Green Channel:
# 0.8707340614468444
# 0.8968211910135624
# 0.9764705882352941
# 0.046110442887267664
# 0.21473342284625294
# -1.9896095991596465
# 2.9549142121136702
# 5.661425928062567
# 1315.161734068628
# 0.16036705923497577
# 0.28061306831761995
# 0.7813006392106414
# 0.0007598776301216885
# 0.020067763596655703
# Calculating Statistical Features for Blue Channel:
# 0.8063652487362132
# 0.8467211868349428
# 0.9411764705882353
# 0.06671185386575894
# 0.2582863795591222
# -1.3460651716389527
# 0.6776121337218131
# 6.056872172554101
# 1448.0389246323532
# 0.20580314473170191
# 0.27531828297282
# 0.8334106047097524
# 0.0006902106151281438
# 0.022095318298779
# Image number:  37
# Calculating Statistical features for Red Channel:
# 0.4939982694738051
# 0.5163090470210943
# 0.5490196078431373
# 0.02254074179271636
# 0.15013574455377493
# -1.1025555854220257
# 0.728453433597974
# 6.981723930640576
# 468.1470281862745
# 0.017852189361774386
# 0.1068964104415309
# 0.8406089091170892
# 0.002131609056023795
# 0.007143298946435591
# Calculating Statistical Features for Green Channel:
# 0.49777251598881744
# 0.5116433669870184
# 0.5176470588235295
# 0.014001457307975407
# 0.11832775375192164
# -1.4590305004450639
# 4.176637671750381
# 6.662298703963606
# 465.33455882352945
# 0.01922567693244295
# 0.10761459545421619
# 0.7450871010291641
# 0.0021444716244954074
# 0.00710035709451536
# Calculating Statistical Features for Blue Channel:
# 0.4441667743757659
# 0.4818144363568204
# 0.5215686274509804
# 0.034861027622467955
# 0.1867110806097698
# -0.7523308762016371
# -0.5909559788534033
# 7.197942528603934
# 465.87383578431377
# 0.016598635889478512
# 0.10997293599496752
# 0.8973996384701534
# 0.002141982431520233
# 0.007108568562547757
# Image number:  38
# Calculating Statistical features for Red Channel:
# 0.616757022633272
# 0.6372649193806351
# 0.6509803921568628
# 0.025717352505748955
# 0.16036630726480222
# -1.1337901412726688
# 1.4197814229601402
# 7.197148603518945
# 820.0983455882352
# 0.011498300949900255
# 0.058555732327033205
# 0.7551923001499935
# 0.00121789796451351
# 0.012513598641570443
# Calculating Statistical Features for Green Channel:
# 0.6199769861557904
# 0.6351272143988514
# 0.6431372549019608
# 0.0190151151072274
# 0.1378953048773866
# -1.592094539361867
# 3.9342463428029717
# 6.898003870437923
# 820.4839767156863
# 0.012994097407130284
# 0.05837812926016333
# 0.6688971556404727
# 0.0012173284524459942
# 0.012519442134009375
# Calculating Statistical Features for Blue Channel:
# 0.4892658308440564
# 0.5411822974283477
# 0.5490196078431373
# 0.053497225818299805
# 0.2312946731299703
# -0.2817809884646171
# -1.220924086610026
# 7.586829885738871
# 819.7649509803922
# 0.01005557925700055
# 0.05857232865749564
# 0.882247705324954
# 0.001218390539737519
# 0.012508445917995721
# Image number:  39
# Calculating Statistical features for Red Channel:
# 0.4691867005591299
# 0.512816862013284
# 0.4823529411764706
# 0.042844973983588996
# 0.20699027509423962
# -0.05849149645311278
# -0.7716105013148842
# 7.670342283090692
# 934.0068780637257
# 0.009355531135151553
# 0.06971919644440094
# 0.8324656491134316
# 0.0010695215504864012
# 0.01425180400897896
# Calculating Statistical Features for Green Channel:
# 0.4648071289062499
# 0.5026869159265035
# 0.47058823529411764
# 0.03664846836162824
# 0.19143789687945342
# -0.14436839654579953
# -0.625403178360346
# 7.54220632900676
# 934.7684283088236
# 0.010218569430209847
# 0.0708726792286228
# 0.8041100186083929
# 0.0010686521257221968
# 0.014263427381538737
# Calculating Statistical Features for Blue Channel:
# 0.4121931487438726
# 0.4635962344198656
# 0.4196078431372549
# 0.045018276696890784
# 0.21217510857047012
# 0.06644414211867575
# -0.8211048018963631
# 7.69590474116107
# 930.209068627451
# 0.009273123251140054
# 0.06991856265446769
# 0.8411686235652179
# 0.0010738833973417575
# 0.014193861483610945
# Image number:  40
# Calculating Statistical features for Red Channel:
# 0.36186601227405024
# 0.40328370975226074
# 0.403921568627451
# 0.031690739712422596
# 0.1780189307697993
# -0.9098592141273139
# 0.121497146318017
# 6.409191124236294
# 623.3837162990197
# 0.12900723965575134
# 0.18361210306506132
# 0.8478058862050077
# 0.0016019102226826842
# 0.009512042601813764
# Calculating Statistical Features for Green Channel:
# 0.3967535879097733
# 0.44308037962971836
# 0.4549019607843137
# 0.03890681329353718
# 0.19724810086167416
# -0.931748396264761
# -0.09246790719340492
# 6.52055165715075
# 624.2198835784312
# 0.13119753644592752
# 0.18484009128228923
# 0.8759320502045193
# 0.0015997729959438636
# 0.009524807990261886
# Calculating Statistical Features for Blue Channel:
# 0.3490224202473959
# 0.39007468594717215
# 0.3843137254901961
# 0.030341610781435227
# 0.1741884346948305
# -0.8087003193713314
# 0.0662163425253075
# 6.430863857873403
# 623.0737285539217
# 0.1284089974375919
# 0.18295750328652152
# 0.8411370940962766
# 0.0016027045458259469
# 0.009507322582351426
# Image number:  41
# Calculating Statistical features for Red Channel:
# 0.4037820255055147
# 0.47420357191039475
# 0.5058823529411764
# 0.06182910349124077
# 0.24865458670863236
# -0.518651627656995
# -1.2199721953598768
# 6.917035651805635
# 685.9255055147058
# 0.12309144470604746
# 0.2344472908935633
# 0.9144360472172527
# 0.0014560228378843157
# 0.01046630687570154
# Calculating Statistical Features for Green Channel:
# 0.3936670639935662
# 0.4541055647523491
# 0.4745098039215686
# 0.05123810666573536
# 0.22635835894822917
# -0.6753729963828164
# -0.8915362146558854
# 6.766935353169671
# 680.7329656862747
# 0.12148010003197972
# 0.23581025648307996
# 0.897460475828793
# 0.0014671114280592212
# 0.01038706472850348
# Calculating Statistical Features for Blue Channel:
# 0.38218545352711397
# 0.4646238972861223
# 0.4823529411764706
# 0.0698096450416193
# 0.26421514915238925
# -0.32080981354550264
# -1.4532879769094393
# 6.9174125631409575
# 676.9204656862746
# 0.12832345366710418
# 0.2364073523232659
# 0.925291187858681
# 0.0014753785676919458
# 0.010328859066514042
# Image number:  42
# Calculating Statistical features for Red Channel:
# 0.38997880651595745
# 0.42900898950110994
# 0.37872340425531914
# 0.031965243541152835
# 0.17878826455098454
# 0.11427236803979883
# -1.1780547088594313
# 7.258038215869201
# 227.26966911764708
# 0.014401644475688967
# 0.1191652120888941
# 0.9453179883611182
# 0.004381059903108425
# 0.003467248280141295
# Calculating Statistical Features for Green Channel:
# 0.441595458984375
# 0.4612327310317597
# 0.44680851063829785
# 0.01772908277939474
# 0.1331506018739485
# -0.06328368845844037
# -0.4581240015852459
# 6.990209578931963
# 224.86855085784313
# 0.01589198149137099
# 0.11957205625422301
# 0.9024440847188786
# 0.004427665385810104
# 0.003430602141422882
# Calculating Statistical Features for Blue Channel:
# 0.37491701815990697
# 0.40943745320109376
# 0.3574468085106383
# 0.027076257577881846
# 0.16454864805850533
# 0.14297183104326502
# -0.9321782945582711
# 7.219410748372567
# 221.73658088235297
# 0.014503723067098788
# 0.11907247471074528
# 0.9369668293027396
# 0.004489900654459244
# 0.003382762410419806
# Image number:  43
# Calculating Statistical features for Red Channel:
# 0.6511129341873467
# 0.6709032816153355
# 0.6862745098039216
# 0.026163160216169965
# 0.16175030205897598
# -0.7973534274407247
# 0.40488064196517737
# 7.277979115322649
# 960.4020680147062
# 0.010429184376080824
# 0.04503115384495635
# 0.718139920211562
# 0.0010401588276934075
# 0.014654559412597322
# Calculating Statistical Features for Green Channel:
# 0.6507303275314031
# 0.662115844561081
# 0.6627450980392157
# 0.014947432449706232
# 0.12225969266158913
# -1.11713220692788
# 3.3037777825246897
# 6.884207571816462
# 957.0957261029412
# 0.011898994701952732
# 0.044421908108027035
# 0.5082905626233543
# 0.0010437500056944655
# 0.01460410101780713
# Calculating Statistical Features for Blue Channel:
# 0.5695498597388173
# 0.6091073837708844
# 0.6470588235294118
# 0.04662476223570491
# 0.21592767825293938
# -0.5560761745141286
# -0.8363241102025616
# 7.525101904391262
# 970.3299785539217
# 0.009795301050706485
# 0.04429799329968312
# 0.8401804068369867
# 0.001029526635234823
# 0.014806038459207218
# Image number:  44
# Calculating Statistical features for Red Channel:
# 0.49119240897042404
# 0.5099343548889237
# 0.5168067226890757
# 0.018763063665814407
# 0.13697833283338795
# -0.2994598791979571
# -0.7571057906190588
# 6.845168656309895
# 184.63736213235296
# 0.0205379780940027
# 0.1569572060546583
# 0.9243687655385208
# 0.005387442676903785
# 0.002816659578622413
# Calculating Statistical Features for Green Channel:
# 0.5090326261119682
# 0.5280486363581497
# 0.5546218487394958
# 0.019721147913254626
# 0.14043200459031632
# -0.5907673766686007
# -0.7055790246309503
# 6.80707134091106
# 183.99664522058825
# 0.021086167195807866
# 0.15771055462045436
# 0.9282443752599139
# 0.005406119625303331
# 0.002806795098396682
# Calculating Statistical Features for Blue Channel:
# 0.3924252806591386
# 0.4358403844013869
# 0.3487394957983193
# 0.035959239774744994
# 0.18962921656418083
# -0.07133575592912547
# -1.2851558596457322
# 7.101581175697494
# 178.2140012254902
# 0.019304740716600894
# 0.15865333793216976
# 0.9619106978856831
# 0.005580522301255558
# 0.0027185603188510494
# Image number:  45
# Calculating Statistical features for Red Channel:
# 0.49590944776348034
# 0.524493031009017
# 0.5254901960784314
# 0.02916675919594558
# 0.1707827836637686
# -0.6606029305255333
# 0.07158938112298907
# 7.345538367857447
# 1356.472242647059
# 0.00973766000274975
# 0.048829691116388754
# 0.6431763131763909
# 0.000736668597715364
# 0.02069812179482565
# Calculating Statistical Features for Green Channel:
# 0.4921973733340993
# 0.5209905154526616
# 0.5137254901960784
# 0.029172862874643334
# 0.17080065244208914
# -0.6542897011308527
# 0.27902171258023234
# 7.346860607533865
# 1356.8296109068626
# 0.009969213982885654
# 0.049117015169061924
# 0.6432492799236434
# 0.0007364748375220414
# 0.020703576493493407
# Calculating Statistical Features for Blue Channel:
# 0.4639892578125
# 0.500791119548539
# 0.4980392156862745
# 0.03550571405328452
# 0.1884295997270188
# -0.5652172108070281
# -0.3172101674373753
# 7.48475349685788
# 1353.040303308824
# 0.00912576293697163
# 0.04821090156508586
# 0.7074879559819353
# 0.0007385354315197154
# 0.020645756540255696
# Image number:  46
# Calculating Statistical features for Red Channel:
# 0.41796366373697913
# 0.42939544659103457
# 0.43089430894308944
# 0.009686825348675458
# 0.09842167113332032
# -0.31023978899521293
# 0.1118897001785375
# 6.597688182928196
# 518.7016697303924
# 0.015344937577417967
# 0.07085822081608564
# 0.5884904996035069
# 0.0019242376647079819
# 0.007914758377870697
# Calculating Statistical Features for Green Channel:
# 0.45943872715399514
# 0.4744124090716068
# 0.4715447154471545
# 0.013983189872242353
# 0.11825053857062282
# -0.29273481341002106
# -0.47644099047773336
# 6.852315979622947
# 520.1266390931373
# 0.013315156825060362
# 0.07131193092359048
# 0.7142864911166993
# 0.001918968397212225
# 0.007936501917337961
# Calculating Statistical Features for Blue Channel:
# 0.39958575489075204
# 0.41068760183592407
# 0.4024390243902439
# 0.008995530790130352
# 0.09484477207590492
# -0.021336272879457347
# 0.1113649420450229
# 6.580536063627853
# 517.1423100490196
# 0.014921679918575396
# 0.07082284763057911
# 0.5581213618820453
# 0.0019300272914498488
# 0.007890962885792257
# Image number:  47
# ...
# Image number:  283
# Calculating Statistical features for Red Channel:
# 0.4776733996821385
# 0.5166603305713564
# 0.5176470588235295
# 0.038766020422211285
# 0.1968908845584561
# -0.3881715065948579
# -0.6880136786523803
# 7.482115657910065
# 1183.4845741421573
# 0.010537656989731506
# 0.06903836994987099
# 0.7655153374440641
# 0.0008442565807245724
# 0.018058213063758134
# Calculating Statistical Features for Green Channel:
# 0.4739796956380208
# 0.5099249439232917
# 0.5019607843137255
# 0.03536669655806131
# 0.1880603534987141
# -0.42473818719056017
# -0.41760294073083504
# 7.425721552789397
# 1184.6174632352943
# 0.011645844842850956
# 0.06998765180630771
# 0.7428648587218862
# 0.0008434506522589653
# 0.01807543172120406
# Calculating Statistical Features for Blue Channel:
# 0.43088546453737747
# 0.48034333749209807
# 0.47843137254901963
# 0.04506743832345607
# 0.21229092850015063
# -0.41951038989018
# -0.7807025775146785
# 7.537539358096008
# 1177.0680300245097
# 0.010631414395460765
# 0.07129763439795118
# 0.7993663473358202
# 0.0008488550737678924
# 0.017960228714651527
# Image number:  284
# Calculating Statistical features for Red Channel:
# 0.6134644153071384
# 0.6234370338314612
# 0.6
# 0.012335146304441245
# 0.11106370381200711
# 0.4542087008387868
# 0.21488717603299579
# 6.7854199823735595
# 113.82858455882355
# 0.021494649130622216
# 0.17297759935675222
# 0.9292274508931405
# 0.008710263458350858
# 0.0017368258766597942
# Calculating Statistical Features for Green Channel:
# 0.6114542643229166
# 0.6201049189365901
# 0.596078431372549
# 0.010653793130675816
# 0.10321721334484775
# 0.4809211149996378
# 0.7494731543344693
# 6.662093112554328
# 113.89731924019608
# 0.022876019873195826
# 0.17236452967076749
# 0.9180192215607205
# 0.008705156447044142
# 0.0017378928219260034
# Calculating Statistical Features for Blue Channel:
# 0.5517575133080576
# 0.561171667614968
# 0.5725490196078431
# 0.010477287041872698
# 0.10235861977319105
# -1.085486092316465
# 1.8318501678822265
# 6.603152894031387
# 114.21067708333335
# 0.023852770517661548
# 0.16999893478661848
# 0.9162430623527515
# 0.008681548484089426
# 0.0017426770441670949
# Image number:  285
# Calculating Statistical features for Red Channel:
# 0.49020170222567977
# 0.5360571220943301
# 0.536723163841808
# 0.047059529283101476
# 0.21693208449443682
# -0.2555227834351153
# -1.2638847255898502
# 7.030062784811781
# 175.22682291666663
# 0.023306535287724243
# 0.21083362372711748
# 0.9713888858674438
# 0.005675255639255105
# 0.0026737318773994204
# Calculating Statistical Features for Green Channel:
# 0.5212702347060383
# 0.5549667789558939
# 0.5480225988700564
# 0.03626546815419186
# 0.19043494467715705
# -0.3353131518483061
# -0.9038057961301802
# 6.976292645438989
# 173.02699142156865
# 0.023240028997842277
# 0.21140608989933424
# 0.9633384791155046
# 0.005747002532973525
# 0.002640142180569834
# Calculating Statistical Features for Blue Channel:
# 0.45948567363501946
# 0.5259703753092935
# 0.4745762711864407
# 0.06551775142717148
# 0.25596435577472787
# -0.07096682990705405
# -1.4368471026165799
# 7.180361599453792
# 175.22846200980393
# 0.021912202927335915
# 0.20958812939531776
# 0.9794377482338582
# 0.005675157938771321
# 0.002673737244356119
# Image number:  286
# Calculating Statistical features for Red Channel:
# 0.5176820906381758
# 0.5637656483041565
# 0.5714285714285714
# 0.049836959240293424
# 0.22324192984359686
# -0.4190208916350826
# -1.075808253747344
# 7.567842067575349
# 511.47901348039215
# 0.01240491063161111
# 0.10926798534530273
# 0.9211116447151579
# 0.0019513466502547219
# 0.007804523100764969
# Calculating Statistical Features for Green Channel:
# 0.5197500804113963
# 0.553252463405867
# 0.5476190476190477
# 0.0359481421770073
# 0.18959995299843116
# -0.716845740106025
# -0.22337409802991948
# 7.374068753180162
# 510.9682138480391
# 0.01374452270454383
# 0.11036057189122402
# 0.8909944850804559
# 0.001953298701186891
# 0.007796723988535214
# Calculating Statistical Features for Blue Channel:
# 0.4780191088479663
# 0.5245879074757761
# 0.5119047619047619
# 0.046690204246009545
# 0.21607916198932636
# -0.4965320997266017
# -0.824834154015043
# 7.570371647597106
# 513.2475643382354
# 0.012163723307288385
# 0.10999751967414573
# 0.915636498167533
# 0.001944634692213312
# 0.007831500634169354
# Image number:  287
# Calculating Statistical features for Red Channel:
# 0.3846778420840993
# 0.4174188703557653
# 0.3764705882352941
# 0.026261471138603953
# 0.16205391429584154
# 0.17555359627030004
# -0.9203141789245541
# 7.305093508126457
# 192.95842524509803
# 0.014428065396665139
# 0.13592175155250355
# 0.9433554191209714
# 0.005156127616950355
# 0.0029420434743286272
# Calculating Statistical Features for Green Channel:
# 0.4277107986749388
# 0.45302668186064365
# 0.4470588235294118
# 0.02229664717451087
# 0.14932061871861793
# -0.5326965147689483
# -0.43077094010654493
# 7.173203341958074
# 193.73978247549024
# 0.014967012408489883
# 0.13636687377640969
# 0.9329901498755331
# 0.005135452292620566
# 0.0029540944878536143
# Calculating Statistical Features for Blue Channel:
# 0.2863733029833027
# 0.3279543385052538
# 0.2549019607843137
# 0.02554437948285213
# 0.15982609137075252
# 0.550672384309929
# -0.5925933644602561
# 7.193045596053463
# 190.48679534313726
# 0.015591187342831698
# 0.13686088579344713
# 0.9424640731449692
# 0.005222717454611764
# 0.0029043770879106034
# Image number:  288
# Calculating Statistical features for Red Channel:
# 0.5385365679981263
# 0.5731254411932558
# 0.6138211382113821
# 0.0384511362717637
# 0.19608961286045648
# -1.2807877588175594
# 0.40698755834144906
# 6.898072052025681
# 302.02270220588235
# 0.01967009591513844
# 0.128955832225382
# 0.9396796262790148
# 0.0033002970070513207
# 0.004608432263456734
# Calculating Statistical Features for Green Channel:
# 0.5143986523635988
# 0.5437393731293967
# 0.573170731707317
# 0.031046532337662663
# 0.17620026202495462
# -1.4503129093581613
# 1.0174850699987363
# 6.757344064777613
# 299.56377144607853
# 0.020022330952811897
# 0.13006716386993578
# 0.9258975056570145
# 0.0033273026071719827
# 0.00457089690162497
# Calculating Statistical Features for Blue Channel:
# 0.45686327926511683
# 0.5052199046152951
# 0.5528455284552846
# 0.046523096078611714
# 0.2156921326303111
# -0.8400676997878692
# -0.7155717053490136
# 7.114287242575148
# 296.8238817401961
# 0.016673564253566784
# 0.12473465695946505
# 0.9510617037949817
# 0.0033578770847252516
# 0.004529083663309821
# Image number:  289
# Calculating Statistical features for Red Channel:
# 0.5202376145582932
# 0.5435776785299172
# 0.5128205128205128
# 0.02482951699467076
# 0.157573846163222
# -0.46681176838469435
# 0.25552115433945266
# 6.772164883146528
# 56.17477022058823
# 0.03669036729635787
# 0.306482963905296
# 0.9826596886282697
# 0.017501463167253904
# 0.0008571442865982496
# Calculating Statistical Features for Green Channel:
# 0.5577221210186297
# 0.581891258387375
# 0.558974358974359
# 0.027543472314123643
# 0.16596226171670367
# -0.558541356159893
# 0.3400969953251529
# 6.830692769852112
# 53.846200980392155
# 0.03569067282060801
# 0.3081758112182276
# 0.9850166531003541
# 0.018244675964307882
# 0.0008216060481905387
# Calculating Statistical Features for Blue Channel:
# 0.38440520457732374
# 0.43479722589268427
# 0.41025641025641024
# 0.04128126633783984
# 0.20317791793853937
# -0.1885863755222836
# -1.01343031484629
# 6.966458463736102
# 50.42495404411764
# 0.033488523723283724
# 0.3052624933831183
# 0.990622277570378
# 0.019458483813876777
# 0.0007693955647375654
# Image number:  290
# Calculating Statistical features for Red Channel:
# 0.5284681133195465
# 0.5558334361251102
# 0.5882352941176471
# 0.029672261919125895
# 0.17225638426231377
# -1.2672922139402427
# 0.9621692250286897
# 7.0550970986501955
# 608.8699142156863
# 0.018326738788863567
# 0.11444775938529794
# 0.8425077362859076
# 0.001639743210536256
# 0.00929045454160336
# Calculating Statistical Features for Green Channel:
# 0.5133140414368872
# 0.5308067303968574
# 0.5411764705882353
# 0.018264479898331666
# 0.13514614274307524
# -1.4514052886090474
# 2.598695730088444
# 6.827280900943024
# 608.8032169117649
# 0.018376850177189805
# 0.11463965322980302
# 0.7441293323203787
# 0.001639922697814201
# 0.009289372536550343
# Calculating Statistical Features for Blue Channel:
# 0.5265345554725797
# 0.5580325694141282
# 0.5882352941176471
# 0.03416171042022669
# 0.18482886792984124
# -1.2529942504313556
# 0.8601092541628454
# 7.1418537686064125
# 609.8315257352941
# 0.017282806517106734
# 0.11637642931890826
# 0.8629776539929117
# 0.0016371589424718168
# 0.009305063398087291
# Image number:  291
# Calculating Statistical features for Red Channel:
# 0.40634562174479166
# 0.457074356540998
# 0.41568627450980394
# 0.043800203096206046
# 0.20928498057960596
# -0.08466227765615614
# -1.3304806219912617
# 7.505482119149585
# 502.87412683823527
# 0.01291764548115362
# 0.12143110010820962
# 0.911641873987584
# 0.0019846735207144036
# 0.0076725354295665085
# Calculating Statistical Features for Green Channel:
# 0.4536582797181372
# 0.4889788329658982
# 0.4980392156862745
# 0.033294464331872185
# 0.18246770764130343
# -0.3987021214586128
# -0.976412949031292
# 7.365846772984789
# 504.24626225490204
# 0.013108950683370169
# 0.12000892542286562
# 0.8835231333463617
# 0.0019792842046489076
# 0.007693443013937347
# Calculating Statistical Features for Blue Channel:
# 0.3279754638671875
# 0.3958335013995083
# 0.30980392156862746
# 0.0491162559312977
# 0.22162187602151937
# 0.09326199299522034
# -1.4091061344440403
# 7.426417017041612
# 496.2194087009805
# 0.018376811869113722
# 0.13046549073173228
# 0.9222270436791973
# 0.0020112588990423208
# 0.007571071333741366
# Image number:  292
# Calculating Statistical features for Red Channel:
# 0.477368044385723
# 0.5276741841864189
# 0.5568627450980392
# 0.05055979485615303
# 0.22485505299226216
# -0.5530422046979494
# -1.0558063418928252
# 7.4531697836921955
# 449.22879901960783
# 0.017272606672606775
# 0.15321517052548242
# 0.9318379625966311
# 0.0022211781381243387
# 0.006854677282586
# Calculating Statistical Features for Green Channel:
# 0.46938500497855384
# 0.5094479112089085
# 0.5254901960784314
# 0.03921489133640282
# 0.19802750146482892
# -0.6535041480030764
# -0.7016150247279751
# 7.401138661988176
# 444.72921262254914
# 0.016778366145180235
# 0.15407695060492593
# 0.9130048115469466
# 0.0022435990633026233
# 0.0067860242173251855
# Calculating Statistical Features for Blue Channel:
# 0.37866881127450974
# 0.4517630480027373
# 0.4215686274509804
# 0.0606997829086732
# 0.24637325932144746
# -0.16303456624591983
# -1.5336603895117482
# 7.364213706141727
# 430.6692861519609
# 0.020323864490122457
# 0.1645068844241159
# 0.9455340732602586
# 0.0023166973336403327
# 0.006571490376445105
# Image number:  293
# Calculating Statistical features for Red Channel:
# 0.9051389806410847
# 0.9292008742120418
# 1.0
# 0.04413769036044124
# 0.2100897197876213
# -2.49587565324654
# 5.186251256308676
# 3.8797602671728804
# 413.958149509804
# 0.49156835578891794
# 0.5823387859961237
# 0.9281108786804826
# 0.002412739761106099
# 0.006316499703537612
# Calculating Statistical Features for Green Channel:
# 0.9334063960056681
# 0.9514659596121622
# 1.0
# 0.03403997219640293
# 0.18449924714318736
# -3.3712297148627486
# 10.501800448094679
# 3.6202076175729583
# 362.7301317401961
# 0.45997672838959214
# 0.604337901883725
# 0.9183456137908315
# 0.0027527722445778663
# 0.005534820269498943
# Calculating Statistical Features for Blue Channel:
# 0.8438783533432904
# 0.8904647171381559
# 1.0
# 0.08079673722655267
# 0.2842476688146319
# -1.7897950496442943
# 1.8130718839110775
# 4.371702912530152
# 457.28284313725493
# 0.47119913528078405
# 0.5553857741242103
# 0.9566016395788159
# 0.0021843044254149374
# 0.006977582069451147
# Image number:  294
# Calculating Statistical features for Red Channel:
# 0.49146261776194855
# 0.5181481690373356
# 0.5098039215686274
# 0.026942020419316193
# 0.16414024619000725
# -0.6587092352999095
# 0.5544601641771334
# 7.312964938624249
# 669.0186121323532
# 0.013351447133060338
# 0.11130464250719967
# 0.8095481139047578
# 0.0014925255944666634
# 0.010208395218837582
# Calculating Statistical Features for Green Channel:
# 0.5116381476907169
# 0.5337997181474187
# 0.5333333333333333
# 0.023168544921875776
# 0.152212170741619
# -0.9798821493343188
# 1.6347217772563498
# 7.14198333833476
# 673.9937806372546
# 0.014266190948612931
# 0.11110755599583375
# 0.7768874989707971
# 0.0014815264442807755
# 0.010284292032982995
# Calculating Statistical Features for Blue Channel:
# 0.483543186561734
# 0.5307611309477408
# 0.5372549019607843
# 0.04789336485464896
# 0.21884552738095644
# -0.457429481529166
# -0.7416980150779393
# 7.627500126864445
# 657.4265165441178
# 0.013078717215702546
# 0.11316764786855867
# 0.894660437114029
# 0.0015188025373548064
# 0.010031448626906532
# Image number:  295
# Calculating Statistical features for Red Channel:
# 0.5167803980195473
# 0.5388299145014434
# 0.551440329218107
# 0.023275696984391064
# 0.15256374728090244
# -0.40867468027339365
# -0.06840106418985004
# 7.142972466560392
# 48.10805759803922
# 0.024247969538840487
# 0.2380603714922453
# 0.9841436790511617
# 0.020373316732516883
# 0.0007335027831046915
# Calculating Statistical Features for Green Channel:
# 0.598840219003183
# 0.6173900260886763
# 0.6008230452674898
# 0.02256083641799633
# 0.15020265116833434
# -0.21869528083698087
# -0.08771391299697928
# 7.164005468200497
# 45.82308517156862
# 0.023529302060737924
# 0.24385095486741104
# 0.9844092428589141
# 0.021367724146535056
# 0.0006986489810904589
# Calculating Statistical Features for Blue Channel:
# 0.34814377772955246
# 0.4055680358438161
# 0.3497942386831276
# 0.04328134172640688
# 0.20804168266577464
# -0.12726804017779061
# -1.3857150125790014
# 7.239302050732412
# 42.9031556372549
# 0.02893472602320551
# 0.2543340771063617
# 0.9923903476773185
# 0.022792427517362535
# 0.0006540327239316136
# Image number:  296
# Calculating Statistical features for Red Channel:
# 0.5428500904756434
# 0.5773810221320946
# 0.5607843137254902
# 0.03868262398888825
# 0.1966789871564531
# -0.4789161085404088
# -0.41095698999278385
# 7.578197759456824
# 552.558226102941
# 0.011062128083878657
# 0.09658809355705963
# 0.8903209691253389
# 0.00180653079824183
# 0.008431238400066318
# Calculating Statistical Features for Green Channel:
# 0.5459937002144608
# 0.5735116760058581
# 0.5450980392156862
# 0.030806521841169825
# 0.1755178675838156
# -0.5317879355909032
# 0.12233720772745338
# 7.402645581214285
# 551.1009037990196
# 0.01199289072051632
# 0.09712973585490307
# 0.86261229421437
# 0.0018113024555316563
# 0.008409000819273971
# Calculating Statistical Features for Blue Channel:
# 0.5023157456341911
# 0.546725379619069
# 0.5254901960784314
# 0.046587532407581594
# 0.21584145201416152
# -0.38345217842826557
# -0.7291775907549023
# 7.673210072940212
# 551.0987132352942
# 0.01083792621509701
# 0.0973731982642472
# 0.9091696347333994
# 0.0018113058531491262
# 0.008408994606621952
# Image number:  297
# Calculating Statistical features for Red Channel:
# 0.4422993379480698
# 0.46034127756757093
# 0.4392156862745098
# 0.01628538748324247
# 0.12761421348440177
# 0.11832104556055117
# -0.32900117557004016
# 7.031835270944632
# 255.7535386029412
# 0.014347904372402737
# 0.10183847034423593
# 0.8793031145426107
# 0.0038950033194350745
# 0.0039023878427042625
# Calculating Statistical Features for Green Channel:
# 0.4457320867800245
# 0.4562327533600476
# 0.44313725490196076
# 0.009471232053214703
# 0.09732025510249499
# 0.044099362851022644
# 0.39458864981192665
# 6.670397250374106
# 255.51663602941173
# 0.016635324119307147
# 0.10198681422198906
# 0.792767420406301
# 0.003898635466862853
# 0.0038987154391855973
# Calculating Statistical Features for Blue Channel:
# 0.3813874487783394
# 0.40163215093868027
# 0.3686274509803922
# 0.01585199858198033
# 0.12590472025297675
# 0.08765989268716819
# -0.6584623141417199
# 6.994195154349424
# 254.32640931372546
# 0.014414722616873194
# 0.10230766198320451
# 0.8764623865572982
# 0.003916776419382631
# 0.0038805625877160145
# Image number:  298
# Calculating Statistical features for Red Channel:
# 0.3654957490808823
# 0.4370891348394998
# 0.3843137254901961
# 0.05745976919854709
# 0.23970767446735428
# -0.14702365803147074
# -1.2099088363167816
# 7.169648615434653
# 798.3077205882353
# 0.12073827112215954
# 0.1954128064462358
# 0.8928622151724604
# 0.0012512716324541
# 0.01218120707977407
# Calculating Statistical Features for Green Channel:
# 0.3760337679993873
# 0.437167338629178
# 0.43529411764705883
# 0.04971388728830138
# 0.22296611242137532
# -0.46184894106381025
# -0.9693729779382823
# 6.966397832040282
# 793.1979932598041
# 0.12047068654162317
# 0.19761544064652584
# 0.8768936634016369
# 0.0012593228892305523
# 0.01210323934647391
# Calculating Statistical Features for Blue Channel:
# 0.3621327718098958
# 0.43512406604903703
# 0.38823529411764707
# 0.05819280843632865
# 0.2412318561805813
# -0.14338645840630443
# -1.2129442816536278
# 7.147582986759695
# 797.3447303921571
# 0.12413337253643585
# 0.19661662619145223
# 0.8943485177590624
# 0.0012527865150733758
# 0.012166512402913882
# Image number:  299

# %%
#change the specific channels to csv data
import pandas as pd
#Convert red channel
red_file = pd.read_excel('RedChannel.xlsx')
red_file.to_csv('RedData.csv')

#Convert green channel
green_file = pd.read_excel('GreenChannel.xlsx')
green_file.to_csv('GreenData.csv')

#Convert blue channel
blue_file = pd.read_excel('BlueChannel.xlsx')
blue_file.to_csv('BlueData.csv')

# %%
#change the main file which contains features of all the three channels into csv
file = pd.read_excel('Output.xlsx')
file.to_csv('Output.csv')

# %% [markdown]
# # SVM

# %% [markdown]
# ## Apply SVM on Red Channel

# %%
# #read the data
# redData = pd.read_csv('RedData.csv')
# labelled = pd.read_csv('Labels1.csv')

# #classify data into dependent and indepedent variables
# redX = redData.iloc[:, :]
# redY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# redx_train, redx_test, redy_train, redy_test = train_test_split(redX, redY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# redSVC = SVC()

# #fit the model
# redSVC.fit(redx_train, redy_train)
# pred_r = redSVC.predict(redx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(redy_test, pred_r))

# %% [markdown]
# ## Apply SVM on Green Channel

# %%
# #read the data
# greenData = pd.read_csv('GreenData.csv')

# #classify data into dependent and indepedent variables
# greenX = greenData.iloc[:, :]
# greenY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# greenx_train, greenx_test, greeny_train, greeny_test = train_test_split(greenX, greenY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# greenSVC = SVC()

# #fit the model
# greenSVC.fit(greenx_train, greeny_train)
# pred_g = greenSVC.predict(greenx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for green Channel is ", accuracy_score(greeny_test, pred_g))

# %% [markdown]
# ## Apply SVM on Blue Channel

# %%
# #read the data
# blueData = pd.read_csv('BlueData.csv')

# #classify data into dependent and indepedent variables
# blueX = blueData.iloc[:, :]
# blueY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# bluex_train, bluex_test, bluey_train, bluey_test = train_test_split(blueX, blueY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.svm import SVC
# blueSVC = SVC()

# #fit the model
# blueSVC.fit(bluex_train, bluey_train)
# pred_b = blueSVC.predict(bluex_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(bluey_test, pred_b))

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Apply Random Forest on red channel

# %%
# #read the data
# RedData = pd.read_csv('RedData.csv')
# labelled = pd.read_csv('Labels1.csv')

# #classify data into dependent and indepedent variables
# RedX = RedData.iloc[:, :]
# RedY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Redx_train, Redx_test, Redy_train, Redy_test = train_test_split(RedX, RedY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# RedRF = RandomForestClassifier()

# #fit the model
# RedRF.fit(Redx_train, Redy_train)
# pred_R = RedRF.predict(Redx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(Redy_test, pred_R))

# %% [markdown]
# ## Apply Random Forest on green channel

# %%
# #read the data
# GreenData = pd.read_csv('GreenData.csv')

# #classify data into dependent and indepedent variables
# GreenX = GreenData.iloc[:, :]
# GreenY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Greenx_train, Greenx_test, Greeny_train, Greeny_test = train_test_split(GreenX, GreenY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# GreenRF = RandomForestClassifier()

# #fit the model
# GreenRF.fit(Greenx_train, Greeny_train)
# pred_G = GreenRF.predict(Greenx_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for green Channel is ", accuracy_score(Greeny_test, pred_G))

# %% [markdown]
# ## Apply Random Forest on blue channel

# %%
# #read the data
# BlueData = pd.read_csv('BlueData.csv')

# #classify data into dependent and indepedent variables
# BlueX = BlueData.iloc[:, :]
# BlueY = labelled.iloc[:, :]

# #classify the data into training and testing
# from sklearn.model_selection import train_test_split
# Bluex_train, Bluex_test, Bluey_train, Bluey_test = train_test_split(BlueX, BlueY, test_size = 0.2, random_state = 0)

# #now predict using svm classifier
# from sklearn.ensemble import RandomForestClassifier
# BlueRF = RandomForestClassifier()

# #fit the model
# BlueRF.fit(Bluex_train, Bluey_train)
# pred_B = BlueRF.predict(Bluex_test)

# #lets now find the accuracy
# from sklearn.metrics import accuracy_score
# print("The accuracy for red Channel is ", accuracy_score(Bluey_test, pred_B))
